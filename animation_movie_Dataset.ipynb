# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/animation_movie_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []
images = []
number = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(1,8100,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=animation&start=&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)

            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)

            try:
              image = store.find('img')
              imge = image['loadlate']
              images.append(imge)  
            except:
                images.append(None)

            numbers = store.find('img')
            num = numbers['data-tconst'][:]
            try:
              number.append(num)
            except:
             number.append(None)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601, 651, 701, 751, 801, 851, 901, 951, 1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151, 2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701, 2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251, 3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801, 3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351, 4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901, 4951, 5001, 5051, 5101, 5151, 5201, 5251, 5301, 5351, 5401, 5451, 5501, 5551, 5601, 5651, 5701, 5751, 5801, 5851, 5901, 5951, 6001, 6051, 6101, 6151, 6201, 6251, 6301, 6351, 6401, 6451, 6501, 6551, 6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101, 7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651, 7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051]

# %%
a = { "Movie Name": movie_name, "IMDB ID":number, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts, "IMDB Image":images}

# %%
a
# Out:
# {'Movie Name': ['DC League of Super-Pets',
#   'Strange World',
#   'Sing 2',
#   'Minions: The Rise of Gru',
#   'Lightyear',
#   'Jujutsu Kaisen 0: The Movie',
#   'Dragon Ball Super: Super Hero',
#   'Disenchanted',
#   'Drifting Home',
#   "Guillermo del Toro's Pinocchio",
#   'Encanto',
#   'Pinocchio',
#   'Luck',
#   'Lyle, Lyle, Crocodile',
#   'The Bad Guys',
#   'The Little Mermaid',
#   'Spider-Man: Into the Spider-Verse',
#   'Cars',
#   'The Lion King',
#   'The Lion King',
#   'The Nightmare Before Christmas',
#   'Spirited Away',
#   'Ratatouille',
#   'The Sea Beast',
#   'Coco',
#   'Enchanted',
#   'Untitled Super Mario Project',
#   'Moana',
#   'Coraline',
#   'The House',
#   'Turning Red',
#   "Chip 'n Dale: Rescue Rangers",
#   'Sing',
#   'Inside Out',
#   'Toy Story',
#   'The Incredibles',
#   'Zootopia',
#   "Howl's Moving Castle",
#   'Shrek',
#   'Your Name.',
#   'Frozen',
#   'Marcel the Shell with Shoes On',
#   'Sausage Party',
#   'Paws of Fury: The Legend of Hank',
#   'WALL·E',
#   'Grave of the Fireflies',
#   'Despicable Me',
#   'Mad God',
#   'Finding Nemo',
#   'Tangled',
#   'Incredibles 2',
#   'Hercules',
#   'Monsters, Inc.',
#   "A Bug's Life",
#   'Minions',
#   'Up',
#   'Soul',
#   'Aladdin',
#   'Mufasa: The Lion King',
#   'Luca',
#   'One Piece Film: Red',
#   'Elemental',
#   'The Iron Giant',
#   'Raya and the Last Dragon',
#   'Corpse Bride',
#   'How to Train Your Dragon',
#   'Spider-Man: Across the Spider-Verse',
#   'The Princess and the Frog',
#   'Toy Story 4',
#   'Puss in Boots: The Last Wish',
#   'Kung Fu Panda',
#   'Atlantis: The Lost Empire',
#   'Beauty and the Beast',
#   'Madagascar',
#   'Who Framed Roger Rabbit',
#   'Toy Story 3',
#   'Princess Mononoke',
#   'Ice Age',
#   'Mulan',
#   "The Emperor's New Groove",
#   'Fantastic Mr. Fox',
#   'Wendell & Wild',
#   'Robots',
#   'The Prince of Egypt',
#   'Big Hero 6',
#   'Shrek 2',
#   'The Lord of the Rings',
#   'Monster House',
#   'Brave',
#   'Cars 3',
#   'Cars 2',
#   'Hotel Transylvania: Transformania',
#   'Despicable Me 2',
#   'Hotel Transylvania',
#   'Perfect Blue',
#   'Treasure Planet',
#   'The Addams Family',
#   'Akira',
#   'Frozen II',
#   'The Adventures of Tintin',
#   'Rango',
#   'Belle',
#   'Anastasia',
#   'Lilo & Stitch',
#   'My Neighbor Totoro',
#   'Tarzan',
#   'Tad the Lost Explorer and the Emerald Tablet',
#   'Robin Hood',
#   "The Bob's Burgers Movie",
#   'The Book of Life',
#   'The Mitchells vs the Machines',
#   'Pocahontas',
#   'Wreck-It Ralph',
#   'The Hunchback of Notre Dame',
#   'Toy Story 2',
#   'Spies in Disguise',
#   'Snow White and the Seven Dwarfs',
#   'Megamind',
#   'The Lego Movie',
#   'The Jungle Book',
#   'Despicable Me 3',
#   'Beowulf',
#   'Monsters University',
#   'Finding Dory',
#   'Cloudy with a Chance of Meatballs',
#   'Mary Poppins Returns',
#   'Ralph Breaks the Internet',
#   'Demon Slayer the Movie: Mugen Train',
#   'Diary of a Wimpy Kid',
#   'The Secret Life of Pets',
#   'James and the Giant Peach',
#   '9',
#   'Ghost in the Shell',
#   'The Emoji Movie',
#   'Tom and Jerry',
#   'Onward',
#   'Cinderella',
#   'Fritz the Cat',
#   'The Road to El Dorado',
#   'Space Jam: A New Legacy',
#   'Ferdinand',
#   'Alvin and the Chipmunks',
#   'A Silent Voice: The Movie',
#   'Peter Pan',
#   'Sonic the Hedgehog 3',
#   'Fantasia',
#   'Meet the Robinsons',
#   'Heavy Metal',
#   'Alice in Wonderland',
#   'Vivo',
#   'Bee Movie',
#   'How to Train Your Dragon: The Hidden World',
#   'The Addams Family 2',
#   'Clifford the Big Red Dog',
#   'Pinocchio: A True Story',
#   "The Queen's Corgi",
#   'Ice Age: Collision Course',
#   'FernGully: The Last Rainforest',
#   'The Croods: A New Age',
#   'Wish',
#   'Isle of Dogs',
#   'Rio',
#   'The Lego Batman Movie',
#   'The AristoCats',
#   'Shark Tale',
#   'A Goofy Movie',
#   'Happy Feet',
#   'Kung Fu Panda 3',
#   'Sleeping Beauty',
#   'Chicken Run',
#   'The Lord of the Rings: The War of the Rohirrim',
#   'Ponyo',
#   'Space Jam',
#   'Bolt',
#   'Rumble',
#   'PAW Patrol: The Movie',
#   'Rise of the Teenage Mutant Ninja Turtles: The Movie',
#   "Kiki's Delivery Service",
#   'Home',
#   'The Polar Express',
#   'Shrek the Third',
#   'Trolls',
#   'How to Train Your Dragon 2',
#   'The Boss Baby',
#   'Chicken Little',
#   "We're Back! A Dinosaur's Story",
#   'One Hundred and One Dalmatians',
#   'Klaus',
#   'The Croods',
#   'The Secret Life of Pets 2',
#   'Hotel Transylvania 3: Summer Vacation',
#   'Kung Fu Panda 2',
#   'Frankenweenie',
#   "Ron's Gone Wrong",
#   'Monsters vs. Aliens',
#   'Brother Bear',
#   'Dinosaur',
#   'Neon Genesis Evangelion: The End of Evangelion',
#   'Dragon Ball Super: Broly',
#   'Trolls World Tour',
#   'The Lorax',
#   'The Boss Baby: Family Business',
#   'The Witcher: Nightmare of the Wolf',
#   'Inside Out 2',
#   'Weathering with You',
#   'Fire and Ice',
#   'Flushed Away',
#   'Paprika',
#   'Redline',
#   'The SpongeBob SquarePants Movie',
#   'Beavis and Butt-Head Do the Universe',
#   'Cool World',
#   'Ice Age: Dawn of the Dinosaurs',
#   'The Good Dinosaur',
#   'Antz',
#   'Scoob!',
#   'Epic',
#   'Lady and the Tramp',
#   'The Black Cauldron',
#   'Wizards',
#   'The Wind Rises',
#   'A Scanner Darkly',
#   'Over the Hedge',
#   'Monkeybone',
#   'The Land Before Time',
#   'The Sword in the Stone',
#   'Oliver & Company',
#   'Teenage Mutant Ninja Turtles: Mutant Mayhem',
#   'Castle in the Sky',
#   'The Grinch',
#   'Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc',
#   'The SpongeBob Movie: Sponge on the Run',
#   'The Simpsons Movie',
#   'Shrek Forever After',
#   'Persepolis',
#   'Rise of the Guardians',
#   'Back to the Outback',
#   'ParaNorman',
#   'The Fox and the Hound',
#   'Hotel Transylvania 2',
#   'Horton Hears a Who!',
#   'All Dogs Go to Heaven',
#   "Hey Good Lookin'",
#   'Spirit: Stallion of the Cimarron',
#   'Madagascar: Escape 2 Africa',
#   "Surf's Up",
#   'The Ice Age Adventures of Buck Wild',
#   'I Want to Eat Your Pancreas',
#   'Nausicaä of the Valley of the Wind',
#   'Angry Birds',
#   'Waking Life',
#   'The Rescuers',
#   'Cloudy with a Chance of Meatballs 2',
#   'Open Season',
#   'Mary and Max',
#   'The Secret World of Arrietty',
#   'The Smurfs',
#   'Paddington 3',
#   'The Rescuers Down Under',
#   'Garfield',
#   'Wish Dragon',
#   'Planes',
#   'Batman: Mask of the Phantasm',
#   'Turbo',
#   'Garfield',
#   'Bedknobs and Broomsticks',
#   'Bambi',
#   'The Lego Movie 2: The Second Part',
#   'Ace',
#   'Kubo and the Two Strings',
#   'Ice Age: Continental Drift',
#   'Fireheart',
#   'Winnie the Pooh',
#   'Wolfwalkers',
#   'Apollo 10½: A Space Age Childhood',
#   'Batman: The Long Halloween, Part One',
#   'The Pagemaster',
#   "Madagascar 3: Europe's Most Wanted",
#   'My Little Pony: A New Generation',
#   'Evangelion: 3.0+1.01 Thrice Upon a Time',
#   'Chicken Run: Dawn of the Nugget',
#   'Penguins of Madagascar',
#   'The Secret of NIMH',
#   'Injustice',
#   'Suzume no tojimari',
#   'Batman: The Killing Joke',
#   'Looney Tunes: Back in Action',
#   'The Last Unicorn',
#   'Spellbound',
#   'Captain Underpants: The First Epic Movie',
#   'Rio 2',
#   'South Park: Bigger, Longer & Uncut',
#   "Pete's Dragon",
#   'Puss in Boots',
#   'An American Tail',
#   'Batman: The Long Halloween',
#   'Bubble',
#   'The Angry Birds Movie 2',
#   'Titan A.E.',
#   'Whisper of the Heart',
#   'Dumbo',
#   'A Christmas Carol',
#   'Loving Vincent',
#   'Watership Down',
#   'Wallace & Gromit: The Curse of the Were-Rabbit',
#   'The Great Mouse Detective',
#   'Barnyard',
#   'Abominable',
#   'Anomalisa',
#   'Hoodwinked!',
#   'Arthur and the Invisibles',
#   'Elio',
#   'Song of the South',
#   'Fantastic Planet',
#   'America: The Motion Picture',
#   'Ice Age: The Meltdown',
#   'Catwoman: Hunted',
#   'Gnomeo & Juliet',
#   "My Hero Academia: World Heroes' Mission",
#   'The Pirates! Band of Misfits',
#   'Smurfs: The Lost Village',
#   'Balto',
#   'Osmosis Jones',
#   'Mr. Peabody & Sherman',
#   'Diary of a Wimpy Kid: Rodrick Rules',
#   '5 Centimeters per Second',
#   'My Little Pony: The Movie',
#   'Thumbelina',
#   'The Lego Ninjago Movie',
#   'TMNT',
#   'The Garden of Words',
#   'When Marnie Was There',
#   'The Brave Little Toaster',
#   'Jimmy Neutron: Boy Genius',
#   'Sinbad: Legend of the Seven Seas',
#   'Spirit Untamed',
#   'Night at the Museum: Kahmunrah Rises Again',
#   'Leap!',
#   'Bigfoot Family',
#   'The Little Prince',
#   'The Cat Returns',
#   'The Tale of The Princess Kaguya',
#   'The Amazing Maurice',
#   'The SpongeBob Movie: Sponge Out of Water',
#   'Over the Moon',
#   'Coonskin',
#   'Porco Rosso',
#   'Midori',
#   'The Willoughbys',
#   'Curious George',
#   'Green Lantern: Beware My Power',
#   'Alvin and the Chipmunks: The Road Chip',
#   "Legend of the Guardians: The Owls of Ga'Hoole",
#   'Quest for Camelot',
#   'Tales from Earthsea',
#   'Blaze',
#   'Ninja Scroll',
#   'Storks',
#   'White Snake',
#   'Untitled Adventures of Tintin Sequel',
#   'Planet 51',
#   'Alvin and the Chipmunks: The Squeakquel',
#   'The Many Adventures of Winnie the Pooh',
#   'Song of the Sea',
#   'From Up on Poppy Hill',
#   'Alvin and the Chipmunks: Chipwrecked',
#   'The Swan Princess',
#   'Evil Toons',
#   'Inu-oh',
#   'The Little Mermaid',
#   'Happy Feet Two',
#   'UglyDolls',
#   'Stuart Little 2',
#   'Strange Magic',
#   'Vampire Hunter D: Bloodlust',
#   'The Boxtrolls',
#   'Star Wars: The Clone Wars',
#   'Ladybug & Cat Noir: Awakening',
#   'Despicable Me 4',
#   'Batman: The Long Halloween, Part Two',
#   'Beavis and Butt-Head Do America',
#   'Tarzan',
#   'Marmaduke',
#   'Kung Fu Panda 4',
#   'Only Yesterday',
#   'Garfield: A Tail of Two Kitties',
#   "Charlotte's Web",
#   'Fixed',
#   'Where Is Anne Frank',
#   'Wicked City',
#   'The Ant Bully',
#   'Trouble',
#   'Primal: Tales of Savagery',
#   'Josee, the Tiger and the Fish',
#   'Cowboy Bebop: The Movie',
#   'Trollhunters: Rise of the Titans',
#   'Little Nemo: Adventures in Slumberland',
#   'Chickenhare and the Hamster of Darkness',
#   'The Transformers: The Movie',
#   'Constantine: City of Demons - The Movie',
#   'Home on the Range',
#   'The Smurfs 2',
#   'The Peanuts Movie',
#   'Teen Titans GO! To the Movies',
#   'The Thief and the Cobbler',
#   'G-Force',
#   'Star Wars: A Droid Story',
#   'A Whisker Away',
#   'Seal Team',
#   'Heavy Metal 2000',
#   'Fantasia 2000',
#   'Spider-Man: Beyond the Spider-Verse',
#   'Wolf Children',
#   'Tad: The Lost Explorer',
#   'Violet Evergarden: The Movie',
#   'One Piece Film Z',
#   'Promare',
#   'Memories',
#   'One Piece: Stampede',
#   'Gantz: O',
#   'Sherlock Gnomes',
#   'The Breadwinner',
#   'Red Shoes and the Seven Dwarfs',
#   'Xiong chu mo: Chong fan di qiu',
#   'Pengin haiwei',
#   'The Last: Naruto the Movie',
#   'Wildwood',
#   'The Wild',
#   "Pil's Adventures",
#   'Final Fantasy: The Spirits Within',
#   'Around the World in 80 Days',
#   'Scrooge: A Christmas Carol',
#   'Goodbye, Don Glees!',
#   'Animal Crackers',
#   'The Secret of Kells',
#   'The Adventures of Ichabod and Mr. Toad',
#   'Charming',
#   'Yogi Bear',
#   'An American Tail: Fievel Goes West',
#   'Rock-A-Doodle',
#   'Batman Ninja',
#   'The Summit of the Gods',
#   'Untitled Shrek Reboot',
#   'Extinct',
#   'Hop',
#   'Hoodwinked Too! Hood vs. Evil',
#   'Smallfoot',
#   'The Adventures of Rocky & Bullwinkle',
#   'I Lost My Body',
#   'Igor',
#   'The Canterville Ghost',
#   'Missing Link',
#   'The Girl Who Leapt Through Time',
#   'Tom and Jerry: The Movie',
#   'Astro Boy',
#   'Valiant',
#   'Planes: Fire & Rescue',
#   "Mobile Suit Gundam: Cucuruz Doan's Island",
#   'Belladonna of Sadness',
#   'Yellow Submarine',
#   'Pokémon: The First Movie - Mewtwo Strikes Back',
#   "Dragon's Lair: The Movie",
#   'Alice',
#   'Next Gen',
#   'The Spine of Night',
#   'Tokyo Godfathers',
#   'Pom Poko',
#   'Mutafukaz',
#   "Everyone's Hero",
#   "My Father's Dragon",
#   'Flash Gordon',
#   'The Tale of Despereaux',
#   '100% Wolf',
#   'Once Upon a Forest',
#   'Peter Pan 2: Return to Never Land',
#   'Pokémon the Movie: I Choose You!',
#   'Foodfight!',
#   'When the Wind Blows',
#   'Boruto: Naruto The Movie',
#   'Alpha and Omega',
#   'Shaun the Sheep Movie',
#   'Under the Boardwalk',
#   'Coyote v. Acme',
#   'The Nut Job',
#   'Eight Crazy Nights',
#   'The Triplets of Belleville',
#   "It's Such a Beautiful Day",
#   'Metropolis',
#   'Riverdance: The Animated Adventure',
#   'Free Birds',
#   'Steven Universe: The Movie',
#   'Berserk: The Golden Age Arc I - The Egg of the King',
#   'Heavy Traffic',
#   'Escape from Planet Earth',
#   'A Christmas Carol',
#   'The Jungle Book 2',
#   'Scoob!: Holiday Haunt',
#   'Mars Needs Moms',
#   'Summer Wars',
#   'Monster Family 2',
#   'Batman: Gotham by Gaslight',
#   'Mortal Kombat Legends: Battle of the Realms',
#   "Mortal Kombat Legends: Scorpion's Revenge",
#   'One Piece Film: Gold',
#   'Secret Magic Control Agency',
#   'Dragon Ball Z: Battle of Gods',
#   'The Congress',
#   'Middle School: The Worst Years of My Life',
#   'Secret of the Wings',
#   'Strays',
#   'The Rugrats Movie',
#   'Naya Legend of the Golden Dolphin',
#   'Final Fantasy VII: Advent Children',
#   'Berserk: The Golden Age Arc III - The Advent',
#   'My Life as a Zucchini',
#   'Rock Dog',
#   'Sailor Moon Eternal',
#   'Rugrats in Paris',
#   'Arthur Christmas',
#   'Tout le monde aime Jeanne',
#   'The Ark and the Aardvark',
#   'Aqua Teen Forever: Plantasm',
#   'Evangelion: 1.0 You Are (Not) Alone',
#   'The Boy and the Beast',
#   'Batman and Harley Quinn',
#   'The Wolf House',
#   'Pets United',
#   'Millennium Actress',
#   'Animal Farm',
#   "The Tiger's Apprentice",
#   'Gnome Alone',
#   'Pinocchio',
#   'Early Man',
#   'Gandahar',
#   'Starship Troopers: Traitor of Mars',
#   'The Wild Thornberrys',
#   'Mirai',
#   'Resident Evil: Vendetta',
#   'Monster Family',
#   'My Sweet Monster',
#   'Harold and the Purple Crayon',
#   'Demon Slayer: Kimetsu no Yaiba - Mt. Natagumo Arc',
#   'Dragon Ball Z: Broly - The Legendary Super Saiyan',
#   "Mary and the Witch's Flower",
#   'Justice Society: World War II',
#   'A Troll in Central Park',
#   'The Red Turtle',
#   'Batman: Soul of the Dragon',
#   'Thunderbirds Are GO',
#   'American Pop',
#   'Extraordinary Tales',
#   'Ride Your Wave',
#   'Son of Bigfoot',
#   'Charlotte',
#   "Treasure Island Part II: Captain Flint's Treasure",
#   'Made in Abyss: Dawn of the Deep Soul',
#   'Wan pisu firumu: sutorongu warudo',
#   "Pooh's Heffalump Movie",
#   'Maquia: When the Promised Flower Blooms',
#   'A Shaun the Sheep Movie: Farmageddon',
#   'A Fish Tale',
#   'Vampire Hunter D',
#   'PAW Patrol: The Mighty Movie',
#   'Kingsglaive: Final Fantasy XV',
#   'Lupin III: The First',
#   'Lupin III: The Castle of Cagliostro',
#   'Jin-Roh: The Wolf Brigade',
#   'Phineas and Ferb the Movie: Candace Against the Universe',
#   'Sword Art Online: Progressive - Aria of a Starless Night',
#   'Who Framed Roger Rabbit 2',
#   'Sword of the Stranger',
#   'My Hero Academia: Two Heroes',
#   'Nimona',
#   'Tad, the Lost Explorer, and the Secret of King Midas',
#   'Dragon Rider',
#   'Mobile Suit Gundam: Hathaway',
#   'Pinocchio and the Emperor of the Night',
#   'Ghost in the Shell 2: Innocence',
#   "Cats Don't Dance",
#   'Jungle Beat: The Movie',
#   "Blue's Big City Adventure",
#   'Wonder Park',
#   "Recess: School's Out",
#   'Altered Carbon: Resleeved',
#   'A Monster in Paris',
#   'How Do You Live?',
#   'Starship Troopers: Invasion',
#   'Arthur 3: The War of the Two Worlds',
#   'Transformers: A New Generation',
#   'My Hero Academia: Heroes Rising',
#   'Teen Titans Go! & DC Super Hero Girls: Mayhem in the Multiverse',
#   'The Deer King',
#   'Walking with Dinosaurs 3D',
#   'The Chipmunk Adventure',
#   'Rascal Does Not Dream of a Dreaming Girl',
#   'Cats',
#   "Bebe's Kids",
#   'Evangelion: 2.0 You Can (Not) Advance',
#   'Kuso',
#   'Road to Ninja - Naruto the Movie',
#   'Mind Game',
#   'Mars',
#   'DuckTales the Movie: Treasure of the Lost Lamp',
#   'The Illusionist',
#   'Fruits Basket: Prelude',
#   'Happily Ever After',
#   'Pokémon the Movie 2000',
#   "Legends of Oz: Dorothy's Return",
#   'The Princess and the Goblin',
#   'Urotsukidoji: Legend of the Overfiend',
#   'Hell and Back',
#   'Pokémon: Mewtwo Strikes Back - Evolution',
#   'Trolls 3',
#   'Ernest & Celestine',
#   'The Nut Job 2: Nutty by Nature',
#   'Ratchet & Clank',
#   'Woody Woodpecker',
#   'The Place Promised in Our Early Days',
#   'Words Bubble Up Like Soda Pop',
#   'The Tigger Movie',
#   'Dragon Ball Z: Resurrection "F"',
#   'Ronal the Barbarian',
#   'The Nine Lives of Fritz the Cat',
#   'The Three Caballeros',
#   'One Piece: The Movie',
#   'The Loud House Movie',
#   'Seoul Station',
#   "Kensuke's Kingdom",
#   'Moonbound',
#   'Yu-Gi-Oh!: The Movie - Pyramid of Light',
#   'NiNoKuni',
#   'The Plague Dogs',
#   'The SpongeBob SquarePants Movie Rehydrated',
#   'Evangelion: 3.0 You Can (Not) Redo',
#   'Street Fighter II: The Animated Movie',
#   'Junk Head',
#   'Code Geass: Lelouch of the Re;Surrection',
#   'The Little Vampire 3D',
#   'The BFG',
#   'Asterix and Obelix: Mansion of the Gods',
#   'Tarzoon: Shame of the Jungle',
#   'Abruptio',
#   'Arctic Dogs',
#   'Cryptozoo',
#   'Blame!',
#   'Children of the Sea',
#   'The Amazing World of Gumball: The Movie',
#   'Berserk: The Golden Age Arc II - The Battle for Doldrey',
#   'Children Who Chase Lost Voices',
#   'Doogal',
#   "A Turtle's Tale: Sammy's Adventures",
#   'Pokémon the Movie: Secrets of the Jungle',
#   'The Care Bears Movie',
#   'Reign of the Supermen',
#   'Fun and Fancy Free',
#   'The Wild Life',
#   'All Dogs Go to Heaven 2',
#   'Rugrats Go Wild',
#   'Nicktoons',
#   'Where the Dead Go to Die',
#   'To the Forest of Firefly Lights',
#   'Double Dutchess: Seeing Double',
#   'The Reef',
#   'Playmobil: The Movie',
#   'CJ7',
#   'Ainbo',
#   'Steamboy',
#   'Winx Club: The Secret of the Lost Kingdom',
#   'Open Season 3',
#   'Asterix: The Secret of the Magic Potion',
#   'The Ogglies',
#   'Mad Monster Party?',
#   'Night of the Animated Dead',
#   'Unicorn Wars',
#   'Koati',
#   'The Powerpuff Girls Movie',
#   'Wonder Woman: Bloodlines',
#   'The Nutcracker and the Magic Flute',
#   'The Incredible Mr. Limpet',
#   'Pokémon: Arceus and the Jewel of Life',
#   'Mune: Guardian of the Moon',
#   'All Creatures Big And Small',
#   'The Monkey King',
#   'The Quintessential Quintuplets Movie',
#   "Demon Slayer: Kimetsu no Yaiba - Sibling's Bond",
#   'White Snake 2: Green Snake',
#   'Space Chimps',
#   'Capture the Flag',
#   'The Adventures of Mark Twain',
#   'Black Knight',
#   'Rock & Rule',
#   'Ramayana: The Legend of Prince Rama',
#   'Neon Genesis Evangelion: Death & Rebirth',
#   'Violet Evergarden: Eternity and the Auto Memory Doll',
#   "Happily N'Ever After",
#   'Ghost in the Shell 2.0',
#   'Spriggan',
#   'Care Bears Movie II: A New Generation',
#   'Ella Bella Bingo',
#   'The Pebble and the Penguin',
#   'Arthur et la vengeance de Maltazard',
#   'Digimon: The Movie',
#   'Dreambuilders',
#   'Pompo: The Cinéphile',
#   'Hunter X Hunter: Phantom Rouge',
#   'The Night Is Short, Walk on Girl',
#   'The Point',
#   'Regular Show: The Movie',
#   'Minions & More 1',
#   'Felidae',
#   'Justice League vs the Fatal Five',
#   'Titanic: The Legend Goes On...',
#   "Fate/stay night [Heaven's Feel] I. presage flower",
#   'Tekkonkinkreet',
#   'Hitpig',
#   'Sahara',
#   'A Thousand & One Nights',
#   'Dragon Ball Z: Revival Fusion',
#   'Finding Jesus',
#   'Sprung! The Magic Roundabout',
#   "Kenji Miyazawa's Night on the Galactic Railroad",
#   'Aqua Teen Hunger Force Colon Movie Film for Theaters',
#   'Attack on Titan: Chronicle',
#   "Dragon Ball Z: Cooler's Revenge",
#   'Batman: Return of the Caped Crusaders',
#   'Yu-Gi-Oh!: The Dark Side of Dimensions',
#   'Resident Evil: Damnation',
#   'Cleopatra',
#   'Khumba',
#   'Gulliver Returns',
#   'The Pinchcliffe Grand Prix',
#   'Neo Tokyo',
#   'The Phantom Tollbooth',
#   "Fate/stay night [Heaven's Feel] II. lost butterfly",
#   'Cats & Dogs: The Revenge of Kitty Galore',
#   'Colorful',
#   'Raggedy Ann & Andy: A Musical Adventure',
#   'Checkered Ninja',
#   'Tekken: Blood Vengeance',
#   'The Wonderful World of the Brothers Grimm',
#   'Sword Art Online the Movie: Ordinal Scale',
#   'Ne Zha',
#   'Jack and the Cuckoo-Clock Heart',
#   "The Magician's Elephant",
#   'White Fang',
#   'Norm of the North',
#   'The Star',
#   'Groove Tails',
#   'Thunderbird 6',
#   'April and the Extraordinary World',
#   'The Silk Road Rally',
#   'Heart of Darkness',
#   'The Trouble with Terkel',
#   'Birdboy: The Forgotten Children',
#   'Pokémon 3 the Movie: Spell of the Unown',
#   'Happy Halloween, Scooby-Doo!',
#   'The King and I',
#   'The Hero of Color City',
#   'One Piece: Baron Omatsuri and the Secret Island',
#   'In This Corner (and Other Corners) of the World',
#   'Harlock: Space Pirate',
#   'Digimon Adventure: Last Evolution Kizuna',
#   'Big Fish & Begonia',
#   'Animalympics',
#   'Gintama: The Final',
#   'Dragon Hunters',
#   'The Monster of Highgate Ponds',
#   'Melody Time',
#   'Pippi Longstocking',
#   'Dofus: Book 1 - Julith',
#   'Make Mine Music',
#   'The Inventor',
#   'My Neighbors the Yamadas',
#   'Nezha Reborn',
#   "Dragon Ball Z: The World's Strongest",
#   'Scooby-Doo Meets Batman',
#   'Flanimals',
#   'Demon Slayer: Kimetsu no Yaiba - Asakusa Arc',
#   'Naruto Shippûden: The Movie',
#   'Foxy Trotter',
#   'The Lego Batman Movie 2',
#   'Watch the Skies',
#   'Mia and Me: The Hero of Centopia',
#   'My Little Pony: The Movie',
#   'Animal Farm',
#   'Untitled Ghostbuster/Jason Reitman Project',
#   'Resident Evil: Degeneration',
#   'Jetsons: The Movie',
#   'Monkey King: Hero Is Back',
#   'Battle for Terra',
#   'A Cat in Paris',
#   'Mouse Guard',
#   "Pilgrim's Progress",
#   'Fearless',
#   'Strings',
#   'Child of Kamiari Month',
#   'Dragon Ball: Curse of the Blood Rubies',
#   'B.O.O.: Bureau of Otherworldly Operations',
#   'Demon Slayer: Kimetsu no Yaiba - The Hashira Meeting Arc',
#   'Hey Arnold! The Movie',
#   "Gulliver's Travels",
#   'Migration',
#   'Deathstroke: Knights & Dragons - The Movie',
#   'Naruto the Movie: Ninja Clash in the Land of Snow',
#   'Dragon Quest: Your Story',
#   'Otesánek',
#   'Pokemon 4Ever: Celebi - Voice of the Forest',
#   'Knor',
#   'The Stranger by the Beach',
#   "Clifford's Really Big Movie",
#   'Dragon Ball Z: Wrath of the Dragon',
#   'The Reluctant Dragon',
#   'Patema Inverted',
#   'Bright: Samurai Soul',
#   'The Stolen Princess',
#   'The Adventures of Drunky',
#   "JoJo's Bizarre Adventure: Phantom Blood",
#   'Blood: The Last Vampire',
#   'Adventures in Zambezia',
#   "Konosuba!: God's Blessing on This Wonderful World! - Legend of Crimson",
#   'Jonah: A VeggieTales Movie',
#   'The Drawn Together Movie: The Movie!',
#   "Kahlil Gibran's The Prophet",
#   'Arjun: The Warrior Prince',
#   'Dead Leaves',
#   'Space Adventure Cobra',
#   'Boom and Topper: Safari Hunters',
#   "Jay and Silent Bob's Super Groovy Cartoon Movie",
#   "Piglet's Big Movie",
#   'Naruto Shippuden: The Movie - Bonds',
#   'Kirikou and the Sorceress',
#   'Poupelle of Chimney Town',
#   'Conference of Animals',
#   'Metropia',
#   'Return to Zootopia',
#   'Interstella 5555: The 5tory of the 5ecret 5tar 5ystem',
#   'Postman Pat: The Movie',
#   'Delgo',
#   'Appleseed Alpha',
#   'LEGO DC: Shazam - Magic & Monsters',
#   'Bleach the Movie: Hell Verse',
#   'Valhalla',
#   'Thelma the Unicorn',
#   'Dragon Ball Z: Tree of Might',
#   'Dogtanian and the Three Muskehounds',
#   'Son of the White Mare',
#   'Realm of Terracotta',
#   'Un rescate de huevitos',
#   'Godzilla: Planet of the Monsters',
#   'Buñuel in the Labyrinth of the Turtles',
#   "Barbie in Rock 'N Royals",
#   'Magnetic Rose',
#   'My Love Affair with Marriage',
#   'Banking on Mr. Toad',
#   'The Legend of Hei',
#   'Habfürdö',
#   'Steins;Gate: The Movie - Load Region of Déjà Vu',
#   "Fate/stay night [Heaven's Feel] III. spring song",
#   'Dragon Ball Z: Bojack Unbound',
#   'Winx Club: The Mystery of the Abyss',
#   'Cats & Dogs 3: Paws Unite',
#   'Encanto Sing-Along',
#   'Werner - Beinhart!',
#   'Chico & Rita',
#   'Duck Duck Goose',
#   'Checkered Ninja 2',
#   'Fullmetal Alchemist: The Sacred Star of Milos',
#   'Kizumonogatari Part 1: Tekketsu',
#   'So Dear to My Heart',
#   'Made in Abyss: Wandering Twilight',
#   'Minuscule: Valley of the Lost Ants',
#   'Cat City',
#   'Rock Dog 2: Rock Around the Park',
#   'Hair High',
#   'Sinbad: Beyond the Veil of Mists',
#   "Monkey King: A Hero's Journey to the West",
#   'Hello World',
#   'Heavenly Sword',
#   "Made in Abyss: Journey's Dawn",
#   'Dirty Duck',
#   'Barefoot Gen',
#   "Azur & Asmar: The Princes' Quest",
#   'The Masters of Time',
#   'Unplugged',
#   'The Nutcracker Prince',
#   "A Winter's Journey",
#   'Sing a Bit of Harmony',
#   'Panda vs. Aliens',
#   'Finding Jesus 2',
#   'Justin and the Knights of Valour',
#   'Ruben Brandt, Collector',
#   'The Big Trip',
#   'LEGO DC Batman: Family Matters',
#   'Terra Willy',
#   'Underdogs',
#   'Ghost in the Shell: SAC_2045 - Sustainable War',
#   'The Brillant World of Tom Gates',
#   'Natsu e no tunnel, Sayonara no deguchi',
#   'The Cat in the Hat',
#   'The Water Babies',
#   'Free Jimmy',
#   'Starchaser: The Legend of Orin',
#   'Heroes of the Golden Masks',
#   'The Land of Sometimes',
#   'Asterix in America',
#   'The Garden of Sinners: Overlooking View',
#   'Fullmetal Alchemist the Movie: Conqueror of Shamballa',
#   'Ozi - Voice of the Forest',
#   'My Dream Is Yours',
#   'Bilal: A New Breed of Hero',
#   'Given',
#   'To Your Last Death',
#   'Paw Patrol: Jet to the Rescue',
#   'Luis and the Aliens',
#   'Peter Pan, Land of Forever',
#   'Renaissance',
#   "Five Nights at Freddy's 4",
#   'One Piece: Clockwork Island Adventure',
#   'Dragon Ball Z: The Return of Cooler',
#   'Ozzy',
#   'Puella Magi Madoka Magica the Movie Part III: The Rebellion Story',
#   'Blind Willow, Sleeping Woman',
#   'High in the Clouds',
#   'Dragon Ball Z: Bio-Broly',
#   'A Movie of Eggs',
#   'Asterix the Gaul',
#   'Naruto the Movie 3: Guardians of the Crescent Moon Kingdom',
#   'Fist of the North Star',
#   'Eiga Yurukyan',
#   'The Seven Deadly Sins: Cursed by Light',
#   "Hope's Legacy",
#   'Robodog',
#   'The Snow Queen',
#   'Saezuru Tori Wa Habatakanai: The Clouds Gather',
#   'Wish Dragon 2',
#   'Pinocchio 3000',
#   'Sir Billi',
#   'Dragon Ball Z: Broly - Second Coming',
#   'Yu-Gi-Oh! Bonds Beyond Time',
#   'Les secrets de mon père',
#   'Lu Over the Wall',
#   'Flavors of Youth',
#   'Shrek Retold',
#   'Ghost in the Shell: The New Movie',
#   'StarDog and TurboCat',
#   'Baba Yaga',
#   'Patlabor: The Movie',
#   'Chuck Steel: Night of the Trampires',
#   'Titina',
#   'Our RoboCop Remake',
#   'Scooby-Doo & Batman: The Brave and the Bold',
#   "Dante's Inferno",
#   'Finnick',
#   'Gurren Lagann the Movie: The Lights in the Sky are Stars',
#   'The Twelve Tasks of Asterix',
#   'Fairy Tail: Dragon Cry',
#   'Pokémon Heroes',
#   'The Boxcar Children',
#   'Ethel & Ernest',
#   'I Am What I Am',
#   'The Adventures of Prince Achmed',
#   'Spy Cat',
#   'Wings of Honneamise',
#   'Detective Conan: The Bride of Halloween',
#   'Godzilla vs. Hedorah',
#   "Okko's Inn",
#   'Tamako Love Story',
#   'Stand by Me Doraemon',
#   'Even Mice Belong in Heaven',
#   'Nahuel and the Magic Book',
#   'The Sky Crawlers',
#   'Tehran Taboo',
#   'Icarus',
#   'Kaena: The Prophecy',
#   'The Pink Panther',
#   'Attack on Titan: The Roar of Awakening',
#   'Naruto Shippuden the Movie: Blood Prison',
#   'Teenage Mutant Ninja Turtles 2012',
#   'Pierre the Pigeon-Hawk',
#   'The Big Bad Fox and Other Tales',
#   'Sgt. Stubby: An American Hero',
#   'New Gods: Yang Jian',
#   'Bleach: Memories of Nobody',
#   'Dragon Ball: The Path to Power',
#   'Gekijouban Isekai Quartet: Another World',
#   'Detective Conan: The Fist of Blue Sapphire',
#   "Teacher's Pet",
#   "Daisy Quokka: World's Scariest Animal",
#   'The Lord of the Rings: The Empire of Saruman',
#   'Barbie: The Princess & the Popstar',
#   'The Incredible Story of the Giant Pear',
#   'Trunk Train: The Movie',
#   'Godzilla: The Planet Eater',
#   'The Smurfs Musical',
#   'The Seven Deadly Sins: Prisoners of the Sky',
#   'Latte & the Magic Waterstone',
#   'The Miracle Maker',
#   'Curious George 2: Follow That Monkey!',
#   'You Animal!',
#   'My Little Pony: Equestria Girls',
#   ...],
#  'IMDB ID': ['tt8912936',
#   'tt10298840',
#   'tt6467266',
#   'tt5113044',
#   'tt10298810',
#   'tt14331144',
#   'tt14614892',
#   'tt1596342',
#   'tt15494038',
#   'tt1488589',
#   'tt2953050',
#   'tt0032910',
#   'tt7214954',
#   'tt14668630',
#   'tt8115900',
#   'tt0097757',
#   'tt4633694',
#   'tt0317219',
#   'tt0110357',
#   'tt6105098',
#   'tt0107688',
#   'tt0245429',
#   'tt0382932',
#   'tt9288046',
#   'tt2380307',
#   'tt0461770',
#   'tt6718170',
#   'tt3521164',
#   'tt0327597',
#   'tt11703050',
#   'tt8097030',
#   'tt3513500',
#   'tt3470600',
#   'tt2096673',
#   'tt0114709',
#   'tt0317705',
#   'tt2948356',
#   'tt0347149',
#   'tt0126029',
#   'tt5311514',
#   'tt2294629',
#   'tt15339456',
#   'tt1700841',
#   'tt4428398',
#   'tt0910970',
#   'tt0095327',
#   'tt1323594',
#   'tt15090124',
#   'tt0266543',
#   'tt0398286',
#   'tt3606756',
#   'tt0119282',
#   'tt0198781',
#   'tt0120623',
#   'tt2293640',
#   'tt1049413',
#   'tt2948372',
#   'tt0103639',
#   'tt13186482',
#   'tt12801262',
#   'tt16183464',
#   'tt15789038',
#   'tt0129167',
#   'tt5109280',
#   'tt0121164',
#   'tt0892769',
#   'tt9362722',
#   'tt0780521',
#   'tt1979376',
#   'tt3915174',
#   'tt0441773',
#   'tt0230011',
#   'tt0101414',
#   'tt0351283',
#   'tt0096438',
#   'tt0435761',
#   'tt0119698',
#   'tt0268380',
#   'tt0120762',
#   'tt0120917',
#   'tt0432283',
#   'tt5181830',
#   'tt0358082',
#   'tt0120794',
#   'tt2245084',
#   'tt0298148',
#   'tt0077869',
#   'tt0385880',
#   'tt1217209',
#   'tt3606752',
#   'tt1216475',
#   'tt9848626',
#   'tt1690953',
#   'tt0837562',
#   'tt0156887',
#   'tt0133240',
#   'tt1620981',
#   'tt0094625',
#   'tt4520988',
#   'tt0983193',
#   'tt1192628',
#   'tt13651628',
#   'tt0118617',
#   'tt0179955',
#   'tt11207240',
#   'tt0365296',
#   'tt0144608',
#   'tt8657268',
#   'tt9418812',
#   'tt2006753',
#   'tt10068158',
#   'tt0072882',
#   'tt0085218',
#   'tt0439123',
#   'tt0084315',
#   'tt14449482',
#   'tt0100281',
#   'tt11819736',
#   'tt13064272',
#   'tt5990174',
#   'tt13944728',
#   'tt1639826',
#   'tt6241872',
#   'tt7403614',
#   'tt10327712',
#   'tt8329148',
#   'tt1634003',
#   'tt15392166',
#   'tt15405372',
#   'tt17382524',
#   'tt2321555',
#   'tt0078477',
#   'tt0298337',
#   'tt0090065',
#   'tt6349210',
#   'tt3517106',
#   'tt0109162',
#   'tt1155650',
#   'tt0485323',
#   'tt12981702',
#   'tt0041671',
#   'tt3576728',
#   'tt11802992',
#   'tt3748918',
#   'tt13107908',
#   'tt4410000',
#   'tt7409674',
#   'tt0386741',
#   'tt5646314',
#   'tt0832449',
#   'tt0142237',
#   'tt5770430',
#   'tt2457282',
#   'tt9320184',
#   'tt1458167',
#   'tt0142234',
#   'tt0824696',
#   'tt0061369',
#   'tt1071815',
#   'tt0142371',
#   'tt14364238',
#   'tt13884144',
#   'tt10413092',
#   'tt3501062',
#   'tt0050987',
#   'tt10675392',
#   'tt12105364',
#   'tt0332318',
#   'tt0851471',
#   'tt0142239',
#   'tt1587157',
#   'tt4264554',
#   'tt6452332',
#   'tt8176578',
#   'tt9334162',
#   'tt4337072',
#   'tt7531096',
#   'tt3136634',
#   'tt0100339',
#   'tt4278346',
#   'tt11225228',
#   'tt3528906',
#   'tt7578566',
#   'tt0479008',
#   'tt15547806',
#   'tt1422651',
#   'tt0072901',
#   'tt6548966',
#   'tt0347791',
#   'tt3246908',
#   'tt1725969',
#   'tt16345484',
#   'tt0015532',
#   'tt5746054',
#   'tt0093207',
#   'tt19770970',
#   'tt0067148',
#   'tt8328740',
#   'tt3413018',
#   'tt3331846',
#   'tt3804810',
#   'tt9881630',
#   'tt1056437',
#   'tt5584796',
#   'tt13558022',
#   'tt0297753',
#   'tt3640382',
#   'tt7941892',
#   'tt1999167',
#   'tt18293572',
#   'tt8509458',
#   'tt5851904',
#   'tt5314190',
#   'tt19757204',
#   'tt1105263',
#   'tt0142250',
#   'tt15801642',
#   'tt9501310',
#   'tt0350194',
#   'tt11482894',
#   'tt9386672',
#   'tt2396690',
#   'tt7006206',
#   'tt14317018',
#   'tt8478602',
#   'tt18069420',
#   'tt9089294',
#   'tt9038290',
#   'tt0208298',
#   'tt1350484',
#   'tt11102242',
#   'tt2908228',
#   ...],
#  'Year of Release': ['2022',
#   '2022',
#   '2021',
#   '2022',
#   '2022',
#   '2021',
#   '2022',
#   '2022',
#   '2022',
#   'II) ',
#   '2021',
#   '1940',
#   'I) (',
#   '2022',
#   '2022',
#   '1989',
#   '2018',
#   '2006',
#   '1994',
#   '2019',
#   '1993',
#   '2001',
#   '2007',
#   '2022',
#   'I) (',
#   '2007',
#   '2023',
#   'I) (',
#   '2009',
#   'III)',
#   '2022',
#   '2022',
#   '2016',
#   'I) (',
#   '1995',
#   '2004',
#   '2016',
#   '2004',
#   '2001',
#   '2016',
#   'I) (',
#   '2021',
#   '2016',
#   '2022',
#   '2008',
#   '1988',
#   '2010',
#   '2021',
#   '2003',
#   '2010',
#   '2018',
#   '1997',
#   '2001',
#   'I) (',
#   '2015',
#   '2009',
#   '2020',
#   '1992',
#   '2024',
#   '2021',
#   '2022',
#   '2023',
#   '1999',
#   '2021',
#   '2005',
#   '2010',
#   '2023',
#   '2009',
#   '2019',
#   '2022',
#   '2008',
#   '2001',
#   '1991',
#   '2005',
#   '1988',
#   '2010',
#   '1997',
#   '2002',
#   '1998',
#   '2000',
#   '2009',
#   '2022',
#   '2005',
#   '1998',
#   '2014',
#   '2004',
#   '1978',
#   '2006',
#   '2012',
#   '2017',
#   '2011',
#   '2022',
#   '2013',
#   '2012',
#   '1997',
#   '2002',
#   '2019',
#   '1988',
#   '2019',
#   '2011',
#   '2011',
#   '2021',
#   '1997',
#   '2002',
#   '1988',
#   '1999',
#   '2022',
#   '1973',
#   '2022',
#   '2014',
#   '2021',
#   'I) (',
#   '2012',
#   '1996',
#   '1999',
#   '2019',
#   '1937',
#   '2010',
#   '2014',
#   '1967',
#   '2017',
#   '2007',
#   '2013',
#   '2016',
#   '2009',
#   '2018',
#   '2018',
#   '2020',
#   '2021',
#   '2016',
#   '1996',
#   'I) (',
#   '1995',
#   '2017',
#   '2021',
#   'I) (',
#   '1950',
#   '1972',
#   '2000',
#   '2021',
#   '2017',
#   '2007',
#   '2016',
#   '1953',
#   '2024',
#   '1940',
#   '2007',
#   '1981',
#   '1951',
#   'I) (',
#   '2007',
#   '2019',
#   '2021',
#   '2021',
#   '2021',
#   '2019',
#   '2016',
#   '1992',
#   '2020',
#   'II) ',
#   '2018',
#   '2011',
#   '2017',
#   '1970',
#   '2004',
#   '1995',
#   '2006',
#   '2016',
#   '1959',
#   '2000',
#   '2023',
#   '2008',
#   '1996',
#   '2008',
#   '2021',
#   '2021',
#   '2022',
#   '1989',
#   'II) ',
#   '2004',
#   '2007',
#   '2016',
#   '2014',
#   '2017',
#   '2005',
#   '1993',
#   '1961',
#   '2019',
#   '2013',
#   '2019',
#   '2018',
#   '2011',
#   '2012',
#   '2021',
#   '2009',
#   '2003',
#   '2000',
#   '1997',
#   '2018',
#   '2020',
#   '2012',
#   '2021',
#   '2021',
#   '2024',
#   '2019',
#   '1983',
#   '2006',
#   '2006',
#   '2009',
#   '2004',
#   '2022',
#   '1992',
#   '2009',
#   '2015',
#   '1998',
#   '2020',
#   '2013',
#   '1955',
#   '1985',
#   '1977',
#   '2013',
#   '2006',
#   '2006',
#   '2001',
#   '1988',
#   '1963',
#   '1988',
#   '2023',
#   '1986',
#   '2018',
#   '2021',
#   '2020',
#   '2007',
#   '2010',
#   '2007',
#   '2012',
#   '2021',
#   '2012',
#   '1981',
#   '2015',
#   '2008',
#   '1989',
#   '1982',
#   '2002',
#   '2008',
#   '2007',
#   '2022',
#   '2018',
#   '1984',
#   '2016',
#   '2001',
#   '1977',
#   '2013',
#   '2006',
#   '2009',
#   '2010',
#   '2011',
#   'I)',
#   '1990',
#   '2004',
#   '2021',
#   '2013',
#   '1993',
#   '2013',
#   '2024',
#   '1971',
#   '1942',
#   '2019',
#   '2022',
#   '2016',
#   '2012',
#   '2022',
#   '2011',
#   '2020',
#   '2022',
#   '2021',
#   '1994',
#   '2012',
#   '2021',
#   '2021',
#   '2023',
#   '2014',
#   '1982',
#   '2021',
#   '2022',
#   '2016',
#   '2003',
#   '1982',
#   '2023',
#   '2017',
#   '2014',
#   '1999',
#   '1977',
#   '2011',
#   '1986',
#   '2022',
#   '2022',
#   '2019',
#   '2000',
#   '1995',
#   '1941',
#   '2009',
#   '2017',
#   '1978',
#   '2005',
#   '1986',
#   '2006',
#   '2019',
#   '2015',
#   '2005',
#   '2006',
#   '2024',
#   '1946',
#   '1973',
#   '2021',
#   '2006',
#   '2022',
#   '2011',
#   '2021',
#   '2012',
#   '2017',
#   '1995',
#   '2001',
#   '2014',
#   '2022',
#   '2007',
#   '2017',
#   '1994',
#   '2017',
#   '2007',
#   '2013',
#   '2014',
#   '1987',
#   '2001',
#   '2003',
#   '2021',
#   '2022',
#   '2016',
#   '2020',
#   '2015',
#   '2002',
#   '2013',
#   '2022',
#   '2015',
#   '2020',
#   '1974',
#   '1992',
#   '1992',
#   '2020',
#   '2006',
#   '2022',
#   '2015',
#   '2010',
#   '1998',
#   '2006',
#   '2022',
#   '1993',
#   '2016',
#   '2019',
#   '2027',
#   '2009',
#   '2009',
#   '1977',
#   '2014',
#   '2011',
#   '2011',
#   '1994',
#   '1992',
#   '2021',
#   '1975',
#   '2011',
#   '2019',
#   '2002',
#   '2015',
#   '2000',
#   '2014',
#   '2008',
#   '2022',
#   '2024',
#   '2021',
#   '1996',
#   '2013',
#   '2022',
#   '2024',
#   '1991',
#   '2006',
#   '1973',
#   'IV)',
#   '2021',
#   '1987',
#   '2006',
#   'I) (',
#   '2019',
#   '2020',
#   '2001',
#   '2021',
#   '1989',
#   '2022',
#   '1986',
#   '2018',
#   '2004',
#   '2013',
#   '2015',
#   '2018',
#   '1993',
#   '2009',
#   '2025',
#   '2020',
#   '2021',
#   '2000',
#   '1999',
#   '2024',
#   '2012',
#   '2012',
#   '2020',
#   '2012',
#   '2019',
#   '1995',
#   '2019',
#   '2016',
#   '2018',
#   '2017',
#   '2019',
#   '2022',
#   '2018',
#   '2014',
#   '2023',
#   '2006',
#   '2021',
#   '2001',
#   '2021',
#   '2022',
#   '2021',
#   '2017',
#   '2009',
#   '1949',
#   '2018',
#   '2010',
#   '1991',
#   '1991',
#   '2018',
#   '2021',
#   '',
#   '2021',
#   '2011',
#   '2011',
#   '2018',
#   '2000',
#   '2019',
#   '2008',
#   '',
#   '2019',
#   '2006',
#   '1992',
#   '2009',
#   '2005',
#   '2014',
#   '2022',
#   '1973',
#   '1968',
#   '1998',
#   '',
#   '1988',
#   'I) (',
#   '2021',
#   '2003',
#   '1994',
#   '2017',
#   '2006',
#   '2022',
#   '',
#   '2008',
#   '2020',
#   '1993',
#   '2002',
#   '2017',
#   '2012',
#   '1986',
#   '2015',
#   '2010',
#   '2015',
#   '',
#   '2023',
#   'I) (',
#   '2002',
#   '2003',
#   '2012',
#   '2001',
#   '2021',
#   '2013',
#   '2019',
#   '2012',
#   '1973',
#   '2012',
#   '2020',
#   '2003',
#   '',
#   '2011',
#   '2009',
#   '2021',
#   '2018',
#   '2021',
#   '2020',
#   '2016',
#   '2021',
#   '2013',
#   '2013',
#   '2016',
#   '2012',
#   '2023',
#   '1998',
#   '2023',
#   '2005',
#   '2013',
#   '2016',
#   '2016',
#   '2021',
#   '2000',
#   '2011',
#   '2022',
#   '2024',
#   '2022',
#   '2007',
#   '2015',
#   '2017',
#   '2018',
#   '2019',
#   '2001',
#   '1954',
#   '2024',
#   '2017',
#   'III)',
#   '2018',
#   '1987',
#   '2017',
#   '2002',
#   '2018',
#   '2017',
#   '2017',
#   '2021',
#   '2023',
#   '2020',
#   '1993',
#   '2017',
#   '2021',
#   '1994',
#   '2016',
#   '2021',
#   '1966',
#   '1981',
#   '2013',
#   '2019',
#   '2017',
#   'III)',
#   '1989',
#   '2020',
#   '2009',
#   '2005',
#   '2018',
#   '2019',
#   '2000',
#   '1985',
#   '2023',
#   '2016',
#   '2019',
#   '1979',
#   '1999',
#   '2020',
#   '2021',
#   '2022',
#   '2007',
#   '2018',
#   '2023',
#   '2017',
#   '2020',
#   '2021',
#   '1987',
#   '2004',
#   '1997',
#   '2020',
#   '2022',
#   '2019',
#   '2001',
#   '2020',
#   '2011',
#   '2026',
#   '2012',
#   '2010',
#   '2023',
#   '2019',
#   '2022',
#   '2021',
#   '2013',
#   '1987',
# ...
#   'https://m.media-amazon.com/images/M/MV5BMDM4ZmZlMTgtNmE1ZS00ZDA3LTg0MTQtMTVlMTFkZGE0Njg4XkEyXkFqcGdeQXVyOTg4MDYyNw@@._V1_UY98_CR2,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BODU1ODlhNGEtZGNlOC00NTU0LThhMmItNzVmZjQxOGE1MGMxXkEyXkFqcGdeQXVyMjQ0OTA1Nzc@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BZTZjOGFhYTctNTI2Zi00NDBlLThkMGItNzUyZGM4YmZjMDdiXkEyXkFqcGdeQXVyMjMwODE4ODI@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMjI5MjA0NzA3NV5BMl5BanBnXkFtZTgwODgyNjk5NTE@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BNzU5MzM1ZGQtNzM4ZC00YzZlLWIyZDItMTJkYzA5OWNhZjdlXkEyXkFqcGdeQXVyODMyNTM0MjM@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BZjVjYmFmNTgtNDcyMS00ZWZhLWJhOTAtMGI3MDlmY2NjYTMyXkEyXkFqcGdeQXVyMTM2NDc1Njcy._V1_UY98_CR53,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BZGQxYTY2ODItM2ViYi00NjJjLTk4MTAtMGJiMGRjODMxMjU3XkEyXkFqcGdeQXVyOTI4MzgyNTk@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/S/sash/NapCxx-VwSOJtCZ.png',
#   'https://m.media-amazon.com/images/M/MV5BYjQ1MmY1NjItNDQxNS00Nzg1LWE5Y2ItYzMxMjAwNmE2ZjZkXkEyXkFqcGdeQXVyNjcwMzExMzU@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5B
# 3          6.6  Animation, Adventure, Comedy
# 4          5.9  Animation, Action, Adventure
#
#                                          Description        Director  \
# 0  Krypto the Super-Dog and Superman are insepara...     Jared Stern
# 1  The legendary Clades are a family of explorers...        Don Hall
# 2  Buster Moon and his friends must persuade recl...  Garth Jennings
# 3  The untold story of one twelve-year-old's drea...      Kyle Balda
# 4  While spending years attempting to return home...   Angus MacLane
#
#                                           Cast  \
# 0              (Sam J. Levine, Dwayne Johnson)
# 1      (Jake Gyllenhaal, Jaboukie Young-White)
# 2  (Christophe Lourdelet, Matthew McConaughey)
# 3             (Brad Ableson, Jonathan del Val)
# 4                   (Chris Evans, Keke Palmer)
#
#                                           IMDB Image
# 0  https://m.media-amazon.com/images/M/MV5BZTIyNz...
# 1  https://m.media-amazon.com/images/M/MV5BZTk1Nz...
# 2  https://m.media-amazon.com/images/M/MV5BMWRiZG...
# 3  https://m.media-amazon.com/images/M/MV5BZDQyOD...
# 4  https://m.media-amazon.com/images/M/MV5BYTg2Zj...

# %%
df['IMDB Image']
# Out:
# 0       https://m.media-amazon.com/images/M/MV5BZTIyNz...
# 1       https://m.media-amazon.com/images/M/MV5BZTk1Nz...
# 2       https://m.media-amazon.com/images/M/MV5BMWRiZG...
# 3       https://m.media-amazon.com/images/M/MV5BZDQyOD...
# 4       https://m.media-amazon.com/images/M/MV5BYTg2Zj...
#                               ...
# 8074    https://m.media-amazon.com/images/S/sash/NapCx...
# 8075    https://m.media-amazon.com/images/S/sash/NapCx...
# 8076    https://m.media-amazon.com/images/M/MV5BMzAyMG...
# 8077    https://m.media-amazon.com/images/S/sash/NapCx...
# 8078    https://m.media-amazon.com/images/S/sash/NapCx...
# Name: IMDB Image, Length: 8079, dtype: object

# %%
df.shape
# Out:
# (8079, 10)

# %%
df['Movie Name'].value_counts()
# Out:
# Pinocchio                                4
# Puss in Boots                            4
# Wish                                     3
# A Christmas Carol                        3
# Astro Boy                                3
#                                         ..
# Chhota Bheem in the Incan Adventure      1
# Chien Pourri, la vie à Paris!            1
# Magic Wonderland                         1
# Wrath of the Ninja: The Yotoden Movie    1
# Mugge & hans mærkelige hjerne            1
# Name: Movie Name, Length: 7978, dtype: int64

# %%
df.tail()
# Out:
#                                    Movie Name     IMDB ID Year of Release  \
# 8074                The Boy Who Hated Numbers  tt22236278
# 8075        Bamse och världens minsta äventyr  tt22246236            2023
# 8076                             Eisen Flügel  tt22248742
# 8077  Master Giovanni N: Blast Into the Flim!  tt22300738
# 8078            Mugge & hans mærkelige hjerne  tt22326118            2022
#
#      Watch Time Movie Rating                                 Genres  \
# 8074       None         None                  Animation
# 8075       None         None                  Animation
# 8076       None         None                  Animation
# 8077       None         None                  Animation
# 8078       None         None  Animation, Comedy, Family
#
#                                             Description             Director  \
# 8074  Somewhere in the remote areas of Western North...                 None
# 8075                                         Add a Plot  Christian Ryltenius
# 8076                                         Add a Plot      Seiji Mizushima
# 8077                                         Add a Plot             Giovanni
# 8078                                         Add a Plot  Anders Morgenthaler
#
#                                 Cast  \
# 8074                            None
# 8075  (Rolf Lassgård, Johan Ulveson)
# 8076                            None
# 8077                            None
# 8078                            None
#
#                                              IMDB Image
# 8074  https://m.media-amazon.com/images/S/sash/NapCx...
# 8075  https://m.media-amazon.com/images/S/sash/NapCx...
# 8076  https://m.media-amazon.com/images/M/MV5BMzAyMG...
# 8077  https://m.media-amazon.com/images/S/sash/NapCx...
# 8078  https://m.media-amazon.com/images/S/sash/NapCx...

# %%
df = df.dropna()
df
# Out:
#                                       Movie Name     IMDB ID Year of Release  \
# 0                        DC League of Super-Pets   tt8912936            2022
# 2                                         Sing 2   tt6467266            2021
# 3                       Minions: The Rise of Gru   tt5113044            2022
# 4                                      Lightyear  tt10298810            2022
# 5                    Jujutsu Kaisen 0: The Movie  tt14331144            2021
# ...                                          ...         ...             ...
# 7923                        El Bandido Cucaracha   tt4997844            2015
# 7969              História Antes de Uma História   tt4265532            2014
# 7996                            Magiczna Gwiazda   tt3324068            2003
# 8045                                  Acid Space   tt4883574            2015
# 8049  Castelao (Biografía de un ilustre gallego)   tt0301085            1980
#
#      Watch Time Movie Rating                                    Genres  \
# 0       105 min          7.5  Animation, Action, Adventure
# 2       110 min          7.4  Animation, Adventure, Comedy
# 3        87 min          6.6  Animation, Adventure, Comedy
# 4       100 min          5.9  Animation, Action, Adventure
# 5       112 min          7.9    Animation, Action, Fantasy
# ...         ...          ...                                       ...
# 7923     74 min          7.4            Animation, Western
# 7969     80 min          7.2                     Animation
# 7996     60 min          6.0                     Animation
# 8045     70 min          5.5     Animation, Fantasy, Music
# 8049     90 min          7.3                     Animation
#
#                                             Description          Director  \
# 0     Krypto the Super-Dog and Superman are insepara...       Jared Stern
# 2     Buster Moon and his friends must persuade recl...    Garth Jennings
# 3     The untold story of one twelve-year-old's drea...        Kyle Balda
# 4     While spending years attempting to return home...     Angus MacLane
# 5     Yuta Okkotsu, a high schooler who gains contro...     Seong-Hu Park
# ...                                                 ...               ...
# 7923  This is the story of Mariano Gavín's life and ...       Juan Alonso
# 7969                                         Add a Plot  Wilson Lazaretti
# 7996                                         Add a Plot     Wieslaw Zieba
# 8045  The famous rock band "Paperback Music" is unwi...  Stefano Bertelli
# 8049                                         Add a Plot    Jorge Preloran
#
#                                              Cast  \
# 0                 (Sam J. Levine, Dwayne Johnson)
# 2     (Christophe Lourdelet, Matthew McConaughey)
# 3                (Brad Ableson, Jonathan del Val)
# 4                      (Chris Evans, Keke Palmer)
# 5                    (Chinatsu Akasaki, Aya Endô)
# ...                                           ...
# 7923                (Héctor Pisa, Javier Coronas)
# 7969                (Lóra Brito, Fabio de Castro)
# 7996            (Iwona Choluj, Leszek Filipowicz)
# 8045   (Alessio De Filippis, Stefano Broccoletti)
# 8049          (Manolo Ferrol, Luis Medina Castro)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BZTIyNz...
# 2     https://m.media-amazon.com/images/M/MV5BMWRiZG...
# 3     https://m.media-amazon.com/images/M/MV5BZDQyOD...
# 4     https://m.media-amazon.com/images/M/MV5BYTg2Zj...
# 5     https://m.media-amazon.com/images/M/MV5BYzFmMj...
# ...                                                 ...
# 7923  https://m.media-amazon.com/images/M/MV5BYmFlOT...
# 7969  https://m.media-amazon.com/images/M/MV5BZTRjMD...
# 7996  https://m.media-amazon.com/images/M/MV5BM2EwZT...
# 8045  https://m.media-amazon.com/images/M/MV5BMmM1ZT...
# 8049  https://m.media-amazon.com/images/S/sash/NapCx...
#
# [3901 rows x 10 columns]

# %%
df.sort_values("Movie Name", inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 5478                #TubeClash02  tt6467082            2016     86 min
# 1166                       $9.99  tt0790799            2008     78 min
# 2901            .Hack//The Movie  tt2064704            2012    112 min
# 3371         .hack//G.U. Trilogy  tt1164545            2007     93 min
# 5719           00 - Zero Zero 3D  tt1864227            2011     75 min
# ...                          ...        ...             ...        ...
# 4917  ¡Qué vecinos tan animales!  tt0233001            1998     69 min
# 3643               Æblet & ormen  tt1183707            2009     75 min
# 4830          Çanakkale Geçilmez  tt1826959            2008     80 min
# 3140      Ének a csodaszarvasról  tt0309114            2002     89 min
# 2662               Érase una vez  tt0043163            1950     90 min
#
#      Movie Rating                                    Genres  \
# 5478          7.4      Animation, Comedy, Drama
# 1166          6.7     Animation, Drama, Fantasy
# 2901          6.3     Animation, Action, Sci-Fi
# 3371          5.4  Animation, Action, Adventure
# 5719          5.8                     Animation
# ...           ...                                       ...
# 4917          8.2                     Animation
# 3643          6.4             Animation, Family
# 4830          6.3                     Animation
# 3140          6.8   Animation, Fantasy, History
# 2662          7.1                     Animation
#
#                                             Description  \
# 5478  After the events of "#TubeClash", ten new Germ...
# 1166  A stop-motion animated story about people livi...
# 2901  In 2024, the computer network prevails through...
# 3371  After one of his friends falls into a coma pla...
# 5719  An insecure boy travels through the woods with...
# ...                                                 ...
# 4917                                         Add a Plot
# 3643  an apple gets a worm in him and goes on a long...
# 4830                                         Add a Plot
# 3140  Divided into four sections, "Song" is inspired...
# 2662                                         Add a Plot
#
#                        Director                                Cast  \
# 5478                DarkViktory         (DarkViktory, Paperblossom)
# 1166            Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 2901          Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 3371          Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# 5719               Marco Pavone  (Alex Polidori, Massimiliano Alto)
# ...                         ...                                 ...
# 4917       Maite Ruiz de Austri          (Emma Cohen, Gemma Cuervo)
# 3643        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 4830                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 3140          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 2662  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
#
#                                              IMDB Image
# 5478  https://m.media-amazon.com/images/M/MV5BZDVlNG...
# 1166  https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 2901  https://m.media-amazon.com/images/M/MV5BZjBmNm...
# 3371  https://m.media-amazon.com/images/M/MV5BODU4Nz...
# 5719  https://m.media-amazon.com/images/M/MV5BNGEzMW...
# ...                                                 ...
# 4917  https://m.media-amazon.com/images/M/MV5BNTE2NG...
# 3643  https://m.media-amazon.com/images/M/MV5BOTAwMD...
# 4830  https://m.media-amazon.com/images/M/MV5BZjljZm...
# 3140  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 2662  https://m.media-amazon.com/images/M/MV5BNmI4ZG...
#
# [3901 rows x 10 columns]

# %%
df['Movie Name'].value_counts()
# Out:
# Puss in Boots                               4
# The Snow Queen                              3
# Pinocchio                                   3
# A Christmas Carol                           3
# The House                                   2
#                                            ..
# Gu-Gu Ganmo                                 1
# Guardianes de Oz                            1
# Guardians of the Lost Code 3D               1
# Guess How Much I Love You: Autumn's Here    1
# Érase una vez                               1
# Name: Movie Name, Length: 3870, dtype: int64

# %%
df = df.drop_duplicates(subset=['IMDB ID'])
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 5478                #TubeClash02  tt6467082            2016     86 min
# 1166                       $9.99  tt0790799            2008     78 min
# 2901            .Hack//The Movie  tt2064704            2012    112 min
# 3371         .hack//G.U. Trilogy  tt1164545            2007     93 min
# 5719           00 - Zero Zero 3D  tt1864227            2011     75 min
# ...                          ...        ...             ...        ...
# 4917  ¡Qué vecinos tan animales!  tt0233001            1998     69 min
# 3643               Æblet & ormen  tt1183707            2009     75 min
# 4830          Çanakkale Geçilmez  tt1826959            2008     80 min
# 3140      Ének a csodaszarvasról  tt0309114            2002     89 min
# 2662               Érase una vez  tt0043163            1950     90 min
#
#      Movie Rating                                    Genres  \
# 5478          7.4      Animation, Comedy, Drama
# 1166          6.7     Animation, Drama, Fantasy
# 2901          6.3     Animation, Action, Sci-Fi
# 3371          5.4  Animation, Action, Adventure
# 5719          5.8                     Animation
# ...           ...                                       ...
# 4917          8.2                     Animation
# 3643          6.4             Animation, Family
# 4830          6.3                     Animation
# 3140          6.8   Animation, Fantasy, History
# 2662          7.1                     Animation
#
#                                             Description  \
# 5478  After the events of "#TubeClash", ten new Germ...
# 1166  A stop-motion animated story about people livi...
# 2901  In 2024, the computer network prevails through...
# 3371  After one of his friends falls into a coma pla...
# 5719  An insecure boy travels through the woods with...
# ...                                                 ...
# 4917                                         Add a Plot
# 3643  an apple gets a worm in him and goes on a long...
# 4830                                         Add a Plot
# 3140  Divided into four sections, "Song" is inspired...
# 2662                                         Add a Plot
#
#                        Director                                Cast  \
# 5478                DarkViktory         (DarkViktory, Paperblossom)
# 1166            Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 2901          Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 3371          Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# 5719               Marco Pavone  (Alex Polidori, Massimiliano Alto)
# ...                         ...                                 ...
# 4917       Maite Ruiz de Austri          (Emma Cohen, Gemma Cuervo)
# 3643        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 4830                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 3140          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 2662  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
#
#                                              IMDB Image
# 5478  https://m.media-amazon.com/images/M/MV5BZDVlNG...
# 1166  https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 2901  https://m.media-amazon.com/images/M/MV5BZjBmNm...
# 3371  https://m.media-amazon.com/images/M/MV5BODU4Nz...
# 5719  https://m.media-amazon.com/images/M/MV5BNGEzMW...
# ...                                                 ...
# 4917  https://m.media-amazon.com/images/M/MV5BNTE2NG...
# 3643  https://m.media-amazon.com/images/M/MV5BOTAwMD...
# 4830  https://m.media-amazon.com/images/M/MV5BZjljZm...
# 3140  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 2662  https://m.media-amazon.com/images/M/MV5BNmI4ZG...
#
# [3901 rows x 10 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 0                   #TubeClash02  tt6467082            2016     86 min
# 1                          $9.99  tt0790799            2008     78 min
# 2               .Hack//The Movie  tt2064704            2012    112 min
# 3            .hack//G.U. Trilogy  tt1164545            2007     93 min
# 4              00 - Zero Zero 3D  tt1864227            2011     75 min
# ...                          ...        ...             ...        ...
# 3896  ¡Qué vecinos tan animales!  tt0233001            1998     69 min
# 3897               Æblet & ormen  tt1183707            2009     75 min
# 3898          Çanakkale Geçilmez  tt1826959            2008     80 min
# 3899      Ének a csodaszarvasról  tt0309114            2002     89 min
# 3900               Érase una vez  tt0043163            1950     90 min
#
#      Movie Rating                                    Genres  \
# 0             7.4      Animation, Comedy, Drama
# 1             6.7     Animation, Drama, Fantasy
# 2             6.3     Animation, Action, Sci-Fi
# 3             5.4  Animation, Action, Adventure
# 4             5.8                     Animation
# ...           ...                                       ...
# 3896          8.2                     Animation
# 3897          6.4             Animation, Family
# 3898          6.3                     Animation
# 3899          6.8   Animation, Fantasy, History
# 3900          7.1                     Animation
#
#                                             Description  \
# 0     After the events of "#TubeClash", ten new Germ...
# 1     A stop-motion animated story about people livi...
# 2     In 2024, the computer network prevails through...
# 3     After one of his friends falls into a coma pla...
# 4     An insecure boy travels through the woods with...
# ...                                                 ...
# 3896                                         Add a Plot
# 3897  an apple gets a worm in him and goes on a long...
# 3898                                         Add a Plot
# 3899  Divided into four sections, "Song" is inspired...
# 3900                                         Add a Plot
#
#                        Director                                Cast  \
# 0                   DarkViktory         (DarkViktory, Paperblossom)
# 1               Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 2             Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 3             Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# 4                  Marco Pavone  (Alex Polidori, Massimiliano Alto)
# ...                         ...                                 ...
# 3896       Maite Ruiz de Austri          (Emma Cohen, Gemma Cuervo)
# 3897        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 3898                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 3899          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 3900  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BZDVlNG...
# 1     https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 2     https://m.media-amazon.com/images/M/MV5BZjBmNm...
# 3     https://m.media-amazon.com/images/M/MV5BODU4Nz...
# 4     https://m.media-amazon.com/images/M/MV5BNGEzMW...
# ...                                                 ...
# 3896  https://m.media-amazon.com/images/M/MV5BNTE2NG...
# 3897  https://m.media-amazon.com/images/M/MV5BOTAwMD...
# 3898  https://m.media-amazon.com/images/M/MV5BZjljZm...
# 3899  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 3900  https://m.media-amazon.com/images/M/MV5BNmI4ZG...
#
# [3901 rows x 10 columns]

# %%
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 0                   #TubeClash02  tt6467082            2016     86 min
# 1                          $9.99  tt0790799            2008     78 min
# 2               .Hack//The Movie  tt2064704            2012    112 min
# 3            .hack//G.U. Trilogy  tt1164545            2007     93 min
# 4              00 - Zero Zero 3D  tt1864227            2011     75 min
# ...                          ...        ...             ...        ...
# 3896  ¡Qué vecinos tan animales!  tt0233001            1998     69 min
# 3897               Æblet & ormen  tt1183707            2009     75 min
# 3898          Çanakkale Geçilmez  tt1826959            2008     80 min
# 3899      Ének a csodaszarvasról  tt0309114            2002     89 min
# 3900               Érase una vez  tt0043163            1950     90 min
#
#      Movie Rating                                    Genres  \
# 0             7.4      Animation, Comedy, Drama
# 1             6.7     Animation, Drama, Fantasy
# 2             6.3     Animation, Action, Sci-Fi
# 3             5.4  Animation, Action, Adventure
# 4             5.8                     Animation
# ...           ...                                       ...
# 3896          8.2                     Animation
# 3897          6.4             Animation, Family
# 3898          6.3                     Animation
# 3899          6.8   Animation, Fantasy, History
# 3900          7.1                     Animation
#
#                                             Description  \
# 0     After the events of "#TubeClash", ten new Germ...
# 1     A stop-motion animated story about people livi...
# 2     In 2024, the computer network prevails through...
# 3     After one of his friends falls into a coma pla...
# 4     An insecure boy travels through the woods with...
# ...                                                 ...
# 3896                                         Add a Plot
# 3897  an apple gets a worm in him and goes on a long...
# 3898                                         Add a Plot
# 3899  Divided into four sections, "Song" is inspired...
# 3900                                         Add a Plot
#
#                        Director                                Cast  \
# 0                   DarkViktory         (DarkViktory, Paperblossom)
# 1               Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 2             Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 3             Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# 4                  Marco Pavone  (Alex Polidori, Massimiliano Alto)
# ...                         ...                                 ...
# 3896       Maite Ruiz de Austri          (Emma Cohen, Gemma Cuervo)
# 3897        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 3898                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 3899          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 3900  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BZDVlNG...
# 1     https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 2     https://m.media-amazon.com/images/M/MV5BZjBmNm...
# 3     https://m.media-amazon.com/images/M/MV5BODU4Nz...
# 4     https://m.media-amazon.com/images/M/MV5BNGEzMW...
# ...                                                 ...
# 3896  https://m.media-amazon.com/images/M/MV5BNTE2NG...
# 3897  https://m.media-amazon.com/images/M/MV5BOTAwMD...
# 3898  https://m.media-amazon.com/images/M/MV5BZjljZm...
# 3899  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 3900  https://m.media-amazon.com/images/M/MV5BNmI4ZG...
#
# [3901 rows x 10 columns]

# %%
df.to_csv('animation.csv')

# %%
df[df['Movie Name'] == 'Sleeping Beauty']
# Out:
#            Movie Name    IMDB ID Year of Release Watch Time Movie Rating  \
# 2811  Sleeping Beauty  tt0053285            1959     75 min          7.2
#
#                                         Genres  \
# 2811  Animation, Adventure, Family
#
#                                             Description   Director  \
# 2811  After being snubbed by the royal family, a mal...  Les Clark
#
#                                Cast  \
# 2811  (Clyde Geronimi, Eric Larson)
#
#                                              IMDB Image
# 2811  https://m.media-amazon.com/images/M/MV5BOTJmZj...

# %%
fshhh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-45c1632dbf33> in <module>
# ----> 1 fshhh
#
# NameError: name 'fshhh' is not defined

# %%
pag = requests.get("")
soup = BeautifulSoup(pag.text, 'html.parser')
movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
sleep(randint(2,8))
for store in movie_data:
  name = store.find('h3', class_= 'lister-item-header').find('a').text
  movie_name.append(name)

  release = store.find('h3', class_= 'lister-item-header')
  try:
    year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
    year.append(year_of_release)
  except:
    year.append(None)

  try: 
     runtime = store.p.find('span', class_ = 'runtime').text[0:7]
     time.append(runtime)
  except:
      time.append(None)

  rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
  try:
      ratings = (rate.find('strong').text)
      rating.append(ratings)
  except:
       rating.append(None)

  genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
  genres.append(genre)

  describe = store.find_all('p', class_ = 'text-muted')
  description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
  description.append(description_)
            
  try:
    direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
    director.append(direct)
  except:
    director.append(None)

  try:
      cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
      casts.append(cast)
  except:
      casts.append(None)

  try:
      image = store.find('img')
      imge = image['loadlate']
      images.append(imge)  
  except:
       images.append(None)

  numbers = store.find('img')
  num = numbers['data-tconst'][:]
  try:
    number.append(num)
  except:
    number.append(None)
