# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/fantasy_movie_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []
images = []
number = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(1,10000,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=fantasy&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)

            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)

            try:
              image = store.find('img')
              imge = image['loadlate']
              images.append(imge)  
            except:
                images.append(None)

            numbers = store.find('img')
            num = numbers['data-tconst'][:]
            try:
              number.append(num)
            except:
             number.append(None)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601, 651, 701, 751, 801, 851, 901, 951, 1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151, 2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701, 2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251, 3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801, 3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351, 4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901, 4951, 5001, 5051, 5101, 5151, 5201, 5251, 5301, 5351, 5401, 5451, 5501, 5551, 5601, 5651, 5701, 5751, 5801, 5851, 5901, 5951, 6001, 6051, 6101, 6151, 6201, 6251, 6301, 6351, 6401, 6451, 6501, 6551, 6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101, 7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651, 7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051, 8101, 8151, 8201, 8251, 8301, 8351, 8401, 8451, 8501, 8551, 8601, 8651, 8701, 8751, 8801, 8851, 8901, 8951, 9001, 9051, 9101, 9151, 9201, 9251, 9301, 9351, 9401, 9451, 9501, 9551, 9601, 9651, 9701, 9751, 9801, 9851, 9901, 9951]

# %%
a = { "Movie Name": movie_name, "IMDB ID":number, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts, "IMDB Image":images}

# %%
a
# Out:
# {'Movie Name': ['Thor: Love and Thunder',
#   'Pinocchio',
#   'Avatar: The Way of Water',
#   'Three Thousand Years of Longing',
#   'The Little Mermaid',
#   'Everything Everywhere All at Once',
#   'The Munsters',
#   'Hocus Pocus 2',
#   'Avatar',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Hocus Pocus',
#   'Black Adam',
#   'Samaritan',
#   'Meet Cute',
#   'The Northman',
#   'Spider-Man: No Way Home',
#   'This Is the End',
#   'DC League of Super-Pets',
#   'Brahmastra Part One: Shiva',
#   'Constantine',
#   'Barbie',
#   'Doctor Strange in the Multiverse of Madness',
#   'Mona Lisa and the Blood Moon',
#   'The Lord of the Rings: The Return of the King',
#   'Day Shift',
#   'Strange World',
#   "Harry Potter and the Sorcerer's Stone",
#   'Constantine 2',
#   'The Lord of the Rings: The Two Towers',
#   'The Hobbit: An Unexpected Journey',
#   'Ghostbusters: Afterlife',
#   'Men',
#   'Jujutsu Kaisen 0: The Movie',
#   'Paddington 2',
#   'Dragon Ball Super: Super Hero',
#   'Paddington',
#   'Eternals',
#   'Disenchanted',
#   'The Mortal Instruments: City of Bones',
#   'The VVitch: A New-England Folktale',
#   'Beetlejuice',
#   'Thor: Ragnarok',
#   'Fantastic Beasts: The Secrets of Dumbledore',
#   'The Mummy',
#   'Drifting Home',
#   'The Hobbit: The Desolation of Smaug',
#   "Guillermo del Toro's Pinocchio",
#   'Dracula',
#   'Free Guy',
#   'The Green Mile',
#   'Willow',
#   'Encanto',
#   'Star Wars',
#   'Pinocchio',
#   'Scooby-Doo',
#   'Luck',
#   'Suicide Squad',
#   'The Princess Bride',
#   'Lyle, Lyle, Crocodile',
#   'Suspiria',
#   'Twilight',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'The Little Mermaid',
#   'Ghostbusters',
#   "Zack Snyder's Justice League",
#   'Thor',
#   'Interview with the Vampire: The Vampire Chronicles',
#   'Spider-Man: Into the Spider-Verse',
#   'Sonic the Hedgehog 2',
#   'The Hobbit: The Battle of the Five Armies',
#   "Disney's Snow White",
#   'About Time',
#   'The School for Good and Evil',
#   'Vampire Academy',
#   'Wonka',
#   'The Age of Adaline',
#   'Practical Magic',
#   'The Nightmare Before Christmas',
#   'Doctor Sleep',
#   'Wonder Woman',
#   'Thunderbolts',
#   'Spirited Away',
#   'Beauty and the Beast',
#   'Meet Joe Black',
#   'Ratatouille',
#   'Shang-Chi and the Legend of the Ten Rings',
#   'Aladdin',
#   'The Sea Beast',
#   'The NeverEnding Story',
#   'Coco',
#   'Enchanted',
#   "Pan's Labyrinth",
#   'Untitled Super Mario Project',
#   'Harry Potter and the Chamber of Secrets',
#   'Harry Potter and the Goblet of Fire',
#   'Moana',
#   'Coraline',
#   'King Arthur: Legend of the Sword',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   'The Innocents',
#   'Peter Pan & Wendy',
#   'Star Wars: The Rise Of Skywalker',
#   'Wicked',
#   'Van Helsing',
#   'Cinderella',
#   'The House',
#   'Turning Red',
#   'Matilda',
#   'House of Dracula',
#   'Star Wars: Episode I - The Phantom Menace',
#   'Dragonball Evolution',
#   'The Shape of Water',
#   'The Lighthouse',
#   'It Chapter Two',
#   'Harry Potter and the Prisoner of Azkaban',
#   'Inside Out',
#   'Palm Springs',
#   'The Wizard of Oz',
#   'The Addams Family',
#   'Dogma',
#   'Aquaman',
#   'Mortal Kombat',
#   'Toy Story',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Snow White and the Huntsman',
#   'Clash of the Titans',
#   'Shazam!',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'Casper',
#   'Alice in Wonderland',
#   'Justice League',
#   'Jumanji: Welcome to the Jungle',
#   "Howl's Moving Castle",
#   'Shrek',
#   'Scott Pilgrim vs. the World',
#   'Edward Scissorhands',
#   'Stardust',
#   'Matilda',
#   'Your Name.',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'Frozen',
#   'Dungeons & Dragons: Honor Among Thieves',
#   'Marcel the Shell with Shoes On',
#   'Big Trouble in Little China',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   'Charlie and the Chocolate Factory',
#   'Vanilla Sky',
#   'The Princess',
#   'Thor: The Dark World',
#   'Wonder Woman 1984',
#   'Hook',
#   'A Cure for Wellness',
#   'Lamb',
#   'Labyrinth',
#   'Sausage Party',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'The Green Knight',
#   'Doctor Strange',
#   'The Craft',
#   'The Mummy',
#   'Little Nicky',
#   'Aquaman and the Lost Kingdom',
#   'Haunted Mansion',
#   'Harry Potter and the Order of the Phoenix',
#   'Pride and Prejudice and Zombies',
#   'The Flash',
#   'Mulan',
#   'Star Wars: Episode III - Revenge of the Sith',
#   'Love on a Leash',
#   'Jumanji: The Next Level',
#   'Mad God',
#   'Evil Dead Rise',
#   'Beetlejuice 2',
#   'Tangled',
#   'The Lovely Bones',
#   'Sleepy Hollow',
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Death Becomes Her',
#   'Big Fish',
#   'The Secret Life of Walter Mitty',
#   'Hercules',
#   'Monsters, Inc.',
#   'Perfume: The Story of a Murderer',
#   'Sonic the Hedgehog',
#   'Legend',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   'Star Wars: Episode VIII - The Last Jedi',
#   'Fantastic Beasts and Where to Find Them',
#   'Harry Potter and the Half-Blood Prince',
#   'Yesterday',
#   'The Mask',
#   "A Bug's Life",
#   'The Mummy Returns',
#   'Tomb Raider',
#   'The Crow',
#   'Sucker Punch',
#   'Pinocchio',
#   'Jungle Cruise',
#   'Monty Python and the Holy Grail',
#   'Bedazzled',
#   'Rebel Moon',
#   'Blade',
#   'Soul',
#   'Aladdin',
#   'Willy Wonka & the Chocolate Factory',
#   'Jumanji',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Cinderella',
#   'Groundhog Day',
#   'The Curious Case of Benjamin Button',
#   'A Little Princess',
#   "The Huntsman: Winter's War",
#   'Valerian and the City of a Thousand Planets',
#   'Ghost',
#   'The Marvels',
#   'Gremlins',
#   'The Jungle Book',
#   'Big',
#   'What Dreams May Come',
#   'Luca',
#   'One Piece Film: Red',
#   'Elemental',
#   'Teen Wolf',
#   'Conan the Barbarian',
#   "It's a Wonderful Life",
#   'Star Wars: Episode II - Attack of the Clones',
#   'Raya and the Last Dragon',
#   'Immortals',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '13 Going on 30',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   'Corpse Bride',
#   'Karthikeya 2',
#   'How to Train Your Dragon',
#   'Midnight in Paris',
#   'Last Christmas',
#   'Lilo & Stitch',
#   'Highlander',
#   'The Witches',
#   'Spider-Man: Across the Spider-Verse',
#   'Let the Right One In',
#   'The Mummy: Tomb of the Dragon Emperor',
#   'Power Rangers',
#   'The Princess and the Frog',
#   '17 Again',
#   'Mandy',
#   'Toy Story 4',
#   'Puss in Boots: The Last Wish',
#   'Shazam! Fury of the Gods',
#   'The Three Musketeers',
#   'Bridge to Terabithia',
#   'Kung Fu Panda',
#   'Atlantis: The Lost Empire',
#   'Life of Pi',
#   'Ghostbusters: Answer the Call',
#   'The Great Wall',
#   'Fantasy Island',
#   'Fright Night',
#   'Beauty and the Beast',
#   'Swiss Army Man',
#   "Miss Peregrine's Home for Peculiar Children",
#   'Addams Family Values',
#   'Ghost Rider',
#   'Night at the Museum',
#   'Maleficent',
#   'Warcraft',
#   'Who Framed Roger Rabbit',
#   'Chaos Walking',
#   'Mary Poppins',
#   'Toy Story 3',
#   'Peter Pan',
#   'Into the Woods',
#   'Batman Returns',
#   'Princess Mononoke',
#   'Barbarella',
#   'The Holy Mountain',
#   'Dark Shadows',
#   'Mulan',
#   "Pirates of the Caribbean: At World's End",
#   "The Emperor's New Groove",
#   'The Last Airbender',
#   'Wendell & Wild',
#   'The Cursed',
#   'A Series of Unfortunate Events',
#   'The Prince of Egypt',
#   'Pan',
#   'Super Mario Bros.',
#   'Mr. Nobody',
#   'Dracula 2000',
#   'Love and Monsters',
#   'Monster Hunter',
#   'Underworld',
#   'Liar Liar',
#   'The Imaginarium of Doctor Parnassus',
#   'Shrek 2',
#   'The Lord of the Rings',
#   'Monster House',
#   'Brave',
#   'Fantastic Four',
#   'Kong: Skull Island',
#   'Hellboy',
#   'Sorry to Bother You',
#   'Elf',
#   'Hotel Transylvania: Transformania',
#   'Gods of Egypt',
#   'The Legend of Tarzan',
#   'Hotel Transylvania',
#   'The Fall',
#   'Treasure Planet',
#   'Mama',
#   'The Addams Family',
#   'Drive Angry',
#   'Akira',
#   'Frozen II',
#   'Conan the Barbarian',
#   'Bright',
#   'Excalibur',
#   'Fire in the Sky',
#   'Enter the Void',
#   'Belle',
#   'Pet Sematary',
#   'Anastasia',
#   'Colossal',
#   'Lilo & Stitch',
#   'Click',
#   'Journey to the Center of the Earth',
#   'Krull',
#   'My Neighbor Totoro',
#   'The Dark Tower',
#   'What Happened to Monday',
#   'Prince of Persia: The Sands of Time',
#   'Fantastic Four: Rise of the Silver Surfer',
#   'Dolittle',
#   'The Haunted Mansion',
#   'Dark City',
#   'Field of Dreams',
#   'The Man from Earth',
#   'The Change-Up',
#   'Deliver Us from Evil',
#   'Let Me In',
#   'Legion',
#   'Last Action Hero',
#   'Hellboy',
#   'The Lost Girls',
#   'Percy Jackson: Sea of Monsters',
#   'Hansel & Gretel: Witch Hunters',
#   'Ghostbusters II',
#   'Mortal Engines',
#   'Thir13en Ghosts',
#   'Mortal Kombat',
#   'Cats',
#   'The Book of Life',
#   'Exodus: Gods and Kings',
#   'The Twilight Saga: Eclipse',
#   'Wreck-It Ralph',
#   'Tumbbad',
#   'Being John Malkovich',
#   'The Wolfman',
#   'Toy Story 2',
#   'Snow White and the Seven Dwarfs',
#   'The Witches of Eastwick',
#   'Hugo',
#   'Godzilla: King of the Monsters',
#   'The Fisher King',
#   'The Legend of Maula Jatt',
#   'Alienoid',
#   'Hercules',
#   'The Adventures of Pinocchio',
#   'Night Teeth',
#   'Lara Croft: Tomb Raider',
#   'The Lego Movie',
#   'Queen of the Damned',
#   'Eraserhead',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   'Triangle',
#   'Reign of Fire',
#   'Nosferatu',
#   'The Jungle Book',
#   'How the Grinch Stole Christmas',
#   'The Twilight Saga: New Moon',
#   'Bruce Almighty',
#   'Tomorrowland',
#   '1408',
#   "The Dead Don't Die",
#   'The Witches',
#   'The League of Extraordinary Gentlemen',
#   'Seventh Son',
#   'Powder',
#   'The Shack',
#   'Stuart Little',
#   'Maleficent: Mistress of Evil',
#   '47 Ronin',
#   'The Brothers Grimm',
#   'The Frighteners',
#   'Beowulf',
#   'Monsters University',
#   'Teen Witch',
#   'Buffy the Vampire Slayer',
#   'Nightbreed',
#   'Cloudy with a Chance of Meatballs',
#   'The Woman in Black',
#   'Mary Poppins Returns',
#   'Return to Oz',
#   'Ralph Breaks the Internet',
#   'The Golden Compass',
#   'The Chronicles of Narnia: Prince Caspian',
#   'A Nightmare on Elm Street 3: Dream Warriors',
#   'Demon Slayer the Movie: Mugen Train',
#   'The Cat in the Hat',
#   'Pleasantville',
#   'Imaginary Friends',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Abraham Lincoln: Vampire Hunter',
#   'Braindead',
#   'Apostle',
#   'The Tree of Life',
#   'Only Lovers Left Alive',
#   'James and the Giant Peach',
#   'Across the Universe',
#   'Beautiful Creatures',
#   '9',
#   'Clash of the Titans',
#   'The Haunting',
#   'Slayers',
#   'Aquamarine',
#   'The Emoji Movie',
#   'Death Note',
#   'Pacific Rim: Uprising',
#   'Fullmetal Alchemist: The Revenge of Scar',
#   'Downsizing',
#   'R.I.P.D.',
#   'The VelociPastor',
#   'Tom and Jerry',
#   'The Covenant',
#   'The Secret Garden',
#   'Oz the Great and Powerful',
#   'Spirit Halloween',
#   'Ella Enchanted',
#   'Masters of the Universe',
#   'Snake Eyes',
#   'Hancock',
#   'In the Mouth of Madness',
#   'Blood Red Sky',
#   'Onward',
#   'Cinderella',
#   'Kung Fu Hustle',
#   'Dracula Untold',
#   'The Road to El Dorado',
#   'The Scorpion King',
#   'Space Jam: A New Legacy',
#   'The Family Man',
#   'Petite Maman',
#   'Avatar 3',
#   'Creepshow',
#   'The Gift',
#   'Jack the Giant Slayer',
#   'Alvin and the Chipmunks',
#   'Teeth',
#   'Peter Pan',
#   'Odd Thomas',
#   'Sonic the Hedgehog 3',
#   'A Ghost Story',
#   'Fantasia',
#   'Wrath of the Titans',
#   'Heavy Metal',
#   'Aristotle and Dante Discover the Secrets of the Universe',
#   'Alice in Wonderland',
#   'Lady in the Water',
#   'The Seventh Seal',
#   'Pixels',
#   'How to Train Your Dragon: The Hidden World',
#   'Freaky Friday',
#   'The Addams Family 2',
#   'Scooby-Doo 2: Monsters Unleashed',
#   'Clifford the Big Red Dog',
#   'Mack & Rita',
#   'Pinocchio: A True Story',
#   'Epic Movie',
#   'Ponniyin Selvan: I',
#   'Rookie of the Year',
#   'The Spiderwick Chronicles',
#   'FernGully: The Last Rainforest',
#   "The King's Daughter",
#   'Journey 2: The Mysterious Island',
#   'The Croods: A New Age',
#   'The Illusionist',
#   'Mannequin',
#   'The Flintstones',
#   'Wish',
#   'Splash',
#   'Night at the Museum: Battle of the Smithsonian',
#   'The Hot Chick',
#   'Alice Through the Looking Glass',
#   'The Lego Batman Movie',
#   'Conan the Destroyer',
#   'House',
#   '10,000 BC',
#   'The Sea of Trees',
#   'The Lake House',
#   'The Endless',
#   'Dumbo',
#   'The Craft: Legacy',
#   'Kung Fu Panda 3',
#   'Ginger Snaps',
#   'Sleeping Beauty',
#   'Hush, Hush',
#   'Inkheart',
#   'Dragon Blade',
#   'Goosebumps',
#   'The Old Guard 2',
#   'Aladdin 2',
#   'We Can Be Heroes',
#   'Fallen',
#   'A Monster Calls',
#   'The Adventures of Sharkboy and Lavagirl 3-D',
#   'Spider-Man Beyond Negative',
#   "The Time Traveler's Wife",
#   'The Lord of the Rings: The War of the Rohirrim',
#   'Ponyo',
#   'Space Jam',
#   'Thinner',
#   'The Santa Clause',
#   'Rumble',
#   'Idle Hands',
#   'PAW Patrol: The Movie',
#   'Rise of the Teenage Mutant Ninja Turtles: The Movie',
#   'Just Like Heaven',
#   'Gremlins 2: The New Batch',
#   "Kiki's Delivery Service",
#   'The Last Witch Hunter',
#   'The BFG',
#   'Renfield',
#   'The Monster Squad',
#   'Mirror Mirror',
#   'A Wrinkle in Time',
#   'Shallow Hal',
#   'Mystery Men',
#   'Home',
#   'The Polar Express',
#   'Dora and the Lost City of Gold',
#   'Shrek the Third',
#   'Trolls',
#   'How to Train Your Dragon 2',
#   'End of Days',
#   'Pompeii',
#   'Sliding Doors',
#   'Night at the Museum: Secret of the Tomb',
#   'Mirage',
#   'Nanny McPhee',
#   'Peggy Sue Got Married',
#   'The Uninvited',
#   'Shin Ultraman',
#   'HollyBlood',
#   'Chitty Chitty Bang Bang',
#   'The Boss Baby',
#   'Popeye',
#   'Dracula',
#   'The NeverEnding Story III',
#   'Eragon',
#   'The Beastmaster',
#   'Leprechaun',
#   'The Neverending Story',
#   'What Women Want',
#   'The Invention of Lying',
#   'Chicken Little',
#   "We're Back! A Dinosaur's Story",
#   'Hellboy II: The Golden Army',
#   'Thirst',
#   'Gremlins 3',
#   'Christopher Robin',
#   'Before I Fall',
#   'Prisoners of the Ghostland',
#   'Klaus',
#   'Cat People',
#   "The Sorcerer's Apprentice",
#   'The Croods',
#   'Border',
#   'Hotel Transylvania 3: Summer Vacation',
#   'If I Stay',
#   'Kung Fu Panda 2',
#   'Monsters vs. Aliens',
#   'Brother Bear',
#   'Somewhere in Time',
#   'Dinosaur',
#   'Knight of Cups',
#   'Dragon Ball Super: Broly',
#   'Trolls World Tour',
#   'The Lorax',
#   'Troll',
#   'Oxygen',
#   'The Boss Baby: Family Business',
#   'The Witcher: Nightmare of the Wolf',
#   'Peter Rabbit',
#   'Inside Out 2',
#   'Time Bandits',
#   'Ghost Rider: Spirit of Vengeance',
#   'Wolves',
#   'The Monkey King: The Legend Begins',
#   'Supercool',
#   'The Prince and the Pauper',
#   'Before I Wake',
#   'Slumberland',
#   'Weathering with You',
#   'Underworld: Blood Wars',
#   'Fire and Ice',
#   'Paprika',
#   'Mowgli: Legend of the Jungle',
#   'House on Haunted Hill',
#   'The Dark Crystal',
#   "Charlotte's Web",
#   'The Little Vampire',
#   'Thunder Force',
#   'Stranger Than Fiction',
#   'Pink Floyd: The Wall',
#   'The SpongeBob SquarePants Movie',
#   'Red Riding Hood',
#   "A Dog's Purpose",
#   'Cool World',
#   'The Forbidden Kingdom',
#   'Big Gold Brick',
#   'Drop Dead Fred',
#   'Antz',
#   'Wings of Desire',
#   'Red Sonja',
#   'Scoob!',
#   'Angels in the Outfield',
#   'Epic',
#   'Elektra',
#   'Pumpkinhead',
#   'Evan Almighty',
#   'The Black Cauldron',
#   'Wizards',
#   'Cabin in the Sky',
#   'The NeverEnding Story II: The Next Chapter',
#   'Mayday',
#   'Xanadu',
#   'Aliens in the Attic',
#   'Monkeybone',
#   'The Prophecy',
#   'The Sword in the Stone',
#   'The Final Girls',
#   'Where the Wild Things Are',
#   'When We First Met',
#   'Harry and the Hendersons',
#   'Red Lights',
#   'Sex and Zen',
#   'Dorian Gray',
#   'Iron Mask',
#   'Life After Beth',
#   'Your Highness',
#   'Teenage Mutant Ninja Turtles: Mutant Mayhem',
#   'Castle in the Sky',
#   'The Grinch',
#   'Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansion Arc',
#   'Secret Things',
#   'New Nightmare',
#   'The SpongeBob Movie: Sponge on the Run',
#   'The Borrowers',
#   'Delirious',
#   'Dead Man',
#   'Shrek Forever After',
#   'Ladyhawke',
#   'Interstate 60: Episodes of the Road',
#   'Zathura: A Space Adventure',
#   'Rise of the Guardians',
#   'Shaolin Soccer',
#   'ParaNorman',
#   'Star Trek V: The Final Frontier',
#   'Zapped!',
#   'City of Angels',
#   'Bedtime Stories',
#   'Wishmaster',
#   'Hotel Transylvania 2',
#   'DragonHeart',
#   'Horton Hears a Who!',
#   'Nightbooks',
#   'All Dogs Go to Heaven',
#   'Welcome to Marwen',
#   'Night of the Demons',
#   'The Little Mermaid',
#   'The Legend of Hercules',
#   'The Keep',
#   'Creepshow 2',
#   'Son of the Mask',
#   'Catwoman',
#   'Meet the Spartans',
#   'Cosmopolis',
#   'Jason and the Argonauts',
#   'Gretel & Hansel',
#   'Thor: God of Thunder',
#   'Waking Life',
#   'The Grudge',
#   "Dante's Hell",
#   'The Wiz',
#   'The Voices',
#   'The Rescuers',
#   'City of Ember',
#   'Little Monsters',
#   'Cloudy with a Chance of Meatballs 2',
#   'Thelma',
#   'The Secret World of Arrietty',
#   "Pete's Dragon",
#   'The Smurfs',
#   'Paddington 3',
#   'Jack',
#   'Book of Shadows: Blair Witch 2',
#   'Artemis Fowl',
#   'The Rescuers Down Under',
#   'Once Bitten',
#   'Valhalla Rising',
#   'Bubba Ho-Tep',
#   'Garfield',
#   'Fable',
#   'Wish Dragon',
#   'Phantom of the Paradise',
#   'Something Wicked This Way Comes',
#   'The Map of Tiny Perfect Things',
#   'Sleepwalkers',
#   'Superman: Solar',
#   'Paradise Hills',
#   'The Jacket',
#   'The Omen',
#   'Zoom',
#   'Orlando',
#   'Underworld: Evolution',
#   'Garfield',
#   'Lara Croft Tomb Raider: The Cradle of Life',
#   'Mine',
#   'An American Werewolf in Paris',
#   'Horns',
#   'Bedknobs and Broomsticks',
#   'Season of the Witch',
#   'Krampus',
#   'Tuck Everlasting',
#   'The Man Who Killed Don Quixote',
#   'Mortal Kombat: Annihilation',
#   'Still Breathing',
#   'Trollhunter',
#   'How High',
#   'Priest',
#   'The Lego Movie 2: The Second Part',
#   'Lady in White',
#   'Jaadugar',
#   'Race to Witch Mountain',
#   'The Adventures of Baron Munchausen',
#   'Safety Not Guaranteed',
#   'Just My Luck',
#   'Dungeons & Dragons',
#   'Kubo and the Two Strings',
#   'Winnie the Pooh',
#   'The Barbarians',
#   'Kate & Leopold',
#   'Wolfwalkers',
#   'BRZRKR',
#   'One Million Years B.C.',
#   'Alexander and the Terrible, Horrible, No Good, Very Bad Day',
#   'Nine Days',
#   'Fullmetal Alchemist',
#   'Fistful of Vengeance',
#   'The Pagemaster',
#   'The Sword and the Sorcerer',
#   'The Lure',
#   'My Little Pony: A New Generation',
#   'Malnazidos',
#   'The Golden Child',
#   'Beastly',
#   'The Master of Disguise',
#   'Nobody Sleeps in the Woods Tonight',
#   'Kazaam',
#   'Underworld: Rise of the Lycans',
#   'Byzantium',
#   'Jason Goes to Hell: The Final Friday',
#   'The Room',
#   'The Secret of NIMH',
#   'Injustice',
#   'The House with a Clock in Its Walls',
#   'The One I Love',
#   'Suzume no tojimari',
#   'Zardoz',
#   'The Last Unicorn',
#   'Spellbound',
#   'Starf*cker',
#   'Witch Hunt',
#   'BloodRayne',
#   'In the Name of the King: A Dungeon Siege Tale',
#   "A Midsummer Night's Dream",
#   'Under the Shadow',
#   'Ghosts of Girlfriends Past',
#   'Above the Shadows',
#   'A Nightmare on Elm Street 5: The Dream Child',
#   'An American Pickle',
#   'Slaughterhouse Rulez',
#   'South Park: Bigger, Longer & Uncut',
#   'Scrooged',
#   "Freddy's Dead: The Final Nightmare",
#   'Toys',
#   'Birth',
#   "Pete's Dragon",
#   'Puss in Boots',
#   'Doctor Dolittle',
#   'Black Mirror: Bandersnatch',
#   'Bubble',
#   'The Crow',
#   'Barbarian Queen',
#   'The Bye Bye Man',
#   'The Mortuary Collection',
#   'Inland Empire',
#   'Freaks Out',
#   'Dumbo',
#   '20,000 Leagues Under the Sea',
#   'The Nutcracker and the Four Realms',
#   'Mortal',
#   'Always',
#   'Needful Things',
#   'Considering Love and Other Magic',
#   'Stay Alive',
#   'Dave Made a Maze',
#   'Naked',
#   'The Phantom',
#   'Earwig',
#   'Supergirl',
#   'A Christmas Carol',
#   'Anastasia: Once Upon a Time',
#   'The Next Voice You Hear...',
#   'Ruby Sparks',
#   'Left Behind',
#   'Peter Rabbit 2: The Runaway',
#   'The Spirit',
#   'Wallace & Gromit: The Curse of the Were-Rabbit',
#   'Outside the Wire',
#   'The Indian in the Cupboard',
#   'Dracula: Dead and Loving It',
#   'The Heavenly Kid',
#   'The Gate',
#   'The Last Son',
#   "Vampire's Kiss",
#   'Abominable',
#   'More Than a Miracle',
#   'Fatman',
#   'Jonah Hex',
#   'Masters of the Universe',
#   'Journey to the Center of the Earth',
#   '*batteries not included',
#   'Arthur and the Invisibles',
#   'The Hungover Games',
#   'Tale of Tales',
#   'Lost River',
#   'Elio',
#   'Fallen',
#   'The Santa Clause 2',
#   'Song of the South',
#   'Penelope',
#   'Rubber',
#   'The Double Life of Véronique',
#   'Mortal Kombat 2',
#   'Darkness Falls',
#   'America: The Motion Picture',
#   'Pinocchio',
#   'Needle in a Timestack',
#   'Gnomeo & Juliet',
#   "Isn't It Romantic",
#   "My Hero Academia: World Heroes' Mission",
#   'Escape to Witch Mountain',
#   'The Pirates! Band of Misfits',
#   'Asterix & Obelix: Mission Cleopatra',
#   'Smurfs: The Lost Village',
#   'The Santa Clause 3: The Escape Clause',
#   'Osmosis Jones',
#   'I Am Dragon',
#   "Don't Be Afraid of the Dark",
#   'Mr. Peabody & Sherman',
#   'Dragonslayer',
#   'Tales from the Crypt: Demon Knight',
#   'Beauty and the Beast',
#   'Bulletproof Monk',
#   'The Mummy',
#   'Stay Tuned',
#   'Zookeeper',
#   'Double Dragon',
#   'Dead Snow',
#   'Michael',
#   'Ghosts, Italian Style',
#   "A Dog's Journey",
#   'Knights of the Zodiac',
#   'My Little Pony: The Movie',
#   'The Company of Wolves',
#   'A Dark Song',
#   'Thumbelina',
#   'Like Mike',
#   'Untitled Ghostbusters Afterlife Sequel',
#   'A Haunted House',
#   'The Lego Ninjago Movie',
#   'Goosebumps 2: Haunted Halloween',
#   'Along With the Gods: The Two Worlds',
#   'TMNT',
#   'Are We There Yet?',
#   'Troll 2',
#   'Strawberry Mansion',
#   'The Kid Who Would Be King',
#   'The Brave Little Toaster',
#   'The Cobbler',
#   'Sinbad: Legend of the Seven Seas',
#   'Boys of Summer',
#   'Night at the Museum: Kahmunrah Rises Again',
#   'Hereafter',
#   'Cronos',
#   "Don't Knock Twice",
#   'Solomon Kane',
#   '4 Horsemen: Apocalypse',
#   'Every Day',
#   'Pieles',
#   'Arabian Nights',
#   'La Belle Époque',
#   'Blithe Spirit',
#   'Look Away',
#   'The One and Only Ivan',
#   'The Little Prince',
#   'Ernest Scared Stupid',
#   'The Old Ways',
#   'Underworld: Awakening',
#   'The Cat Returns',
#   'Gaia',
#   'The Tale of The Princess Kaguya',
#   'The SpongeBob Movie: Sponge Out of Water',
#   "Bill & Ted's Bogus Journey",
#   'Space Sweepers',
#   'Herbie Fully Loaded',
#   'Over the Moon',
#   'Ghoulies',
#   'Underground',
#   'The Prodigy',
#   'Long Story Short',
#   'Howl',
#   'Abbott and Costello Meet Frankenstein',
#   'The City of Lost Children',
#   'Porco Rosso',
#   'Bordello of Blood',
#   'Premonition',
#   'Cat People',
#   "Gulliver's Travels",
#   'Carousel',
#   'The Hudsucker Proxy',
#   'The Lost World',
#   'Alvin and the Chipmunks: The Road Chip',
#   "Mr. Popper's Penguins",
#   "Legend of the Guardians: The Owls of Ga'Hoole",
#   'Quest for Camelot',
#   'Spy Kids 4: All the Time in the World',
#   'Night of the Demons',
#   'Tales from Earthsea',
#   'Blaze',
#   'Ninja Scroll',
#   'A Christmas Carol',
#   'Storks',
#   'Phenomenon',
#   'White Snake',
#   'The Happytime Murders',
#   'The Zero Theorem',
#   'Candy',
#   'The Clan of the Cave Bear',
#   'Iké Boys',
#   'Ghost Town',
#   'Winchester',
#   'Wish Upon',
#   'Planet 51',
#   'Deathstalker',
#   'Om Shanti Om',
#   'Attack on Titan Part 1',
#   'Alvin and the Chipmunks: The Squeakquel',
#   'Star Wars: Rogue Squadron',
#   'Song of the Sea',
#   'Alvin and the Chipmunks: Chipwrecked',
#   "Cirque du Freak: The Vampire's Assistant",
#   'The Swan Princess',
#   'Dampyr',
#   "Mr. Magorium's Wonder Emporium",
#   'In Fabric',
#   'Nanny McPhee Returns',
#   'L.A. Story',
#   'The Toxic Avenger',
#   'The Secret Garden',
#   'The Hunchback of Notre Dame',
#   'Evil Toons',
#   'Inu-oh',
#   'The Beast',
#   "Winter's Tale",
#   'The Water Horse',
#   'Hercules',
#   'The Little Mermaid',
#   'Heaven Can Wait',
#   'Dagon',
#   'UglyDolls',
#   'Stuart Little 2',
#   'The Hole',
#   'Bring It On: Cheer or Die',
#   'Dr. Dolittle 2',
#   'Strange Magic',
#   'John Dies at the End',
#   'Bewitched',
#   'The Night Flier',
#   ...],
#  'IMDB ID': ['tt10648342',
#   'tt4593060',
#   'tt1630029',
#   'tt9198364',
#   'tt5971474',
#   'tt6710474',
#   'tt14813212',
#   'tt11909878',
#   'tt0499549',
#   'tt0120737',
#   'tt0107120',
#   'tt6443346',
#   'tt5500218',
#   'tt14900738',
#   'tt11138512',
#   'tt10872600',
#   'tt1245492',
#   'tt8912936',
#   'tt6277462',
#   'tt0360486',
#   'tt1517268',
#   'tt9419884',
#   'tt8760670',
#   'tt0167260',
#   'tt13314558',
#   'tt10298840',
#   'tt0241527',
#   'tt1071873',
#   'tt0167261',
#   'tt0903624',
#   'tt4513678',
#   'tt13841850',
#   'tt14331144',
#   'tt4468740',
#   'tt14614892',
#   'tt1109624',
#   'tt9032400',
#   'tt1596342',
#   'tt1538403',
#   'tt4263482',
#   'tt0094721',
#   'tt3501632',
#   'tt4123432',
#   'tt0120616',
#   'tt15494038',
#   'tt1170358',
#   'tt1488589',
#   'tt0103874',
#   'tt6264654',
#   'tt0120689',
#   'tt0096446',
#   'tt2953050',
#   'tt0076759',
#   'tt0032910',
#   'tt0267913',
#   'tt7214954',
#   'tt1386697',
#   'tt0093779',
#   'tt14668630',
#   'tt1034415',
#   'tt1099212',
#   'tt0325980',
#   'tt0097757',
#   'tt0087332',
#   'tt12361974',
#   'tt0800369',
#   'tt0110148',
#   'tt4633694',
#   'tt12412888',
#   'tt2310332',
#   'tt6208148',
#   'tt2194499',
#   'tt2935622',
#   'tt1686821',
#   'tt6166392',
#   'tt1655441',
#   'tt0120791',
#   'tt0107688',
#   'tt5606664',
#   'tt0451279',
#   'tt20969586',
#   'tt0245429',
#   'tt2771200',
#   'tt0119643',
#   'tt0382932',
#   'tt9376612',
#   'tt6139732',
#   'tt9288046',
#   'tt0088323',
#   'tt2380307',
#   'tt0461770',
#   'tt0457430',
#   'tt6718170',
#   'tt0295297',
#   'tt0330373',
#   'tt3521164',
#   'tt0327597',
#   'tt1972591',
#   'tt1201607',
#   'tt4028464',
#   'tt5635026',
#   'tt2527338',
#   'tt1262426',
#   'tt0338526',
#   'tt1661199',
#   'tt11703050',
#   'tt8097030',
#   'tt0117008',
#   'tt0037793',
#   'tt0120915',
#   'tt1098327',
#   'tt5580390',
#   'tt7984734',
#   'tt7349950',
#   'tt0304141',
#   'tt2096673',
#   'tt9484998',
#   'tt0032138',
#   'tt0101272',
#   'tt0120655',
#   'tt1477834',
#   'tt0293429',
#   'tt0114709',
#   'tt0926084',
#   'tt1735898',
#   'tt0800320',
#   'tt0448115',
#   'tt0363771',
#   'tt0112642',
#   'tt1014759',
#   'tt0974015',
#   'tt2283362',
#   'tt0347149',
#   'tt0126029',
#   'tt0446029',
#   'tt0099487',
#   'tt0486655',
#   'tt3954936',
#   'tt13623880',
#   'tt1212419',
#   'tt0104029',
#   'tt3622110',
#   'tt0970452',
#   'tt19766560',
#   'tt7026672',
#   'tt5808778',
#   'tt0071502',
#   'tt9172422',
#   'tt10334148',
#   'tt5834760',
#   'tt3661394',
#   'tt1754656',
#   'tt0101821',
#   'tt12829958',
#   'tt1496025',
#   'tt0347618',
#   'tt11881160',
#   'tt2576852',
#   'tt2279373',
#   'tt0101452',
#   'tt12838766',
#   'tt0400497',
#   'tt7488208',
#   'tt0089200',
#   'tt0114787',
#   'tt4504044',
#   'tt10896634',
#   'tt2393827',
#   'tt0040068',
#   'tt0112682',
#   'tt0104652',
#   'tt0117826',
#   'tt0477071',
#   'tt0034587',
#   'tt1320261',
#   'tt0049055',
#   'tt0110074',
#   'tt0054038',
#   'tt2974918',
#   'tt1396218',
#   'tt1219342',
#   'tt0120800',
#   'tt1517489',
#   'tt1268809',
#   'tt0495596',
#   'tt11018264',
#   'tt0107692',
#   'tt0044008',
#   'tt4624424',
#   'tt0117333',
#   'tt9288776',
#   'tt1308728',
#   'tt2333804',
#   'tt0062776',
#   'tt0090848',
#   'tt11348164',
#   'tt0995039',
#   'tt1072748',
#   'tt5322012',
#   'tt0762125',
#   'tt0087127',
#   'tt1024943',
#   'tt2072230',
#   'tt1231580',
#   'tt10300394',
#   'tt1865505',
#   'tt1615918',
#   'tt0450405',
#   'tt0111333',
#   'tt10315050',
#   'tt0457419',
#   'tt7464188',
#   'tt1415283',
#   'tt0102250',
#   'tt1633359',
#   'tt2702920',
#   'tt9613354',
#   'tt0099524',
#   'tt10540510',
#   'tt0072752',
#   'tt1837709',
#   'tt0760329',
#   'tt21068738',
#   'tt0070326',
#   'tt0077663',
#   'tt0264508',
#   'tt1946502',
#   'tt0243585',
#   'tt1085779',
#   'tt20101986',
#   'tt0240462',
#   'tt4191054',
#   'tt1783732',
#   'tt0374536',
#   'tt0119784',
#   ...],
#  'Year of Release': ['2022',
#   'I) (',
#   '2022',
#   '2022',
#   '2023',
#   '2022',
#   '2022',
#   '2022',
#   '2009',
#   '2001',
#   '1993',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2021',
#   '2013',
#   '2022',
#   '2022',
#   '2005',
#   '2023',
#   '2022',
#   '2021',
#   '2003',
#   '2022',
#   '2022',
#   '2001',
#   '',
#   '2002',
#   '2012',
#   '2021',
#   '2022',
#   '2021',
#   '2017',
#   '2022',
#   '2014',
#   '2021',
#   '2022',
#   '2013',
#   '2015',
#   '1988',
#   '2017',
#   '2022',
#   '1999',
#   '2022',
#   '2013',
#   'II) ',
#   '1992',
#   '2021',
#   '1999',
#   '1988',
#   '2021',
#   '1977',
#   '1940',
#   '2002',
#   'I) (',
#   '2016',
#   '1987',
#   '2022',
#   'I) (',
#   'I) (',
#   '2003',
#   '1989',
#   '1984',
#   '2021',
#   '2011',
#   '1994',
#   '2018',
#   '2022',
#   '2014',
#   '2024',
#   'I) (',
#   '2022',
#   '2014',
#   '2023',
#   '2015',
#   '1998',
#   '1993',
#   '2019',
#   '2017',
#   '2024',
#   '2001',
#   'I) (',
#   '1998',
#   '2007',
#   '2021',
#   '2019',
#   '2022',
#   '1984',
#   'I) (',
#   '2007',
#   '2006',
#   '2023',
#   '2002',
#   '2005',
#   'I) (',
#   '2009',
#   '2017',
#   '2011',
#   '2021',
#   '2023',
#   '2019',
#   '2024',
#   '2004',
#   'I) (',
#   'III)',
#   '2022',
#   '1996',
#   '1945',
#   '1999',
#   '2009',
#   '2017',
#   'I) (',
#   '2019',
#   '2004',
#   'I) (',
#   '2020',
#   '1939',
#   '1991',
#   '1999',
#   '2018',
#   '2021',
#   '1995',
#   '2010',
#   '2012',
#   '2010',
#   '2019',
#   '2005',
#   '1995',
#   'I) (',
#   '2017',
#   '2017',
#   '2004',
#   '2001',
#   '2010',
#   '1990',
#   '2007',
#   'I) (',
#   '2016',
#   '2017',
#   'I) (',
#   '2023',
#   '2021',
#   '1986',
#   '2010',
#   '2005',
#   '2001',
#   'I) (',
#   '2013',
#   '2020',
#   '1991',
#   '2016',
#   '2021',
#   '1986',
#   '2016',
#   '1980',
#   '2021',
#   '2016',
#   '1996',
#   '2017',
#   '2000',
#   '2023',
#   '2023',
#   '2007',
#   '2016',
#   '2023',
#   '2020',
#   '2005',
#   '2011',
#   '2019',
#   '2021',
#   '2023',
#   '',
#   '2010',
#   '2009',
#   '1999',
#   '1983',
#   '1992',
#   '2003',
#   '2013',
#   '1997',
#   '2001',
#   '2006',
#   '2020',
#   '1985',
#   '2018',
#   '2017',
#   '2016',
#   '2009',
#   'III)',
#   '1994',
#   'I) (',
#   '2001',
#   '2018',
#   '1994',
#   '2011',
#   '2019',
#   '2021',
#   '1975',
#   '2000',
#   '',
#   '2023',
#   '2020',
#   '1992',
#   '1971',
#   '1995',
#   '2006',
#   'I) (',
#   '1993',
#   '2008',
#   '1995',
#   '2016',
#   '2017',
#   '1990',
#   '2023',
#   '1984',
#   '2016',
#   '1988',
#   '1998',
#   '2021',
#   '2022',
#   '2023',
#   '1985',
#   '1982',
#   '1946',
#   '2002',
#   '2021',
#   '2011',
#   '2011',
#   '2004',
#   '2012',
#   '2005',
#   '2022',
#   '2010',
#   '2011',
#   '2019',
#   '2024',
#   '1986',
#   '2020',
#   '2023',
#   '2008',
#   '2008',
#   '2017',
#   '2009',
#   '2009',
#   'I) (',
#   '2019',
#   '2022',
#   '2023',
#   '2011',
#   '2007',
#   '2008',
#   '2001',
#   '2012',
#   '2016',
#   'I) (',
#   '2020',
#   '1985',
#   '1991',
#   '2016',
#   '2016',
#   '1993',
#   '2007',
#   '2006',
#   '2014',
#   '2016',
#   '1988',
#   '2021',
#   '1964',
#   '2010',
#   '2003',
#   '2014',
#   '1992',
#   '1997',
#   '1968',
#   '1973',
#   '2012',
#   '1998',
#   '2007',
#   '2000',
#   '2010',
#   '2022',
#   '2021',
#   '2004',
#   '1998',
#   '2015',
#   '1993',
#   '2009',
#   '2000',
#   'I) (',
#   'I) (',
#   '2003',
#   '1997',
#   '2009',
#   '2004',
#   '1978',
#   '2006',
#   '2012',
#   'I) (',
#   '2017',
#   '2019',
#   '2018',
#   '2003',
#   '2022',
#   '2016',
#   '2016',
#   '2012',
#   'I) (',
#   '2002',
#   'I) (',
#   '2019',
#   '2011',
#   '1988',
#   '2019',
#   '2011',
#   'I) (',
#   '1981',
#   '1993',
#   '2009',
#   '2021',
#   '1989',
#   '1997',
#   '2016',
#   '2002',
#   '2006',
#   '2008',
#   '1983',
#   '1988',
#   '2017',
#   '2017',
#   '2010',
#   '2007',
#   '2020',
#   '2003',
#   '1998',
#   '1989',
#   '2007',
#   '2011',
#   'I) (',
#   'I) (',
#   '2010',
#   '1993',
#   '2004',
#   '2022',
#   '2013',
#   '2013',
#   '1989',
#   '2018',
#   '2001',
#   '1995',
#   '2019',
#   '2014',
#   '2014',
#   '2010',
#   '2012',
#   '2018',
#   '1999',
#   '2010',
#   '1999',
#   '1937',
#   '1987',
#   '2011',
#   '2019',
#   '1991',
#   '2022',
#   '2022',
#   'I) (',
#   '1996',
#   '2021',
#   '2001',
#   '2014',
#   '2002',
#   '1977',
#   '2011',
#   '2009',
#   '2002',
#   '1922',
#   '1967',
#   '2000',
#   '2009',
#   '2003',
#   '2015',
#   '2007',
#   '2019',
#   '1990',
#   '2003',
#   'I) (',
#   '1995',
#   'I) (',
#   '1999',
#   '2019',
#   '2013',
#   '2005',
#   '1996',
#   '2007',
#   '2013',
#   '1989',
#   '1992',
#   '1990',
#   '2009',
#   '2012',
#   '2018',
#   '1985',
#   '2018',
#   '2007',
#   '2008',
#   '1987',
#   '2020',
#   '2003',
#   '1998',
#   '2024',
#   '2010',
#   '2012',
#   '1992',
#   '2018',
#   '2011',
#   '2013',
#   '1996',
#   '2007',
#   '2013',
#   'I) (',
#   '1981',
#   '1999',
#   '2022',
#   '2006',
#   '2017',
#   'I) (',
#   '2018',
#   '2022',
#   '2017',
#   '2013',
#   '2018',
#   '2021',
#   '2006',
#   '1993',
#   '2013',
#   '2022',
#   '2004',
#   '1987',
#   '2021',
#   '2008',
#   '1994',
#   '2021',
#   'I) (',
#   '1950',
#   '2004',
#   '2014',
#   '2000',
#   '2002',
#   '2021',
#   '2000',
#   '2021',
#   '2024',
#   '1982',
#   '2000',
#   '2013',
#   '2007',
#   'I) (',
#   '1953',
#   '2013',
#   '2024',
#   '2017',
#   '1940',
#   '2012',
#   '1981',
#   '2022',
#   '1951',
#   '2006',
#   '1957',
#   '2015',
#   '2019',
#   '2003',
#   '2021',
#   '2004',
#   '2021',
#   '2022',
#   '2021',
#   '2007',
#   '2022',
#   '1993',
#   '2008',
#   '1992',
#   '2022',
#   '2012',
#   '2020',
#   '2006',
#   '1987',
#   '1994',
#   'II) ',
#   '1983',
#   '2009',
#   '2002',
#   '2016',
#   '2017',
#   '1984',
#   '1985',
#   '2008',
#   '2015',
#   '2006',
#   'I) (',
#   '2019',
#   '2020',
#   '2016',
#   '2000',
#   '1959',
#   '2022',
#   '2008',
#   '2015',
#   '2015',
#   '',
#   '2025',
#   'II) ',
#   '1998',
#   '2016',
#   '2004',
#   '2023',
#   '2009',
#   '2023',
#   '2008',
#   '1996',
#   '1996',
#   '1994',
#   '2021',
#   '1999',
#   '2021',
#   '2022',
#   '2005',
#   '1990',
#   '1989',
#   '2015',
#   '2016',
#   '2023',
#   '1987',
#   'I) (',
#   '2018',
#   '2001',
#   '1999',
#   'II) ',
#   '2004',
#   '2019',
#   '2007',
#   '2016',
#   '2014',
#   '1999',
#   'I) (',
#   '1998',
#   '2014',
#   '2018',
#   '2005',
#   '1986',
#   '2009',
#   '2022',
#   '2022',
#   '1968',
#   '2017',
#   '1980',
#   '1931',
#   '1994',
#   '2006',
#   '1982',
#   '1993',
#   '',
#   '2000',
#   '2009',
#   '2005',
#   '1993',
#   '2008',
#   '2009',
#   '2023',
#   '2018',
#   '2017',
#   '2021',
#   '2019',
#   '1982',
#   '2010',
#   '2013',
#   '2018',
#   '2018',
#   '2014',
#   '2011',
#   '2009',
#   '2003',
#   '1980',
#   '2000',
#   '2015',
#   '2018',
#   '2020',
#   '2012',
#   '2022',
#   '2021',
#   '2021',
#   '2021',
#   '2018',
#   '2024',
#   '1981',
#   '2011',
#   '2014',
#   '2022',
#   'I) (',
#   '1937',
#   '2016',
#   '2022',
#   '2019',
#   '2016',
#   '1983',
#   '2006',
#   '2018',
#   '1999',
#   '1982',
#   '2006',
#   '2000',
#   '2021',
#   '2006',
#   '1982',
#   '2004',
#   '2011',
#   '2017',
#   '1992',
#   '2008',
#   '2022',
#   '1991',
#   '1998',
#   '1987',
#   '1985',
#   '2020',
#   '1994',
#   '2013',
#   '2005',
#   '1988',
#   '2007',
#   '1985',
#   '1977',
#   '1943',
#   '1990',
#   '2021',
#   '1980',
#   '2009',
#   '2001',
#   '1995',
#   '1963',
#   '2015',
#   '2009',
#   '2018',
#   '1987',
#   '2012',
#   '1991',
#   '2009',
#   '2019',
#   '2014',
#   '2011',
#   '2023',
#   '1986',
#   '2018',
#   '2021',
#   '2002',
#   '1994',
#   '2020',
#   '1997',
#   '1991',
#   '1995',
#   '2010',
#   '1985',
#   '2002',
#   '2005',
#   '2012',
#   '2001',
#   '2012',
#   '1989',
#   '1982',
#   '1998',
#   '2008',
#   '1997',
#   '2015',
#   '1996',
#   '2008',
#   '2021',
#   '1989',
#   '2018',
#   '1988',
#   '2018',
#   '2014',
#   '1983',
#   '1987',
#   '2005',
#   '2004',
#   '2008',
#   '2012',
#   '1963',
#   '2020',
#   '2022',
#   '2001',
#   'I) (',
#   '2022',
#   '1978',
#   '2014',
#   '1977',
#   '2008',
#   '1989',
#   '2013',
#   '2017',
#   '2010',
#   '2016',
#   '2011',
#   'I)',
#   '1996',
#   '2000',
#   '2020',
#   '1990',
#   '1985',
#   '2009',
#   '2002',
#   '2004',
#   '2022',
#   '2021',
#   '1974',
#   '1983',
#   '2021',
#   '1992',
#   '2023',
#   '2019',
#   '2005',
#   '2006',
#   '2006',
#   '1992',
#   '2006',
#   '2024',
#   '2003',
#   'II) ',
#   '1997',
#   '2013',
#   '1971',
#   '2011',
#   'I) (',
#   '2002',
#   '2018',
#   '1997',
#   '1997',
#   '2010',
#   '2001',
#   '2011',
#   '2019',
#   '1988',
#   '2022',
#   '2009',
#   '1988',
#   '2012',
#   '2006',
#   '2000',
#   '2016',
#   '2011',
#   '1987',
#   '2001',
#   '2020',
#   '',
#   '1966',
#   '2014',
#   '2020',
#   '2017',
#   '2022',
#   '1994',
#   '1982',
#   '2015',
#   '2021',
#   '2020',
#   '1986',
#   '2011',
#   '2002',
#   '2020',
#   '1996',
#   '2009',
#   '2012',
#   '1993',
#   '2019',
#   '1982',
#   '2021',
#   '2018',
#   '2014',
#   '2022',
#   '1974',
#   '1982',
#   '2023',
#   '2022',
#   'I) (',
#   '2005',
#   '2007',
#   '1999',
#   '2016',
#   '2009',
#   '2019',
#   '1989',
#   '2020',
#   '2018',
#   '1999',
#   '1988',
#   '1991',
#   '1992',
#   '2004',
#   '1977',
#   '2011',
#   '1998',
#   '2018',
#   '2022',
#   '',
#   '1985',
#   '2017',
#   '2019',
#   '2006',
#   '2021',
#   '1941',
#   '1954',
#   '2018',
#   'I) (',
#   '1989',
#   '1993',
#   '2016',
#   '2006',
#   '2017',
#   'I) (',
#   '1996',
#   '2021',
#   '1984',
#   '2009',
#   '2020',
#   '1950',
#   '2012',
#   'I) (',
#   '2021',
#   '2008',
#   '2005',
#   '2021',
#   '1995',
#   '1995',
#   '1985',
#   '1987',
#   '2021',
#   '1988',
#   '2019',
#   '1967',
#   '2020',
#   '2010',
#   '2024',
#   '1959',
#   '1987',
#   '2006',
#   '2014',
#   '2015',
#   '2014',
#   '2024',
#   'II) ',
#   '2002',
#   '1946',
#   '2006',
#   '2010',
#   '1991',
#   '',
#   '2003',
#   '2021',
#   '2002',
#   '2021',
#   '2011',
#   '2019',
#   '2021',
#   '1975',
#   '2012',
#   '2002',
#   '2017',
#   '2006',
#   '2001',
#   '2015',
#   '2010',
#   '2014',
#   '1981',
#   '1995',
#   '2014',
#   '2003',
#   '1932',
#   '1992',
#   '2011',
#   '1994',
#   '2009',
#   '1996',
#   '1967',
#   '2019',
#   '2023',
#   '2017',
#   '1984',
#   '2016',
#   '1994',
#   '2002',
#   '2023',
#   '2013',
#   '2017',
#   '2018',
#   '2017',
#   '2007',
#   '2005',
#   '1990',
#   '2021',
#   '2019',
#   '1987',
#   '2014',
#   '2003',
#   '2022',
#   '2022',
#   '2010',
#   '1993',
#   '2016',
#   '2009',
#   '2022',
#   '2018',
#   '2017',
#   '1974',
#   '2019',
#   '2020',
#   '2018',
#   '2020',
#   '2015',
#   '1991',
#   'II) ',
#   '2012',
#   '2002',
#   '2021',
#   '2013',
#   '2015',
#   '1991',
#   '2021',
#   '2005',
#   '2020',
#   '1985',
#   '1995',
#   '2019',
#   '2021',
#   'I) (',
#   '1948',
#   '1995',
#   '1992',
#   '1996',
#   'I) (',
#   '1942',
#   '2010',
#   '1956',
#   '1994',
#   '1960',
#   '2015',
#   '2011',
#   '2010',
EyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/S/sash/NapCxx-VwSOJtCZ.png',
#   'https://m.media-amazon.com/images/M/MV5BNGRmZDI0ZTItZGE1Yy00YmQ3LTgxNmQtMzM3Nzc3M2UwZmYzXkEyXkFqcGdeQXVyNjQ2MjQ5NzM@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTk5MDA1ZTQtMGZlMi00OTJmLThlZjEtMjNlZmFkYWRiNmY5XkEyXkFqcGdeQXVyMTY3OTcwMzk@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMjkzODE4MjMzM15BMl5BanBnXkFtZTgwMDQ1MzQ1MzE@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BYTFmZDgwMDctYWI2ZS00MDhmLTg1ZDAtMGUzZjVmZTM3ZTM5XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTc1MjcxMjg5OV5BMl5BanBnXkFtZTcwNDE1NzYzMw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/S/sash/NapCxx-VwSOJtCZ.png',
#   'https://m.media-amazon.com/images/M/MV5BZjI0MTk4NmQtOGE2Mi00ZjZmLThkMjktNWY4OTE2NjU4YzcxXkEyXkFqcGdeQXVyNzMwOTY2NTI@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BN2NlOGI1YTMtZjk3My00YWY4LWE2ZGUtNzA2Y2E1ZjU0ZTZmXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BY2NjNWM0Y2UtNzZmZi00ODBjLTgzNGEtMjEyMGM5NTVmM2ZiXkEyXkFqcGdeQXVyOTY0NzE2NTU@._V1_UY98_CR1,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTc0NjE2ODM2OV5BMl5BanBnXkFtZTgwMjQyNDUzNzM@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTYyNDg0Njc2Nl5BMl5BanBnXkFtZTYwMDc3NzQ3._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTQxMzA2NTE1M15BMl5BanBnXkFtZTcwNjc5OTUzOA@@._V1_UY98_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BYmJhOTA2N2MtYzg2NC00MmNhLTgxZWItYzU5ZDJiMmQ2NDM1XkEyXkFqcGdeQXVyMTAxMTM4NzU@._V1_UY98_CR6,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BYTZhMWZkYjgtNjE5MS00OWY4LWFmMWQtMDc4M2RlMjg4Y2NhXkEyXkFqcGdeQXVyNTUyMzE4Mzg@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMjA0NjU3MTU5OF5BMl5BanBnXkFtZTgwMTYyMDQ3MzE@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTUyNzIyNzc0MV5BMl5BanBnXkFtZTcwOTM5ODg1OA@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BNmNmYzJhODQtZWEyMS00NzUyLWFmYTAtZjYzMDNlNWU3NzVjXkEyXkFqcGdeQXVyNTUyMzE4Mzg@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMWM0OTY1YWItYTY2ZC00MzVhLTliM2ItNzJiMzIxMDJhMDI3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY98_CR0,0,67,98_AL_.jpg',
#   ...]}

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df.head()
# Out:
#                         Movie Name     IMDB ID Year of Release Watch Time  \
# 0           Thor: Love and Thunder  tt10648342            2022    118 min
# 1                        Pinocchio   tt4593060            I) (    105 min
# 2         Avatar: The Way of Water   tt1630029            2022       None
# 3  Three Thousand Years of Longing   tt9198364            2022    108 min
# 4               The Little Mermaid   tt5971474            2023       None
#
#   Movie Rating                                  Genres  \
# 0          6.4   Action, Adventure, Comedy
# 1          5.1    Adventure, Comedy, Drama
# 2         None  Action, Adventure, Fantasy
# 3          6.8     Drama, Fantasy, Romance
# 4         None  Adventure, Family, Fantasy
#
#                                          Description         Director  \
# 0  Thor enlists the help of Valkyrie, Korg and ex...    Taika Waititi
# 1  A puppet is brought to life by a fairy, who as...  Robert Zemeckis
# 2  Jake Sully lives with his newfound family form...    James Cameron
# 3  A lonely scholar, on a trip to Istanbul, disco...    George Miller
# 4  A young mermaid makes a deal with a sea witch,...     Rob Marshall
#
#                                  Cast  \
# 0  (Chris Hemsworth, Natalie Portman)
# 1   (Joseph Gordon-Levitt, Tom Hanks)
# 2         (Zoe Saldana, Kate Winslet)
# 3         (Tilda Swinton, Idris Elba)
# 4    (Halle Bailey, Jonah Hauer-King)
#
#                                           IMDB Image
# 0  https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1  https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 2  https://m.media-amazon.com/images/M/MV5BMWFmYm...
# 3  https://m.media-amazon.com/images/M/MV5BODFjMm...
# 4  https://m.media-amazon.com/images/M/MV5BZWUxOG...

# %%
df['IMDB Image']
# Out:
# 0       https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1       https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 2       https://m.media-amazon.com/images/M/MV5BMWFmYm...
# 3       https://m.media-amazon.com/images/M/MV5BODFjMm...
# 4       https://m.media-amazon.com/images/M/MV5BZWUxOG...
#                               ...
# 9995    https://m.media-amazon.com/images/S/sash/NapCx...
# 9996    https://m.media-amazon.com/images/M/MV5BZjY4MG...
# 9997    https://m.media-amazon.com/images/M/MV5BMjA5Nj...
# 9998    https://m.media-amazon.com/images/M/MV5BZGIxYz...
# 9999    https://m.media-amazon.com/images/S/sash/NapCx...
# Name: IMDB Image, Length: 10000, dtype: object

# %%
df.shape
# Out:
# (10000, 10)

# %%
df['Movie Name'].value_counts()
# Out:
# Pinocchio                11
# Sleeping Beauty          11
# Cinderella                9
# Beauty and the Beast      9
# Alice in Wonderland       8
#                          ..
# Princess Arete            1
# Identity Theft            1
# Entwined                  1
# Morpheus                  1
# Histoires abominables     1
# Name: Movie Name, Length: 9633, dtype: int64

# %%
df.tail()
# Out:
#                       Movie Name     IMDB ID Year of Release Watch Time  \
# 9995  A Matter of Life and Death  tt10456134                       None
# 9996            13 Weird Stories   tt4666242            2015    123 min
# 9997                   Hasenherz   tt0093151            1987     78 min
# 9998                      Astral   tt2087689            2010    120 min
# 9999       Histoires abominables  tt15022852            1979     78 min
#
#      Movie Rating                                  Genres  \
# 9995         None                     Fantasy
# 9996          5.6     Comedy, Fantasy, Horror
# 9997          7.2  Adventure, Family, Fantasy
# 9998          6.5                     Fantasy
# 9999         None                     Fantasy
#
#                                             Description            Director  \
# 9995  A firefighting pilot survives bailing out of h...                None
# 9996  In this anthology of horror episodes, 13 bizar...    Petter Baiestorf
# 9997  The thirteen year old Janni is depressed, beca...    Gunter Friedrich
# 9998                                         Add a Plot      Enrique Olvera
# 9999                                         Add a Plot  Patrick Bokanowski
#
#                                           Cast  \
# 9995                                      None
# 9996      (Paulo Biscaia Filho, Cláudia Borba)
# 9997  (Volkmar Kleinert, Mario von Jascheroff)
# 9998           (Soufiane Astea, Javier Espejo)
# 9999                     (Henry Colomer, Gébé)
#
#                                              IMDB Image
# 9995  https://m.media-amazon.com/images/S/sash/NapCx...
# 9996  https://m.media-amazon.com/images/M/MV5BZjY4MG...
# 9997  https://m.media-amazon.com/images/M/MV5BMjA5Nj...
# 9998  https://m.media-amazon.com/images/M/MV5BZGIxYz...
# 9999  https://m.media-amazon.com/images/S/sash/NapCx...

# %%
df = df.dropna()
df
# Out:
#                              Movie Name     IMDB ID Year of Release  \
# 0                Thor: Love and Thunder  tt10648342            2022
# 1                             Pinocchio   tt4593060            I) (
# 3       Three Thousand Years of Longing   tt9198364            2022
# 5     Everything Everywhere All at Once   tt6710474            2022
# 6                          The Munsters  tt14813212            2022
# ...                                 ...         ...             ...
# 9992                   The barrio kings   tt0338910            1985
# 9993                      Dormir al sol   tt0417610            2010
# 9996                   13 Weird Stories   tt4666242            2015
# 9997                          Hasenherz   tt0093151            1987
# 9998                             Astral   tt2087689            2010
#
#      Watch Time Movie Rating                                  Genres  \
# 0       118 min          6.4   Action, Adventure, Comedy
# 1       105 min          5.1    Adventure, Comedy, Drama
# 3       108 min          6.8     Drama, Fantasy, Romance
# 5       139 min          8.1   Action, Adventure, Comedy
# 6       109 min          4.1     Comedy, Family, Fantasy
# ...         ...          ...                                     ...
# 9992     93 min          6.9      Comedy, Drama, Fantasy
# 9993     83 min          6.3                     Fantasy
# 9996    123 min          5.6     Comedy, Fantasy, Horror
# 9997     78 min          7.2  Adventure, Family, Fantasy
# 9998    120 min          6.5                     Fantasy
#
#                                             Description           Director  \
# 0     Thor enlists the help of Valkyrie, Korg and ex...      Taika Waititi
# 1     A puppet is brought to life by a fairy, who as...    Robert Zemeckis
# 3     A lonely scholar, on a trip to Istanbul, disco...      George Miller
# 5     An aging Chinese immigrant is swept up in an i...           Dan Kwan
# 6     Reboot of "The Munsters", that followed a fami...         Rob Zombie
# ...                                                 ...                ...
# 9992  Teen angst in Mexico City is made all the wors...      Gerardo Pardo
# 9993  Lucio Bordenave carries on the Grey lifestyle ...  Alejandro Chomski
# 9996  In this anthology of horror episodes, 13 bizar...   Petter Baiestorf
# 9997  The thirteen year old Janni is depressed, beca...   Gunter Friedrich
# 9998                                         Add a Plot     Enrique Olvera
#
#                                           Cast  \
# 0           (Chris Hemsworth, Natalie Portman)
# 1            (Joseph Gordon-Levitt, Tom Hanks)
# 3                  (Tilda Swinton, Idris Elba)
# 5            (Daniel Scheinert, Michelle Yeoh)
# 6      (Cassandra Peterson, Sheri Moon Zombie)
# ...                                        ...
# 9992          (Lucy Reina, Gerardo de la Peña)
# 9993               (Luis Machín, Esther Goris)
# 9996      (Paulo Biscaia Filho, Cláudia Borba)
# 9997  (Volkmar Kleinert, Mario von Jascheroff)
# 9998           (Soufiane Astea, Javier Espejo)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1     https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 3     https://m.media-amazon.com/images/M/MV5BODFjMm...
# 5     https://m.media-amazon.com/images/M/MV5BYTdiOT...
# 6     https://m.media-amazon.com/images/M/MV5BYmYyYW...
# ...                                                 ...
# 9992  https://m.media-amazon.com/images/M/MV5BNTcwNW...
# 9993  https://m.media-amazon.com/images/M/MV5BMTc4OT...
# 9996  https://m.media-amazon.com/images/M/MV5BZjY4MG...
# 9997  https://m.media-amazon.com/images/M/MV5BMjA5Nj...
# 9998  https://m.media-amazon.com/images/M/MV5BZGIxYz...
#
# [7887 rows x 10 columns]

# %%
df.sort_values("Movie Name", inplace=True)
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 2970                       $9.99  tt0790799            2008     78 min
# 8602                'Til Morning  tt2777190            2013     57 min
# 842      *batteries not included  tt0092494            1987    106 min
# 6046                   ...Almost  tt0098959            1990     84 min
# 8458         ...a zase ta Lucie!  tt0086833            1984     82 min
# ...                          ...        ...             ...        ...
# 6192                  È già ieri  tt0374358            2004     90 min
# 7239      Ének a csodaszarvasról  tt0309114            2002     89 min
# 6692                    Ésimésac  tt2458582            2012    104 min
# 7241  Üç süpermen olimpiyatlarda  tt0310292            1984     65 min
# 8589                  Üçüncü Göz  tt0304982            1988     90 min
#
#      Movie Rating                                   Genres  \
# 2970          6.7    Animation, Drama, Fantasy
# 8602          7.2       Drama, Family, Fantasy
# 842           6.6      Comedy, Family, Fantasy
# 6046          5.2      Drama, Fantasy, Romance
# 8458          6.4      Comedy, Family, Fantasy
# ...           ...                                      ...
# 6192          6.5              Comedy, Fantasy
# 7239          6.8  Animation, Fantasy, History
# 6692          6.0   Adventure, Fantasy, Sci-Fi
# 7241          3.0   Action, Adventure, Fantasy
# 8589          6.5               Drama, Fantasy
#
#                                             Description            Director  \
# 2970  A stop-motion animated story about people livi...     Tatia Rosenthal
# 8602  A dark modern twist on the Peter Pan legend, '...       Brendan Russo
# 842   Aliens help a feisty old New York couple in th...     Matthew Robbins
# 6046  Romantic comedy that mixes magical realism wit...   Michael Pattinson
# 8458  Osvald, stripped of the honor of being the lea...      Jindrich Polák
# ...                                                 ...                 ...
# 6192  Filippo (Antonio Albanese) is a star on the It...  Giulio Manfredonia
# 7239  Divided into four sections, "Song" is inspired...   Marcell Jankovics
# 6692  The residents of Saint-Élie-de-Caxton have bar...          Luc Picard
# 7241   Three supermen go to Olympics and mayhem ensues.    Yavuz Yalinkiliç
# 8589  A writer who begins to believe in his script i...          Orhan Oguz
#
#                                      Cast  \
# 2970    (Geoffrey Rush, Anthony LaPaglia)
# 8602       (Juliette Danielle, Nick Feld)
# 842          (Hume Cronyn, Jessica Tandy)
# 6046     (Rosanna Arquette, Bruce Spence)
# 8458  (Zaneta Fuchsová, Jirina Bohdalová)
# ...                                   ...
# 6192   (Antonio Albanese, Fabio De Luigi)
# 7239       (Árpád Besenczi, Ildikó Bokor)
# 6692    (Nicola-Frank Vachon, Gildor Roy)
# 7241   (Italo Martinenghi, Cavit Yürüklü)
# 8589           (Tarik Akan, Meral Konrat)
#
#                                              IMDB Image
# 2970  https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 8602  https://m.media-amazon.com/images/M/MV5BOWU1Yj...
# 842   https://m.media-amazon.com/images/M/MV5BM2JlMD...
# 6046  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 8458  https://m.media-amazon.com/images/M/MV5BOTA0MD...
# ...                                                 ...
# 6192  https://m.media-amazon.com/images/M/MV5BMjUwNz...
# 7239  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 6692  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 7241  https://m.media-amazon.com/images/M/MV5BOTcxMT...
# 8589  https://m.media-amazon.com/images/M/MV5BMDg1N2...
#
# [7887 rows x 10 columns]

# %%
df['Movie Name'].value_counts()
# Out:
# Sleeping Beauty                          10
# Pinocchio                                10
# Beauty and the Beast                      9
# Alice in Wonderland                       7
# Cinderella                                7
#                                          ..
# Hou wang da zhan tian bing tian jiang     1
# Hotel Transylvania: Transformania         1
# Hotel Transylvania 3: Summer Vacation     1
# Hotel Transylvania 2                      1
# Üçüncü Göz                                1
# Name: Movie Name, Length: 7645, dtype: int64

# %%
df = df.drop_duplicates(subset=['IMDB ID'])
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 2970                       $9.99  tt0790799            2008     78 min
# 8602                'Til Morning  tt2777190            2013     57 min
# 842      *batteries not included  tt0092494            1987    106 min
# 6046                   ...Almost  tt0098959            1990     84 min
# 8458         ...a zase ta Lucie!  tt0086833            1984     82 min
# ...                          ...        ...             ...        ...
# 6192                  È già ieri  tt0374358            2004     90 min
# 7239      Ének a csodaszarvasról  tt0309114            2002     89 min
# 6692                    Ésimésac  tt2458582            2012    104 min
# 7241  Üç süpermen olimpiyatlarda  tt0310292            1984     65 min
# 8589                  Üçüncü Göz  tt0304982            1988     90 min
#
#      Movie Rating                                   Genres  \
# 2970          6.7    Animation, Drama, Fantasy
# 8602          7.2       Drama, Family, Fantasy
# 842           6.6      Comedy, Family, Fantasy
# 6046          5.2      Drama, Fantasy, Romance
# 8458          6.4      Comedy, Family, Fantasy
# ...           ...                                      ...
# 6192          6.5              Comedy, Fantasy
# 7239          6.8  Animation, Fantasy, History
# 6692          6.0   Adventure, Fantasy, Sci-Fi
# 7241          3.0   Action, Adventure, Fantasy
# 8589          6.5               Drama, Fantasy
#
#                                             Description            Director  \
# 2970  A stop-motion animated story about people livi...     Tatia Rosenthal
# 8602  A dark modern twist on the Peter Pan legend, '...       Brendan Russo
# 842   Aliens help a feisty old New York couple in th...     Matthew Robbins
# 6046  Romantic comedy that mixes magical realism wit...   Michael Pattinson
# 8458  Osvald, stripped of the honor of being the lea...      Jindrich Polák
# ...                                                 ...                 ...
# 6192  Filippo (Antonio Albanese) is a star on the It...  Giulio Manfredonia
# 7239  Divided into four sections, "Song" is inspired...   Marcell Jankovics
# 6692  The residents of Saint-Élie-de-Caxton have bar...          Luc Picard
# 7241   Three supermen go to Olympics and mayhem ensues.    Yavuz Yalinkiliç
# 8589  A writer who begins to believe in his script i...          Orhan Oguz
#
#                                      Cast  \
# 2970    (Geoffrey Rush, Anthony LaPaglia)
# 8602       (Juliette Danielle, Nick Feld)
# 842          (Hume Cronyn, Jessica Tandy)
# 6046     (Rosanna Arquette, Bruce Spence)
# 8458  (Zaneta Fuchsová, Jirina Bohdalová)
# ...                                   ...
# 6192   (Antonio Albanese, Fabio De Luigi)
# 7239       (Árpád Besenczi, Ildikó Bokor)
# 6692    (Nicola-Frank Vachon, Gildor Roy)
# 7241   (Italo Martinenghi, Cavit Yürüklü)
# 8589           (Tarik Akan, Meral Konrat)
#
#                                              IMDB Image
# 2970  https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 8602  https://m.media-amazon.com/images/M/MV5BOWU1Yj...
# 842   https://m.media-amazon.com/images/M/MV5BM2JlMD...
# 6046  https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 8458  https://m.media-amazon.com/images/M/MV5BOTA0MD...
# ...                                                 ...
# 6192  https://m.media-amazon.com/images/M/MV5BMjUwNz...
# 7239  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 6692  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 7241  https://m.media-amazon.com/images/M/MV5BOTcxMT...
# 8589  https://m.media-amazon.com/images/M/MV5BMDg1N2...
#
# [7887 rows x 10 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 0                          $9.99  tt0790799            2008     78 min
# 1                   'Til Morning  tt2777190            2013     57 min
# 2        *batteries not included  tt0092494            1987    106 min
# 3                      ...Almost  tt0098959            1990     84 min
# 4            ...a zase ta Lucie!  tt0086833            1984     82 min
# ...                          ...        ...             ...        ...
# 7882                  È già ieri  tt0374358            2004     90 min
# 7883      Ének a csodaszarvasról  tt0309114            2002     89 min
# 7884                    Ésimésac  tt2458582            2012    104 min
# 7885  Üç süpermen olimpiyatlarda  tt0310292            1984     65 min
# 7886                  Üçüncü Göz  tt0304982            1988     90 min
#
#      Movie Rating                                   Genres  \
# 0             6.7    Animation, Drama, Fantasy
# 1             7.2       Drama, Family, Fantasy
# 2             6.6      Comedy, Family, Fantasy
# 3             5.2      Drama, Fantasy, Romance
# 4             6.4      Comedy, Family, Fantasy
# ...           ...                                      ...
# 7882          6.5              Comedy, Fantasy
# 7883          6.8  Animation, Fantasy, History
# 7884          6.0   Adventure, Fantasy, Sci-Fi
# 7885          3.0   Action, Adventure, Fantasy
# 7886          6.5               Drama, Fantasy
#
#                                             Description            Director  \
# 0     A stop-motion animated story about people livi...     Tatia Rosenthal
# 1     A dark modern twist on the Peter Pan legend, '...       Brendan Russo
# 2     Aliens help a feisty old New York couple in th...     Matthew Robbins
# 3     Romantic comedy that mixes magical realism wit...   Michael Pattinson
# 4     Osvald, stripped of the honor of being the lea...      Jindrich Polák
# ...                                                 ...                 ...
# 7882  Filippo (Antonio Albanese) is a star on the It...  Giulio Manfredonia
# 7883  Divided into four sections, "Song" is inspired...   Marcell Jankovics
# 7884  The residents of Saint-Élie-de-Caxton have bar...          Luc Picard
# 7885   Three supermen go to Olympics and mayhem ensues.    Yavuz Yalinkiliç
# 7886  A writer who begins to believe in his script i...          Orhan Oguz
#
#                                      Cast  \
# 0       (Geoffrey Rush, Anthony LaPaglia)
# 1          (Juliette Danielle, Nick Feld)
# 2            (Hume Cronyn, Jessica Tandy)
# 3        (Rosanna Arquette, Bruce Spence)
# 4     (Zaneta Fuchsová, Jirina Bohdalová)
# ...                                   ...
# 7882   (Antonio Albanese, Fabio De Luigi)
# 7883       (Árpád Besenczi, Ildikó Bokor)
# 7884    (Nicola-Frank Vachon, Gildor Roy)
# 7885   (Italo Martinenghi, Cavit Yürüklü)
# 7886           (Tarik Akan, Meral Konrat)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 1     https://m.media-amazon.com/images/M/MV5BOWU1Yj...
# 2     https://m.media-amazon.com/images/M/MV5BM2JlMD...
# 3     https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 4     https://m.media-amazon.com/images/M/MV5BOTA0MD...
# ...                                                 ...
# 7882  https://m.media-amazon.com/images/M/MV5BMjUwNz...
# 7883  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 7884  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 7885  https://m.media-amazon.com/images/M/MV5BOTcxMT...
# 7886  https://m.media-amazon.com/images/M/MV5BMDg1N2...
#
# [7887 rows x 10 columns]

# %%
df
# Out:
#                       Movie Name    IMDB ID Year of Release Watch Time  \
# 0                          $9.99  tt0790799            2008     78 min
# 1                   'Til Morning  tt2777190            2013     57 min
# 2        *batteries not included  tt0092494            1987    106 min
# 3                      ...Almost  tt0098959            1990     84 min
# 4            ...a zase ta Lucie!  tt0086833            1984     82 min
# ...                          ...        ...             ...        ...
# 7882                  È già ieri  tt0374358            2004     90 min
# 7883      Ének a csodaszarvasról  tt0309114            2002     89 min
# 7884                    Ésimésac  tt2458582            2012    104 min
# 7885  Üç süpermen olimpiyatlarda  tt0310292            1984     65 min
# 7886                  Üçüncü Göz  tt0304982            1988     90 min
#
#      Movie Rating                                   Genres  \
# 0             6.7    Animation, Drama, Fantasy
# 1             7.2       Drama, Family, Fantasy
# 2             6.6      Comedy, Family, Fantasy
# 3             5.2      Drama, Fantasy, Romance
# 4             6.4      Comedy, Family, Fantasy
# ...           ...                                      ...
# 7882          6.5              Comedy, Fantasy
# 7883          6.8  Animation, Fantasy, History
# 7884          6.0   Adventure, Fantasy, Sci-Fi
# 7885          3.0   Action, Adventure, Fantasy
# 7886          6.5               Drama, Fantasy
#
#                                             Description            Director  \
# 0     A stop-motion animated story about people livi...     Tatia Rosenthal
# 1     A dark modern twist on the Peter Pan legend, '...       Brendan Russo
# 2     Aliens help a feisty old New York couple in th...     Matthew Robbins
# 3     Romantic comedy that mixes magical realism wit...   Michael Pattinson
# 4     Osvald, stripped of the honor of being the lea...      Jindrich Polák
# ...                                                 ...                 ...
# 7882  Filippo (Antonio Albanese) is a star on the It...  Giulio Manfredonia
# 7883  Divided into four sections, "Song" is inspired...   Marcell Jankovics
# 7884  The residents of Saint-Élie-de-Caxton have bar...          Luc Picard
# 7885   Three supermen go to Olympics and mayhem ensues.    Yavuz Yalinkiliç
# 7886  A writer who begins to believe in his script i...          Orhan Oguz
#
#                                      Cast  \
# 0       (Geoffrey Rush, Anthony LaPaglia)
# 1          (Juliette Danielle, Nick Feld)
# 2            (Hume Cronyn, Jessica Tandy)
# 3        (Rosanna Arquette, Bruce Spence)
# 4     (Zaneta Fuchsová, Jirina Bohdalová)
# ...                                   ...
# 7882   (Antonio Albanese, Fabio De Luigi)
# 7883       (Árpád Besenczi, Ildikó Bokor)
# 7884    (Nicola-Frank Vachon, Gildor Roy)
# 7885   (Italo Martinenghi, Cavit Yürüklü)
# 7886           (Tarik Akan, Meral Konrat)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BMTMwNz...
# 1     https://m.media-amazon.com/images/M/MV5BOWU1Yj...
# 2     https://m.media-amazon.com/images/M/MV5BM2JlMD...
# 3     https://m.media-amazon.com/images/M/MV5BMjE3ND...
# 4     https://m.media-amazon.com/images/M/MV5BOTA0MD...
# ...                                                 ...
# 7882  https://m.media-amazon.com/images/M/MV5BMjUwNz...
# 7883  https://m.media-amazon.com/images/M/MV5BNzc2Y2...
# 7884  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 7885  https://m.media-amazon.com/images/M/MV5BOTcxMT...
# 7886  https://m.media-amazon.com/images/M/MV5BMDg1N2...
#
# [7887 rows x 10 columns]

# %%
df.to_csv('fantasy.csv')

# %%
df[df['Movie Name'] == 'Sleeping Beauty']
# Out:
#            Movie Name    IMDB ID Year of Release Watch Time Movie Rating  \
# 5404  Sleeping Beauty  tt0121641            1949     99 min          6.4
# 5405  Sleeping Beauty  tt0048010            1955     82 min          6.9
# 5406  Sleeping Beauty  tt0330236            1917     64 min          5.8
# 5407  Sleeping Beauty  tt0067012            1971     71 min          5.9
# 5408  Sleeping Beauty  tt0053285            1959     75 min          7.2
# 5409  Sleeping Beauty  tt5078202            2016     82 min          6.0
# 5410  Sleeping Beauty  tt0100626            1990     94 min          6.2
# 5411  Sleeping Beauty  tt3343136            II)      89 min          2.8
# 5412  Sleeping Beauty  tt3334390            I) (     88 min          3.5
# 5413  Sleeping Beauty  tt0093993            1987     90 min          5.7
#
#                                         Genres  \
# 5404      Family, Fantasy, Romance
# 5405      Family, Fantasy, Musical
# 5406               Family, Fantasy
# 5407               Family, Fantasy
# 5408  Animation, Adventure, Family
# 5409        Comedy, Drama, Fantasy
# 5410            Adventure, Fantasy
# 5411    Adventure, Fantasy, Horror
# 5412      Action, Adventure, Drama
# 5413      Family, Fantasy, Musical
#
#                                             Description            Director  \
# 5404                                         Add a Plot         Edvin Laine
# 5405  A fairy tale classic that is faithful to the f...      Fritz Genschow
# 5406                                         Add a Plot           Paul Leni
# 5407  The King and Queen plan an opulent feast to ce...         Walter Beck
# 5408  After being snubbed by the royal family, a mal...           Les Clark
# 5409  In the Kingdom of Letonia, Prince Egon has onl...      Adolfo Arrieta
# 5410                                         Add a Plot  Stanislav Párnicky
# 5411  When a young Prince and his trusted aid learn ...     Casper Van Dien
# 5412  The beautiful Aurora is cursed into everlastin...          Rene Perez
# 5413  Feature-length, live-action musical version of...        David Irving
#
#                                     Cast  \
# 5404        (Aarne Laine, Mirjam Novero)
# 5405       (Karin Hardt, Fritz Genschow)
# 5406         (Mabel Kaul, Harry Liedtke)
# 5407   (Juliane Korén, Vera Oelschlegel)
# 5408       (Clyde Geronimi, Eric Larson)
# 5409  (Niels Schneider, Agathe Bonitzer)
# 5410      (Dana Dinková, Jozef Adamovic)
# 5411        (Finn Jones, Grace Van Dien)
# 5412     (Jenny Allford, Robert Amstler)
# 5413         (Tahnee Welch, Kenny Baker)
#
#                                              IMDB Image
# 5404  https://m.media-amazon.com/images/M/MV5BZTFjYW...
# 5405  https://m.media-amazon.com/images/M/MV5BNmE3Nj...
# 5406  https://m.media-amazon.com/images/M/MV5BN2RkZm...
# 5407  https://m.media-amazon.com/images/M/MV5BNzA0MD...
# 5408  https://m.media-amazon.com/images/M/MV5BOTJmZj...
# 5409  https://m.media-amazon.com/images/M/MV5BNjNjMD...
# 5410  https://m.media-amazon.com/images/M/MV5BMTU1Mz...
# 5411  https://m.media-amazon.com/images/M/MV5BNDc3Mz...
# 5412  https://m.media-amazon.com/images/M/MV5BNTA3NT...
# 5413  https://m.media-amazon.com/images/M/MV5BNzA0Mz...

# %%
pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=action&after=WzEwODQwOSwidHQwMzA1ODMxIiwxMDY1MV0%3D&explore=genres&ref_=adv_nxt")
soup = BeautifulSoup(pag.text, 'html.parser')
movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
sleep(randint(2,8))
for store in movie_data:
  name = store.find('h3', class_= 'lister-item-header').find('a').text
  movie_name.append(name)

  release = store.find('h3', class_= 'lister-item-header')
  try:
    year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
    year.append(year_of_release)
  except:
    year.append(None)

  try: 
     runtime = store.p.find('span', class_ = 'runtime').text[0:7]
     time.append(runtime)
  except:
      time.append(None)

  rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
  try:
      ratings = (rate.find('strong').text)
      rating.append(ratings)
  except:
       rating.append(None)

  genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
  genres.append(genre)

  describe = store.find_all('p', class_ = 'text-muted')
  description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
  description.append(description_)
            
  try:
    direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
    director.append(direct)
  except:
    director.append(None)

  try:
      cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
      casts.append(cast)
  except:
      casts.append(None)

  try:
      image = store.find('img')
      imge = image['loadlate']
      images.append(imge)  
  except:
       images.append(None)

  numbers = store.find('img')
  num = numbers['data-tconst'][:]
  try:
    number.append(num)
  except:
    number.append(None)
