# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/Action_movie_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = np.arange(1,25000,50)

#the whole core of the script
for page in pages:
    page = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=action&sort=alpha,asc&start="+str(page)+"&explore=genres&ref_=adv_nxt")
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            year_of_release = store.h3.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
            year.append(year_of_release)

            
            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)

# %%
a = { "Movie Name": movie_name, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts}

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df.head()
# Out:
#              Movie Name Year of Release Watch Time Movie Rating  \
# 0                   #66            2015    116 min          5.7
# 1  #FightClub Blood Out                       None         None
# 2           #Santa4Real                       None         None
# 3                #Alive            2020     98 min          6.3
# 4          #Selfieparty            2016     90 min          5.2
#
#                                   Genres  \
# 0                     Action
# 1              Action, Drama
# 2  Action, Adventure, Comedy
# 3      Action, Drama, Horror
# 4   Action, Comedy, Thriller
#
#                                          Description           Director  \
# 0  66 tells the story of an assassin-for-hire, wh...       Asun Mawardi
# 1                                         Add a Plot       Romane Simon
# 2  3 best friends go on an adventure to prove tha...           Ben Deka
# 3  The rapid spread of an unknown infection has l...             Il Cho
# 4  Four friends who are all students, wake up at ...  Lyubomyr Levytsky
#
#                                 Cast
# 0  (Ari Riski Ananda, Erwin Bagindo)
# 1         (Luis Moncada, Blac Chyna)
# 2                               None
# 3         (Yoo Ah-in, Park Shin-Hye)
# 4    (Sergei Zorenko, Boris Savenko)

# %%
df.to_csv('Test.csv')

# %%
df.tail()
# Out:
#                          Movie Name Year of Release Watch Time Movie Rating  \
# 24993       .9999 (Four Nines Fine)                       None         None
# 24994           .hack//G.U. Trilogy            2007     93 min          5.4
# 24995  Oh! Those Most Secret Agents            1964     83 min          5.6
# 24996                     006 kaçis            2014       None          4.0
# 24997                009 Re: Cyborg            2012    103 min          5.8
#
#                                          Genres  \
# 24993                        Action
# 24994  Animation, Action, Adventure
# 24995                Action, Comedy
# 24996                Action, Comedy
# 24997     Animation, Action, Sci-Fi
#
#                                              Description           Director  \
# 24993  Five billion dollars in gold is missing from a...               None
# 24994  After one of his friends falls into a coma pla...  Hiroshi Matsuyama
# 24995  Franco and Ciccio are two simple-minded Italia...        Lucio Fulci
# 24996                                         Add a Plot     Ferhat Alpözen
# 24997  All over the world, ordinary people are commit...     Kenji Kamiyama
#
#                                      Cast
# 24993                                None
# 24994  (Takahiro Sakurai, Ayako Kawasumi)
# 24995  (Franco Franchi, Ciccio Ingrassia)
# 24996  (Ismail Nadir Bilgili, Furat Emir)
# 24997          (Chiwa Saitô, Daisuke Ono)

# %%
df = df.dropna()
df
# Out:
#                                Movie Name Year of Release Watch Time  \
# 0                                     #66            2015    116 min
# 3                                  #Alive            2020     98 min
# 4                            #Selfieparty            2016     90 min
# 6                               #Victoria            2018    119 min
# 9      $50K and a Call Girl: A Love Story            2014     90 min
# ...                                   ...             ...        ...
# 24991                                .357            2013     97 min
# 24992                         .357 Magnum            1977     71 min
# 24994                 .hack//G.U. Trilogy            2007     93 min
# 24995        Oh! Those Most Secret Agents            1964     83 min
# 24997                      009 Re: Cyborg            2012    103 min
#
#       Movie Rating                                    Genres  \
# 0              5.7                        Action
# 3              6.3         Action, Drama, Horror
# 4              5.2      Action, Comedy, Thriller
# 6              4.3       Action, Drama, Thriller
# 9              6.8     Action, Adventure, Comedy
# ...            ...                                       ...
# 24991          5.0                 Action, Drama
# 24992          4.4                 Action, Drama
# 24994          5.4  Animation, Action, Adventure
# 24995          5.6                Action, Comedy
# 24997          5.8     Animation, Action, Sci-Fi
#
#                                              Description            Director  \
# 0      66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 3      The rapid spread of an unknown infection has l...              Il Cho
# 4      Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 6      Victoria moves from out of town into the poor ...  Mark K. Buddington
# 9      When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                  ...                 ...
# 24991  On her wedding night, Jade wakes up holding th...         Brian Skiba
# 24992  Agent Jonathan Hightower's weapon of chose is ...        Nick Millard
# 24994  After one of his friends falls into a coma pla...   Hiroshi Matsuyama
# 24995  Franco and Ciccio are two simple-minded Italia...         Lucio Fulci
# 24997  All over the world, ordinary people are commit...      Kenji Kamiyama
#
#                                       Cast
# 0        (Ari Riski Ananda, Erwin Bagindo)
# 3               (Yoo Ah-in, Park Shin-Hye)
# 4          (Sergei Zorenko, Boris Savenko)
# 6      (Jason Barkley, Mark K. Buddington)
# 9         (Ross Patterson, Jessie Wiseman)
# ...                                    ...
# 24991       (Laurie Love, Fred Williamson)
# 24992            (Gary Boyd, Silvi Walter)
# 24994   (Takahiro Sakurai, Ayako Kawasumi)
# 24995   (Franco Franchi, Ciccio Ingrassia)
# 24997           (Chiwa Saitô, Daisuke Ono)
#
# [15378 rows x 8 columns]

# %%
df.sort_values("Movie Name", inplace=False)
df
# Out:
#                                Movie Name Year of Release Watch Time  \
# 0                                     #66            2015    116 min
# 3                                  #Alive            2020     98 min
# 4                            #Selfieparty            2016     90 min
# 6                               #Victoria            2018    119 min
# 9      $50K and a Call Girl: A Love Story            2014     90 min
# ...                                   ...             ...        ...
# 24991                                .357            2013     97 min
# 24992                         .357 Magnum            1977     71 min
# 24994                 .hack//G.U. Trilogy            2007     93 min
# 24995        Oh! Those Most Secret Agents            1964     83 min
# 24997                      009 Re: Cyborg            2012    103 min
#
#       Movie Rating                                    Genres  \
# 0              5.7                        Action
# 3              6.3         Action, Drama, Horror
# 4              5.2      Action, Comedy, Thriller
# 6              4.3       Action, Drama, Thriller
# 9              6.8     Action, Adventure, Comedy
# ...            ...                                       ...
# 24991          5.0                 Action, Drama
# 24992          4.4                 Action, Drama
# 24994          5.4  Animation, Action, Adventure
# 24995          5.6                Action, Comedy
# 24997          5.8     Animation, Action, Sci-Fi
#
#                                              Description            Director  \
# 0      66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 3      The rapid spread of an unknown infection has l...              Il Cho
# 4      Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 6      Victoria moves from out of town into the poor ...  Mark K. Buddington
# 9      When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                  ...                 ...
# 24991  On her wedding night, Jade wakes up holding th...         Brian Skiba
# 24992  Agent Jonathan Hightower's weapon of chose is ...        Nick Millard
# 24994  After one of his friends falls into a coma pla...   Hiroshi Matsuyama
# 24995  Franco and Ciccio are two simple-minded Italia...         Lucio Fulci
# 24997  All over the world, ordinary people are commit...      Kenji Kamiyama
#
#                                       Cast
# 0        (Ari Riski Ananda, Erwin Bagindo)
# 3               (Yoo Ah-in, Park Shin-Hye)
# 4          (Sergei Zorenko, Boris Savenko)
# 6      (Jason Barkley, Mark K. Buddington)
# 9         (Ross Patterson, Jessie Wiseman)
# ...                                    ...
# 24991       (Laurie Love, Fred Williamson)
# 24992            (Gary Boyd, Silvi Walter)
# 24994   (Takahiro Sakurai, Ayako Kawasumi)
# 24995   (Franco Franchi, Ciccio Ingrassia)
# 24997           (Chiwa Saitô, Daisuke Ono)
#
# [15378 rows x 8 columns]

# %%
df = df.drop_duplicates(subset='Movie Name')
df
# Out:
#                               Movie Name Year of Release Watch Time  \
# 0                                    #66            2015    116 min
# 3                                 #Alive            2020     98 min
# 4                           #Selfieparty            2016     90 min
# 6                              #Victoria            2018    119 min
# 9     $50K and a Call Girl: A Love Story            2014     90 min
# ...                                  ...             ...        ...
# 9990                        Danger Close            2019    118 min
# 9991                         Danger Diva            2020    105 min
# 9993                       Danger Island            1931    220 min
# 9994                          Danger One            2018    101 min
# 9996                       Danger Patrol            1937     59 min
#
#      Movie Rating                                  Genres  \
# 0             5.7                      Action
# 3             6.3       Action, Drama, Horror
# 4             5.2    Action, Comedy, Thriller
# 6             4.3     Action, Drama, Thriller
# 9             6.8   Action, Adventure, Comedy
# ...           ...                                     ...
# 9990          6.8          Action, Drama, War
# 9991          8.4    Action, Sci-Fi, Thriller
# 9993          5.8  Action, Adventure, Romance
# 9994          6.0       Action, Comedy, Crime
# 9996          5.5      Action, Drama, Romance
#
#                                             Description            Director  \
# 0     66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 3     The rapid spread of an unknown infection has l...              Il Cho
# 4     Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 6     Victoria moves from out of town into the poor ...  Mark K. Buddington
# 9     When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                 ...                 ...
# 9990  In August 1966, in a Vietnamese rubber plantat...       Kriv Stenders
# 9991  DANGER DIVA is a cyberpunk musical/thriller ab...     Robert McGinley
# 9993  The daughter of a man who has discovered radiu...          Ray Taylor
# 9994  While transporting a dying man to the hospital...           Tom Oesch
# 9996  A romance drama involving people who transport...         Lew Landers
#
#                                      Cast
# 0       (Ari Riski Ananda, Erwin Bagindo)
# 3              (Yoo Ah-in, Park Shin-Hye)
# 4         (Sergei Zorenko, Boris Savenko)
# 6     (Jason Barkley, Mark K. Buddington)
# 9        (Ross Patterson, Jessie Wiseman)
# ...                                   ...
# 9990          (Travis Fimmel, Toby Blome)
# 9991            (Molly Sides, Mike Dooly)
# 9993      (Kenneth Harlan, Lucile Browne)
# 9994     (Tom Everett Scott, James Jurdi)
# 9996            (Sally Eilers, John Beal)
#
# [4679 rows x 8 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                               Movie Name Year of Release Watch Time  \
# 0                                    #66            2015    116 min
# 1                                 #Alive            2020     98 min
# 2                           #Selfieparty            2016     90 min
# 3                              #Victoria            2018    119 min
# 4     $50K and a Call Girl: A Love Story            2014     90 min
# ...                                  ...             ...        ...
# 4674                        Danger Close            2019    118 min
# 4675                         Danger Diva            2020    105 min
# 4676                       Danger Island            1931    220 min
# 4677                          Danger One            2018    101 min
# 4678                       Danger Patrol            1937     59 min
#
#      Movie Rating                                  Genres  \
# 0             5.7                      Action
# 1             6.3       Action, Drama, Horror
# 2             5.2    Action, Comedy, Thriller
# 3             4.3     Action, Drama, Thriller
# 4             6.8   Action, Adventure, Comedy
# ...           ...                                     ...
# 4674          6.8          Action, Drama, War
# 4675          8.4    Action, Sci-Fi, Thriller
# 4676          5.8  Action, Adventure, Romance
# 4677          6.0       Action, Comedy, Crime
# 4678          5.5      Action, Drama, Romance
#
#                                             Description            Director  \
# 0     66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1     The rapid spread of an unknown infection has l...              Il Cho
# 2     Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3     Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4     When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                 ...                 ...
# 4674  In August 1966, in a Vietnamese rubber plantat...       Kriv Stenders
# 4675  DANGER DIVA is a cyberpunk musical/thriller ab...     Robert McGinley
# 4676  The daughter of a man who has discovered radiu...          Ray Taylor
# 4677  While transporting a dying man to the hospital...           Tom Oesch
# 4678  A romance drama involving people who transport...         Lew Landers
#
#                                      Cast
# 0       (Ari Riski Ananda, Erwin Bagindo)
# 1              (Yoo Ah-in, Park Shin-Hye)
# 2         (Sergei Zorenko, Boris Savenko)
# 3     (Jason Barkley, Mark K. Buddington)
# 4        (Ross Patterson, Jessie Wiseman)
# ...                                   ...
# 4674          (Travis Fimmel, Toby Blome)
# 4675            (Molly Sides, Mike Dooly)
# 4676      (Kenneth Harlan, Lucile Browne)
# 4677     (Tom Everett Scott, James Jurdi)
# 4678            (Sally Eilers, John Beal)
#
# [4679 rows x 8 columns]

# %%
df.to_csv('movies.csv')

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = np.arange(25000,51390,50)

#the whole core of the script
for page in pages:
    page = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=action&sort=alpha,asc&start="+str(page)+"&explore=genres&ref_=adv_nxt")
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            year_of_release = store.h3.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
            year.append(year_of_release)

            
            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)

# %%
b = { "Movie Name": movie_name, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts}

# %%
df1 = pd.DataFrame.from_dict(b, orient='index')
df1 = df1.transpose()
df1.head()
# Out:
#              Movie Name Year of Release Watch Time Movie Rating  \
# 0                   #66            2015    116 min          5.7
# 1  #FightClub Blood Out                       None         None
# 2           #Santa4Real                       None         None
# 3                #Alive            2020     98 min          6.3
# 4          #Selfieparty            2016     90 min          5.2
#
#                                   Genres  \
# 0                     Action
# 1              Action, Drama
# 2  Action, Adventure, Comedy
# 3      Action, Drama, Horror
# 4   Action, Comedy, Thriller
#
#                                          Description           Director  \
# 0  66 tells the story of an assassin-for-hire, wh...       Asun Mawardi
# 1                                         Add a Plot       Romane Simon
# 2  3 best friends go on an adventure to prove tha...           Ben Deka
# 3  The rapid spread of an unknown infection has l...             Il Cho
# 4  Four friends who are all students, wake up at ...  Lyubomyr Levytsky
#
#                                 Cast
# 0  (Ari Riski Ananda, Erwin Bagindo)
# 1         (Luis Moncada, Blac Chyna)
# 2                               None
# 3         (Yoo Ah-in, Park Shin-Hye)
# 4    (Sergei Zorenko, Boris Savenko)

# %%
df = df.append(df1,ignore_index=True)

# %%
df
# Out:
#                                Movie Name Year of Release Watch Time  \
# 0                                     #66            2015    116 min
# 1                                  #Alive            2020     98 min
# 2                            #Selfieparty            2016     90 min
# 3                               #Victoria            2018    119 min
# 4      $50K and a Call Girl: A Love Story            2014     90 min
# ...                                   ...             ...        ...
# 56072             .9999 (Four Nines Fine)                       None
# 56073                 .hack//G.U. Trilogy            2007     93 min
# 56074        Oh! Those Most Secret Agents            1964     83 min
# 56075                           006 kaçis            2014       None
# 56076                      009 Re: Cyborg            2012    103 min
#
#       Movie Rating                                    Genres  \
# 0              5.7                        Action
# 1              6.3         Action, Drama, Horror
# 2              5.2      Action, Comedy, Thriller
# 3              4.3       Action, Drama, Thriller
# 4              6.8     Action, Adventure, Comedy
# ...            ...                                       ...
# 56072         None                        Action
# 56073          5.4  Animation, Action, Adventure
# 56074          5.6                Action, Comedy
# 56075          4.0                Action, Comedy
# 56076          5.8     Animation, Action, Sci-Fi
#
#                                              Description            Director  \
# 0      66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1      The rapid spread of an unknown infection has l...              Il Cho
# 2      Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3      Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4      When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                  ...                 ...
# 56072  Five billion dollars in gold is missing from a...                None
# 56073  After one of his friends falls into a coma pla...   Hiroshi Matsuyama
# 56074  Franco and Ciccio are two simple-minded Italia...         Lucio Fulci
# 56075                                         Add a Plot      Ferhat Alpözen
# 56076  All over the world, ordinary people are commit...      Kenji Kamiyama
#
#                                       Cast
# 0        (Ari Riski Ananda, Erwin Bagindo)
# 1               (Yoo Ah-in, Park Shin-Hye)
# 2          (Sergei Zorenko, Boris Savenko)
# 3      (Jason Barkley, Mark K. Buddington)
# 4         (Ross Patterson, Jessie Wiseman)
# ...                                    ...
# 56072                                 None
# 56073   (Takahiro Sakurai, Ayako Kawasumi)
# 56074   (Franco Franchi, Ciccio Ingrassia)
# 56075   (Ismail Nadir Bilgili, Furat Emir)
# 56076           (Chiwa Saitô, Daisuke Ono)
#
# [56077 rows x 8 columns]

# %%
df.sort_values("Movie Name", inplace=False)
# Out:
#         Movie Name Year of Release Watch Time Movie Rating  \
# 0              #66            2015    116 min          5.7
# 39677          #66            2015    116 min          5.7
# 39727          #66            2015    116 min          5.7
# 39777          #66            2015    116 min          5.7
# 39827          #66            2015    116 min          5.7
# ...            ...             ...        ...          ...
# 18406      Z Storm            2014     92 min          5.3
# 39806      Z Storm            2014     92 min          5.3
# 16806      Z Storm            2014     92 min          5.3
# 54656      Z Storm            2014     92 min          5.3
# 9226   Zona Surena            2009     80 min         None
#
#                                  Genres  \
# 0                    Action
# 39677                Action
# 39727                Action
# 39777                Action
# 39827                Action
# ...                                 ...
# 18406         Action, Crime
# 39806         Action, Crime
# 16806         Action, Crime
# 54656         Action, Crime
# 9226   Action, Crime, Drama
#
#                                              Description  \
# 0      66 tells the story of an assassin-for-hire, wh...
# 39677  66 tells the story of an assassin-for-hire, wh...
# 39727  66 tells the story of an assassin-for-hire, wh...
# 39777  66 tells the story of an assassin-for-hire, wh...
# 39827  66 tells the story of an assassin-for-hire, wh...
# ...                                                  ...
# 18406  This is a story about the biggest financial fr...
# 39806  This is a story about the biggest financial fr...
# 16806  This is a story about the biggest financial fr...
# 54656  This is a story about the biggest financial fr...
# 9226   A small town in Texas, a group of gang members...
#
#                      Director                                         Cast
# 0                Asun Mawardi            (Ari Riski Ananda, Erwin Bagindo)
# 39677            Asun Mawardi            (Ari Riski Ananda, Erwin Bagindo)
# 39727            Asun Mawardi            (Ari Riski Ananda, Erwin Bagindo)
# 39777            Asun Mawardi            (Ari Riski Ananda, Erwin Bagindo)
# 39827            Asun Mawardi            (Ari Riski Ananda, Erwin Bagindo)
# ...                       ...                                          ...
# 18406               David Lam                     (Louis Koo, Ka-Tung Lam)
# 39806               David Lam                     (Louis Koo, Ka-Tung Lam)
# 16806               David Lam                     (Louis Koo, Ka-Tung Lam)
# 54656               David Lam                     (Louis Koo, Ka-Tung Lam)
# 9226   Luis Antonio Rodriguez  (Marcelino 'Dibujo' Torres, Ramiro Cavazos)
#
# [56077 rows x 8 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                Movie Name Year of Release Watch Time  \
# 0                                     #66            2015    116 min
# 1                                  #Alive            2020     98 min
# 2                            #Selfieparty            2016     90 min
# 3                               #Victoria            2018    119 min
# 4      $50K and a Call Girl: A Love Story            2014     90 min
# ...                                   ...             ...        ...
# 56070                                .357            2013     97 min
# 56071                         .357 Magnum            1977     71 min
# 56073                 .hack//G.U. Trilogy            2007     93 min
# 56074        Oh! Those Most Secret Agents            1964     83 min
# 56076                      009 Re: Cyborg            2012    103 min
#
#       Movie Rating                                    Genres  \
# 0              5.7                        Action
# 1              6.3         Action, Drama, Horror
# 2              5.2      Action, Comedy, Thriller
# 3              4.3       Action, Drama, Thriller
# 4              6.8     Action, Adventure, Comedy
# ...            ...                                       ...
# 56070          5.0                 Action, Drama
# 56071          4.4                 Action, Drama
# 56073          5.4  Animation, Action, Adventure
# 56074          5.6                Action, Comedy
# 56076          5.8     Animation, Action, Sci-Fi
#
#                                              Description            Director  \
# 0      66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1      The rapid spread of an unknown infection has l...              Il Cho
# 2      Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3      Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4      When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                  ...                 ...
# 56070  On her wedding night, Jade wakes up holding th...         Brian Skiba
# 56071  Agent Jonathan Hightower's weapon of chose is ...        Nick Millard
# 56073  After one of his friends falls into a coma pla...   Hiroshi Matsuyama
# 56074  Franco and Ciccio are two simple-minded Italia...         Lucio Fulci
# 56076  All over the world, ordinary people are commit...      Kenji Kamiyama
#
#                                       Cast
# 0        (Ari Riski Ananda, Erwin Bagindo)
# 1               (Yoo Ah-in, Park Shin-Hye)
# 2          (Sergei Zorenko, Boris Savenko)
# 3      (Jason Barkley, Mark K. Buddington)
# 4         (Ross Patterson, Jessie Wiseman)
# ...                                    ...
# 56070       (Laurie Love, Fred Williamson)
# 56071            (Gary Boyd, Silvi Walter)
# 56073   (Takahiro Sakurai, Ayako Kawasumi)
# 56074   (Franco Franchi, Ciccio Ingrassia)
# 56076           (Chiwa Saitô, Daisuke Ono)
#
# [38537 rows x 8 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                Movie Name Year of Release Watch Time  \
# 0                                     #66            2015    116 min
# 1                                  #Alive            2020     98 min
# 2                            #Selfieparty            2016     90 min
# 3                               #Victoria            2018    119 min
# 4      $50K and a Call Girl: A Love Story            2014     90 min
# ...                                   ...             ...        ...
# 38532                                .357            2013     97 min
# 38533                         .357 Magnum            1977     71 min
# 38534                 .hack//G.U. Trilogy            2007     93 min
# 38535        Oh! Those Most Secret Agents            1964     83 min
# 38536                      009 Re: Cyborg            2012    103 min
#
#       Movie Rating                                    Genres  \
# 0              5.7                        Action
# 1              6.3         Action, Drama, Horror
# 2              5.2      Action, Comedy, Thriller
# 3              4.3       Action, Drama, Thriller
# 4              6.8     Action, Adventure, Comedy
# ...            ...                                       ...
# 38532          5.0                 Action, Drama
# 38533          4.4                 Action, Drama
# 38534          5.4  Animation, Action, Adventure
# 38535          5.6                Action, Comedy
# 38536          5.8     Animation, Action, Sci-Fi
#
#                                              Description            Director  \
# 0      66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1      The rapid spread of an unknown infection has l...              Il Cho
# 2      Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3      Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4      When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                  ...                 ...
# 38532  On her wedding night, Jade wakes up holding th...         Brian Skiba
# 38533  Agent Jonathan Hightower's weapon of chose is ...        Nick Millard
# 38534  After one of his friends falls into a coma pla...   Hiroshi Matsuyama
# 38535  Franco and Ciccio are two simple-minded Italia...         Lucio Fulci
# 38536  All over the world, ordinary people are commit...      Kenji Kamiyama
#
#                                       Cast
# 0        (Ari Riski Ananda, Erwin Bagindo)
# 1               (Yoo Ah-in, Park Shin-Hye)
# 2          (Sergei Zorenko, Boris Savenko)
# 3      (Jason Barkley, Mark K. Buddington)
# 4         (Ross Patterson, Jessie Wiseman)
# ...                                    ...
# 38532       (Laurie Love, Fred Williamson)
# 38533            (Gary Boyd, Silvi Walter)
# 38534   (Takahiro Sakurai, Ayako Kawasumi)
# 38535   (Franco Franchi, Ciccio Ingrassia)
# 38536           (Chiwa Saitô, Daisuke Ono)
#
# [38537 rows x 8 columns]

# %%
df = df.drop_duplicates(subset='Movie Name')

# %%
df
# Out:
#                               Movie Name Year of Release Watch Time  \
# 0                                    #66            2015    116 min
# 1                                 #Alive            2020     98 min
# 2                           #Selfieparty            2016     90 min
# 3                              #Victoria            2018    119 min
# 4     $50K and a Call Girl: A Love Story            2014     90 min
# ...                                  ...             ...        ...
# 4674                        Danger Close            2019    118 min
# 4675                         Danger Diva            2020    105 min
# 4676                       Danger Island            1931    220 min
# 4677                          Danger One            2018    101 min
# 4678                       Danger Patrol            1937     59 min
#
#      Movie Rating                                  Genres  \
# 0             5.7                      Action
# 1             6.3       Action, Drama, Horror
# 2             5.2    Action, Comedy, Thriller
# 3             4.3     Action, Drama, Thriller
# 4             6.8   Action, Adventure, Comedy
# ...           ...                                     ...
# 4674          6.8          Action, Drama, War
# 4675          8.4    Action, Sci-Fi, Thriller
# 4676          5.8  Action, Adventure, Romance
# 4677          6.0       Action, Comedy, Crime
# 4678          5.5      Action, Drama, Romance
#
#                                             Description            Director  \
# 0     66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1     The rapid spread of an unknown infection has l...              Il Cho
# 2     Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3     Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4     When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                 ...                 ...
# 4674  In August 1966, in a Vietnamese rubber plantat...       Kriv Stenders
# 4675  DANGER DIVA is a cyberpunk musical/thriller ab...     Robert McGinley
# 4676  The daughter of a man who has discovered radiu...          Ray Taylor
# 4677  While transporting a dying man to the hospital...           Tom Oesch
# 4678  A romance drama involving people who transport...         Lew Landers
#
#                                      Cast
# 0       (Ari Riski Ananda, Erwin Bagindo)
# 1              (Yoo Ah-in, Park Shin-Hye)
# 2         (Sergei Zorenko, Boris Savenko)
# 3     (Jason Barkley, Mark K. Buddington)
# 4        (Ross Patterson, Jessie Wiseman)
# ...                                   ...
# 4674          (Travis Fimmel, Toby Blome)
# 4675            (Molly Sides, Mike Dooly)
# 4676      (Kenneth Harlan, Lucile Browne)
# 4677     (Tom Everett Scott, James Jurdi)
# 4678            (Sally Eilers, John Beal)
#
# [4679 rows x 8 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                               Movie Name Year of Release Watch Time  \
# 0                                    #66            2015    116 min
# 1                                 #Alive            2020     98 min
# 2                           #Selfieparty            2016     90 min
# 3                              #Victoria            2018    119 min
# 4     $50K and a Call Girl: A Love Story            2014     90 min
# ...                                  ...             ...        ...
# 4674                        Danger Close            2019    118 min
# 4675                         Danger Diva            2020    105 min
# 4676                       Danger Island            1931    220 min
# 4677                          Danger One            2018    101 min
# 4678                       Danger Patrol            1937     59 min
#
#      Movie Rating                                  Genres  \
# 0             5.7                      Action
# 1             6.3       Action, Drama, Horror
# 2             5.2    Action, Comedy, Thriller
# 3             4.3     Action, Drama, Thriller
# 4             6.8   Action, Adventure, Comedy
# ...           ...                                     ...
# 4674          6.8          Action, Drama, War
# 4675          8.4    Action, Sci-Fi, Thriller
# 4676          5.8  Action, Adventure, Romance
# 4677          6.0       Action, Comedy, Crime
# 4678          5.5      Action, Drama, Romance
#
#                                             Description            Director  \
# 0     66 tells the story of an assassin-for-hire, wh...        Asun Mawardi
# 1     The rapid spread of an unknown infection has l...              Il Cho
# 2     Four friends who are all students, wake up at ...   Lyubomyr Levytsky
# 3     Victoria moves from out of town into the poor ...  Mark K. Buddington
# 4     When Ross is diagnosed with terminal brain can...       Seth Grossman
# ...                                                 ...                 ...
# 4674  In August 1966, in a Vietnamese rubber plantat...       Kriv Stenders
# 4675  DANGER DIVA is a cyberpunk musical/thriller ab...     Robert McGinley
# 4676  The daughter of a man who has discovered radiu...          Ray Taylor
# 4677  While transporting a dying man to the hospital...           Tom Oesch
# 4678  A romance drama involving people who transport...         Lew Landers
#
#                                      Cast
# 0       (Ari Riski Ananda, Erwin Bagindo)
# 1              (Yoo Ah-in, Park Shin-Hye)
# 2         (Sergei Zorenko, Boris Savenko)
# 3     (Jason Barkley, Mark K. Buddington)
# 4        (Ross Patterson, Jessie Wiseman)
# ...                                   ...
# 4674          (Travis Fimmel, Toby Blome)
# 4675            (Molly Sides, Mike Dooly)
# 4676      (Kenneth Harlan, Lucile Browne)
# 4677     (Tom Everett Scott, James Jurdi)
# 4678            (Sally Eilers, John Beal)
#
# [4679 rows x 8 columns]

# %%
df.to_csv('movies.csv')

# %%
df[56:]
# Out:
#                             Movie Name Year of Release Watch Time  \
# 56                  100 kilos de plomo            2002     90 min
# 57    100% lucha, el amo de los clones            2009     80 min
# 58             100% lucha, la película            2008     83 min
# 59                         10000 Hours            2013    107 min
# 60                            100Volta            2009    120 min
# ...                                ...             ...        ...
# 4674                      Danger Close            2019    118 min
# 4675                       Danger Diva            2020    105 min
# 4676                     Danger Island            1931    220 min
# 4677                        Danger One            2018    101 min
# 4678                     Danger Patrol            1937     59 min
#
#      Movie Rating                                  Genres  \
# 56            3.2                      Action
# 57            5.2   Action, Adventure, Sci-Fi
# 58            4.6   Action, Adventure, Comedy
# 59            7.2     Action, Drama, Thriller
# 60            3.7   Action, Adventure, Comedy
# ...           ...                                     ...
# 4674          6.8          Action, Drama, War
# 4675          8.4    Action, Sci-Fi, Thriller
# 4676          5.8  Action, Adventure, Romance
# 4677          6.0       Action, Comedy, Crime
# 4678          5.5      Action, Drama, Romance
#
#                                             Description          Director  \
# 56                                           Add a Plot  Raymundo Calixto
# 57    The movie of the popular Argentinian wrestling...       Pablo Parés
# 58    Koshe Plostenko (Carlos Kaspar), a mob man, is...       Juan Iribas
# 59    A senator is forced to go on the run after kil...      Joyce Bernal
# 60                                           Add a Plot      Daniel Souza
# ...                                                 ...               ...
# 4674  In August 1966, in a Vietnamese rubber plantat...     Kriv Stenders
# 4675  DANGER DIVA is a cyberpunk musical/thriller ab...   Robert McGinley
# 4676  The daughter of a man who has discovered radiu...        Ray Taylor
# 4677  While transporting a dying man to the hospital...         Tom Oesch
# 4678  A romance drama involving people who transport...       Lew Landers
#
#                                    Cast
# 56    (Jorge Aldama, Eric del Castillo)
# 57      (Paulo Soria, Roberto Carnaghi)
# 58      (Chechu Bonelli, Eduardo Husni)
# 59     (Robin Padilla, Michael De Mesa)
# 60         (Daniel Souza, Rafael Sousa)
# ...                                 ...
# 4674        (Travis Fimmel, Toby Blome)
# 4675          (Molly Sides, Mike Dooly)
# 4676    (Kenneth Harlan, Lucile Browne)
# 4677   (Tom Everett Scott, James Jurdi)
# 4678          (Sally Eilers, John Beal)
#
# [4623 rows x 8 columns]
