# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/adventure_movie_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []
images = []
number = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(1,10000,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=adventure&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)

            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)

            try:
              image = store.find('img')
              imge = image['loadlate']
              images.append(imge)  
            except:
                images.append(None)

            numbers = store.find('img')
            num = numbers['data-tconst'][:]
            try:
              number.append(num)
            except:
             number.append(None)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601, 651, 701, 751, 801, 851, 901, 951, 1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151, 2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701, 2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251, 3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801, 3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351, 4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901, 4951, 5001, 5051, 5101, 5151, 5201, 5251, 5301, 5351, 5401, 5451, 5501, 5551, 5601, 5651, 5701, 5751, 5801, 5851, 5901, 5951, 6001, 6051, 6101, 6151, 6201, 6251, 6301, 6351, 6401, 6451, 6501, 6551, 6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101, 7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651, 7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051, 8101, 8151, 8201, 8251, 8301, 8351, 8401, 8451, 8501, 8551, 8601, 8651, 8701, 8751, 8801, 8851, 8901, 8951, 9001, 9051, 9101, 9151, 9201, 9251, 9301, 9351, 9401, 9451, 9501, 9551, 9601, 9651, 9701, 9751, 9801, 9851, 9901, 9951]

# %%
a = { "Movie Name": movie_name, "IMDB ID":number, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts, "IMDB Image":images}

# %%
a
# Out:
# {'Movie Name': ['Thor: Love and Thunder',
#   'Pinocchio',
#   'Avatar: The Way of Water',
#   'The Little Mermaid',
#   'Everything Everywhere All at Once',
#   'Avatar',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Jurassic World Dominion',
#   'Prey',
#   'Rogue One: A Star Wars Story',
#   'Beast',
#   'Moonfall',
#   'The Northman',
#   'Spider-Man: No Way Home',
#   'Morbius',
#   'Dune',
#   'DC League of Super-Pets',
#   'Brahmastra Part One: Shiva',
#   'Barbie',
#   'Doctor Strange in the Multiverse of Madness',
#   'Uncharted',
#   'Thirteen Lives',
#   'The Lord of the Rings: The Return of the King',
#   'Strange World',
#   'Interstellar',
#   'The Lost City',
#   'Sing 2',
#   'Minions: The Rise of Gru',
#   "Harry Potter and the Sorcerer's Stone",
#   'The Greatest Beer Run Ever',
#   'No Time to Die',
#   'The Lord of the Rings: The Two Towers',
#   'The Hobbit: An Unexpected Journey',
#   'Inception',
#   'The Goonies',
#   'Lightyear',
#   'Vikrant Rona',
#   'Stand by Me',
#   'Indiana Jones 5',
#   'Ghostbusters: Afterlife',
#   'Black Panther: Wakanda Forever',
#   'Avengers: Endgame',
#   'The Expendables 4',
#   'Paddington 2',
#   'Dragon Ball Super: Super Hero',
#   'Paddington',
#   'Eternals',
#   'Disenchanted',
#   'The Mortal Instruments: City of Bones',
#   'Jurassic Park',
#   'Thor: Ragnarok',
#   'Fantastic Beasts: The Secrets of Dumbledore',
#   'The Mummy',
#   'Drifting Home',
#   'The Hobbit: The Desolation of Smaug',
#   'Inglourious Basterds',
#   'Gladiator',
#   'Free Guy',
#   'Back to the Future',
#   'Spider-Man',
#   'Black Widow',
#   'The Suicide Squad',
#   'Willow',
#   'Star Wars',
#   'Pinocchio',
#   "The King's Man",
#   'Scooby-Doo',
#   'Luck',
#   'Suicide Squad',
#   'Broad Peak',
#   'The Princess Bride',
#   'The Hunger Games',
#   'Mad Max: Fury Road',
#   'Lyle, Lyle, Crocodile',
#   'The Bad Guys',
#   'Dune: Part Two',
#   'Jaws',
#   'Avengers: Infinity War',
#   'Divergent',
#   'Vesper',
#   'Ready Player One',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'The Little Mermaid',
#   'Raiders of the Lost Ark',
#   "Zack Snyder's Justice League",
#   'Thor',
#   'Spider-Man: Into the Spider-Verse',
#   'Sonic the Hedgehog 2',
#   'The Hobbit: The Battle of the Five Armies',
#   'Guardians of the Galaxy',
#   "Disney's Snow White",
#   'Deadpool',
#   'Cars',
#   'Black Panther',
#   'The Grand Budapest Hotel',
#   'Deadpool 2',
#   'The Lion King',
#   'The Lion King',
#   'Wonka',
#   'Jurassic World',
#   'Ad Astra',
#   'Avengers: Secret Wars',
#   'Wonder Woman',
#   'Aliens',
#   'Thunderbolts',
#   'Spirited Away',
#   'The Adam Project',
#   'Beauty and the Beast',
#   'Ratatouille',
#   'Mission: Impossible - Fallout',
#   'The Incredible Hulk',
#   'Predator',
#   'Shang-Chi and the Legend of the Ten Rings',
#   'Aladdin',
#   'The Sea Beast',
#   'The NeverEnding Story',
#   'Ant-Man and the Wasp: Quantumania',
#   'Coco',
#   'Enchanted',
#   'The Avengers',
#   'Spider-Man: Homecoming',
#   'Iron Man',
#   'Guardians of the Galaxy Vol. 3',
#   'Untitled Super Mario Project',
#   'Harry Potter and the Chamber of Secrets',
#   '2001: A Space Odyssey',
#   'Harry Potter and the Goblet of Fire',
#   'Moana',
#   'King Arthur: Legend of the Sword',
#   'Casino Royale',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   'Peter Pan & Wendy',
#   'Star Wars: The Rise Of Skywalker',
#   'Wicked',
#   'Edge of Tomorrow',
#   'Van Helsing',
#   'Jurassic World: Fallen Kingdom',
#   "A Knight's Tale",
#   'Captain Marvel',
#   'Cruella',
#   'Cinderella',
#   'The Man from Toronto',
#   'Turning Red',
#   'Kingsman: The Secret Service',
#   'The Fifth Element',
#   'Railway Children',
#   'Star Wars: Episode I - The Phantom Menace',
#   'The Good, the Bad and the Ugly',
#   'Dragonball Evolution',
#   "Chip 'n Dale: Rescue Rangers",
#   'Catherine Called Birdy',
#   'Almost Famous',
#   'World War Z',
#   'Mission: Impossible - Dead Reckoning - Part One',
#   'Idiocracy',
#   'Harry Potter and the Prisoner of Azkaban',
#   'Inside Out',
#   'Transformers',
#   'George of the Jungle',
#   'The Revenant',
#   'The Wizard of Oz',
#   'Venom: Let There Be Carnage',
#   'Austin Powers: International Man of Mystery',
#   'Annihilation',
#   'Rat Race',
#   'Dogma',
#   'The Parent Trap',
#   'The Blue Lagoon',
#   'Aquaman',
#   'Mortal Kombat',
#   'Twister',
#   'E.T. the Extra-Terrestrial',
#   'Toy Story',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   'Snow White and the Huntsman',
#   'Clash of the Titans',
#   'Shazam!',
#   'Apocalypto',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'Captain America: The First Avenger',
#   'Dune',
#   'Alita: Battle Angel',
#   'Prometheus',
#   'Spider-Man 3',
#   'Alice in Wonderland',
#   'The Incredibles',
#   'Justice League',
#   'Jumanji: Welcome to the Jungle',
#   'Terminator: Dark Fate',
#   'Zootopia',
#   'Vacation',
#   'Indiana Jones and the Temple of Doom',
#   "Howl's Moving Castle",
#   'Shrek',
#   'Enola Holmes',
#   'The Descent',
#   'Into the Wild',
#   'The Fast and the Furious',
#   'Captain America: New World Order',
#   'Stardust',
#   'Skyfall',
#   'The Tomorrow War',
#   'Star Wars: Episode VII - The Force Awakens',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'The Hunger Games: The Ballad of Songbirds and Snakes',
#   'Deliverance',
#   'Frozen',
#   'Batman',
#   'Fantastic Four',
#   'Dungeons & Dragons: Honor Among Thieves',
#   'Indiana Jones and the Last Crusade',
#   'X-Men',
#   'The Man from U.N.C.L.E.',
#   'Star Trek',
#   'Big Trouble in Little China',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   'Star Trek Beyond',
#   'Charlie and the Chocolate Factory',
#   'Mission: Impossible - Rogue Nation',
#   'Batgirl',
#   'Thor: The Dark World',
#   'Wonder Woman 1984',
#   'Hook',
#   'The Predator',
#   'X-Men: Apocalypse',
#   'Man of Steel',
#   'Labyrinth',
#   'The Amazing Spider-Man',
#   'Venom',
#   'Sausage Party',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'The Green Knight',
#   'Doctor Strange',
#   'Oblivion',
#   'The Martian',
#   'The Mummy',
#   'Starship Troopers',
#   'WALL·E',
#   'Aquaman and the Lost Kingdom',
#   'Spider-Man 2',
#   'Birds of Prey',
#   'Guardians of the Galaxy Vol. 2',
#   'Interceptor',
#   'Harry Potter and the Order of the Phoenix',
#   'The Expendables',
#   'The Flash',
#   'Mulan',
#   'Mission: Impossible',
#   'Kingdom of Heaven',
#   'Star Wars: Episode III - Revenge of the Sith',
#   'Green Lantern',
#   'Despicable Me',
#   'The Expendables 3',
#   'Solo: A Star Wars Story',
#   'Jumanji: The Next Level',
#   'Avengers: Age of Ultron',
#   'The Rock',
#   'Secret Headquarters',
#   'TRON: Legacy',
#   'Finding Nemo',
#   'Tangled',
#   'Incredibles 2',
#   'Men in Black',
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Captain America: Civil War',
#   'Fantastic Four',
#   'Big Fish',
#   'Quantum of Solace',
#   'The Secret Life of Walter Mitty',
#   'Hercules',
#   'Independence Day',
#   'Monsters, Inc.',
#   'Sonic the Hedgehog',
#   'Legend',
#   'The Hunt for Red October',
#   'Transformers: Rise of the Beasts',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   'Star Wars: Episode VIII - The Last Jedi',
#   'Cannibal Holocaust',
#   'Fantastic Beasts and Where to Find Them',
#   'Spectre',
#   'Spider-Man: Far from Home',
#   'Harry Potter and the Half-Blood Prince',
#   'The Impossible',
#   'Iron Man 2',
#   "A Bug's Life",
#   'The Mummy Returns',
#   'The Divergent Series: Insurgent',
#   'Tomb Raider',
#   'Minions',
#   'X: First Class',
#   'Up',
#   'Sucker Punch',
#   'The Hunger Games: Catching Fire',
#   'Galaxy Quest',
#   'Jungle Cruise',
#   'Batman v Superman: Dawn of Justice',
#   'Mat Kilau',
#   'Monty Python and the Holy Grail',
#   'Austin Powers: The Spy Who Shagged Me',
#   'Rebel Moon',
#   'Blade',
#   'Kingsman: The Golden Circle',
#   'Soul',
#   'Aladdin',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   'Mutiny on the Bounty',
#   'The Green Inferno',
#   'Blood Diamond',
#   'Madame Web',
#   'X-Men: Dark Phoenix',
#   'Jumanji',
#   'Crawl',
#   "Charlie's Angels",
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'The Last of the Mohicans',
#   'Battleship',
#   'The Blues Brothers',
#   '2012',
#   'Sherlock Holmes',
#   'The Day After Tomorrow',
#   'The Great Escape',
#   "The Huntsman: Winter's War",
#   'GoldenEye',
#   'Valerian and the City of a Thousand Planets',
#   'The Marvels',
#   'The Jungle Book',
#   'Mad Max',
#   "National Lampoon's Vacation",
#   'Jungle',
#   'Armageddon',
#   'Mufasa: The Lion King',
#   'X-Men: Days of Future Past',
#   'Luca',
#   'One Piece Film: Red',
#   'Elemental',
#   'Terminator Genisys',
#   'Austin Powers in Goldmember',
#   'Holes',
#   'John Carter',
#   'Blue Beetle',
#   'Conan the Barbarian',
#   'Superman',
#   'Total Recall',
#   'Star Wars: Episode II - Attack of the Clones',
#   'Back to the Future Part II',
#   'The Iron Giant',
#   'Cast Away',
#   'Raya and the Last Dragon',
#   'Lawrence of Arabia',
#   'Iron Man Three',
#   'Pirates of the Caribbean: On Stranger Tides',
#   'The Beach',
#   'Batman Forever',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   'Knight and Day',
#   'Captain America: The Winter Soldier',
#   'Karthikeya 2',
#   'How to Train Your Dragon',
#   'Lilo & Stitch',
#   'The Host',
#   'Highlander',
#   'Escape Room',
#   'Black Crab',
#   'The Fast and the Furious: Tokyo Drift',
#   'The Vault',
#   'Teenage Mutant Ninja Turtles',
#   'The Witches',
#   'Spider-Man: Across the Spider-Verse',
#   'The Mummy: Tomb of the Dragon Emperor',
#   'Piggy',
#   'Power Rangers',
#   'The Princess and the Frog',
#   'The Lost World: Jurassic Park',
#   'Three Kings',
#   'Ant-Man',
#   'Pacific Rim',
#   'King Arthur',
#   'Toy Story 4',
#   'Puss in Boots: The Last Wish',
#   'Shazam! Fury of the Gods',
#   'The Three Musketeers',
#   'Borderlands',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   'Kung Fu Panda',
#   'Atlantis: The Lost Empire',
#   'The Amazing Spider-Man 2',
#   'Life of Pi',
#   'Sahara',
#   'The Great Wall',
#   'War of the Worlds',
#   'Allegiant',
#   'Scary Stories to Tell in the Dark',
#   "Miss Peregrine's Home for Peculiar Children",
#   'Rampage',
#   'King Kong',
#   'Night at the Museum',
#   'Maleficent',
#   'Warcraft',
#   'Finch',
#   'Madagascar',
#   'The Core',
#   'North by Northwest',
#   'Who Framed Roger Rabbit',
#   'Chaos Walking',
#   'The Losers',
#   'The Magnificent Seven',
#   'Toy Story 3',
#   'Peter Pan',
#   'The Peanut Butter Falcon',
#   'O Brother, Where Art Thou?',
#   'Predators',
#   'Enola Holmes 2',
#   'Commando',
#   'Apollo 13',
#   'Sicario: Day of the Soldado',
#   'Into the Woods',
#   'Princess Mononoke',
#   'Barbarella',
#   'Ice Age',
#   'The Holy Mountain',
#   'Mulan',
#   'Maverick',
#   "Pirates of the Caribbean: At World's End",
#   'Dances with Wolves',
#   'Robin Hood: Prince of Thieves',
#   "The Emperor's New Groove",
#   'Fantastic Mr. Fox',
#   'National Treasure',
#   'The Last Airbender',
#   'Speed',
#   'Jaws 2',
#   'Mission: Impossible III',
#   'Wendell & Wild',
#   'A Series of Unfortunate Events',
#   'Robots',
#   'The Prince of Egypt',
#   'Pan',
#   'Super Mario Bros.',
#   'High Life',
#   'Planet of the Apes',
#   'Big Hero 6',
#   'Thelma & Louise',
#   'Terminator Salvation',
#   'Love and Monsters',
#   'Monster Hunter',
#   'Game Night',
#   'Star Trek Into Darkness',
#   'Fear and Loathing in Las Vegas',
#   'Papillon',
#   'Barry Lyndon',
#   'The Imaginarium of Doctor Parnassus',
#   'Shrek 2',
#   'The Lord of the Rings',
#   'Escape from New York',
#   'The Perfect Storm',
#   'Avengers: The Kang Dynasty',
#   'The Expendables 2',
#   'Brave',
#   'Transformers: The Last Knight',
#   'Fantastic Four',
#   'Kong: Skull Island',
#   'First Blood',
#   'Hellboy',
#   'X-Men: The Last Stand',
#   'Stargate',
#   'Cars 3',
#   'The Curse of Bridge Hollow',
#   'Men in Black 3',
#   'Cars 2',
#   'Elf',
#   'San Andreas',
#   'Waterworld',
#   'Hotel Transylvania: Transformania',
#   'The Count of Monte Cristo',
#   'Teenage Mutant Ninja Turtles',
#   'Homeward Bound: The Incredible Journey',
#   'Gods of Egypt',
#   'Master and Commander: The Far Side of the World',
#   'Despicable Me 2',
#   'The Legend of Tarzan',
#   'Hotel Transylvania',
#   'Adventures in Babysitting',
#   'Serenity',
#   'Kate',
#   'Men in Black II',
#   'Chef',
#   'The Fall',
#   'Escape Room: Tournament of Champions',
#   'Treasure Planet',
#   'Deep Rising',
#   'Frozen II',
#   'Ant-Man and the Wasp',
#   'Everest',
#   'The Chronicles of Riddick',
#   'Conan the Barbarian',
#   'Jupiter Ascending',
#   'The Abyss',
#   'The Nightingale',
#   'Wild Hogs',
#   'Furious 6',
#   'The Adventures of Tintin',
#   'Voyagers',
#   'The Road Warrior',
#   'Excalibur',
#   'In the Heart of the Sea',
#   'Robin Hood',
#   'Rango',
#   'Belle',
#   'Jurassic Park III',
#   "Charlie's Angels",
#   'Now You See Me 2',
#   'Total Recall',
#   'Anastasia',
#   'Mission: Impossible II',
#   'Lilo & Stitch',
#   'Furiosa',
#   'Spaceballs',
#   'Journey to the Center of the Earth',
#   'Planet of the Apes',
#   'Krull',
#   'Bumblebee',
#   'The Dark Tower',
#   'Prince of Persia: The Sands of Time',
#   'Tarzan',
#   'Fantastic Four: Rise of the Silver Surfer',
#   'Kraven the Hunter',
#   'Tad the Lost Explorer and the Emerald Tablet',
#   'Dolittle',
#   '777 Charlie',
#   'The Colony',
#   'The Lost City of Z',
#   'Bill & Ted Face the Music',
#   "Ender's Game",
#   'Alien vs. Predator',
#   'Robin Hood',
#   'Deliver Us from Evil',
#   "The Hitchhiker's Guide to the Galaxy",
#   'Spartacus',
#   'The 5th Wave',
#   "The Bob's Burgers Movie",
#   'Last Action Hero',
#   'End of Watch',
#   'Hellboy',
#   'Robin Hood: Men in Tights',
#   'The 13th Warrior',
#   '47 Meters Down',
#   '2 Fast 2 Furious',
#   'Percy Jackson: Sea of Monsters',
#   'Cold Mountain',
#   'Men in Black: International',
#   'Big Fat Liar',
#   'The Adventures of Buckaroo Banzai Across the 8th Dimension',
#   'The Hunger Games: Mockingjay - Part 2',
#   'Mortal Engines',
#   'Mortal Kombat',
#   'Good Boys',
#   'The Book of Life',
#   'Exodus: Gods and Kings',
#   'Superman Returns',
#   'War for the Planet of the Apes',
#   'The Mitchells vs the Machines',
#   '28 Weeks Later',
#   'Crouching Tiger, Hidden Dragon',
#   'The Twilight Saga: Eclipse',
#   'Jay and Silent Bob Reboot',
#   'Pocahontas',
#   'Wreck-It Ralph',
#   "Weekend at Bernie's",
#   'Maze Runner: The Death Cure',
#   'Against the Ice',
#   'The Ghost and the Darkness',
#   'Jumper',
#   'Robin Hood',
#   "Assassin's Creed",
#   'Die Another Day',
#   'Toy Story 2',
#   'Spies in Disguise',
#   'The Happening',
#   'Snow White and the Seven Dwarfs',
#   'Shamshera',
#   'Home Alone 2: Lost in New York',
#   'Sherlock Holmes: A Game of Shadows',
#   'The Man in the Iron Mask',
#   'Hugo',
#   'Godzilla: King of the Monsters',
#   'Transformers: Age of Extinction',
#   'Boss Level',
#   'Alienoid',
#   'Hercules',
#   'The Adventures of Pinocchio',
#   'The Ten Commandments',
#   'Lara Croft: Tomb Raider',
#   'Smokey and the Bandit',
#   'The Lego Movie',
#   'Honey, I Shrunk the Kids',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   'Reign of Fire',
#   "Logan's Run",
#   'Below Zero',
#   'The Jungle Book',
#   'The Twilight Saga: New Moon',
#   'Rambo: First Blood Part II',
#   'The Interview',
#   'Hanna',
#   'Tomorrowland',
#   'Inferno',
#   'The Bourne Legacy',
#   'The Witches',
#   'Cliffhanger',
#   'Transformers: Dark of the Moon',
#   'Frozen',
#   'The League of Extraordinary Gentlemen',
#   'Spy Kids',
#   'Paul',
#   'Seventh Son',
#   'Lost in Space',
#   'The Three Musketeers',
#   'Godzilla',
#   'Riddick',
#   'Easy Rider',
#   'Wild',
#   'Leave No Trace',
#   'The Hunger Games: Mockingjay - Part 1',
#   'Stuart Little',
#   'Hunt for the Wilderpeople',
#   'Sherlock Holmes 3',
#   'Maleficent: Mistress of Evil',
#   'Despicable Me 3',
#   'The Midnight Sky',
#   'Romancing the Stone',
#   'Without a Paddle',
#   'The Brothers Grimm',
#   'Okja',
#   'Back to the Future Part III',
#   'Beowulf',
#   'Monsters University',
#   'Miami Vice',
#   'The A-Team',
#   'Finding Dory',
#   'The Call of the Wild',
#   'The Mask of Zorro',
#   'Cloudy with a Chance of Meatballs',
#   'Pokémon Detective Pikachu',
#   'Dr. No',
#   'The Book of Eli',
#   'Mary Poppins Returns',
#   'Return to Oz',
#   "Bill & Ted's Excellent Adventure",
#   'Ralph Breaks the Internet',
#   'The World Is Not Enough',
#   'The Golden Compass',
#   'The Chronicles of Narnia: Prince Caspian',
#   'Demon Slayer the Movie: Mugen Train',
#   'Maze Runner: The Scorch Trials',
#   'The Cat in the Hat',
#   'The Dirty Dozen',
#   'Paper Towns',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Ghosted',
#   'The Lone Ranger',
#   'The Secret Life of Pets',
#   'James and the Giant Peach',
#   'Get Smart',
#   'The Day the Earth Stood Still',
#   'Goldfinger',
#   'Australia',
#   'Rambo',
#   'Dawn of the Planet of the Apes',
#   'Deep Blue Sea',
#   'Point Break',
#   'The Time Machine',
#   '9',
#   'Clash of the Titans',
#   'G.I. Joe: The Rise of Cobra',
#   'The Darjeeling Limited',
#   'The Rocketeer',
#   'The Emoji Movie',
#   'Marrowbone',
#   'Battle Royale',
#   'The Life Aquatic with Steve Zissou',
#   'Pacific Rim: Uprising',
#   'Transformers: Revenge of the Fallen',
#   'Fullmetal Alchemist: The Revenge of Scar',
#   'xXx',
#   'Against All Odds',
#   'R.I.P.D.',
#   'The VelociPastor',
#   'Aliens vs. Predator: Requiem',
#   'Flash Gordon',
#   'Tom and Jerry',
#   'Die Hard with a Vengeance',
#   'The Covenant',
#   'TRON',
#   'Oz the Great and Powerful',
#   'Spirit Halloween',
#   'Ben-Hur',
#   'The Poseidon Adventure',
#   'Masters of the Universe',
#   'Snake Eyes',
#   'Blood Red Sky',
#   'Onward',
#   'The Ice Road',
#   'Gran Turismo',
#   'The Spy Who Dumped Me',
#   'Into the Blue',
#   'The Road to El Dorado',
#   'Street Fighter',
#   'The Scorpion King',
#   'Space Jam: A New Legacy',
#   'Avatar 3',
#   'The Way Back',
#   'Jack the Giant Slayer',
#   'Ferdinand',
#   'Alvin and the Chipmunks',
#   'The Bridge on the River Kwai',
#   'Mighty Morphin Power Rangers: The Movie',
#   'Peter Pan',
#   'Sonic the Hedgehog 3',
#   'Licence to Kill',
#   'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   'News of the World',
#   "Dante's Peak",
#   'Meet the Robinsons',
#   'Tomorrow Never Dies',
#   'Noah',
#   'Star Trek: The Motion Picture',
#   'Wrath of the Titans',
#   'Heavy Metal',
#   'Alice in Wonderland',
#   'Independence Day: Resurgence',
#   'Stowaway',
#   'Moonraker',
#   'For Your Eyes Only',
#   'Dope',
#   'Vivo',
#   'Bee Movie',
#   "It's a Mad Mad Mad Mad World",
#   'Escape from L.A.',
#   'Battlefield Earth',
#   'How to Train Your Dragon: The Hidden World',
#   'The Addams Family 2',
#   'Scooby-Doo 2: Monsters Unleashed',
#   'Clifford the Big Red Dog',
#   'Anaconda',
#   'Epic Movie',
#   'Ice Age: Collision Course',
#   'The Spiderwick Chronicles',
#   'FernGully: The Last Rainforest',
#   'Innerspace',
#   "The King's Daughter",
#   'Journey 2: The Mysterious Island',
#   'The Croods: A New Age',
#   'Star Trek II: The Wrath of Khan',
#   'Crocodile Dundee',
#   'Wish',
#   'Isle of Dogs',
#   'Night at the Museum: Battle of the Smithsonian',
#   'Alice Through the Looking Glass',
#   'The Last Starfighter',
#   'Rio',
#   'The Wrath of God',
#   'The Lego Batman Movie',
#   'Conan the Destroyer',
#   '30 Days of Night',
#   'The AristoCats',
#   '10,000 BC',
#   "On Her Majesty's Secret Service",
#   'Shark Tale',
#   'King Kong',
#   'Diary of a Wimpy Kid: The Long Haul',
#   'A Goofy Movie',
#   'Tarzan and the Amazons',
#   'The Brothers Grimsby',
#   'Happy Feet',
#   'Howard the Duck',
#   'American Honey',
#   'Open Water',
#   'Dumbo',
#   'Kung Fu Panda 3',
#   'Sleeping Beauty',
#   'Inkheart',
#   'The Wild Bunch',
#   'Goosebumps',
#   'The Old Guard 2',
#   'Aladdin 2',
#   'A Monster Calls',
#   'Chicken Run',
#   'I Am Number Four',
#   'The Adventures of Sharkboy and Lavagirl 3-D',
#   'Spider-Man Beyond Negative',
#   'The Lord of the Rings: The War of the Rohirrim',
#   'Ponyo',
#   'The Treasure of the Sierra Madre',
#   'Space Jam',
#   'Django/Zorro',
#   'Skyscraper',
#   'Octopussy',
#   '101 Dalmatians',
#   'Lord of the Flies',
#   'Harold & Kumar Go to White Castle',
#   "Pee-wee's Big Adventure",
#   'G.I. Joe: Retaliation',
#   'Bolt',
#   'PAW Patrol: The Movie',
#   'Body Cam',
#   "Heaven's Gate",
#   'Rise of the Teenage Mutant Ninja Turtles: The Movie',
#   'S.W.A.T.',
#   "Kiki's Delivery Service",
#   'The Last Witch Hunter',
#   'The Bounty',
#   'The Living Daylights',
#   'The BFG',
#   'Nerve',
#   'The Misfits',
#   'Pushpa: The Rise - Part 1',
#   'Mirror Mirror',
#   'A Wrinkle in Time',
#   'Joe Dirt',
#   'Hardcore Henry',
#   'Home',
#   'The Polar Express',
#   'Dora and the Lost City of Gold',
#   '47 Meters Down: Uncaged',
#   'Small Soldiers',
#   'Shrek the Third',
#   'Girls Trip',
#   'The Aeronauts',
#   'After Earth',
#   'Godzilla vs. Kong 2',
#   'Trolls',
#   'How to Train Your Dragon 2',
#   'The Searchers',
#   'The Magnificent Seven',
#   'The Guns of Navarone',
#   'The Spy Who Loved Me',
#   "Fool's Gold",
#   'Forbidden Planet',
#   'The Gods Must Be Crazy',
#   'Pompeii',
#   'Night at the Museum: Secret of the Tomb',
#   'Mechanic: Resurrection',
#   'Poseidon',
#   'Mad Max Beyond Thunderdome',
#   'Shin Ultraman',
#   'War Horse',
#   'Chitty Chitty Bang Bang',
#   'The Boss Baby',
#   'Popeye',
#   'Adrift',
#   'The NeverEnding Story III',
#   'Monsters',
#   'Flight of the Navigator',
#   'Eragon',
#   'The Beastmaster',
#   'The Neverending Story',
#   'The Grey',
#   'Chicken Little',
#   "We're Back! A Dinosaur's Story",
#   'Hellboy II: The Golden Army',
#   'A View to a Kill',
#   'One Hundred and One Dalmatians',
#   'Where Eagles Dare',
#   'Christopher Robin',
#   'Alcarràs',
#   'The Saint',
#   'The Rundown',
#   'Tommy Boy',
#   'Togo',
#   'Klaus',
#   'Batman v Superman: Dawn of Justice - Ultimate Edition',
#   'National Treasure: Book of Secrets',
#   'Wyatt Earp',
#   'King Kong',
#   "The Sorcerer's Apprentice",
#   'The Croods',
#   'The Secret Life of Pets 2',
#   'Cool Runnings',
#   'Seven Years in Tibet',
#   'On the Road',
#   'Awake',
#   'Hotel Transylvania 3: Summer Vacation',
#   'The Postman',
#   'Kung Fu Panda 2',
#   'The Mission',
#   'xXx: Return of Xander Cage',
#   'Diamonds Are Forever',
#   'Thunderball',
#   'Star Trek VI: The Undiscovered Country',
#   "National Lampoon's European Vacation",
#   "Ron's Gone Wrong",
#   'Johnny English',
#   'National Treasure 3',
#   'Leviathan',
#   'Monsters vs. Aliens',
#   'Land of the Lost',
#   'Brother Bear',
#   'Lady and the Tramp',
#   "Charlie's Angels: Full Throttle",
#   'Dinosaur',
#   'The Ridiculous 6',
#   'Snakes on a Plane',
#   'Dragon Ball Super: Broly',
#   'Trolls World Tour',
#   'The Lorax',
#   'Return to the Blue Lagoon',
#   'Troll',
#   'The Boss Baby: Family Business',
#   'The Witcher: Nightmare of the Wolf',
#   'Flesh+Blood',
#   'Spies Like Us',
#   'Peter Rabbit',
#   'Inside Out 2',
#   'Time Bandits',
#   'Gemini Man',
#   'Cheaper by the Dozen',
#   'Virgin Territory',
#   'The Professionals',
#   'Live and Let Die',
#   'The Prince and the Pauper',
#   'The Big Blue',
#   'Hero',
#   'The Guardian',
#   'Speed Racer',
#   'Major Dundee',
#   'The Man with the Golden Gun',
#   'Slumberland',
#   'Underworld: Blood Wars',
#   'Fire and Ice',
#   'Eight Legged Freaks',
#   'Congo',
#   '65',
#   'Flushed Away',
#   'Zoolander 2',
#   'Mowgli: Legend of the Jungle',
#   'Explorers',
#   'Major Payne',
#   'The Dark Crystal',
#   'The Bucket List',
#   "Charlotte's Web",
#   'Venom 3',
#   'The Little Vampire',
#   'Superman II',
#   'Thunder Force',
#   'The SpongeBob SquarePants Movie',
#   "A Dog's Purpose",
#   'Shanghai Noon',
#   'The Forbidden Kingdom',
#   'Paradise',
#   'Ice Age: Dawn of the Dinosaurs',
#   '2010: The Year We Make Contact',
#   'The Walk',
#   'The Good Dinosaur',
#   'Far and Away',
#   'Antz',
#   'Six Days Seven Nights',
#   'Red Sonja',
#   'Scoob!',
#   'Rambo III',
#   'Epic',
#   'Lady and the Tramp',
#   'Seeking a Friend for the End of the World',
#   'Æon Flux',
#   'Elektra',
#   'The Black Cauldron',
#   'Wizards',
#   'True Grit',
#   'Bloodshot',
#   'Never Say Never Again',
#   'The NeverEnding Story II: The Next Chapter',
#   'Over the Hedge',
#   'Red One',
#   'Aliens in the Attic',
#   'Star Trek: First Contact',
#   'Walkabout',
#   'The Land Before Time',
#   'The Sword in the Stone',
#   'Oliver & Company',
#   'Prey',
#   'Iron Sky',
#   'Where the Wild Things Are',
#   "Don't Listen",
#   'Untitled Star Trek Sequel',
#   'Iron Mask',
#   'Your Highness',
#   'Spy Kids 3: Game Over',
#   'Teenage Mutant Ninja Turtles: Mutant Mayhem',
#   'Castle in the Sky',
#   'The Grinch',
#   'From Russia with Love',
#   'The Crazies',
#   'The SpongeBob Movie: Sponge on the Run',
#   'The Borrowers',
#   'Cheaper by the Dozen 2',
#   'Tenacious D in the Pick of Destiny',
#   'The Simpsons Movie',
#   'Alpha',
#   'Battle Los Angeles',
#   'Nebraska',
#   ...],
#  'IMDB ID': ['tt10648342',
#   'tt4593060',
#   'tt1630029',
#   'tt5971474',
#   'tt6710474',
#   'tt0499549',
#   'tt0120737',
#   'tt8041270',
#   'tt11866324',
#   'tt3748528',
#   'tt13223398',
#   'tt5834426',
#   'tt11138512',
#   'tt10872600',
#   'tt5108870',
#   'tt1160419',
#   'tt8912936',
#   'tt6277462',
#   'tt1517268',
#   'tt9419884',
#   'tt1464335',
#   'tt12262116',
#   'tt0167260',
#   'tt10298840',
#   'tt0816692',
#   'tt13320622',
#   'tt6467266',
#   'tt5113044',
#   'tt0241527',
#   'tt10268488',
#   'tt2382320',
#   'tt0167261',
#   'tt0903624',
#   'tt1375666',
#   'tt0089218',
#   'tt10298810',
#   'tt12015102',
#   'tt0092005',
#   'tt1462764',
#   'tt4513678',
#   'tt9114286',
#   'tt4154796',
#   'tt3291150',
#   'tt4468740',
#   'tt14614892',
#   'tt1109624',
#   'tt9032400',
#   'tt1596342',
#   'tt1538403',
#   'tt0107290',
#   'tt3501632',
#   'tt4123432',
#   'tt0120616',
#   'tt15494038',
#   'tt1170358',
#   'tt0361748',
#   'tt0172495',
#   'tt6264654',
#   'tt0088763',
#   'tt0145487',
#   'tt3480822',
#   'tt6334354',
#   'tt0096446',
#   'tt0076759',
#   'tt0032910',
#   'tt6856242',
#   'tt0267913',
#   'tt7214954',
#   'tt1386697',
#   'tt8983230',
#   'tt0093779',
#   'tt1392170',
#   'tt1392190',
#   'tt14668630',
#   'tt8115900',
#   'tt15239678',
#   'tt0073195',
#   'tt4154756',
#   'tt1840309',
#   'tt20225374',
#   'tt1677720',
#   'tt0325980',
#   'tt0097757',
#   'tt0082971',
#   'tt12361974',
#   'tt0800369',
#   'tt4633694',
#   'tt12412888',
#   'tt2310332',
#   'tt2015381',
#   'tt6208148',
#   'tt1431045',
#   'tt0317219',
#   'tt1825683',
#   'tt2278388',
#   'tt5463162',
#   'tt0110357',
#   'tt6105098',
#   'tt6166392',
#   'tt0369610',
#   'tt2935510',
#   'tt21361444',
#   'tt0451279',
#   'tt0090605',
#   'tt20969586',
#   'tt0245429',
#   'tt2463208',
#   'tt2771200',
#   'tt0382932',
#   'tt4912910',
#   'tt0800080',
#   'tt0093773',
#   'tt9376612',
#   'tt6139732',
#   'tt9288046',
#   'tt0088323',
#   'tt10954600',
#   'tt2380307',
#   'tt0461770',
#   'tt0848228',
#   'tt2250912',
#   'tt0371746',
#   'tt6791350',
#   'tt6718170',
#   'tt0295297',
#   'tt0062622',
#   'tt0330373',
#   'tt3521164',
#   'tt1972591',
#   'tt0381061',
#   'tt1201607',
#   'tt5635026',
#   'tt2527338',
#   'tt1262426',
#   'tt1631867',
#   'tt0338526',
#   'tt4881806',
#   'tt11116912',
#   'tt6932874',
#   'tt11657662',
#   'tt0089153',
#   'tt0090056',
#   'tt5117670',
#   'tt22022452',
#   'tt0081633',
#   'tt1025100',
#   'tt6705162',
#   'tt0437954',
#   'tt0060862',
#   'tt0070328',
#   'tt0029440',
#   'tt0095250',
#   'tt0299977',
#   'tt0406816',
#   'tt0811080',
#   'tt0059418',
#   'tt0071807',
#   'tt13320662',
#   'tt3717252',
#   'tt0085542',
#   'tt0271367',
#   'tt0112715',
#   'tt12261776',
#   'tt0424095',
#   'tt1608290',
#   'tt2388771',
#   'tt0089114',
#   'tt0110443',
#   'tt0083791',
#   'tt0825232',
#   'tt0413895',
#   'tt16366836',
#   'tt0192255',
#   'tt0081573',
#   'tt10121392',
#   'tt0345950',
#   'tt1753383',
#   'tt0184894',
#   'tt0865556',
#   'tt0084469',
#   'tt1080016',
#   'tt0086837',
#   'tt3488710',
#   'tt1979388',
#   'tt0104231',
#   'tt0120587',
#   'tt0120828',
#   'tt0089893',
#   'tt3152592',
#   'tt0095956',
#   'tt0848537',
#   'tt0048280',
#   'tt1307068',
#   'tt0402022',
#   'tt0357277',
#   'tt0088814',
#   'tt0076929',
#   'tt0065126',
#   'tt1634106',
#   'tt0086006',
#   'tt0100240',
#   'tt0327084',
#   'tt14948432',
#   'tt0775552',
#   'tt0117731',
#   'tt0067959',
#   'tt0095489',
#   'tt0057546',
#   'tt0095776',
#   'tt15198608',
#   'tt1034314',
#   'tt0386117',
#   'tt11750282',
#   'tt4756228',
#   'tt6218010',
#   'tt1240982',
#   'tt0338459',
#   'tt8589698',
#   'tt0092067',
#   'tt2709692',
#   'tt0057076',
#   'tt0455407',
#   'tt4823776',
#   'tt0118755',
#   'tt0452598',
#   'tt0365830',
#   'tt0462538',
#   'tt4244998',
#   'tt1217613',
#   'tt1821549',
#   ...],
#  'Year of Release': ['2022',
#   'I) (',
#   '2022',
#   '2023',
#   '2022',
#   '2009',
#   '2001',
#   '2022',
#   'I) (',
#   '2016',
#   'I) (',
#   '2022',
#   '2022',
#   '2021',
#   '2022',
#   '2021',
#   '2022',
#   '2022',
#   '2023',
#   '2022',
#   '2022',
#   '2022',
#   '2003',
#   '2022',
#   '2014',
#   '2022',
#   '2021',
#   '2022',
#   '2001',
#   '2022',
#   '2021',
#   '2002',
#   '2012',
#   '2010',
#   '1985',
#   '2022',
#   '2022',
#   '1986',
#   '2023',
#   '2021',
#   '2022',
#   '2019',
#   '2023',
#   '2017',
#   '2022',
#   '2014',
#   '2021',
#   '2022',
#   '2013',
#   '1993',
#   '2017',
#   '2022',
#   '1999',
#   '2022',
#   '2013',
#   '2009',
#   '2000',
#   '2021',
#   '1985',
#   '2002',
#   '2021',
#   '2021',
#   '1988',
#   '1977',
#   '1940',
#   '2021',
#   '2002',
#   'I) (',
#   '2016',
#   '2022',
#   '1987',
#   '2012',
#   '2015',
#   '2022',
#   '2022',
#   '2023',
#   '1975',
#   '2018',
#   '2014',
#   '2022',
#   '2018',
#   '2003',
#   '1989',
#   '1981',
#   '2021',
#   '2011',
#   '2018',
#   '2022',
#   '2014',
#   '2014',
#   '2024',
#   '2016',
#   '2006',
#   '2018',
#   '2014',
#   '2018',
#   '1994',
#   '2019',
#   '2023',
#   '2015',
#   '2019',
#   '2025',
#   '2017',
#   '1986',
#   '2024',
#   '2001',
#   '2022',
#   'I) (',
#   '2007',
#   '2018',
#   '2008',
#   '1987',
#   '2021',
#   '2019',
#   '2022',
#   '1984',
#   '2023',
#   'I) (',
#   '2007',
#   '2012',
#   '2017',
#   '2008',
#   '2023',
#   '2023',
#   '2002',
#   '1968',
#   '2005',
#   'I) (',
#   '2017',
#   '2006',
#   '2011',
#   '2023',
#   '2019',
#   '2024',
#   '2014',
#   '2004',
#   '2018',
#   '2001',
#   '2019',
#   '2021',
#   'I) (',
#   '2022',
#   '2022',
#   '2014',
#   '1997',
#   '2022',
#   '1999',
#   '1966',
#   '2009',
#   '2022',
#   '2022',
#   '2000',
#   '2013',
#   '2023',
#   '2006',
#   '2004',
#   'I) (',
#   '2007',
#   '1997',
#   '2015',
#   '1939',
#   '2021',
#   '1997',
#   'I) (',
#   '2001',
#   '1999',
#   '1998',
#   '1980',
#   '2018',
#   '2021',
#   'I) (',
#   '1982',
#   '1995',
#   '2010',
#   '2012',
#   '2010',
#   '2019',
#   '2006',
#   '2005',
#   '2011',
#   '1984',
#   '2019',
#   'I) (',
#   '2007',
#   'I) (',
#   '2004',
#   '2017',
#   '2017',
#   '2019',
#   '2016',
#   'I) (',
#   '1984',
#   '2004',
#   '2001',
#   '2020',
#   '2005',
#   '2007',
#   '2001',
#   '2024',
#   '2007',
#   '2012',
#   '2021',
#   '2015',
#   '2017',
#   '2023',
#   '1972',
#   'I) (',
#   '1989',
#   '2024',
#   '2023',
#   '1989',
#   '2000',
#   '2015',
#   '2009',
#   '1986',
#   '2010',
#   '2016',
#   '2005',
#   '2015',
#   '',
#   '2013',
#   '2020',
#   '1991',
#   '2018',
#   '2016',
#   '2013',
#   '1986',
#   '2012',
#   '2018',
#   '2016',
#   '1980',
#   '2021',
#   '2016',
#   'I) (',
#   '2015',
#   '2017',
#   '1997',
#   '2008',
#   '2023',
#   '2004',
#   '2020',
#   '2017',
#   '2022',
#   '2007',
#   '2010',
#   '2023',
#   '2020',
#   '1996',
#   '2005',
#   '2005',
#   '2011',
#   '2010',
#   '2014',
#   '2018',
#   '2019',
#   '2015',
#   '1996',
#   '2022',
#   '2010',
#   '2003',
#   '2010',
#   '2018',
#   '1997',
#   '1983',
#   '2016',
#   '2015',
#   '2003',
#   '2008',
#   '2013',
#   '1997',
#   '1996',
#   '2001',
#   '2020',
#   '1985',
#   '1990',
#   '2023',
#   '2018',
#   '2017',
#   '1980',
#   '2016',
#   'I) (',
#   '2019',
#   '2009',
#   '2012',
#   '2010',
#   'I) (',
#   '2001',
#   '2015',
#   '2018',
#   '2015',
#   '2011',
#   '2009',
#   '2011',
#   '2013',
#   '1999',
#   '2021',
#   '2016',
#   '2022',
#   '1975',
#   '1999',
#   '',
#   '2023',
#   '2017',
#   '2020',
#   '1992',
#   '2019',
#   '1962',
#   '2013',
#   '2006',
#   '2023',
#   '2019',
#   '1995',
#   'I) (',
#   '2019',
#   '2006',
#   '1992',
#   '2012',
#   '1980',
#   'I) (',
#   '2009',
#   '2004',
#   '1963',
#   '2016',
#   '1995',
#   '2017',
#   '2023',
#   '2016',
#   '1979',
#   '1983',
#   'I) (',
#   '1998',
#   '2024',
#   '2014',
#   '2021',
#   '2022',
#   '2023',
#   '2015',
#   '2002',
#   '2003',
#   '2012',
#   '2023',
#   '1982',
#   '1978',
#   '1990',
#   '2002',
#   '1989',
#   '1999',
#   '2000',
#   '2021',
#   '1962',
#   '2013',
#   '2011',
#   'I) (',
#   '1995',
#   '2012',
#   '2010',
#   '2014',
#   '2022',
#   '2010',
#   '2024',
#   '2013',
#   '1986',
#   'I) (',
#   '2022',
#   '2006',
#   '2021',
#   '1990',
#   '2020',
#   '2023',
#   '2008',
#   '2022',
#   '2017',
#   '2009',
#   '1997',
#   '1999',
#   '2015',
#   '2013',
#   '2004',
#   '2019',
#   '2022',
#   '2023',
#   '2011',
#   '2022',
#   '2008',
#   '2008',
#   '2001',
#   '2014',
#   '2012',
#   '2005',
#   'I) (',
#   '2005',
#   '2016',
#   '2019',
#   '2016',
#   '2018',
#   '2005',
#   '2006',
#   '2014',
#   '2016',
#   '2021',
#   '2005',
#   '2003',
#   '1959',
#   '1988',
#   '2021',
#   'I) (',
#   '2016',
#   '2010',
#   '2003',
#   '2019',
#   '2000',
#   '2010',
#   '2022',
#   '1985',
#   'I) (',
#   '2018',
#   '2014',
#   '1997',
#   '1968',
#   '2002',
#   '1973',
#   '1998',
#   '1994',
#   '2007',
#   '1990',
#   '1991',
#   '2000',
#   '2009',
#   '2004',
#   '2010',
#   '1994',
#   '1978',
#   '2006',
#   '2022',
#   '2004',
#   '2005',
#   '1998',
#   '2015',
#   '1993',
#   '2018',
#   '2001',
#   '2014',
#   '1991',
#   '2009',
#   'I) (',
#   'I) (',
#   'I) (',
#   '2013',
#   '1998',
#   'I) (',
#   '1975',
#   '2009',
#   '2004',
#   '1978',
#   '1981',
#   '2000',
#   '2025',
#   '2012',
#   '2012',
#   '2017',
#   'I) (',
#   '2017',
#   '1982',
#   '2019',
#   '2006',
#   '1994',
#   '2017',
#   '2022',
#   '2012',
#   '2011',
#   '2003',
#   '2015',
#   '1995',
#   '2022',
#   '2002',
#   '2014',
#   '1993',
#   '2016',
#   '2003',
#   '2013',
#   '2016',
#   '2012',
#   '1987',
#   '2005',
#   'I) (',
#   '2002',
#   '2014',
#   'I) (',
#   '2021',
#   '2002',
#   '1998',
#   '2019',
#   '2018',
#   '2015',
#   '2004',
#   '2011',
#   '2015',
#   '1989',
#   'I) (',
#   '2007',
#   '2013',
#   '2011',
#   '2021',
#   '1981',
#   '1981',
#   '2015',
#   '2018',
#   '2011',
#   '2021',
#   '2001',
#   '2000',
#   '2016',
#   'I) (',
#   '1997',
#   '2000',
#   '2002',
#   '2024',
#   '1987',
#   '2008',
#   '1968',
#   '1983',
#   'I) (',
#   '2017',
#   '2010',
#   '1999',
#   '2007',
#   '2023',
#   '2022',
#   '2020',
#   '2022',
#   '2021',
#   '2016',
#   '2020',
#   '2013',
#   '2004',
#   '1973',
#   'I) (',
#   '2005',
#   '1960',
#   '2016',
#   '2022',
#   '1993',
#   '2012',
#   '2004',
#   '1993',
#   '1999',
#   '2017',
#   '2003',
#   '2013',
#   '2003',
#   '2019',
#   '2002',
#   '1984',
#   '2015',
#   '2018',
#   '1995',
#   '2019',
#   '2014',
#   '2014',
#   '2006',
#   '2017',
#   '2021',
#   '2007',
#   '2000',
#   '2010',
#   '2019',
#   'I) (',
#   '2012',
#   '1989',
#   '2018',
#   '2022',
#   '1996',
#   '2008',
#   '2010',
#   '2016',
#   '2002',
#   '1999',
#   '2019',
#   '2008',
#   '1937',
#   '2022',
#   '1992',
#   '2011',
#   'I) (',
#   '2011',
#   '2019',
#   '2014',
#   '2020',
#   '2022',
#   'I) (',
#   '1996',
#   '1956',
#   '2001',
#   '1977',
#   '2014',
#   '1989',
#   '2011',
#   '2002',
#   '1976',
#   '2021',
#   '1967',
#   '2009',
#   '1985',
#   'II) ',
#   '2011',
#   '2015',
#   'I) (',
#   '2012',
#   '1990',
#   '1993',
#   '2011',
#   'I) (',
#   '2003',
#   '2001',
#   '2011',
#   'I) (',
#   '1998',
#   '1993',
#   '2014',
#   '2013',
#   '1969',
#   'I) (',
#   '2018',
#   '2014',
#   '1999',
#   '2016',
#   '',
#   '2019',
#   '2017',
#   '2020',
#   '1984',
#   '2004',
#   '2005',
#   '2017',
#   '1990',
#   '2007',
#   '2013',
#   '2006',
#   '2010',
#   '2016',
#   '2020',
#   '1998',
#   '2009',
#   '2019',
#   '1962',
#   '2010',
#   '2018',
#   '1985',
#   '1989',
#   '2018',
#   '1999',
#   '2007',
#   '2008',
#   '2020',
#   '2015',
#   '2003',
#   '1967',
#   '2015',
#   '2010',
#   'IX)',
#   '2013',
#   '2016',
#   '1996',
#   '2008',
#   '2008',
#   '1964',
#   '2008',
#   '2008',
#   '2014',
#   '1999',
#   '2015',
#   '2002',
#   'I) (',
#   '1981',
#   '2009',
#   '2007',
#   '1991',
#   '2017',
#   '2017',
#   '2000',
#   '2004',
#   '2018',
#   '2009',
#   '2022',
#   '2002',
#   '1984',
#   '2013',
#   '2018',
#   '2007',
#   '1980',
#   '2021',
#   '1995',
#   '2006',
#   '1982',
#   '2013',
#   '2022',
#   '1959',
#   '1972',
#   '1987',
#   '2021',
#   '2021',
#   'I) (',
#   '2021',
#   '2023',
#   '2018',
#   '2005',
#   '2000',
#   '1994',
#   '2002',
#   '2021',
#   '2024',
#   'I) (',
#   '2013',
#   '2017',
#   '2007',
#   '1957',
#   '1995',
#   '1953',
#   '2024',
#   '1989',
#   '2016',
#   '2020',
#   '1997',
#   '2007',
#   '1997',
#   '2014',
#   '1979',
#   '2012',
#   '1981',
#   '1951',
#   '2016',
#   '2021',
#   '1979',
#   '1981',
#   '2015',
#   'I) (',
#   '2007',
#   '1963',
#   '1996',
#   '2000',
#   '2019',
#   '2021',
#   '2004',
#   '2021',
#   '1997',
#   '2007',
#   '2016',
#   '2008',
#   '1992',
#   '1987',
#   '2022',
#   '2012',
#   '2020',
#   '1982',
#   '1986',
#   'II) ',
#   '2018',
#   '2009',
#   '2016',
#   '1984',
#   '2011',
#   '1972',
#   '2017',
#   '1984',
#   '2007',
#   '1970',
#   '2008',
#   '1969',
#   '2004',
#   '1976',
#   '2017',
#   '1995',
#   '1945',
#   '2016',
#   '2006',
#   '1986',
#   '2016',
#   '2003',
#   '2019',
#   '2016',
#   '1959',
#   '2008',
#   '1969',
#   '2015',
#   '',
#   '2025',
#   '2016',
#   '2000',
#   '2011',
#   '2004',
#   '2023',
#   '2023',
#   '2008',
#   '1948',
#   '1996',
#   '2022',
#   '2018',
#   '1983',
#   '1996',
#   '1990',
#   '2004',
#   '1985',
#   '2013',
#   '2008',
#   '2021',
#   '2020',
#   '1980',
#   '2022',
#   '2003',
#   '1989',
#   '2015',
#   '1984',
#   '1987',
#   '2016',
#   'I) (',
#   '2021',
#   '2021',
#   'I) (',
#   '2018',
#   '2001',
#   '2015',
#   'II) ',
#   '2004',
#   '2019',
#   '2019',
#   '1998',
#   '2007',
#   '2017',
#   '2019',
#   '2013',
#   '2024',
#   '2016',
#   '2014',
#   '1956',
#   '1960',
#   '1961',
#   '1977',
#   'I) (',
#   '1956',
#   '1980',
#   'I) (',
#   '2014',
#   '2016',
#   '2006',
#   '1985',
#   '2022',
#   '2011',
#   '1968',
#   '2017',
#   '1980',
#   'I) (',
#   '1994',
#   '2010',
#   '1986',
#   '2006',
#   '1982',
#   '',
#   '2011',
#   '2005',
#   '1993',
#   '2008',
#   '1985',
#   '1961',
#   '1968',
#   '2018',
#   '2022',
#   '1997',
#   '2003',
#   '1995',
#   '2019',
#   '2019',
#   '2016',
#   '2007',
#   '1994',
#   '1933',
#   '2010',
#   '2013',
#   '2019',
#   '1993',
#   '1997',
#   '2012',
#   'III)',
#   '2018',
#   '1997',
#   '2011',
#   '1986',
#   '2017',
#   '1971',
#   '1965',
#   '1991',
#   '1985',
#   '2021',
#   '2003',
#   '2024',
#   '1989',
#   '2009',
#   '2009',
#   '2003',
#   '2019',
#   '2003',
#   '2000',
#   '2015',
#   '2006',
#   '2018',
#   '2020',
#   '2012',
#   '1991',
#   '2022',
#   '2021',
#   '2021',
#   '1985',
#   '1985',
#   '2018',
#   '2024',
#   '1981',
#   '2019',
#   '2022',
#   '2003',
#   '1966',
#   '1973',
#   '1937',
#   '1988',
#   '2002',
#   'I) (',
#   '2008',
#   '1965',
#   '1974',
#   '2022',
#   '2016',
#   '1983',
#   '2002',
# ...
#   'https://m.media-amazon.com/images/M/MV5BMzcwMjkxMzQ3NV5BMl5BanBnXkFtZTgwMzgyNDA5MDI@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BZjE1NTc2MzAtZTgzNi00ZmY0LWIxNjUtZTQwMjdlNTY0ZTM2XkEyXkFqcGdeQXVyMjUzOTY1NTc@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BZGNhYjM3ZmQtMTRlZS00YmZiLWFhYjktYWE3ZTk0MGY0MTIwXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5B
CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTUyMDA3OTc4MV5BMl5BanBnXkFtZTcwNzE5NjkzMQ@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMTgxMDczMTA5N15BMl5BanBnXkFtZTcwMzk1MzMzMw@@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BODI4OTk1ODY3N15BMl5BanBnXkFtZTgwMDI1MTcwNjM@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BMDg2NzQwOGMtMGRkNC00YjAwLTg4NjgtZWQwYzljZmM1YzA4XkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_UX67_CR0,0,67,98_AL_.jpg',
#   'https://m.media-amazon.com/images/M/MV5BOGQzODdlMDktNzU4ZC00N2M3LWFkYTAtYTM1NTE0ZWI5YTg4XkEyXkFqcGdeQXVyMTA1NTM1NDI2._V1_UX67_CR0,0,67,98_AL_.jpg',
#   ...]}

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df.head()
# Out:
#                           Movie Name     IMDB ID Year of Release Watch Time  \
# 0             Thor: Love and Thunder  tt10648342            2022    118 min
# 1                          Pinocchio   tt4593060            I) (    105 min
# 2           Avatar: The Way of Water   tt1630029            2022       None
# 3                 The Little Mermaid   tt5971474            2023       None
# 4  Everything Everywhere All at Once   tt6710474            2022    139 min
#
#   Movie Rating                                  Genres  \
# 0          6.4   Action, Adventure, Comedy
# 1          5.1    Adventure, Comedy, Drama
# 2         None  Action, Adventure, Fantasy
# 3         None  Adventure, Family, Fantasy
# 4          8.1   Action, Adventure, Comedy
#
#                                          Description         Director  \
# 0  Thor enlists the help of Valkyrie, Korg and ex...    Taika Waititi
# 1  A puppet is brought to life by a fairy, who as...  Robert Zemeckis
# 2  Jake Sully lives with his newfound family form...    James Cameron
# 3  A young mermaid makes a deal with a sea witch,...     Rob Marshall
# 4  An aging Chinese immigrant is swept up in an i...         Dan Kwan
#
#                                  Cast  \
# 0  (Chris Hemsworth, Natalie Portman)
# 1   (Joseph Gordon-Levitt, Tom Hanks)
# 2         (Zoe Saldana, Kate Winslet)
# 3    (Halle Bailey, Jonah Hauer-King)
# 4   (Daniel Scheinert, Michelle Yeoh)
#
#                                           IMDB Image
# 0  https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1  https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 2  https://m.media-amazon.com/images/M/MV5BMWFmYm...
# 3  https://m.media-amazon.com/images/M/MV5BZWUxOG...
# 4  https://m.media-amazon.com/images/M/MV5BYTdiOT...

# %%
df['IMDB Image']
# Out:
# 0       https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1       https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 2       https://m.media-amazon.com/images/M/MV5BMWFmYm...
# 3       https://m.media-amazon.com/images/M/MV5BZWUxOG...
# 4       https://m.media-amazon.com/images/M/MV5BYTdiOT...
#                               ...
# 9995    https://m.media-amazon.com/images/M/MV5BMjA4OT...
# 9996    https://m.media-amazon.com/images/M/MV5BMWYxZD...
# 9997    https://m.media-amazon.com/images/M/MV5BZGU2OD...
# 9998    https://m.media-amazon.com/images/M/MV5BMDZjNG...
# 9999    https://m.media-amazon.com/images/M/MV5BMTM1Yz...
# Name: IMDB Image, Length: 10000, dtype: object

# %%
df.shape
# Out:
# (10000, 10)

# %%
df['Movie Name'].value_counts()
# Out:
# Treasure Island          11
# The Three Musketeers     10
# Robin Hood                6
# Alice in Wonderland       6
# Prey                      5
#                          ..
# Year of the Comet         1
# Sands of the Kalahari     1
# Cowgirls 'n Angels        1
# The Last Samurai          1
# Myortvyy sezon            1
# Name: Movie Name, Length: 9631, dtype: int64

# %%
df.tail()
# Out:
#                 Movie Name    IMDB ID Year of Release Watch Time Movie Rating  \
# 9995                Tropix  tt0314803            2004    101 min          3.5
# 9996   Enforcer: The Asset  tt5791654                    110 min         None
# 9997       Maha Shaktimaan  tt0363786            1985    109 min          6.9
# 9998  The Sexy Lady Driver  tt1354548            1982     88 min         None
# 9999        Myortvyy sezon  tt0063332            1968    138 min          7.4
#
#                                       Genres  \
# 9995  Adventure, Crime, Thriller
# 9996   Action, Adventure, Comedy
# 9997  Action, Adventure, Fantasy
# 9998                   Adventure
# 9999            Adventure, Drama
#
#                                             Description           Director  \
# 9995  Erotic Thriller (2004) A tropical vacation goe...      Percy Angress
# 9996  A major breach at the NSA sends Peter on the a...        Don Maxwell
# 9997  Maharaja Purshotam Singh rules over his kingdo...       Swamy V.S.R.
# 9998                                         Add a Plot  Yung-Hsiang Chang
# 9999  Soviet spy Ladeynikov learns that in one of th...       Savva Kulish
#
#                                       Cast  \
# 9995  (Livia Linden, Thomas Scott Stanton)
# 9996            (Don Maxwell, Terry Moore)
# 9997     (Raj Babbar, Meenakshi Sheshadri)
# 9998          (Hsiao-Fen Lu, Fu-Mei Chang)
# 9999       (Donatas Banionis, Rolan Bykov)
#
#                                              IMDB Image
# 9995  https://m.media-amazon.com/images/M/MV5BMjA4OT...
# 9996  https://m.media-amazon.com/images/M/MV5BMWYxZD...
# 9997  https://m.media-amazon.com/images/M/MV5BZGU2OD...
# 9998  https://m.media-amazon.com/images/M/MV5BMDZjNG...
# 9999  https://m.media-amazon.com/images/M/MV5BMTM1Yz...

# %%
df = df.dropna()
df
# Out:
#                                              Movie Name     IMDB ID  \
# 0                                Thor: Love and Thunder  tt10648342
# 1                                             Pinocchio   tt4593060
# 4                     Everything Everywhere All at Once   tt6710474
# 5                                                Avatar   tt0499549
# 6     The Lord of the Rings: The Fellowship of the Ring   tt0120737
# ...                                                 ...         ...
# 9992                        Ne poslat li nam... gontsa?   tt0365548
# 9994                                       Rapto al sol   tt0049657
# 9995                                             Tropix   tt0314803
# 9997                                    Maha Shaktimaan   tt0363786
# 9999                                     Myortvyy sezon   tt0063332
#
#      Year of Release Watch Time Movie Rating  \
# 0               2022    118 min          6.4
# 1               I) (    105 min          5.1
# 4               2022    139 min          8.1
# 5               2009    162 min          7.8
# 6               2001    178 min          8.8
# ...              ...        ...          ...
# 9992            1998     99 min          6.2
# 9994            1956     90 min          5.5
# 9995            2004    101 min          3.5
# 9997            1985    109 min          6.9
# 9999            1968    138 min          7.4
#
#                                       Genres  \
# 0      Action, Adventure, Comedy
# 1       Adventure, Comedy, Drama
# 4      Action, Adventure, Comedy
# 5     Action, Adventure, Fantasy
# 6       Action, Adventure, Drama
# ...                                      ...
# 9992    Adventure, Comedy, Drama
# 9994            Drama, Adventure
# 9995  Adventure, Crime, Thriller
# 9997  Action, Adventure, Fantasy
# 9999            Adventure, Drama
#
#                                             Description         Director  \
# 0     Thor enlists the help of Valkyrie, Korg and ex...    Taika Waititi
# 1     A puppet is brought to life by a fairy, who as...  Robert Zemeckis
# 4     An aging Chinese immigrant is swept up in an i...         Dan Kwan
# 5     A paraplegic Marine dispatched to the moon Pan...    James Cameron
# 6     A meek Hobbit from the Shire and eight compani...    Peter Jackson
# ...                                                 ...              ...
# 9992  Farmer Ivan travels from his village to Moscow...    Valeri Chikov
# 9994  Strong-willed independent owner of trading com...  Fernando Méndez
# 9995  Erotic Thriller (2004) A tropical vacation goe...    Percy Angress
# 9997  Maharaja Purshotam Singh rules over his kingdo...     Swamy V.S.R.
# 9999  Soviet spy Ladeynikov learns that in one of th...     Savva Kulish
#
#                                         Cast  \
# 0         (Chris Hemsworth, Natalie Portman)
# 1          (Joseph Gordon-Levitt, Tom Hanks)
# 4          (Daniel Scheinert, Michelle Yeoh)
# 5             (Sam Worthington, Zoe Saldana)
# 6                (Elijah Wood, Ian McKellen)
# ...                                      ...
# 9992        (Igor Ivanov, Mikhail Evdokimov)
# 9994  (Gilberto Gazcón, Evangelina Elizondo)
# 9995    (Livia Linden, Thomas Scott Stanton)
# 9997       (Raj Babbar, Meenakshi Sheshadri)
# 9999         (Donatas Banionis, Rolan Bykov)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BYmMxZW...
# 1     https://m.media-amazon.com/images/M/MV5BZDIyYj...
# 4     https://m.media-amazon.com/images/M/MV5BYTdiOT...
# 5     https://m.media-amazon.com/images/M/MV5BNjA3NG...
# 6     https://m.media-amazon.com/images/M/MV5BN2EyZj...
# ...                                                 ...
# 9992  https://m.media-amazon.com/images/M/MV5BMWFhN2...
# 9994  https://m.media-amazon.com/images/S/sash/NapCx...
# 9995  https://m.media-amazon.com/images/M/MV5BMjA4OT...
# 9997  https://m.media-amazon.com/images/M/MV5BZGU2OD...
# 9999  https://m.media-amazon.com/images/M/MV5BMTM1Yz...
#
# [8910 rows x 10 columns]

# %%
df.sort_values("Movie Name", inplace=True)
df
# Out:
#                               Movie Name     IMDB ID Year of Release  \
# 7402  $50K and a Call Girl: A Love Story   tt2106284            2014
# 1884                         'Gator Bait   tt0074080            1973
# 5022                   'Pimpernel' Smith   tt0034027            1941
# 9494                 10 Days in Sun City  tt10499474            2017
# 5319                    10 Endrathukulla   tt5128266            2015
# ...                                  ...         ...             ...
# 7258                               Ámbar   tt0109094            1994
# 963                             Æon Flux   tt0402022            2005
# 9442                            Çalikusu   tt0208842            1966
# 9541                            Ésimésac   tt2458582            2012
# 6815                         Özgür Dünya   tt9308170            2019
#
#      Watch Time Movie Rating                                   Genres  \
# 7402     90 min          6.8    Action, Adventure, Comedy
# 1884     88 min          5.4     Action, Adventure, Drama
# 5022    120 min          7.2   Adventure, Drama, Thriller
# 9494     87 min          5.2   Adventure, Comedy, Romance
# 5319    144 min          5.2  Action, Adventure, Thriller
# ...         ...          ...                                      ...
# 7258     91 min          6.3    Adventure, Drama, Mystery
# 963      93 min          5.4    Action, Adventure, Sci-Fi
# 9442    160 min          6.8    Adventure, Drama, Romance
# 9541    104 min          6.0   Adventure, Fantasy, Sci-Fi
# 6815    122 min          2.3    Action, Adventure, Family
#
#                                             Description           Director  \
# 7402  When Ross is diagnosed with terminal brain can...      Seth Grossman
# 1884  Desiree lives deep in the swamp and supports h...  Beverly Sebastian
# 5022  Professor Horatio Smith, while seeming very un...      Leslie Howard
# 9494  A globetrotting traveler, Akpos, brings his gi...          Adze Ugah
# 5319  An enigmatic driving instructor is assigned th...       Vijay Milton
# ...                                                 ...                ...
# 7258  Ambar is a trip that goes beyond the certainti...       Luis Estrada
# 963   Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 9442  An adaptation of Resat Nuri Güntekin's 1922 no...     Osman F. Seden
# 9541  The residents of Saint-Élie-de-Caxton have bar...         Luc Picard
# 6815  The story of a game managed by artificial inte...        Faruk Aksoy
#
#                                       Cast  \
# 7402      (Ross Patterson, Jessie Wiseman)
# 1884    (Ferd Sebastian, Claudia Jennings)
# 5022  (Leslie Howard, Francis L. Sullivan)
# 9494            (Gbenro Ajibade, Ali Baba)
# 5319        (Vikram, Samantha Ruth Prabhu)
# ...                                    ...
# 7258       (Jorge Russek, Alfredo Sevilla)
# 963   (Charlize Theron, Frances McDormand)
# 9442          (Türkan Soray, Kartal Tibet)
# 9541     (Nicola-Frank Vachon, Gildor Roy)
# 6815             (Sevki Es, Murat Serezli)
#
#                                              IMDB Image
# 7402  https://m.media-amazon.com/images/M/MV5BMTY3OT...
# 1884  https://m.media-amazon.com/images/M/MV5BMTI2Nj...
# 5022  https://m.media-amazon.com/images/M/MV5BOGU2Yz...
# 9494  https://m.media-amazon.com/images/M/MV5BNjdlYz...
# 5319  https://m.media-amazon.com/images/M/MV5BMzk3OT...
# ...                                                 ...
# 7258  https://m.media-amazon.com/images/M/MV5BMjRkMD...
# 963   https://m.media-amazon.com/images/M/MV5BMTc2Mz...
# 9442  https://m.media-amazon.com/images/M/MV5BNDAyMD...
# 9541  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 6815  https://m.media-amazon.com/images/M/MV5BMmViYz...
#
# [8910 rows x 10 columns]

# %%
df['Movie Name'].value_counts()
# Out:
# Treasure Island         11
# The Three Musketeers    10
# Prey                     5
# She                      5
# Robin Hood               5
#                         ..
# Hotel Transylvania       1
# Hotel Colonial           1
# Hot Snake                1
# Hot Pepper               1
# Özgür Dünya              1
# Name: Movie Name, Length: 8608, dtype: int64

# %%
df = df.drop_duplicates(subset=['IMDB ID'])
df
# Out:
#                               Movie Name     IMDB ID Year of Release  \
# 7402  $50K and a Call Girl: A Love Story   tt2106284            2014
# 1884                         'Gator Bait   tt0074080            1973
# 5022                   'Pimpernel' Smith   tt0034027            1941
# 9494                 10 Days in Sun City  tt10499474            2017
# 5319                    10 Endrathukulla   tt5128266            2015
# ...                                  ...         ...             ...
# 7258                               Ámbar   tt0109094            1994
# 963                             Æon Flux   tt0402022            2005
# 9442                            Çalikusu   tt0208842            1966
# 9541                            Ésimésac   tt2458582            2012
# 6815                         Özgür Dünya   tt9308170            2019
#
#      Watch Time Movie Rating                                   Genres  \
# 7402     90 min          6.8    Action, Adventure, Comedy
# 1884     88 min          5.4     Action, Adventure, Drama
# 5022    120 min          7.2   Adventure, Drama, Thriller
# 9494     87 min          5.2   Adventure, Comedy, Romance
# 5319    144 min          5.2  Action, Adventure, Thriller
# ...         ...          ...                                      ...
# 7258     91 min          6.3    Adventure, Drama, Mystery
# 963      93 min          5.4    Action, Adventure, Sci-Fi
# 9442    160 min          6.8    Adventure, Drama, Romance
# 9541    104 min          6.0   Adventure, Fantasy, Sci-Fi
# 6815    122 min          2.3    Action, Adventure, Family
#
#                                             Description           Director  \
# 7402  When Ross is diagnosed with terminal brain can...      Seth Grossman
# 1884  Desiree lives deep in the swamp and supports h...  Beverly Sebastian
# 5022  Professor Horatio Smith, while seeming very un...      Leslie Howard
# 9494  A globetrotting traveler, Akpos, brings his gi...          Adze Ugah
# 5319  An enigmatic driving instructor is assigned th...       Vijay Milton
# ...                                                 ...                ...
# 7258  Ambar is a trip that goes beyond the certainti...       Luis Estrada
# 963   Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 9442  An adaptation of Resat Nuri Güntekin's 1922 no...     Osman F. Seden
# 9541  The residents of Saint-Élie-de-Caxton have bar...         Luc Picard
# 6815  The story of a game managed by artificial inte...        Faruk Aksoy
#
#                                       Cast  \
# 7402      (Ross Patterson, Jessie Wiseman)
# 1884    (Ferd Sebastian, Claudia Jennings)
# 5022  (Leslie Howard, Francis L. Sullivan)
# 9494            (Gbenro Ajibade, Ali Baba)
# 5319        (Vikram, Samantha Ruth Prabhu)
# ...                                    ...
# 7258       (Jorge Russek, Alfredo Sevilla)
# 963   (Charlize Theron, Frances McDormand)
# 9442          (Türkan Soray, Kartal Tibet)
# 9541     (Nicola-Frank Vachon, Gildor Roy)
# 6815             (Sevki Es, Murat Serezli)
#
#                                              IMDB Image
# 7402  https://m.media-amazon.com/images/M/MV5BMTY3OT...
# 1884  https://m.media-amazon.com/images/M/MV5BMTI2Nj...
# 5022  https://m.media-amazon.com/images/M/MV5BOGU2Yz...
# 9494  https://m.media-amazon.com/images/M/MV5BNjdlYz...
# 5319  https://m.media-amazon.com/images/M/MV5BMzk3OT...
# ...                                                 ...
# 7258  https://m.media-amazon.com/images/M/MV5BMjRkMD...
# 963   https://m.media-amazon.com/images/M/MV5BMTc2Mz...
# 9442  https://m.media-amazon.com/images/M/MV5BNDAyMD...
# 9541  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 6815  https://m.media-amazon.com/images/M/MV5BMmViYz...
#
# [8910 rows x 10 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                               Movie Name     IMDB ID Year of Release  \
# 0     $50K and a Call Girl: A Love Story   tt2106284            2014
# 1                            'Gator Bait   tt0074080            1973
# 2                      'Pimpernel' Smith   tt0034027            1941
# 3                    10 Days in Sun City  tt10499474            2017
# 4                       10 Endrathukulla   tt5128266            2015
# ...                                  ...         ...             ...
# 8905                               Ámbar   tt0109094            1994
# 8906                            Æon Flux   tt0402022            2005
# 8907                            Çalikusu   tt0208842            1966
# 8908                            Ésimésac   tt2458582            2012
# 8909                         Özgür Dünya   tt9308170            2019
#
#      Watch Time Movie Rating                                   Genres  \
# 0        90 min          6.8    Action, Adventure, Comedy
# 1        88 min          5.4     Action, Adventure, Drama
# 2       120 min          7.2   Adventure, Drama, Thriller
# 3        87 min          5.2   Adventure, Comedy, Romance
# 4       144 min          5.2  Action, Adventure, Thriller
# ...         ...          ...                                      ...
# 8905     91 min          6.3    Adventure, Drama, Mystery
# 8906     93 min          5.4    Action, Adventure, Sci-Fi
# 8907    160 min          6.8    Adventure, Drama, Romance
# 8908    104 min          6.0   Adventure, Fantasy, Sci-Fi
# 8909    122 min          2.3    Action, Adventure, Family
#
#                                             Description           Director  \
# 0     When Ross is diagnosed with terminal brain can...      Seth Grossman
# 1     Desiree lives deep in the swamp and supports h...  Beverly Sebastian
# 2     Professor Horatio Smith, while seeming very un...      Leslie Howard
# 3     A globetrotting traveler, Akpos, brings his gi...          Adze Ugah
# 4     An enigmatic driving instructor is assigned th...       Vijay Milton
# ...                                                 ...                ...
# 8905  Ambar is a trip that goes beyond the certainti...       Luis Estrada
# 8906  Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 8907  An adaptation of Resat Nuri Güntekin's 1922 no...     Osman F. Seden
# 8908  The residents of Saint-Élie-de-Caxton have bar...         Luc Picard
# 8909  The story of a game managed by artificial inte...        Faruk Aksoy
#
#                                       Cast  \
# 0         (Ross Patterson, Jessie Wiseman)
# 1       (Ferd Sebastian, Claudia Jennings)
# 2     (Leslie Howard, Francis L. Sullivan)
# 3               (Gbenro Ajibade, Ali Baba)
# 4           (Vikram, Samantha Ruth Prabhu)
# ...                                    ...
# 8905       (Jorge Russek, Alfredo Sevilla)
# 8906  (Charlize Theron, Frances McDormand)
# 8907          (Türkan Soray, Kartal Tibet)
# 8908     (Nicola-Frank Vachon, Gildor Roy)
# 8909             (Sevki Es, Murat Serezli)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BMTY3OT...
# 1     https://m.media-amazon.com/images/M/MV5BMTI2Nj...
# 2     https://m.media-amazon.com/images/M/MV5BOGU2Yz...
# 3     https://m.media-amazon.com/images/M/MV5BNjdlYz...
# 4     https://m.media-amazon.com/images/M/MV5BMzk3OT...
# ...                                                 ...
# 8905  https://m.media-amazon.com/images/M/MV5BMjRkMD...
# 8906  https://m.media-amazon.com/images/M/MV5BMTc2Mz...
# 8907  https://m.media-amazon.com/images/M/MV5BNDAyMD...
# 8908  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 8909  https://m.media-amazon.com/images/M/MV5BMmViYz...
#
# [8910 rows x 10 columns]

# %%
df
# Out:
#                               Movie Name     IMDB ID Year of Release  \
# 0     $50K and a Call Girl: A Love Story   tt2106284            2014
# 1                            'Gator Bait   tt0074080            1973
# 2                      'Pimpernel' Smith   tt0034027            1941
# 3                    10 Days in Sun City  tt10499474            2017
# 4                       10 Endrathukulla   tt5128266            2015
# ...                                  ...         ...             ...
# 8905                               Ámbar   tt0109094            1994
# 8906                            Æon Flux   tt0402022            2005
# 8907                            Çalikusu   tt0208842            1966
# 8908                            Ésimésac   tt2458582            2012
# 8909                         Özgür Dünya   tt9308170            2019
#
#      Watch Time Movie Rating                                   Genres  \
# 0        90 min          6.8    Action, Adventure, Comedy
# 1        88 min          5.4     Action, Adventure, Drama
# 2       120 min          7.2   Adventure, Drama, Thriller
# 3        87 min          5.2   Adventure, Comedy, Romance
# 4       144 min          5.2  Action, Adventure, Thriller
# ...         ...          ...                                      ...
# 8905     91 min          6.3    Adventure, Drama, Mystery
# 8906     93 min          5.4    Action, Adventure, Sci-Fi
# 8907    160 min          6.8    Adventure, Drama, Romance
# 8908    104 min          6.0   Adventure, Fantasy, Sci-Fi
# 8909    122 min          2.3    Action, Adventure, Family
#
#                                             Description           Director  \
# 0     When Ross is diagnosed with terminal brain can...      Seth Grossman
# 1     Desiree lives deep in the swamp and supports h...  Beverly Sebastian
# 2     Professor Horatio Smith, while seeming very un...      Leslie Howard
# 3     A globetrotting traveler, Akpos, brings his gi...          Adze Ugah
# 4     An enigmatic driving instructor is assigned th...       Vijay Milton
# ...                                                 ...                ...
# 8905  Ambar is a trip that goes beyond the certainti...       Luis Estrada
# 8906  Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 8907  An adaptation of Resat Nuri Güntekin's 1922 no...     Osman F. Seden
# 8908  The residents of Saint-Élie-de-Caxton have bar...         Luc Picard
# 8909  The story of a game managed by artificial inte...        Faruk Aksoy
#
#                                       Cast  \
# 0         (Ross Patterson, Jessie Wiseman)
# 1       (Ferd Sebastian, Claudia Jennings)
# 2     (Leslie Howard, Francis L. Sullivan)
# 3               (Gbenro Ajibade, Ali Baba)
# 4           (Vikram, Samantha Ruth Prabhu)
# ...                                    ...
# 8905       (Jorge Russek, Alfredo Sevilla)
# 8906  (Charlize Theron, Frances McDormand)
# 8907          (Türkan Soray, Kartal Tibet)
# 8908     (Nicola-Frank Vachon, Gildor Roy)
# 8909             (Sevki Es, Murat Serezli)
#
#                                              IMDB Image
# 0     https://m.media-amazon.com/images/M/MV5BMTY3OT...
# 1     https://m.media-amazon.com/images/M/MV5BMTI2Nj...
# 2     https://m.media-amazon.com/images/M/MV5BOGU2Yz...
# 3     https://m.media-amazon.com/images/M/MV5BNjdlYz...
# 4     https://m.media-amazon.com/images/M/MV5BMzk3OT...
# ...                                                 ...
# 8905  https://m.media-amazon.com/images/M/MV5BMjRkMD...
# 8906  https://m.media-amazon.com/images/M/MV5BMTc2Mz...
# 8907  https://m.media-amazon.com/images/M/MV5BNDAyMD...
# 8908  https://m.media-amazon.com/images/M/MV5BOWZjMz...
# 8909  https://m.media-amazon.com/images/M/MV5BMmViYz...
#
# [8910 rows x 10 columns]

# %%
df.to_csv('adventure.csv')

# %%
df[df['Movie Name'] == 'Man in Love']
# Out:
# Empty DataFrame
# Columns: [Movie Name, IMDB ID, Year of Release, Watch Time, Movie Rating, Genres, Description, Director, Cast, IMDB Image]
# Index: []

# %%
pag = requests.get("")
soup = BeautifulSoup(pag.text, 'html.parser')
movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
sleep(randint(2,8))
for store in movie_data:
  name = store.find('h3', class_= 'lister-item-header').find('a').text
  movie_name.append(name)

  release = store.find('h3', class_= 'lister-item-header')
  try:
    year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
    year.append(year_of_release)
  except:
    year.append(None)

  try: 
     runtime = store.p.find('span', class_ = 'runtime').text[0:7]
     time.append(runtime)
  except:
      time.append(None)

  rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
  try:
      ratings = (rate.find('strong').text)
      rating.append(ratings)
  except:
       rating.append(None)

  genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
  genres.append(genre)

  describe = store.find_all('p', class_ = 'text-muted')
  description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
  description.append(description_)
            
  try:
    direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
    director.append(direct)
  except:
    director.append(None)

  try:
      cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
      casts.append(cast)
  except:
      casts.append(None)

  try:
      image = store.find('img')
      imge = image['loadlate']
      images.append(imge)  
  except:
       images.append(None)

  numbers = store.find('img')
  num = numbers['data-tconst'][:]
  try:
    number.append(num)
  except:
    number.append(None)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-20-9ace1c231f90> in <module>
# ----> 1 pag = requests.get("")
#       2 soup = BeautifulSoup(pag.text, 'html.parser')
#       3 movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
#       4 sleep(randint(2,8))
#       5 for store in movie_data:
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     514             hooks=hooks,
#     515         )
# --> 516         prep = self.prepare_request(req)
#     517
#     518         proxies = proxies or {}
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in prepare_request(self, request)
#     457             auth=merge_setting(auth, self.auth),
#     458             cookies=merged_cookies,
# --> 459             hooks=merge_hooks(request.hooks, self.hooks),
#     460         )
#     461         return p
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     312
#     313         self.prepare_method(method)
# --> 314         self.prepare_url(url, params)
#     315         self.prepare_headers(headers)
#     316         self.prepare_cookies(cookies)
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in prepare_url(self, url, params)
#     386             error = error.format(to_native_string(url, 'utf8'))
#     387
# --> 388             raise MissingSchema(error)
#     389
#     390         if not host:
#
# MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?
