# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/Animation_movie_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(1,8100,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=Animation&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)


            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601, 651, 701, 751, 801, 851, 901, 951, 1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151, 2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701, 2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251, 3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801, 3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351, 4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901, 4951, 5001, 5051, 5101, 5151, 5201, 5251, 5301, 5351, 5401, 5451, 5501, 5551, 5601, 5651, 5701, 5751, 5801, 5851, 5901, 5951, 6001, 6051, 6101, 6151, 6201, 6251, 6301, 6351, 6401, 6451, 6501, 6551, 6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101, 7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651, 7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051]

# %%
a = { "Movie Name": movie_name, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts}

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df.head()
# Out:
#             Movie Name Year of Release Watch Time Movie Rating  \
# 0  Don't Worry Darling            I) (    122 min          6.3
# 1              Babylon            I) (       None         None
# 2       The Woman King            2022    135 min          6.1
# 3               Blonde            2022    166 min          6.3
# 4            Pinocchio            I) (    105 min          5.1
#
#                                   Genres  \
# 0   Drama, Mystery, Thriller
# 1     Comedy, Drama, History
# 2     Action, Drama, History
# 3  Biography, Drama, Mystery
# 4   Adventure, Comedy, Drama
#
#                                          Description               Director  \
# 0  A 1950s housewife living with her husband in a...           Olivia Wilde
# 1  A tale of outsized ambition and outrageous exc...        Damien Chazelle
# 2  A historical epic inspired by true events that...  Gina Prince-Bythewood
# 3  A fictionalized chronicle of the inner life of...         Andrew Dominik
# 4  A puppet is brought to life by a fairy, who as...        Robert Zemeckis
#
#                                 Cast
# 0      (Florence Pugh, Harry Styles)
# 1         (Brad Pitt, Margot Robbie)
# 2         (Viola Davis, Thuso Mbedu)
# 3        (Ana de Armas, Lucy DeVito)
# 4  (Joseph Gordon-Levitt, Tom Hanks)

# %%
df.shape
# Out:
# (12727, 8)

# %%
df['Movie Name'].value_counts()
# Out:
# Pinocchio                                  7
# Halloween                                  7
# Dracula                                    6
# Black Christmas                            6
# The Lion King                              6
#                                           ..
# The Tower                                  1
# The Secret Princess                        1
# Human Lost                                 1
# Chhota Bheem Ki Baazi                      1
# Master Giovanni N: Blast Into the Flim!    1
# Name: Movie Name, Length: 10880, dtype: int64

# %%
df.tail()
# Out:
#                                     Movie Name Year of Release Watch Time  \
# 12722                          Billy Blue Bird                       None
# 12723                The Boy Who Hated Numbers                       None
# 12724        Bamse och världens minsta äventyr            2023       None
# 12725                             Eisen Flügel                       None
# 12726  Master Giovanni N: Blast Into the Flim!                       None
#
#       Movie Rating                 Genres  \
# 12722         None  Animation
# 12723         None  Animation
# 12724         None  Animation
# 12725         None  Animation
# 12726         None  Animation
#
#                                              Description             Director  \
# 12722                             Plot kept under wraps.                 None
# 12723  Somewhere in the remote areas of Western North...                 None
# 12724                                         Add a Plot  Christian Ryltenius
# 12725                                         Add a Plot      Seiji Mizushima
# 12726                                         Add a Plot             Giovanni
#
#                                  Cast
# 12722                            None
# 12723                            None
# 12724  (Rolf Lassgård, Johan Ulveson)
# 12725                            None
# 12726                            None

# %%
df = df.dropna()
df
# Out:
#                                        Movie Name Year of Release Watch Time  \
# 0                             Don't Worry Darling            I) (    122 min
# 2                                  The Woman King            2022    135 min
# 3                                          Blonde            2022    166 min
# 4                                       Pinocchio            I) (    105 min
# 5                                       The Whale            2022    117 min
# ...                                           ...             ...        ...
# 12572                        El Bandido Cucaracha            2015     74 min
# 12618              História Antes de Uma História            2014     80 min
# 12645                            Magiczna Gwiazda            2003     60 min
# 12694                                  Acid Space            2015     70 min
# 12698  Castelao (Biografía de un ilustre gallego)            1980     90 min
#
#       Movie Rating                                 Genres  \
# 0              6.3   Drama, Mystery, Thriller
# 2              6.1     Action, Drama, History
# 3              6.3  Biography, Drama, Mystery
# 4              5.1   Adventure, Comedy, Drama
# 5              9.0                      Drama
# ...            ...                                    ...
# 12572          7.4         Animation, Western
# 12618          7.2                  Animation
# 12645          6.0                  Animation
# 12694          5.5  Animation, Fantasy, Music
# 12698          7.3                  Animation
#
#                                              Description  \
# 0      A 1950s housewife living with her husband in a...
# 2      A historical epic inspired by true events that...
# 3      A fictionalized chronicle of the inner life of...
# 4      A puppet is brought to life by a fairy, who as...
# 5      A reclusive English teacher living with severe...
# ...                                                  ...
# 12572  This is the story of Mariano Gavín's life and ...
# 12618                                         Add a Plot
# 12645                                         Add a Plot
# 12694  The famous rock band "Paperback Music" is unwi...
# 12698                                         Add a Plot
#
#                     Director                                        Cast
# 0               Olivia Wilde               (Florence Pugh, Harry Styles)
# 2      Gina Prince-Bythewood                  (Viola Davis, Thuso Mbedu)
# 3             Andrew Dominik                 (Ana de Armas, Lucy DeVito)
# 4            Robert Zemeckis           (Joseph Gordon-Levitt, Tom Hanks)
# 5           Darren Aronofsky                (Brendan Fraser, Sadie Sink)
# ...                      ...                                         ...
# 12572            Juan Alonso               (Héctor Pisa, Javier Coronas)
# 12618       Wilson Lazaretti               (Lóra Brito, Fabio de Castro)
# 12645          Wieslaw Zieba           (Iwona Choluj, Leszek Filipowicz)
# 12694       Stefano Bertelli  (Alessio De Filippis, Stefano Broccoletti)
# 12698         Jorge Preloran         (Manolo Ferrol, Luis Medina Castro)
#
# [8324 rows x 8 columns]

# %%
df.sort_values("Movie Name", inplace=True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                    Movie Name Year of Release Watch Time Movie Rating  \
# 1184                   #Alive            2020     98 min          6.3
# 2484                   #Alive            2020     98 min          6.3
# 10128            #TubeClash02            2016     86 min          7.4
# 5816                    $9.99            2008     78 min          6.7
# 7551         .Hack//The Movie            2012    112 min          6.3
# ...                       ...             ...        ...          ...
# 8292            Æblet & ormen            2009     75 min          6.4
# 9480       Çanakkale Geçilmez            2008     80 min          6.3
# 7789   Ének a csodaszarvasról            2002     89 min          6.8
# 7312            Érase una vez            1950     90 min          7.1
# 3609                Évolution            2015     81 min          5.9
#
#                                         Genres  \
# 1184         Action, Drama, Horror
# 2484         Action, Drama, Horror
# 10128     Animation, Comedy, Drama
# 5816     Animation, Drama, Fantasy
# 7551     Animation, Action, Sci-Fi
# ...                                        ...
# 8292             Animation, Family
# 9480                     Animation
# 7789   Animation, Fantasy, History
# 7312                     Animation
# 3609        Drama, Horror, Mystery
#
#                                              Description  \
# 1184   The rapid spread of an unknown infection has l...
# 2484   The rapid spread of an unknown infection has l...
# 10128  After the events of "#TubeClash", ten new Germ...
# 5816   A stop-motion animated story about people livi...
# 7551   In 2024, the computer network prevails through...
# ...                                                  ...
# 8292   an apple gets a worm in him and goes on a long...
# 9480                                          Add a Plot
# 7789   Divided into four sections, "Song" is inspired...
# 7312                                          Add a Plot
# 3609   The only residents of young Nicholas' sea-side...
#
#                         Director                                Cast
# 1184                      Il Cho          (Yoo Ah-in, Park Shin-Hye)
# 2484                      Il Cho          (Yoo Ah-in, Park Shin-Hye)
# 10128                DarkViktory         (DarkViktory, Paperblossom)
# 5816             Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 7551           Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# ...                          ...                                 ...
# 8292         Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 9480                   Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 7789           Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 7312   Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
# 3609       Lucile Hadzihalilovic          (Marta Blanc, Max Brebant)
#
# [8324 rows x 8 columns]

# %%
df['Movie Name'].value_counts()
# Out:
# Black Christmas                6
# Prey                           6
# The House                      6
# Halloween                      6
# The Lion King                  6
#                               ..
# I Still See You                1
# I Married a Strange Person!    1
# I Love Wolffy 2                1
# I Love Wolffy                  1
# Évolution                      1
# Name: Movie Name, Length: 6656, dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#                    Movie Name Year of Release Watch Time Movie Rating  \
# 1184                   #Alive            2020     98 min          6.3
# 10128            #TubeClash02            2016     86 min          7.4
# 5816                    $9.99            2008     78 min          6.7
# 7551         .Hack//The Movie            2012    112 min          6.3
# 8020      .hack//G.U. Trilogy            2007     93 min          5.4
# ...                       ...             ...        ...          ...
# 8292            Æblet & ormen            2009     75 min          6.4
# 9480       Çanakkale Geçilmez            2008     80 min          6.3
# 7789   Ének a csodaszarvasról            2002     89 min          6.8
# 7312            Érase una vez            1950     90 min          7.1
# 3609                Évolution            2015     81 min          5.9
#
#                                          Genres  \
# 1184          Action, Drama, Horror
# 10128      Animation, Comedy, Drama
# 5816      Animation, Drama, Fantasy
# 7551      Animation, Action, Sci-Fi
# 8020   Animation, Action, Adventure
# ...                                         ...
# 8292              Animation, Family
# 9480                      Animation
# 7789    Animation, Fantasy, History
# 7312                      Animation
# 3609         Drama, Horror, Mystery
#
#                                              Description  \
# 1184   The rapid spread of an unknown infection has l...
# 10128  After the events of "#TubeClash", ten new Germ...
# 5816   A stop-motion animated story about people livi...
# 7551   In 2024, the computer network prevails through...
# 8020   After one of his friends falls into a coma pla...
# ...                                                  ...
# 8292   an apple gets a worm in him and goes on a long...
# 9480                                          Add a Plot
# 7789   Divided into four sections, "Song" is inspired...
# 7312                                          Add a Plot
# 3609   The only residents of young Nicholas' sea-side...
#
#                         Director                                Cast
# 1184                      Il Cho          (Yoo Ah-in, Park Shin-Hye)
# 10128                DarkViktory         (DarkViktory, Paperblossom)
# 5816             Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 7551           Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 8020           Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# ...                          ...                                 ...
# 8292         Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 9480                   Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 7789           Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 7312   Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
# 3609       Lucile Hadzihalilovic          (Marta Blanc, Max Brebant)
#
# [6841 rows x 8 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                   Movie Name Year of Release Watch Time Movie Rating  \
# 0                     #Alive            2020     98 min          6.3
# 1               #TubeClash02            2016     86 min          7.4
# 2                      $9.99            2008     78 min          6.7
# 3           .Hack//The Movie            2012    112 min          6.3
# 4        .hack//G.U. Trilogy            2007     93 min          5.4
# ...                      ...             ...        ...          ...
# 6836           Æblet & ormen            2009     75 min          6.4
# 6837      Çanakkale Geçilmez            2008     80 min          6.3
# 6838  Ének a csodaszarvasról            2002     89 min          6.8
# 6839           Érase una vez            1950     90 min          7.1
# 6840               Évolution            2015     81 min          5.9
#
#                                         Genres  \
# 0            Action, Drama, Horror
# 1         Animation, Comedy, Drama
# 2        Animation, Drama, Fantasy
# 3        Animation, Action, Sci-Fi
# 4     Animation, Action, Adventure
# ...                                        ...
# 6836             Animation, Family
# 6837                     Animation
# 6838   Animation, Fantasy, History
# 6839                     Animation
# 6840        Drama, Horror, Mystery
#
#                                             Description  \
# 0     The rapid spread of an unknown infection has l...
# 1     After the events of "#TubeClash", ten new Germ...
# 2     A stop-motion animated story about people livi...
# 3     In 2024, the computer network prevails through...
# 4     After one of his friends falls into a coma pla...
# ...                                                 ...
# 6836  an apple gets a worm in him and goes on a long...
# 6837                                         Add a Plot
# 6838  Divided into four sections, "Song" is inspired...
# 6839                                         Add a Plot
# 6840  The only residents of young Nicholas' sea-side...
#
#                        Director                                Cast
# 0                        Il Cho          (Yoo Ah-in, Park Shin-Hye)
# 1                   DarkViktory         (DarkViktory, Paperblossom)
# 2               Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 3             Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 4             Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# ...                         ...                                 ...
# 6836        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 6837                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 6838          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 6839  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
# 6840      Lucile Hadzihalilovic          (Marta Blanc, Max Brebant)
#
# [6841 rows x 8 columns]

# %%
df
# Out:
#                   Movie Name Year of Release Watch Time Movie Rating  \
# 0                     #Alive            2020     98 min          6.3
# 1               #TubeClash02            2016     86 min          7.4
# 2                      $9.99            2008     78 min          6.7
# 3           .Hack//The Movie            2012    112 min          6.3
# 4        .hack//G.U. Trilogy            2007     93 min          5.4
# ...                      ...             ...        ...          ...
# 6836           Æblet & ormen            2009     75 min          6.4
# 6837      Çanakkale Geçilmez            2008     80 min          6.3
# 6838  Ének a csodaszarvasról            2002     89 min          6.8
# 6839           Érase una vez            1950     90 min          7.1
# 6840               Évolution            2015     81 min          5.9
#
#                                         Genres  \
# 0            Action, Drama, Horror
# 1         Animation, Comedy, Drama
# 2        Animation, Drama, Fantasy
# 3        Animation, Action, Sci-Fi
# 4     Animation, Action, Adventure
# ...                                        ...
# 6836             Animation, Family
# 6837                     Animation
# 6838   Animation, Fantasy, History
# 6839                     Animation
# 6840        Drama, Horror, Mystery
#
#                                             Description  \
# 0     The rapid spread of an unknown infection has l...
# 1     After the events of "#TubeClash", ten new Germ...
# 2     A stop-motion animated story about people livi...
# 3     In 2024, the computer network prevails through...
# 4     After one of his friends falls into a coma pla...
# ...                                                 ...
# 6836  an apple gets a worm in him and goes on a long...
# 6837                                         Add a Plot
# 6838  Divided into four sections, "Song" is inspired...
# 6839                                         Add a Plot
# 6840  The only residents of young Nicholas' sea-side...
#
#                        Director                                Cast
# 0                        Il Cho          (Yoo Ah-in, Park Shin-Hye)
# 1                   DarkViktory         (DarkViktory, Paperblossom)
# 2               Tatia Rosenthal   (Geoffrey Rush, Anthony LaPaglia)
# 3             Hiroshi Matsuyama         (Saki Fujita, Yukari Fukui)
# 4             Hiroshi Matsuyama  (Takahiro Sakurai, Ayako Kawasumi)
# ...                         ...                                 ...
# 6836        Anders Morgenthaler             (Mads Juul, Frank Hvam)
# 6837                  Orhan Bal    (Ivan Aslan, Hüseyin Gazi Gümet)
# 6838          Marcell Jankovics      (Árpád Besenczi, Ildikó Bokor)
# 6839  Alexandre Cirici Pellicer  (José Escobar, Juan Aristi Eulate)
# 6840      Lucile Hadzihalilovic          (Marta Blanc, Max Brebant)
#
# [6841 rows x 8 columns]

# %%
df.to_csv('Animation.csv')
