# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayank0195/IMDB_Web_Scraping/blob/main/Action_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import requests 
from bs4 import BeautifulSoup
from time import sleep
from random import randint

# %%
#Declaring the headers
header = {"Accept-Language" : "en-US, en; q = 0.5"}

# %%
movie_name = []
year = []
time=[]
rating=[]
genres =[]
description = []
director = []
casts = []

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(1,10002,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=action&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)


            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)
# Out:
# [1, 51, 101, 151, 201, 251, 301, 351, 401, 451, 501, 551, 601, 651, 701, 751, 801, 851, 901, 951, 1001, 1051, 1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601, 1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151, 2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701, 2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251, 3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801, 3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351, 4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901, 4951, 5001, 5051, 5101, 5151, 5201, 5251, 5301, 5351, 5401, 5451, 5501, 5551, 5601, 5651, 5701, 5751, 5801, 5851, 5901, 5951, 6001, 6051, 6101, 6151, 6201, 6251, 6301, 6351, 6401, 6451, 6501, 6551, 6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101, 7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651, 7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051, 8101, 8151, 8201, 8251, 8301, 8351, 8401, 8451, 8501, 8551, 8601, 8651, 8701, 8751, 8801, 8851, 8901, 8951, 9001, 9051, 9101, 9151, 9201, 9251, 9301, 9351, 9401, 9451, 9501, 9551, 9601, 9651, 9701, 9751, 9801, 9851, 9901, 9951, 10001]

# %%
a = { "Movie Name": movie_name, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Genres": genres, "Description":description, "Director":director, "Cast":casts}

# %%
a
# Out:
# {'Movie Name': ['Thor: Love and Thunder',
#   'The Woman King',
#   'Top Gun: Maverick',
#   'Avatar: The Way of Water',
#   'Bullet Train',
#   'Everything Everywhere All at Once',
#   'Lou',
#   'Top Gun',
#   'Avatar',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   'Jurassic World Dominion',
#   'Sita Ramam',
#   'Prey',
#   'The Batman',
#   'Black Adam',
#   'Star Wars: Rogue One',
#   'Samaritan',
#   'The Gray Man',
#   'Moonfall',
#   'The Northman',
#   'Spider-Man: No Way Home',
#   'Morbius',
#   'End of the Road',
#   'Dune',
#   'DC League of Super-Pets',
#   'Brahmastra Part One: Shiva',
#   'Constantine',
#   'Doctor Strange in the Multiverse of Madness',
#   'Uncharted',
#   'Het uur van de waarheid',
#   'Thirteen Lives',
#   'The Karate Kid Part III',
#   'The Lord of the Rings: The Return of the King',
#   'Day Shift',
#   'Strange World',
#   'RRR',
#   'The Lost City',
#   'The Dark Knight',
#   'Constantine 2',
#   'No Time to Die',
#   'The Matrix Resurrections',
#   'Athena',
#   'Medieval',
#   'The Lord of the Rings: The Two Towers',
#   'The Gentlemen',
#   'Inception',
#   'Tenet',
#   'Blade Runner 2049',
#   'Lightyear',
#   'VR (Vikrant Rona)',
#   'Untitled Indiana Jones Project',
#   'The Unbearable Weight of Massive Talent',
#   'Black Panther: Wakanda Forever',
#   'Avengers: Endgame',
#   'Expend4bles',
#   'Jujutsu Kaisen 0: The Movie',
#   'Dragon Ball Super: Super Hero',
#   'Eternals',
#   'Im Westen nichts Neues',
#   'The Mortal Instruments: City of Bones',
#   'Jurassic Park',
#   'Léon',
#   'Thor: Ragnarok',
#   'Heat',
#   'The Karate Kid Part II',
#   'The Mummy',
#   'Spiderhead',
#   'Gladiator',
#   'The Last Duel',
#   'Free Guy',
#   'Spider-Man',
#   'Killer Elite',
#   'Black Widow',
#   'The Suicide Squad',
#   'Willow',
#   'Road House',
#   'De sterrenoorlogen',
#   'Memory',
#   "The King's Man",
#   'The Matrix',
#   'Suicide Squad',
#   'Nobody',
#   'The Hunger Games',
#   'Mad Max: Fury Road',
#   'The Dark Knight Rises',
#   'Dune: Part Two',
#   'Avengers: Infinity War',
#   'Divergent',
#   '1917',
#   'Anna',
#   'Ambulance',
#   'Ready Player One',
#   'Fast X',
#   'Collateral',
#   'John Wick: Chapter 4',
#   'Blade Runner',
#   'The Enforcer',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Last Seen Alive',
#   'Ghostbusters',
#   'Indiana Jones and the Raiders of the Lost Ark',
#   'Cash Truck',
#   "Zack Snyder's Justice League",
#   'Bisang seoneon',
#   'Thor',
#   'Sicario',
#   'Spider-Man: Een nieuw universum',
#   'Sonic the Hedgehog 2',
#   'Guardians of the Galaxy',
#   'Vikram',
#   'Deadpool',
#   'Infinite',
#   'Oldeuboi',
#   'Warrior',
#   'John Wick',
#   'The School for Good and Evil',
#   'Black Panther',
#   'Deadpool 2',
#   'Ek Villain Returns',
#   'Vampire Academy',
#   'The 355',
#   'Drive',
#   'El Camino: A Breaking Bad Movie',
#   'Jurassic World',
#   'Avengers: Secret Wars',
#   'Wonder Woman',
#   'Aliens',
#   'Dunkirk',
#   'Thunderbolts',
#   'Kindergarten Cop',
#   'The Adam Project',
#   'Operation Fortune',
#   'Hit: The First Case',
#   'Mission: Impossible - Fallout',
#   'The Incredible Hulk',
#   'Terminator 2: Judgment Day',
#   'Predator',
#   'Shang-Chi and the Legend of the Ten Rings',
#   'Ant-Man and the Wasp: Quantumania',
#   'The Avengers',
#   'Spider-Man: Homecoming',
#   'Batman Begins',
#   'Fast & Furious 9',
#   'Deep Impact',
#   'From Dusk Till Dawn',
#   'Fury',
#   'De uitroeier',
#   'Iron Man',
#   'Guardians of the Galaxy Vol. 3',
#   'King Arthur: Legend of the Sword',
#   'Casino Royale',
#   'Kill Bill: Vol. 1',
#   'Vendhu Thanindhathu Kaadu',
#   'Peter Pan & Wendy',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   'The Next Karate Kid',
#   'Wicked: Part One',
#   'Edge of Tomorrow',
#   "Le Mans '66",
#   'Van Helsing',
#   'Jurassic World: Fallen Kingdom',
#   'Baby Driver',
#   "A Knight's Tale",
#   'Captain Marvel',
#   'The Guest',
#   '300',
#   'Tropic Thunder',
#   'The Man from Toronto',
#   'Kingsman: The Secret Service',
#   'The Fifth Element',
#   'Star Wars: Episode I - The Phantom Menace',
#   'Dragonball Evolution',
#   'The Contractor',
#   'Jack Reacher',
#   'True Lies',
#   'World War Z',
#   'Dredd',
#   'Mission: Impossible - Dead Reckoning - Part One',
#   'V for Vendetta',
#   'Baywatch',
#   'American Made',
#   'The Nice Guys',
#   'Transformers',
#   'George uit de jungle',
#   'Violent Night',
#   'Kick-Ass',
#   'Beverly Hills Cop',
#   'The Revenant',
#   'Logan',
#   'Beverly Hills Cop: Axel Foley',
#   'Venom: Let There Be Carnage',
#   'Wanted',
#   'Rat Race',
#   'Ready or Not',
#   'Aquaman',
#   'Mortal Kombat',
#   'Twister',
#   'Snow White and the Huntsman',
#   'Clash of the Titans',
#   'Shazam!',
#   'Apocalypto',
#   'Captain America: The First Avenger',
#   'Dune',
#   'Watchmen',
#   'Red Notice',
#   'Alita: Battle Angel',
#   'The Hunt',
#   'Blacklight',
#   'Spider-Man 3',
#   'The Incredibles',
#   'Justice League',
#   'Jumanji: Welcome to the Jungle',
#   'Hot Fuzz',
#   'Terminator: Dark Fate',
#   'Lethal Weapon',
#   'Die Hard',
#   'Indiana Jones en de tempel des doods',
#   'Scott Pilgrim vs. the World',
#   'Enola Holmes',
#   'Khuda Haafiz Chapter II: Agni Pariksha',
#   'The Fast and the Furious',
#   'Layer Cake',
#   'Captain America: New World Order',
#   'Children of Men',
#   'Skyfall',
#   'The Tomorrow War',
#   'Section 8',
#   'Star Wars: Episode VII - The Force Awakens',
#   "Pirates of the Caribbean: Salazar's Revenge",
#   'The Hunger Games: The Ballad of Songbirds and Snakes',
#   'Batman',
#   'Fantastic Four',
#   'Dungeons & Dragons: Honor Among Thieves',
#   'Indiana Jones and the Last Crusade',
#   'Black Hawk Down',
#   '6 Underground',
#   'X-Men',
#   'The Man from U.N.C.L.E.',
#   'Star Trek: The Future Begins',
#   'Big Trouble in Little China',
#   'Star Trek: Beyond',
#   'In Time',
#   'The Princess',
#   'Mission: Impossible - Rogue Nation',
#   'Batgirl',
#   'Thor: The Dark World',
#   'Wonder Woman 1984',
#   'The Predator',
#   'Those Who Wish Me Dead',
#   'X-Men: Apocalypse',
#   'Man of Steel',
#   'Point Break',
#   'The Amazing Spider-Man 3D',
#   'Hulk',
#   'Venom',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   'Doctor Strange',
#   'Oblivion',
#   'Paws of Fury: The Legend of Hank',
#   'The Mummy',
#   'The Maze Runner',
#   'Starship Troopers',
#   'Aquaman and the Lost Kingdom',
#   'Spider-Man 2',
#   'Joker: Folie à Deux',
#   'Birds of Prey and the Fantabulous Emancipation of One Harley Quinn',
#   'Guardians of the Galaxy Vol. 2',
#   'John Wick: Chapter 3 - Parabellum',
#   'Interceptor',
#   'Busanhaeng',
#   'Harry Potter and the Order of the Phoenix',
#   'Pride and Prejudice and Zombies',
#   'The Expendables',
#   'The Flash',
#   'The Warriors',
#   'Lock, Stock and Two Smoking Barrels',
#   'Mulan',
#   'Mission: Impossible',
#   'Kingdom of Heaven',
#   'Death Proof',
#   'Star Wars: Episode III - Revenge of the Sith',
#   'Green Lantern',
#   'The Expendables 3',
#   'American Sniper',
#   'Solo: A Star Wars Story',
#   'Mission: Impossible - Ghost Protocol',
#   'Jumanji: The Next Level',
#   'Avengers: Age of Ultron',
#   'The Rock',
#   'Napoleon',
#   'Secret Headquarters',
#   'TRON: Legacy',
#   'Logan Lucky',
#   'Incredibles 2',
#   'Men in Black',
#   'Polar',
#   'Star Wars: Episode VI - Return of the Jedi',
#   'Captain America: Civil War',
#   'Fantastic Four',
#   'The Italian Job',
#   'Quantum of Solace',
#   'Independence Day',
#   'Minority Report',
#   'Natural Born Killers',
#   'Sonic the Hedgehog',
#   'The Hunt for Red October',
#   'Transformers: Rise of the Beasts',
#   'RoboCop',
#   'Star Wars: Episode VIII - The Last Jedi',
#   'Night Hunter',
#   'Spectre',
#   'Spider-Man: Far from Home',
#   'Harry Potter en de halfbloed prins',
#   'Resident Evil: Welcome to Raccoon City',
#   'Cobra',
#   'Jason Bourne',
#   'Resident Evil',
#   'Iron Man 2',
#   'Army of the Dead',
#   'The Mask',
#   'Training Day',
#   'The Mummy Returns',
#   'Insurgent',
#   'Godzilla vs. Kong',
#   'Tomb Raider',
#   'Snowpiercer',
#   'The Crow',
#   'X-Men: First Class',
#   'The Harder They Fall',
#   'Sucker Punch',
#   'The Equalizer',
#   'Copshop',
#   'The Hunger Games: Catching Fire',
#   'Old Henry',
#   'Batman & Robin',
#   'Jungle Cruise',
#   'RoboCop',
#   'Batman v Superman: Dawn of Justice',
#   'RocknRolla',
#   'Jack Reacher: Never Go Back',
#   'Mat Kilau',
#   'Rush',
#   'Looper',
#   'Austin Powers: The Spy Who Shagged Me',
#   'The Last Samurai',
#   'Blade',
#   'Fast & Furious',
#   'They Live',
#   'Kingsman: The Golden Circle',
#   'Falling Down',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   'The Old Guard',
#   'Daredevil',
#   'Madame Web',
#   'X-Men: Dark Phoenix',
#   'Escape from Alcatraz',
#   'Dick Tracy',
#   'Crawl',
#   "Charlie's Angels",
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'Never Back Down',
#   'The Karate Kid',
#   'Red Sparrow',
#   'The Last of the Mohicans',
#   'Battleship',
#   'Allied',
#   'The Blues Brothers',
#   '2012',
#   'London Has Fallen',
#   'Sherlock Holmes',
#   'The Accountant',
#   'The Day After Tomorrow',
#   "The Huntsman: Winter's War",
#   'X-Men Origins: Wolverine',
#   'GoldenEye',
#   'Valerian and the City of a Thousand Planets',
#   'Lucy',
#   'The Marvels',
#   'Mad Max',
#   'Jungle',
#   'Armageddon',
#   'Badlands',
#   'X-Men: Days of Future Past',
#   'Ava',
#   'One Piece Film: Red',
#   'Terminator Genisys',
#   'Austin Powers in Goldmember',
#   'Predestination',
#   'Gold',
#   'John Carter',
#   'Outlaw King',
#   'Blue Beetle',
#   'The Patriot',
#   'Den of Thieves',
#   'Conan the Barbarian',
#   'Superman',
#   'Fast & Furious 7',
#   'Blade',
#   'Total Recall',
#   'The Bourne Identity',
#   'Vikram Vedha',
#   'Star Wars: Episode II - Attack of the Clones',
#   'Shooter',
#   'De IJzeren reus',
#   "Ocean's Eight",
#   'Raya en de laatste draak',
#   'John Wick: Chapter 2',
#   'Army of Thieves',
#   'Iron Man Three',
#   'Immortals',
#   'Pirates of the Caribbean: On Stranger Tides',
#   'Havoc',
#   'Batman Forever',
#   'Taken',
#   'Young Guns',
#   'Knight and Day',
#   'Sky High',
#   'Emancipation',
#   'Captain America: The Winter Soldier',
#   'The Shallows',
#   'Karthikeya 2',
#   'How to Train Your Dragon',
#   'Lilo & Stitch',
#   'Shichinin no samurai',
#   'Liger',
#   'The Host',
#   'Highlander',
#   '13 Hours',
#   'Mr. & Mrs. Smith',
#   'Escape Room',
#   'Svart krabba',
#   'The Other Guys',
#   'The Fast and the Furious: Tokyo Drift',
#   'Way Down',
#   'Teenage Mutant Ninja Turtles',
#   'Spider-Man: Across the Spider-Verse',
#   'The Protégé',
#   'Dawn of the Dead',
#   'Unhinged',
#   'The Mummy: Tomb of the Dragon Emperor',
#   'Power Rangers',
#   'Underwater',
#   'Mandy',
#   'The Lost World: Jurassic Park',
#   'Three Kings',
#   'Ant-Man',
#   'Law Abiding Citizen',
#   'Pacific Rim',
#   'King Arthur',
#   'Public Enemies',
#   'Shazam! Fury of the Gods',
#   'The Three Musketeers',
#   'Red Dawn',
#   'Borderlands',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   'Extraction',
#   'Kung Fu Panda',
#   "Hitman's Wife's Bodyguard",
#   '3:10 to Yuma',
#   'Ang-ma-reul bo-at-da',
#   'Kill Bill: Vol. 2',
#   'Atlantis: The Lost Empire',
#   'The Amazing Spider-Man 2',
#   'Sahara',
#   'Ghostbusters',
#   'The Great Wall',
#   'War of the Worlds',
#   'The Fighter',
#   'K.G.F: Chapter 2',
#   'Allegiant',
#   '12 Strong',
#   'Rampage: Big Meets Bigger',
#   'Ghost Rider',
#   'King Kong',
#   'Wild Card',
#   'Unstoppable',
#   'The Meg',
#   'Warcraft: The Beginning',
#   'Carter',
#   'The Core',
#   'North by Northwest',
#   'Chaos Walking',
#   "The World's End",
#   'The Losers',
#   'Source Code',
#   'Cloverfield',
#   'The Magnificent Seven',
#   'Lethal Weapon 2',
#   'District 9',
#   'Predators',
#   'The Roundup',
#   'The Last Boy Scout',
#   'Enola Holmes 2',
#   '21 Jump Street',
#   'Commando',
#   'RED',
#   'Miss Congeniality',
#   'Sicario: Day of the Soldado',
#   'Face/Off',
#   'Batman Returns',
#   'Mononoke-hime',
#   'Rush Hour',
#   'Maverick',
#   "Pirates of the Caribbean: At World's End",
#   'Dirty Harry',
#   'Zombieland',
#   'Robin Hood: Prince of Thieves',
#   'Greenland',
#   'Upgrade',
#   'Midnight in the Switchgrass',
#   'National Treasure',
#   'Overlord',
#   'The Last Airbender',
#   'Speed',
#   'Mission: Impossible III',
#   'I Am Legend',
#   'Devotion',
#   'Revenge',
#   'Elysium',
#   'Pan',
#   'Bodyguard',
#   'Knowing',
#   'Planet of the Apes',
#   'Argylle',
#   'Wire Room',
#   'Dracula 2002',
#   'Baymax',
#   'Triple Frontier',
#   'The North Sea',
#   'Munich',
#   'Terminator Salvation',
#   'Love and Monsters',
#   'Monster Hunter',
#   'Game Night',
#   'Wrong Place',
#   'Star Trek: Into Darkness',
#   'Underworld',
#   "Don't Breathe 2",
#   'Predator 2',
#   'The Bad Batch',
#   'Pearl Harbor',
#   'Escape from New York',
#   'Our Man from Jersey',
#   'Lone Survivor',
#   'Enemy of the State',
#   'The Perfect Storm',
#   'Avengers: The Kang Dynasty',
#   'The Expendables 2',
#   'Gone in Sixty Seconds',
#   'Transformers: The Last Knight',
#   'Fantastic Four',
#   'The New Mutants',
#   'Kong: Skull Island',
#   'Greyhound',
#   'First Blood',
#   'Man on Fire',
#   'Hellboy',
#   'X-Men: The Last Stand',
#   'Stargate',
#   'Men in Black 3',
#   'Trauma',
#   'San Andreas',
#   'Waterworld',
#   'The Count of Monte Cristo',
#   'Ronin',
#   'Wicked Game',
#   'Alexander',
#   'Major',
#   'Teenage Mutant Ninja Turtles',
#   'Hotel Mumbai',
#   'Gods of Egypt',
#   'Master and Commander: The Far Side of the World',
#   'The Legend of Tarzan',
#   'Cowboys & Aliens',
#   'No Escape',
#   'Kick-Ass 2',
#   'The Informer',
#   'The Matrix Reloaded',
#   'Serenity',
#   'Kate',
#   'X-Men 2',
#   'Alien Resurrection',
#   'Men in Black II',
#   'Clear and Present Danger',
#   'Escape Room: Tournament of Champions',
#   'The Chronicles of Riddick: Pitch Black',
#   'Midway',
#   'Death Race',
#   'Atomic Blonde',
#   'Deep Rising',
#   'Saloum',
#   'Drive Angry',
#   'Blackbird',
#   'Akira',
#   'Ant-Man and the Wasp',
#   'Con Air',
#   'Everest',
#   'The Chronicles of Riddick',
#   'Conan the Barbarian',
#   'Jupiter Ascending',
#   'Project Wolf Hunting',
#   'Zombieland: Double Tap',
#   'Spy',
#   'Pineapple Express',
#   'Demolition Man',
#   'Wild Hogs',
#   'Fast & Furious 6',
#   'The Adventures of Tintin',
#   'Oldboy',
#   'Bright',
#   'Mad Max 2',
#   'Deepwater Horizon',
#   'The Foreigner',
#   'Pain & Gain',
#   'Super 8',
#   'In the Heart of the Sea',
#   'Doom',
#   'Enemy at the Gates',
#   'Robin Hood',
#   'Rango',
#   'Jackass Forever',
#   'Planet Terror',
#   'Jurassic Park III',
#   "Charlie's Angels",
#   'How It Ends',
#   'A History of Violence',
#   'Now You See Me 2',
#   'Total Recall',
#   'Savages',
#   'The Running Man',
#   'Mission: Impossible II',
#   'Furiosa',
#   'Journey to the Center of the Earth',
#   'The Fugitive',
#   'Krull',
#   'Alien³',
#   'Unbroken',
#   'The Wolverine',
#   'Bãhubali: The Beginning',
#   'Bumblebee',
#   'The Dark Tower',
#   'What Happened to Monday',
#   'Prince of Persia: The Sands of Time',
#   'Vampires',
#   'Fantastic 4: Rise of the Silver Surfer',
#   'Kraven the Hunter',
#   'Operation Crossbow',
#   'One Way',
#   'Next',
#   'A Walk Among the Tombstones',
#   'The Outpost',
#   'Ghost in the Shell',
#   'The Boondock Saints',
#   'Red State',
#   'The Silencing',
#   'Tides',
#   'American Assassin',
#   'Only the Brave',
#   "Ender's Game",
#   'Cobra',
#   'AVP: Alien vs. Predator',
#   'Deliver Us from Evil',
#   'Angels & Demons',
#   'Dead Zone',
#   'Fast & Furious 8',
#   'The 5th Wave',
#   'Legion',
#   'Under Siege',
#   'Last Action Hero',
#   'End of Watch',
#   'Hellboy',
#   'The 13th Warrior',
#   '2 Fast 2 Furious',
#   'Creed',
#   'Rambo: Last Blood',
#   'Fast & Furious 5',
#   'Westworld',
#   'Men in Black: International',
#   'Hansel & Gretel: Witch Hunters',
#   'The Hunger Games: Mockingjay - Part 2',
#   'Ghostbusters II',
#   'Mortal Engines',
#   'The Transporter',
#   'Mortal Kombat',
#   "Willy's Wonderland",
#   'The Equalizer 2',
#   'Hitman',
#   'Deadpool 3',
#   'Bronson',
#   'Exodus: Gods and Kings',
#   'Superman Returns',
#   'War for the Planet of the Apes',
#   'Body of Lies',
#   "The Girl in the Spider's Web",
#   'Bad Boys',
#   '28 Weeks Later',
#   '300: Rise of an Empire',
#   'Wo hu cang long',
#   'The Twilight Saga: Eclipse',
#   'Jay and Silent Bob Reboot',
#   'Maze Runner: The Death Cure',
#   'Captain Phillips',
#   'Angel Has Fallen',
#   'Jumper',
#   'Robin Hood',
#   'Equilibrium',
#   "Assassin's Creed",
#   'Any Which Way You Can',
#   'Die Another Day',
#   'Spies in Disguise',
#   'The Kitchen',
#   'Terminator 3: Rise of the Machines',
#   'Hollow Man',
#   'Shamshera',
#   'Gunpowder Milkshake',
#   'Southpaw',
#   'Thallumaala',
#   'Sherlock Holmes: A Game of Shadows',
#   'The Man in the Iron Mask',
#   'Godzilla II: King of the Monsters',
#   'Unlocked',
#   'Transformers: Age of Extinction',
#   'Boss Level',
#   'The Legend of Maula Jatt',
#   'G.I. Jane',
#   'In the Shadow of the Moon',
#   'Megamind',
#   'Morgan',
#   'Oegye+in 1bu',
#   'Hercules',
#   'Faster',
#   'Night Teeth',
#   'Lara Croft: Tomb Raider',
#   'Smokey and the Bandit',
#   'De Lego Film',
#   "The Hitman's Bodyguard",
#   'Rise of the Planet of the Apes',
#   'The Punisher',
#   'Reign of Fire',
#   "Logan's Run",
#   'Lifeforce',
#   'Bajocero',
#   'Olympus Has Fallen',
#   'Rambo: First Blood Part II',
#   'The Sum of All Fears',
#   'The Interview',
#   'Hanna',
#   'Project T',
#   'Air Force One',
#   'Inferno',
#   'The Bourne Legacy',
#   '3 from Hell',
#   'Ivy + Bean',
#   'Sin City: A Dame to Kill For',
#   'Doomsday',
#   'We Were Soldiers',
#   'Cliffhanger',
#   'Shotgun Wedding',
#   'Geostorm',
#   'Murder Mystery',
#   'Transformers: Dark of the Moon',
#   'The League of Extraordinary Gentlemen',
#   'Spy Kids',
#   'Seventh Son',
#   'Lost in Space',
#   'Freddy vs. Jason',
#   'The Forever Purge',
#   'I, Robot',
#   'The Three Musketeers',
#   'Godzilla',
#   'The Chronicles of Riddick: Rule the Dark',
#   '2 Guns',
#   'Prem Geet 3',
#   'The Hunger Games: Mockingjay - Part 1',
#   'Dangerous',
#   'Maximum Overdrive',
#   'Sherlock Holmes 3',
#   'Hot Shots!',
#   '47 Ronin',
#   'The Marksman',
#   'Jacht op smaragd',
#   'The Raid',
#   'Bloodsport',
#   'The Brothers Grimm',
#   'Okja',
#   '13 Minutes',
#   'The Bourne Ultimatum',
#   'Beowulf',
#   'Miami Vice',
#   'Buffy the Vampire Slayer',
#   'Riders of Justice',
#   'Nightbreed',
#   'Mile 22',
#   'Grindhouse',
#   'The A-Team',
#   'The Killer',
#   'Vendetta',
#   'Out of the Furnace',
#   'WarGames',
#   'Need for Speed',
#   'Walking Tall',
#   'Tango & Cash',
#   'The Mask of Zorro',
#   'White House Down',
#   'Central Intelligence',
#   'Takers',
#   'Pokémon: Detective Pikachu',
#   'Dr. No',
#   'The Book of Eli',
#   'Transporter 2',
#   'Escape Plan',
#   'Bad Boys for Life',
#   'Without Remorse',
#   'The World Is Not Enough',
#   'The Chronicles of Narnia: Prince Caspian',
#   'Kimetsu no Yaiba: Mugen Ressha-Hen',
#   'Joy Ride',
#   'The Bourne Supremacy',
#   'Young Guns II',
#   'Tears of the Sun',
#   'The Island',
#   'Maze Runner: The Scorch Trials',
#   'The Dirty Dozen',
#   'Lethal Weapon 5',
#   'Ghosted',
#   'Confidential Assignment 2: International',
#   'Tag',
#   'Deja Vu',
#   'Abraham Lincoln: Vampire Hunter',
#   'The Lone Ranger',
#   'Bastille Day',
#   'Chronicle',
#   'Dog Soldiers',
#   'Get Smart',
#   'Goldfinger',
#   'A Most Violent Year',
#   'Rambo',
#   'Dawn of the Planet of the Apes',
#   'Guns Akimbo',
#   'Deep Blue Sea',
#   'Open Range',
#   'The Cannonball Run',
#   'Point Break',
#   'Resident Evil: Apocalypse',
#   'The Time Machine',
#   'The Pacifier',
#   '9',
#   'Kôkaku Kidôtai',
#   'Superhero Movie',
#   'The Cloverfield Paradox',
#   'Clash of the Titans',
#   'G.I. Joe: The Rise of Cobra',
#   'Lethal Weapon 3',
#   'Salt',
#   'The Rocketeer',
#   'Alex Cross',
#   'Bullet Proof',
#   'The French Connection',
#   'Batoru rowaiaru',
#   'The Life Aquatic with Steve Zissou',
#   'Akinjeon',
#   'Pacific Rim: Uprising',
#   'Transformers: Revenge of the Fallen',
#   'Fullmetal Alchemist: The Revenge of Scar',
#   'xXx',
#   '22 Jump Street',
#   'Homefront',
#   'Against All Odds',
#   'R.I.P.D.',
#   'The VelociPastor',
#   'AVP2: Aliens vs. Predator 2 - Requiem',
#   'Flash Gordon',
#   'Black Site',
#   'Die Hard: With a Vengeance',
#   'The Covenant',
#   'TRON',
#   'The Poseidon Adventure',
#   'Masters of the Universe',
#   'Road House',
#   'Wolves of War',
#   'Braven',
#   'Snake Eyes: G.I. Joe Origins',
#   'Patriot Games',
#   'Species',
#   'Real Steel',
#   'Hancock',
#   'Blood Red Sky',
#   'The American',
#   'The Quick and the Dead',
#   'Vikram Vedha',
#   'The Ice Road',
#   'The Tourist',
#   'Gran Turismo',
#   'The Machine',
#   'The International',
#   'The Spy Who Dumped Me',
#   'Kung fu',
#   'Tower Heist',
#   'Dracula Untold',
#   'Friday Night Lights',
#   'Into the Blue',
#   'Hitman: Agent 47',
#   'Beverly Hills Cop II',
#   'Street Fighter',
#   'Bonnie and Clyde',
#   'Die Hard 2',
#   'The Scorpion King',
#   'Crank',
#   'Security',
#   'Avatar 3',
#   'Jack the Giant Slayer',
#   'Mighty Morphin Power Rangers: The Movie',
#   'This Means War',
#   'Sonic the Hedgehog 3',
#   'Licence to Kill',
#   'Get Carter',
#   'CHIPS',
#   'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   'News of the World',
#   '1941',
#   'The Heat',
#   'Johnny Cool',
#   'Heon-teu',
#   "Dante's Peak",
#   "You Don't Mess with the Zohan",
#   'Thief',
#   'Spree',
#   'Tomorrow Never Dies',
#   'Noah',
#   'Extraction 2',
#   'Jack Ryan: Shadow Recruit',
#   'Wrath of the Titans',
#   'Independence Day: Resurgence',
#   'Moonraker',
#   'Machete',
#   'The Matrix Revolutions',
#   'Desperado',
#   'For Your Eyes Only',
#   'Rocky Balboa',
#   'Pixels',
#   "'t Is 'n gekke, rare, dolle, dwaze wereld",
#   'Escape from L.A.',
#   'Battlefield Earth',
#   'Super',
#   'In de klauwen van de draak',
#   'How to Train Your Dragon: The Hidden World',
#   'Anaconda',
#   'Days of Thunder',
#   'Seppuku',
#   'Blade: Trinity',
#   'Straw Dogs',
#   'The Commuter',
#   'Kung Fury: The Movie',
#   'Ponniyin Selvan: I',
#   'De Spiderwick kronieken',
#   'Blade II',
#   'Innerspace',
#   '48 Hrs.',
#   "The King's Daughter",
#   'Ip Man',
#   'Journey 2: The Mysterious Island',
#   'Star Trek II: The Wrath of Khan',
#   'Crocodile Dundee',
#   'Die Hard 4.0',
#   'The Purge: Anarchy',
#   'The Principal',
#   'Ran',
#   'The Last Starfighter',
#   'The Lego Batman Movie',
#   'Conan the Destroyer',
#   'Kabzaa',
#   'In a Valley of Violence',
#   '30 Days of Night',
#   'Jolt',
#   '10,000 BC',
#   "On Her Majesty's Secret Service",
#   'Convoy',
#   'Maneater',
#   'Tarzan and the Amazons',
#   'Jason X',
#   'The Long Kiss Goodnight',
#   'Barb Wire',
#   'Grimsby',
#   'Howard the Duck',
#   'A Fistfull of Dollars',
#   'Kung Fu Panda 3',
#   'The Hitcher',
#   'Manyeo',
#   'Filth',
#   'Non-Stop',
#   'Tian jiang xiong shi',
#   'Baahubali 2: The Conclusion',
#   'The Wild Bunch',
#   'The Old Guard 2',
#   'Chappie',
#   'I onde dager',
#   'Judge Dredd',
#   'We Can Be Heroes',
#   'Fallen',
#   'Project Power',
#   ...],
#  'Year of Release': ['2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   'I) (',
#   '1986',
#   '2009',
#   '2001',
#   '2022',
#   '2022',
#   'I) (',
#   '2022',
#   '2022',
#   '2016',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2021',
#   '2022',
#   'II) ',
#   '2021',
#   '2022',
#   '2022',
#   '2005',
#   '2022',
#   '2022',
#   '1984',
#   '2022',
#   '1989',
#   '2003',
#   '2022',
#   '2022',
#   '2022',
#   '2022',
#   '2008',
#   '',
#   '2021',
#   '2021',
#   '2022',
#   '2022',
#   '2002',
#   '2019',
#   '2010',
#   '2020',
#   '2017',
#   '2022',
#   '2022',
#   '2023',
#   '2022',
#   '2022',
#   '2019',
#   '2023',
#   '2021',
#   '2022',
#   '2021',
#   '2022',
#   '2013',
#   '1993',
#   '1994',
#   '2017',
#   '1995',
#   '1986',
#   '1999',
#   '2022',
#   '2000',
#   '2021',
#   '2021',
#   '2002',
#   '2011',
#   '2021',
#   '2021',
#   '1988',
#   '1989',
#   '1977',
#   '2022',
#   '2021',
#   '1999',
#   '2016',
#   'I) (',
#   '2012',
#   '2015',
#   '2012',
#   '2023',
#   '2018',
#   '2014',
#   '2019',
#   'II) ',
#   '2022',
#   '2018',
#   '2023',
#   '2004',
#   '2023',
#   '1982',
#   '2022',
#   '2003',
#   '2022',
#   '1984',
#   '1981',
#   '2021',
#   '2021',
#   '2021',
#   '2011',
#   '2015',
#   '2018',
#   '2022',
#   '2014',
#   '2022',
#   '2016',
#   '2021',
#   '2003',
#   '2011',
#   '2014',
#   '2022',
#   '2018',
#   '2018',
#   '2022',
#   '2014',
#   '2022',
#   'I) (',
#   '2019',
#   '2015',
#   '2025',
#   '2017',
#   '1986',
#   '2017',
#   '2024',
#   '1990',
#   '2022',
#   '2022',
#   '2022',
#   '2018',
#   '2008',
#   '1991',
#   '1987',
#   '2021',
#   '2023',
#   '2012',
#   '2017',
#   '2005',
#   '2021',
#   '1998',
#   '1996',
#   '2014',
#   '1984',
#   '2008',
#   '2023',
#   '2017',
#   '2006',
#   '2003',
#   '2022',
#   '2023',
#   '2019',
#   '1994',
#   '2024',
#   '2014',
#   '2019',
#   '2004',
#   '2018',
#   '2017',
#   '2001',
#   '2019',
#   'I) (',
#   '2006',
#   '2008',
#   '2022',
#   '2014',
#   '1997',
#   '1999',
#   '2009',
#   '2022',
#   '2012',
#   '1994',
#   '2013',
#   '2012',
#   '2023',
#   '2005',
#   '2017',
#   '2017',
#   '2016',
#   '2007',
#   '1997',
#   '2022',
#   '2010',
#   '1984',
#   '2015',
#   '2017',
#   '',
#   '2021',
#   '2008',
#   '2001',
#   'I) (',
#   '2018',
#   '2021',
#   'I) (',
#   '2012',
#   '2010',
#   '2019',
#   '2006',
#   '2011',
#   '1984',
#   '2009',
#   '2021',
#   '2019',
#   'II) ',
#   '2022',
#   '2007',
#   '2004',
#   '2017',
#   '2017',
#   '2007',
#   '2019',
#   '1987',
#   '1988',
#   '1984',
#   '2010',
#   '2020',
#   '2022',
#   '2001',
#   '2004',
#   '2024',
#   '2006',
#   '2012',
#   '2021',
#   'II) ',
#   '2015',
#   '2017',
#   '2023',
#   '1989',
#   '2024',
#   '2023',
#   '1989',
#   '2001',
#   '2019',
#   '2000',
#   '2015',
#   '2009',
#   '1986',
#   '2016',
#   '2011',
#   'I) (',
#   '2015',
#   '',
#   '2013',
#   '2020',
#   '2018',
#   '2021',
#   '2016',
#   '2013',
#   '1991',
#   '2012',
#   '2003',
#   '2018',
#   '1980',
#   '2016',
#   'I) (',
#   '2022',
#   '2017',
#   '2014',
#   '1997',
#   '2023',
#   '2004',
#   '2024',
#   '2020',
#   '2017',
#   '2019',
#   '2022',
#   '2016',
#   '2007',
#   '2016',
#   '2010',
#   '2023',
#   '1979',
#   '1998',
#   '2020',
#   '1996',
#   '2005',
#   '2007',
#   '2005',
#   '2011',
#   '2014',
#   '2014',
#   '2018',
#   '2011',
#   '2019',
#   '2015',
#   '1996',
#   '',
#   '2022',
#   '2010',
#   '2017',
#   '2018',
#   '1997',
#   'I) (',
#   '1983',
#   '2016',
#   '2015',
#   '2003',
#   '2008',
#   '1996',
#   '2002',
#   '1994',
#   '2020',
#   '1990',
#   '2023',
#   '2014',
#   '2017',
#   '2018',
#   'I) (',
#   '2019',
#   '2009',
#   '2021',
#   '2022',
#   'I) (',
#   '2002',
#   '2010',
#   '2021',
#   '1994',
#   '2001',
#   '2001',
#   '2015',
#   '2021',
#   '2018',
#   '2013',
#   '1994',
#   '2011',
#   '2021',
#   '2011',
#   '2014',
#   '2021',
#   '2013',
#   '2021',
#   '1997',
#   '2021',
#   '1987',
#   '2016',
#   '2008',
#   '2016',
#   '2022',
#   'I) (',
#   '2012',
#   '1999',
#   '2003',
#   '2023',
#   '2009',
#   '1988',
#   '2017',
#   '1993',
#   '2019',
#   '2020',
#   '2003',
#   '2023',
#   '2019',
#   '1979',
#   '1990',
#   'I) (',
#   '2019',
#   '2006',
#   '2008',
#   '2010',
#   '2018',
#   '1992',
#   '2012',
#   '2016',
#   '1980',
#   'I) (',
#   '2016',
#   '2009',
#   '2016',
#   '2004',
#   '2016',
#   '2009',
#   '1995',
#   '2017',
#   'I) (',
#   '2023',
#   '1979',
#   'I) (',
#   '1998',
#   '1973',
#   '2014',
#   'IV) ',
#   '2022',
#   '2015',
#   '2002',
#   'I) (',
#   'I) (',
#   '2012',
#   '2018',
#   '2023',
#   '2000',
#   '2018',
#   '1982',
#   '1978',
#   '2015',
#   '1998',
#   '1990',
#   '2002',
#   '2017',
#   '2002',
#   'I) (',
#   '1999',
#   '2018',
#   '2021',
#   '2017',
#   '2021',
#   '2013',
#   '2011',
#   '2011',
#   '2022',
#   '1995',
#   'I) (',
#   '1988',
#   '2010',
#   '2005',
#   '2023',
#   '2014',
#   '2016',
#   '2022',
#   '2010',
#   '2024',
#   '1954',
#   '2022',
#   '2013',
#   '1986',
#   '2016',
#   '2005',
#   'I) (',
#   '2022',
#   '2010',
#   '2006',
#   '2021',
#   '1990',
#   '2023',
#   '2021',
#   '2004',
#   'I) (',
#   '2008',
#   '2017',
#   '2020',
#   'I) (',
#   '1997',
#   '1999',
#   '2015',
#   '2009',
#   '2013',
#   '2004',
#   '2009',
#   '2023',
#   '2011',
#   '1984',
#   '2022',
#   '2008',
#   '2020',
#   '2008',
#   '2021',
#   '2007',
#   '2010',
#   '2004',
#   '2001',
#   '2014',
#   '2005',
#   '2016',
#   'I) (',
#   '2005',
#   'I) (',
#   '2022',
#   '2016',
#   '2018',
#   '2018',
#   '2007',
#   '2005',
#   '2015',
#   '2010',
#   '2018',
#   '2016',
#   'I) (',
#   '2003',
#   '1959',
#   '2021',
#   '2013',
#   'I) (',
#   '2011',
#   '2008',
#   '2016',
#   '1989',
#   '2009',
#   '2010',
#   '2022',
#   '1991',
#   '2022',
#   '2012',
#   '1985',
#   '2010',
#   '2000',
#   '2018',
#   '1997',
#   '1992',
#   '1997',
#   '1998',
#   '1994',
#   '2007',
#   '1971',
#   '2009',
#   '1991',
#   '2020',
#   '2018',
#   '2021',
#   '2004',
#   '2018',
#   '2010',
#   '1994',
#   '2006',
#   '2007',
#   'II) ',
#   'II) ',
#   'I) (',
#   '2015',
#   '1992',
#   '2009',
#   '2001',
#   '2023',
#   '2022',
#   '2000',
#   '2014',
#   '2019',
#   '2021',
#   '2005',
#   '2009',
#   'I) (',
#   'I) (',
#   'I) (',
#   '2022',
#   '2013',
#   '2003',
#   '2021',
#   '1990',
#   '2016',
#   '2001',
#   '1981',
#   '',
#   '2013',
#   '1998',
#   '2000',
#   '2025',
#   '2012',
#   '2000',
#   '2017',
#   'I) (',
#   '2020',
#   '2017',
#   '2020',
#   '1982',
#   '2004',
#   '2019',
#   '2006',
#   '1994',
#   '2012',
#   'II) ',
#   '2015',
#   '1995',
#   '2002',
#   '1998',
#   '2022',
#   '2004',
#   '2022',
#   '2014',
#   '2018',
#   '2016',
#   '2003',
#   '2016',
#   '2011',
#   'I) (',
#   '2013',
#   '2019',
#   '2003',
#   '2005',
#   'I) (',
#   '2003',
#   '1997',
#   '2002',
#   '1994',
#   '2021',
#   '2000',
#   '2019',
#   '2008',
#   '2017',
#   '1998',
#   '2021',
#   '2011',
#   'II) ',
#   '1988',
#   '2018',
#   '1997',
#   '2015',
#   '2004',
#   '2011',
#   '2015',
#   '2022',
#   '2019',
#   '2015',
#   '2008',
#   '1993',
#   '2007',
#   '2013',
#   '2011',
#   '2013',
#   'I) (',
#   '1981',
#   '2016',
#   'I) (',
#   '2013',
#   '2011',
#   '2015',
#   '2005',
#   '2001',
#   '2018',
#   '2011',
#   '2022',
#   '2007',
#   '2001',
#   '2000',
#   '2018',
#   '2005',
#   '2016',
#   'I) (',
#   '2012',
#   '1987',
#   '2000',
#   '2024',
#   '2008',
#   '1993',
#   '1983',
#   '1992',
#   'I) (',
#   '2013',
#   '2015',
#   'I) (',
#   '2017',
#   '2017',
#   '2010',
#   '1998',
#   '2007',
#   '2023',
#   '1965',
#   'I) (',
#   '2007',
#   '2014',
#   '2019',
#   '2017',
#   '1999',
#   '2011',
#   '2020',
#   '2021',
#   '2017',
#   '2017',
#   '2013',
#   '1986',
#   '2004',
#   'I) (',
#   '2009',
#   '2022',
#   '2017',
#   '2016',
#   '2010',
#   '1992',
#   '1993',
#   '2012',
#   '2004',
#   '1999',
#   '2003',
#   'II) ',
#   '2019',
#   '2011',
#   '1973',
#   '2019',
#   '2013',
#   '2015',
#   '1989',
#   '2018',
#   '2002',
#   '1995',
#   '2021',
#   '2018',
#   'I) (',
#   '',
#   '2008',
#   '2014',
#   '2006',
#   '2017',
#   '2008',
#   '2018',
#   '1995',
#   '2007',
#   '2014',
#   '2000',
#   '2010',
#   '2019',
#   '2018',
#   '2013',
#   '2019',
#   '2008',
#   '2010',
#   '2002',
#   '2016',
#   '1980',
#   '2002',
#   '2019',
#   '2019',
#   '2003',
#   '2000',
#   '2022',
#   '2021',
#   '2015',
#   '2022',
#   '2011',
#   'I) (',
#   '2019',
#   'I) (',
#   '2014',
#   '2020',
#   '2022',
#   '1997',
#   '2019',
#   '2010',
#   '2016',
#   '2022',
#   'I) (',
#   '2010',
#   '2021',
#   '2001',
#   '1977',
#   '2014',
#   '2017',
#   '2011',
#   '2004',
#   '2002',
#   '1976',
#   '1985',
#   '2021',
#   '2013',
#   '1985',
#   '2002',
#   'II) ',
#   '2011',
#   '2015',
#   '1997',
#   'I) (',
#   '2012',
#   '2019',
#   '2022',
#   '2014',
#   '2008',
#   '2002',
#   '1993',
#   '2023',
#   '2017',
#   '2019',
#   '2011',
#   '2003',
#   '2001',
#   'I) (',
#   '1998',
#   '2003',
#   '2021',
#   '2004',
#   '1993',
#   '2014',
#   '2013',
#   '2013',
#   '2022',
#   '2014',
#   'III)',
#   '1986',
#   '',
#   '1991',
#   '2013',
#   '2021',
#   '1984',
#   '2011',
#   '1988',
#   '2005',
#   '2017',
#   '2021',
#   '2007',
#   '2007',
#   '2006',
#   '1992',
#   '2020',
#   '1990',
#   '2018',
#   '2007',
#   '2010',
#   '',
#   'I) (',
#   '2013',
#   '1983',
#   '2014',
#   '2004',
#   '1989',
#   '1998',
#   '2013',
#   '2016',
#   '2010',
#   '2019',
#   '1962',
#   '2010',
#   '2005',
#   '2013',
#   '2020',
#   'II) ',
#   '1999',
#   '2008',
#   '2020',
#   '2001',
#   '2004',
#   '1990',
#   '2003',
#   '2005',
#   '2015',
#   '1967',
#   '',
#   'IX)',
#   '2022',
#   'I) (',
#   '2006',
#   '2012',
#   '2013',
#   '2016',
#   '2012',
#   '2002',
#   '2008',
#   '1964',
#   '2014',
#   '2008',
#   '2014',
#   '2019',
#   '1999',
#   '2003',
#   '1981',
#   '2015',
#   '2004',
#   '2002',
#   '2005',
#   'I) (',
#   '1995',
#   '2008',
#   '2018',
#   '1981',
#   '2009',
#   '1992',
#   '2010',
#   '1991',
#   '2012',
#   '2022',
#   '1971',
#   '2000',
#   '2004',
#   '2019',
#   '2018',
#   '2009',
#   '2022',
#   '2002',
#   '2014',
#   'I) (',
#   '1984',
#   '2013',
#   '2018',
#   '2007',
#   '1980',
#   'I) (',
#   '1995',
#   '2006',
#   '1982',
#   '1972',
#   '1987',
#   '',
#   '2022',
#   '2018',
#   '2021',
#   '1992',
#   '1995',
#   '2011',
#   '2008',
#   '2021',
#   '2010',
#   '1995',
#   '2022',
#   '2021',
#   'I) (',
#   '2023',
#   'III)',
#   'I) (',
#   '2018',
#   '2004',
#   '2011',
#   '2014',
#   '2004',
#   '2005',
#   '2015',
#   '1987',
#   '1994',
#   '1967',
#   '1990',
#   '2002',
#   '2006',
#   'I) (',
#   '2024',
#   '2013',
#   '1995',
#   '2012',
#   '2024',
#   '1989',
#   '1971',
#   '2017',
#   '2016',
#   '2020',
#   '1979',
#   'I) (',
#   '1963',
#   '2022',
#   '1997',
#   '2008',
#   '1981',
#   '2020',
#   '1997',
#   '2014',
#   '2023',
#   '2014',
#   '2012',
#   '2016',
#   '1979',
#   '2010',
#   '2003',
#   '1995',
#   '1981',
#   '2006',
#   '2015',
#   '1963',
#   '1996',
#   '2000',
#   'I) (',
#   '1973',
#   '2019',
#   '1997',
#   '1990',
#   '1962',
#   '2004',
#   '2011',
#   'I) (',
#   '2022',
#   '2022',
#   '2008',
#   '2002',
#   '1987',
#   '1982',
#   '2022',
#   '2008',
#   '2012',
#   '1982',
#   '1986',
#   '2007',
#   '2014',
#   '1987',
#   '1985',
#   '1984',
#   '2017',
#   '1984',
#   '2022',
#   '2016',
#   '2007',
#   '2021',
#   '2008',
#   '1969',
#   '1978',
#   '2022',
#   '1945',
#   '2001',
#   '1996',
#   '1996',
#   '2016',
#   '1986',
#   '1964',
#   '2016',
#   '1986',
#   '2018',
#   'I) (',
#   '2014',
#   '2015',
#   '2017',
#   '1969',
#   '',
#   '2015',
#   '2021',
#   '1995',
#   'II) ',
#   '1998',
#   '2020',
#   ...],
#  'Watch Time': ['118 min',
#   '135 min',
#   '130 min',
#   None,
#   '127 min',
#   '139 min',
#   '107 min',
#   '110 min',
#   '162 min',
#   '178 min',
#   '147 min',
#   '163 min',
#   '99 min',
#   '176 min',
#   '124 min',
#   '133 min',
#   '102 min',
#   '122 min',
#   '130 min',
#   '137 min',
#   '148 min',
#   '104 min',
#   '89 min',
#   '155 min',
#   '105 min',
#   '167 min',
#   '121 min',
#   '126 min',
#   '116 min',
#   '126 min',
#   '147 min',
#   '112 min',
#   '201 min',
#   '113 min',
#   None,
#   '187 min',
#   '112 min',
#   '152 min',
#   None,
#   '163 min',
#   '148 min',
#   '99 min',
#   '126 min',
#   '179 min',
#   '113 min',
#   '148 min',
#   '150 min',
#   '164 min',
#   '100 min',
#   '148 min',
#   None,
#   '107 min',
#   None,
#   '181 min',
#   None,
#   '105 min',
#   '100 min',
#   '156 min',
#   '147 min',
#   '130 min',
#   '127 min',
#   '110 min',
#   '130 min',
#   '170 min',
#   '113 min',
#   '124 min',
#   '106 min',
#   '155 min',
#   '152 min',
#   '115 min',
#   '121 min',
#   '116 min',
#   '134 min',
#   '132 min',
#   '126 min',
#   '114 min',
#   '121 min',
#   '114 min',
#   '131 min',
#   '136 min',
#   '123 min',
#   '92 min',
#   '142 min',
#   '120 min',
#   '164 min',
#   None,
#   '149 min',
#   '139 min',
#   '119 min',
#   '118 min',
#   '136 min',
#   '140 min',
#   None,
#   '120 min',
#   None,
#   '117 min',
#   '90 min',
#   '143 min',
#   '95 min',
#   '105 min',
#   '115 min',
#   '119 min',
#   '242 min',
#   '141 min',
#   '115 min',
#   '121 min',
#   '117 min',
#   '122 min',
#   '121 min',
#   '175 min',
#   '108 min',
#   '106 min',
#   '120 min',
#   '140 min',
#   '101 min',
#   '147 min',
#   '134 min',
#   '119 min',
#   '129 min',
#   '104 min',
#   '122 min',
#   '100 min',
#   '122 min',
#   '124 min',
#   None,
#   '141 min',
#   '137 min',
#   '106 min',
#   None,
#   '111 min',
#   '106 min',
#   '114 min',
#   '132 min',
#   '147 min',
#   '112 min',
#   '137 min',
#   '107 min',
#   '132 min',
#   None,
#   '143 min',
#   '133 min',
#   '140 min',
#   '143 min',
#   '120 min',
#   '108 min',
#   '134 min',
#   '107 min',
#   '126 min',
#   None,
#   '126 min',
#   '144 min',
#   '111 min',
#   '177 min',
#   None,
#   '141 min',
#   '107 min',
#   None,
#   '113 min',
#   '152 min',
#   '131 min',
#   '128 min',
#   '113 min',
#   '132 min',
#   '123 min',
#   '100 min',
#   '117 min',
#   '107 min',
#   '110 min',
#   '129 min',
#   '126 min',
#   '136 min',
#   '85 min',
#   '103 min',
#   '130 min',
#   '141 min',
#   '116 min',
#   '95 min',
#   None,
#   '132 min',
#   '116 min',
#   '115 min',
#   '116 min',
#   '144 min',
#   '92 min',
#   '101 min',
#   '117 min',
#   '105 min',
#   '156 min',
#   '137 min',
#   None,
#   '97 min',
#   '110 min',
#   '112 min',
#   '95 min',
#   '143 min',
#   '110 min',
#   '113 min',
#   '127 min',
#   '106 min',
#   '132 min',
#   '139 min',
#   '124 min',
#   '137 min',
#   '162 min',
#   '118 min',
#   '122 min',
#   '90 min',
#   '104 min',
#   '139 min',
#   '115 min',
#   '120 min',
#   '119 min',
#   '121 min',
#   '128 min',
#   '109 min',
#   '132 min',
#   '118 min',
#   '112 min',
#   '123 min',
#   '144 min',
#   '106 min',
#   '105 min',
#   None,
#   '109 min',
#   '143 min',
#   '138 min',
#   '98 min',
#   '138 min',
#   '129 min',
#   None,
#   '126 min',
#   None,
#   None,
#   '127 min',
#   '144 min',
#   '128 min',
#   '104 min',
#   '116 min',
#   '127 min',
#   '99 min',
#   '122 min',
#   '109 min',
#   '94 min',
#   '131 min',
#   None,
#   '112 min',
#   '151 min',
#   '107 min',
#   '100 min',
#   '144 min',
#   '143 min',
#   '122 min',
#   '136 min',
#   '138 min',
#   '112 min',
#   '124 min',
#   '115 min',
#   '124 min',
#   '98 min',
#   '111 min',
#   '113 min',
#   '129 min',
#   None,
#   '127 min',
#   None,
#   '109 min',
#   '136 min',
#   '130 min',
#   '99 min',
#   '118 min',
#   '138 min',
#   '108 min',
#   '103 min',
#   None,
#   '93 min',
#   '107 min',
#   '115 min',
#   '110 min',
#   '144 min',
#   '127 min',
#   '140 min',
#   '114 min',
#   '126 min',
#   '133 min',
#   '135 min',
#   '132 min',
#   '123 min',
#   '141 min',
#   '136 min',
#   None,
#   '104 min',
#   '125 min',
#   '118 min',
#   '118 min',
#   '98 min',
#   '118 min',
#   '131 min',
#   '147 min',
#   '100 min',
#   '111 min',
#   '106 min',
#   '145 min',
#   '145 min',
#   '119 min',
#   '99 min',
#   '135 min',
#   None,
#   '117 min',
#   '152 min',
#   '98 min',
#   '148 min',
#   '129 min',
#   '153 min',
#   '107 min',
#   '183 min',
#   '123 min',
#   '100 min',
#   '124 min',
#   '148 min',
#   '101 min',
#   '122 min',
#   '130 min',
#   '119 min',
#   '113 min',
#   '119 min',
#   '126 min',
#   '102 min',
#   '131 min',
#   '139 min',
#   '110 min',
#   '132 min',
#   '107 min',
#   '146 min',
#   '99 min',
#   '125 min',
#   '127 min',
#   '102 min',
#   '152 min',
#   '114 min',
#   '118 min',
#   '117 min',
#   '123 min',
#   '119 min',
#   '95 min',
#   '154 min',
#   None,
#   '107 min',
#   '94 min',
#   '141 min',
#   '113 min',
#   '137 min',
#   '125 min',
#   '103 min',
#   None,
#   '113 min',
#   '112 min',
#   '105 min',
#   '87 min',
#   '118 min',
#   '151 min',
#   '113 min',
#   '140 min',
#   '140 min',
#   '112 min',
#   '131 min',
#   '124 min',
#   '133 min',
#   '158 min',
#   '99 min',
#   '128 min',
#   '128 min',
#   '124 min',
#   '114 min',
#   '107 min',
#   '130 min',
#   '136 min',
#   '89 min',
#   None,
#   '88 min',
#   '115 min',
#   '151 min',
#   '94 min',
#   '132 min',
#   '96 min',
#   '115 min',
#   '126 min',
#   '94 min',
#   '97 min',
#   '97 min',
#   '132 min',
#   '121 min',
#   None,
#   '165 min',
#   '140 min',
#   '129 min',
#   '143 min',
#   '137 min',
#   '120 min',
#   '113 min',
#   '119 min',
#   '147 min',
#   '142 min',
#   '124 min',
#   '86 min',
#   '110 min',
#   '107 min',
#   '122 min',
#   '127 min',
#   '130 min',
#   '110 min',
#   '137 min',
#   None,
#   '121 min',
#   '90 min',
#   '107 min',
#   '109 min',
#   '100 min',
#   None,
#   '136 min',
#   '86 min',
#   '150 min',
#   '98 min',
#   '85 min',
#   '207 min',
#   '140 min',
#   '125 min',
#   '116 min',
#   '144 min',
#   '120 min',
#   '99 min',
#   '114 min',
#   '107 min',
#   '104 min',
#   '118 min',
#   '93 min',
#   None,
#   '109 min',
#   '101 min',
#   '90 min',
#   '112 min',
#   '124 min',
#   '95 min',
#   '121 min',
#   '129 min',
#   '114 min',
#   '117 min',
#   '109 min',
#   '131 min',
#   '126 min',
#   '140 min',
#   None,
#   '110 min',
#   '114 min',
#   None,
#   '122 min',
#   '116 min',
#   '92 min',
#   '100 min',
#   '122 min',
#   '144 min',
#   '137 min',
#   '95 min',
#   '142 min',
#   '124 min',
#   '117 min',
#   '103 min',
#   '116 min',
#   '116 min',
#   '168 min',
#   '120 min',
#   '130 min',
#   '107 min',
#   '110 min',
#   '187 min',
#   '92 min',
#   '98 min',
#   '113 min',
#   '123 min',
#   '132 min',
#   '135 min',
#   '136 min',
#   '109 min',
#   '109 min',
#   '97 min',
#   '93 min',
#   '85 min',
#   '132 min',
#   '114 min',
#   '112 min',
#   '107 min',
#   '106 min',
#   '105 min',
#   None,
#   '109 min',
#   '90 min',
#   '111 min',
#   '109 min',
#   '122 min',
#   '138 min',
#   '126 min',
#   '134 min',
#   '98 min',
#   '127 min',
#   '169 min',
#   '102 min',
#   '88 min',
#   '143 min',
#   '119 min',
#   '100 min',
#   '99 min',
#   '131 min',
#   '110 min',
#   '103 min',
#   '116 min',
#   '126 min',
#   '101 min',
#   '138 min',
#   '108 min',
#   '109 min',
#   '111 min',
#   '129 min',
#   '121 min',
#   '119 min',
#   None,
#   '96 min',
#   '99 min',
#   '102 min',
#   '125 min',
#   '104 min',
#   '164 min',
#   '115 min',
#   '109 min',
#   '103 min',
#   '100 min',
#   '96 min',
#   '132 min',
#   '121 min',
#   '98 min',
#   '108 min',
#   '118 min',
#   '183 min',
#   '99 min',
#   None,
#   '121 min',
#   '132 min',
#   '130 min',
#   None,
#   '103 min',
#   '118 min',
#   '154 min',
#   '106 min',
#   '94 min',
#   '118 min',
#   '91 min',
#   '93 min',
#   '146 min',
#   '120 min',
#   '104 min',
#   '116 min',
#   '106 min',
#   '106 min',
#   '114 min',
#   '135 min',
#   '131 min',
#   '122 min',
#   None,
#   '175 min',
#   '150 min',
#   '101 min',
#   '123 min',
#   '127 min',
#   '138 min',
#   '110 min',
#   '119 min',
#   '103 min',
#   '103 min',
#   '113 min',
#   '138 min',
#   '119 min',
#   '106 min',
#   '134 min',
#   '109 min',
#   '88 min',
#   '141 min',
#   '88 min',
#   '109 min',
#   '138 min',
#   '105 min',
#   '115 min',
#   '106 min',
#   '84 min',
#   '104 min',
#   '88 min',
#   '124 min',
#   '118 min',
#   '115 min',
#   '121 min',
#   '119 min',
#   '113 min',
#   '127 min',
#   '122 min',
#   '99 min',
#   '120 min',
#   '111 min',
#   '115 min',
#   '100 min',
#   '130 min',
#   '107 min',
#   '104 min',
#   '117 min',
#   '96 min',
#   '107 min',
#   '113 min',
#   '129 min',
#   '112 min',
#   '122 min',
#   '105 min',
#   '131 min',
#   '116 min',
#   '107 min',
#   '96 min',
#   '105 min',
#   '92 min',
#   '98 min',
#   '113 min',
#   '96 min',
#   '129 min',
#   '118 min',
#   '131 min',
#   '101 min',
#   '123 min',
#   None,
#   '93 min',
#   '130 min',
#   '116 min',
#   '114 min',
#   '137 min',
#   '126 min',
#   '159 min',
#   '114 min',
#   '95 min',
#   '123 min',
#   '116 min',
#   '108 min',
#   '92 min',
#   None,
#   '115 min',
#   '95 min',
#   '96 min',
#   '114 min',
#   '123 min',
#   '107 min',
#   '108 min',
#   '88 min',
#   '93 min',
#   '104 min',
#   '111 min',
#   '134 min',
#   '114 min',
#   '87 min',
#   '101 min',
#   '118 min',
#   '138 min',
#   '83 min',
#   '136 min',
#   '112 min',
#   '100 min',
#   '103 min',
#   '130 min',
#   '109 min',
#   '122 min',
#   '102 min',
#   '107 min',
#   '133 min',
#   '89 min',
#   '130 min',
#   '88 min',
#   '114 min',
#   '88 min',
#   '137 min',
#   '108 min',
#   '128 min',
#   '92 min',
#   '101 min',
#   '88 min',
#   '121 min',
#   '100 min',
#   None,
#   '92 min',
#   '150 min',
#   '154 min',
#   '140 min',
#   '128 min',
#   '115 min',
#   '119 min',
#   '100 min',
#   '102 min',
#   '120 min',
#   '124 min',
#   '105 min',
#   '143 min',
#   '134 min',
#   '121 min',
#   '88 min',
#   '140 min',
#   '107 min',
#   '115 min',
#   '116 min',
#   '133 min',
#   '102 min',
#   '102 min',
#   '109 min',
#   '112 min',
#   '178 min',
#   '114 min',
#   '124 min',
#   '148 min',
#   '129 min',
#   '132 min',
#   '132 min',
#   '98 min',
#   '165 min',
#   '100 min',
#   '153 min',
#   '125 min',
#   '115 min',
#   '95 min',
#   '92 min',
#   '142 min',
#   '98 min',
#   '98 min',
#   '107 min',
#   '100 min',
#   '96 min',
#   '100 min',
#   '118 min',
#   '105 min',
#   '124 min',
#   '101 min',
#   '119 min',
#   '101 min',
#   '106 min',
#   '119 min',
#   '96 min',
#   '124 min',
#   '112 min',
#   '111 min',
#   '130 min',
#   '124 min',
#   '121 min',
#   '135 min',
#   '115 min',
#   '56 min',
#   '102 min',
#   '113 min',
#   '138 min',
#   '113 min',
#   None,
#   '109 min',
#   '97 min',
#   '154 min',
#   '110 min',
#   '88 min',
#   '102 min',
#   '130 min',
#   '97 min',
#   '103 min',
#   '115 min',
#   '105 min',
#   '123 min',
#   '119 min',
#   '109 min',
#   '121 min',
#   '123 min',
#   '99 min',
#   '98 min',
#   None,
#   '84 min',
#   '128 min',
#   '108 min',
#   '106 min',
#   '101 min',
#   '92 min',
#   '118 min',
#   '120 min',
#   '108 min',
#   '115 min',
#   '115 min',
#   '132 min',
#   '86 min',
#   '116 min',
#   '102 min',
#   '94 min',
#   '191 min',
#   '117 min',
#   None,
#   '96 min',
#   '116 min',
#   '114 min',
#   '132 min',
#   '86 min',
#   '104 min',
#   '136 min',
#   '131 min',
#   '107 min',
#   '107 min',
#   '104 min',
#   '110 min',
#   '118 min',
#   '87 min',
#   '115 min',
#   '124 min',
#   '109 min',
#   '128 min',
#   '150 min',
#   '117 min',
#   '97 min',
#   '108 min',
#   '104 min',
#   '121 min',
#   '136 min',
#   '131 min',
#   '150 min',
#   None,
#   None,
#   '129 min',
#   '100 min',
#   '126 min',
#   '105 min',
#   '150 min',
#   '92 min',
#   '89 min',
#   '105 min',
#   '110 min',
#   '110 min',
#   '125 min',
#   '92 min',
#   '130 min',
#   '98 min',
#   '105 min',
#   '139 min',
#   '95 min',
#   '114 min',
#   '94 min',
#   '96 min',
#   '95 min',
#   '79 min',
#   '83 min',
#   '75 min',
#   '102 min',
#   '118 min',
#   '118 min',
#   '118 min',
#   '100 min',
#   '108 min',
#   '101 min',
#   '91 min',
#   '104 min',
#   '114 min',
#   '119 min',
#   '109 min',
#   '111 min',
#   '149 min',
#   '125 min',
#   '124 min',
#   '112 min',
#   '100 min',
#   '128 min',
#   '96 min',
#   '75 min',
#   '94 min',
#   '111 min',
#   '93 min',
#   '128 min',
#   '97 min',
#   '96 min',
#   '117 min',
#   '106 min',
#   None,
#   '87 min',
#   '94 min',
#   '121 min',
#   '117 min',
#   '108 min',
#   '127 min',
#   '92 min',
#   '121 min',
#   '105 min',
#   '108 min',
#   '147 min',
#   '109 min',
#   '103 min',
#   None,
#   None,
#   '118 min',
#   '117 min',
#   '99 min',
#   '104 min',
#   '92 min',
#   '118 min',
#   '110 min',
#   '96 min',
#   '100 min',
#   '102 min',
#   '111 min',
#   '124 min',
#   '92 min',
#   '88 min',
#   '88 min',
#   None,
#   '114 min',
#   '95 min',
#   '103 min',
#   None,
#   '133 min',
#   '112 min',
#   '100 min',
#   '112 min',
#   '118 min',
#   '118 min',
#   '117 min',
#   '103 min',
#   '131 min',
#   '108 min',
#   '113 min',
#   '123 min',
#   '93 min',
#   '119 min',
#   '138 min',
#   None,
#   '105 min',
#   '99 min',
#   '120 min',
#   '126 min',
#   '105 min',
#   '129 min',
#   '104 min',
#   '127 min',
#   '102 min',
#   '105 min',
#   '210 min',
#   '101 min',
#   '118 min',
#   '96 min',
#   '102 min',
#   '104 min',
#   '89 min',
#   '107 min',
#   '133 min',
#   '113 min',
#   '110 min',
#   '104 min',
#   None,
#   '170 min',
#   '96 min',
#   '117 min',
#   '120 min',
#   '96 min',
#   '90 min',
#   '106 min',
#   '94 min',
#   '113 min',
#   '97 min',
#   '128 min',
#   '103 min',
#   '109 min',
#   '162 min',
#   '101 min',
#   '104 min',
#   '103 min',
#   None,
#   '104 min',
#   '113 min',
#   '91 min',
#   '109 min',
#   '142 min',
#   '110 min',
#   '89 min',
#   '76 min',
#   '92 min',
#   '121 min',
#   '98 min',
#   '83 min',
#   '110 min',
#   '99 min',
#   '95 min',
#   '97 min',
#   '125 min',
#   '97 min',
#   '106 min',
#   '127 min',
#   '167 min',
#   '145 min',
#   None,
#   '120 min',
#   '113 min',
#   '96 min',
#   '100 min',
#   '124 min',
#   '113 min',
#   ...],
#  'Movie Rating': ['6.4',
#   '6.1',
#   '8.4',
#   None,
#   '7.5',
#   '8.1',
#   '6.1',
#   '6.9',
#   '7.8',
#   '8.8',
#   '5.7',
#   '8.6',
#   '7.2',
#   '7.9',
#   None,
#   '7.8',
#   '5.7',
#   '6.5',
#   '5.1',
#   '7.1',
#   '8.3',
#   '5.2',
#   '4.7',
#   '8.0',
#   '7.5',
#   '5.6',
#   '7.0',
#   '7.0',
#   '6.3',
#   '7.3',
#   '7.8',
#   '5.3',
#   '9.0',
#   '6.1',
#   None,
#   '8.0',
#   '6.1',
#   '9.0',
#   None,
#   '7.3',
#   '5.7',
#   '6.9',
#   '6.5',
#   '8.8',
#   '7.8',
#   '8.8',
#   '7.3',
#   '8.0',
#   '5.9',
#   '7.4',
#   None,
#   '7.0',
#   None,
#   '8.4',
#   None,
#   '7.9',
#   '7.2',
#   '6.3',
#   '8.3',
#   '5.8',
#   '8.2',
#   '8.5',
#   '7.9',
#   '8.3',
#   '6.1',
#   '7.1',
#   '5.4',
#   '8.5',
#   '7.4',
#   '7.1',
#   '7.4',
#   '6.4',
#   '6.7',
#   '7.2',
#   '7.2',
#   '6.6',
#   '8.6',
#   '5.6',
#   '6.3',
#   '8.7',
#   '5.9',
#   '7.4',
#   '7.2',
#   '8.1',
#   '8.4',
#   None,
#   '8.4',
#   '6.6',
#   '8.2',
#   '6.6',
#   '6.1',
#   '7.4',
#   None,
#   '7.5',
#   None,
#   '8.1',
#   '5.2',
#   '8.1',
#   '5.6',
#   '7.8',
#   '8.4',
#   '7.1',
#   '8.0',
#   '7.0',
#   '7.0',
#   '7.6',
#   '8.4',
#   '6.5',
#   '8.0',
#   '8.4',
#   '8.0',
#   '5.4',
#   '8.4',
#   '8.2',
#   '7.4',
#   None,
#   '7.3',
#   '7.7',
#   '4.6',
#   '5.4',
#   '5.5',
#   '7.8',
#   '7.3',
#   '6.9',
#   None,
#   '7.4',
#   '8.4',
#   '7.8',
#   None,
#   '6.2',
#   '6.7',
#   '7.3',
#   '7.0',
#   '7.7',
#   '6.6',
#   '8.6',
#   '7.8',
#   '7.4',
#   None,
#   '8.0',
#   '7.4',
#   '8.2',
#   '5.2',
#   '6.2',
#   '7.2',
#   '7.5',
#   '8.1',
#   '7.9',
#   None,
#   '6.7',
#   '8.0',
#   '8.2',
#   '8.1',
#   None,
#   '6.5',
#   '4.5',
#   None,
#   '7.9',
#   '8.1',
#   '6.0',
#   '6.1',
#   '7.6',
#   '6.9',
#   '6.8',
#   '6.7',
#   '7.6',
#   '7.0',
#   '5.8',
#   '7.7',
#   '7.6',
#   '6.5',
#   '2.6',
#   '5.8',
#   '7.0',
#   '7.3',
#   '7.0',
#   '7.1',
#   None,
#   '8.2',
#   '5.5',
#   '7.1',
#   '7.3',
#   '7.0',
#   '5.5',
#   None,
#   '7.6',
#   '7.3',
#   '8.0',
#   '8.1',
#   None,
#   '5.9',
#   '6.7',
#   '6.4',
#   '6.8',
#   '6.8',
#   '6.1',
#   '6.4',
#   '6.1',
#   '5.8',
#   '7.0',
#   '7.8',
#   '6.9',
#   '6.3',
#   '7.6',
#   '6.3',
#   '7.3',
#   '6.5',
#   '4.7',
#   '6.3',
#   '8.0',
#   '6.1',
#   '6.9',
#   '7.8',
#   '6.2',
#   '7.6',
#   '8.2',
#   '7.5',
#   '7.5',
#   '6.6',
#   '7.8',
#   '6.8',
#   '7.3',
#   None,
#   '7.9',
#   '7.8',
#   '6.5',
#   '4.2',
#   '7.8',
#   '6.5',
#   None,
#   '7.5',
#   None,
#   None,
#   '8.2',
#   '7.7',
#   '6.1',
#   '7.3',
#   '7.2',
#   '7.9',
#   '7.2',
#   '7.0',
#   '6.7',
#   '5.6',
#   '7.4',
#   None,
#   '6.8',
#   '5.4',
#   '5.3',
#   '6.0',
#   '6.9',
#   '7.1',
#   '7.2',
#   '6.9',
#   '5.6',
#   '6.6',
#   '8.7',
#   '7.5',
#   '7.0',
#   '5.6',
#   '5.4',
#   '6.8',
#   '7.3',
#   None,
#   '7.4',
#   None,
#   '6.0',
#   '7.6',
#   '7.4',
#   '4.5',
#   '7.6',
#   '7.5',
#   '5.8',
#   '6.4',
#   None,
#   '7.5',
#   '8.2',
#   '5.7',
#   '7.1',
#   '7.2',
#   '7.0',
#   '7.6',
#   '5.5',
#   '6.1',
#   '7.3',
#   '6.9',
#   '7.4',
#   '6.7',
#   '7.3',
#   '7.4',
#   None,
#   '5.0',
#   '6.8',
#   '7.0',
#   '7.6',
#   '7.3',
#   '6.3',
#   '8.3',
#   '7.8',
#   '4.3',
#   '7.0',
#   '6.6',
#   '7.0',
#   '7.7',
#   '7.2',
#   '6.5',
#   '7.6',
#   None,
#   '6.2',
#   '6.9',
#   '5.9',
#   '6.8',
#   '7.4',
#   '7.6',
#   '5.2',
#   '6.5',
#   '6.6',
#   '6.6',
#   '6.9',
#   '5.7',
#   '6.9',
#   '7.7',
#   '6.4',
#   '6.2',
#   '6.3',
#   '6.3',
#   '7.1',
#   '7.5',
#   '7.7',
#   '6.5',
#   '6.0',
#   '7.2',
#   '6.2',
#   '7.5',
#   '7.2',
#   '3.7',
#   '6.6',
#   '7.6',
#   '6.4',
#   '7.2',
#   '6.1',
#   '5.9',
#   '8.1',
#   '7.4',
#   '6.6',
#   '7.8',
#   None,
#   '6.5',
#   '7.2',
#   '6.7',
#   '7.6',
#   '6.5',
#   '6.6',
#   '5.3',
#   None,
#   '5.7',
#   '7.6',
#   '6.2',
#   '6.1',
#   '4.9',
#   '7.3',
#   '6.5',
#   '6.2',
#   '6.6',
#   '7.7',
#   '5.8',
#   '7.1',
#   '7.9',
#   '5.8',
#   '5.9',
#   '7.6',
#   '7.3',
#   '6.4',
#   '6.1',
#   '6.5',
#   '7.2',
#   '6.4',
#   '6.4',
#   None,
#   '6.8',
#   '6.7',
#   '6.7',
#   '7.7',
#   '7.9',
#   '5.4',
#   '7.2',
#   '6.3',
#   '6.2',
#   '7.4',
#   '5.4',
#   '6.6',
#   '6.9',
#   None,
#   '7.2',
#   '7.0',
#   '6.9',
#   '7.4',
#   '7.1',
#   '7.1',
#   '7.5',
#   '7.9',
#   '8.3',
#   '6.6',
#   '7.2',
#   '8.1',
#   '6.3',
#   '7.3',
#   '7.4',
#   '6.4',
#   '7.1',
#   '6.0',
#   '6.6',
#   None,
#   '5.4',
#   '7.8',
#   '6.8',
#   '6.3',
#   '6.3',
#   None,
# ...
#   ('Sigourney Weaver', 'Winona Ryder'),
#   ('Tommy Lee Jones', 'Will Smith'),
#   ('Harrison Ford', 'Willem Dafoe'),
#   ('Taylor Russell', 'Logan Miller'),
#   ('Radha Mitchell', 'Cole Hauser'),
#   ('Ed Skrein', 'Patrick Wilson'),
#   ('Jason Statham', 'Joan Allen'),
#   ('Charlize Theron', 'James McAvoy'),
#   ('Treat Williams', 'Famke Janssen'),
#   ('Yann Gael', 'Evelyne Ily Juhen'),
#   ('Nicolas Cage', 'Amber Heard'),
#   ('Michael Flatley', 'Eric Roberts'),
#   ('Mitsuo Iwata', 'Nozomu Sasaki'),
#   ('Paul Rudd', 'Evangeline Lilly'),
#   ('Nicolas Cage', 'John Cusack'),
#   ('Jason Clarke', 'Ang Phula Sherpa'),
#   ('Vin Diesel', 'Judi Dench'),
#   ('Jason Momoa', 'Ron Perlman'),
#   ('Lilly Wachowski', 'Channing Tatum'),
#   ('Seo In-Guk', 'Dong-Yoon Jang'),
#   ('Woody Harrelson', 'Jesse Eisenberg'),
#   ('Melissa McCarthy', 'Rose Byrne'),
#   ('Seth Rogen', 'James Franco'),
#   ('Sylvester Stallone', 'Wesley Snipes'),
#   ('Tim Allen', 'Martin Lawrence'),
#   ('Vin Diesel', 'Paul Walker'),
#   ('Jamie Bell', 'Andy Serkis'),
#   ('Josh Brolin', 'Elizabeth Olsen'),
#   ('Will Smith', 'Joel Edgerton'),
#   ('Mel Gibson', 'Bruce Spence'),
#   ('Mark Wahlberg', 'Kurt Russell'),
#   ('Katie Leung', 'Jackie Chan'),
#   ('Mark Wahlberg', 'Dwayne Johnson'),
#   ('Elle Fanning', 'AJ Michalka'),
#   ('Chris Hemsworth', 'Cillian Murphy'),
#   ('Karl Urban', 'Rosamund Pike'),
#   ('Jude Law', 'Ed Harris'),
#   ('Taron Egerton', 'Jamie Foxx'),
#   ('Johnny Depp', 'Isla Fisher'),
#   ('Johnny Knoxville', 'Steve-O'),
#   ('Rose McGowan', 'Freddy Rodríguez'),
#   ('Sam Neill', 'William H. Macy'),
#   ('Cameron Diaz', 'Drew Barrymore'),
#   ('Theo James', 'Kat Graham'),
#   ('Viggo Mortensen', 'Maria Bello'),
#   ('Jesse Eisenberg', 'Mark Ruffalo'),
#   ('Colin Farrell', 'Bokeem Woodbine'),
#   ('Aaron Taylor-Johnson', 'Taylor Kitsch'),
#   ('Arnold Schwarzenegger', 'Maria Conchita Alonso'),
#   ('Tom Cruise', 'Dougray Scott'),
#   ('Anya Taylor-Joy', 'Chris Hemsworth'),
#   ('Brendan Fraser', 'Josh Hutcherson'),
#   ('Harrison Ford', 'Tommy Lee Jones'),
#   ('Ken Marshall', 'Lysette Anthony'),
#   ('Sigourney Weaver', 'Charles S. Dutton'),
#   ("Jack O'Connell", 'Miyavi'),
#   ('Hugh Jackman', 'Will Yun Lee'),
#   ('Prabhas', 'Rana Daggubati'),
#   ('Hailee Steinfeld', 'Jorge Lendeborg Jr.'),
#   ('Idris Elba', 'Matthew McConaughey'),
#   ('Noomi Rapace', 'Glenn Close'),
#   ('Jake Gyllenhaal', 'Gemma Arterton'),
#   ('James Woods', 'Daniel Baldwin'),
#   ('Ioan Gruffudd', 'Jessica Alba'),
#   ('Aaron Taylor-Johnson', 'Russell Crowe'),
#   ('Sophia Loren', 'George Peppard'),
#   ('Travis Fimmel', 'Rhys Coiro'),
#   ('Nicolas Cage', 'Julianne Moore'),
#   ('Liam Neeson', 'Dan Stevens'),
#   ('Scott Eastwood', 'Caleb Landry Jones'),
#   ('Scarlett Johansson', 'Pilou Asbæk'),
#   ('Willem Dafoe', 'Sean Patrick Flanery'),
#   ('Michael Parks', 'Melissa Leo'),
#   ('Nikolaj Coster-Waldau', 'Caleb Ellsworth-Clark'),
#   ('Nora Arnezeder', 'Iain Glen'),
#   ("Dylan O'Brien", 'Michael Keaton'),
#   ('Josh Brolin', 'Miles Teller'),
#   ('Harrison Ford', 'Asa Butterfield'),
#   ('Sylvester Stallone', 'Brigitte Nielsen'),
#   ('Sanaa Lathan', 'Lance Henriksen'),
#   ('Eric Bana', 'Edgar Ramírez'),
#   ('Tom Hanks', 'Ewan McGregor'),
#   ('Chad Michael Collins', 'Jeff Fahey'),
#   ('Vin Diesel', 'Jason Statham'),
#   ('Chloë Grace Moretz', 'Matthew Zuk'),
#   ('Paul Bettany', 'Dennis Quaid'),
#   ('Steven Seagal', 'Gary Busey'),
#   ('Arnold Schwarzenegger', 'F. Murray Abraham'),
#   ('Jake Gyllenhaal', 'Michael Peña'),
#   ('Ron Perlman', 'Doug Jones'),
#   ('Michael Crichton', 'Antonio Banderas'),
#   ('Paul Walker', 'Tyrese Gibson'),
#   ('Michael B. Jordan', 'Sylvester Stallone'),
#   ('Sylvester Stallone', 'Paz Vega'),
#   ('Vin Diesel', 'Paul Walker'),
#   ('Yul Brynner', 'Richard Benjamin'),
#   ('Chris Hemsworth', 'Tessa Thompson'),
#   ('Jeremy Renner', 'Gemma Arterton'),
#   ('Jennifer Lawrence', 'Josh Hutcherson'),
#   ('Bill Murray', 'Dan Aykroyd'),
#   ('Hera Hilmar', 'Robert Sheehan'),
#   ('Corey Yuen', 'Jason Statham'),
#   ('Christopher Lambert', 'Robin Shou'),
#   ('Nicolas Cage', 'Emily Tosta'),
#   ('Denzel Washington', 'Pedro Pascal'),
#   ('Timothy Olyphant', 'Dougray Scott'),
#   ('Ryan Reynolds', 'Leslie Uggams'),
#   ('Tom Hardy', 'Kelly Adams'),
#   ('Christian Bale', 'Joel Edgerton'),
#   ('Brandon Routh', 'Kevin Spacey'),
#   ('Andy Serkis', 'Woody Harrelson'),
#   ('Leonardo DiCaprio', 'Russell Crowe'),
#   ('Claire Foy', 'Beau Gadsdon'),
#   ('Will Smith', 'Martin Lawrence'),
#   ('Jeremy Renner', 'Rose Byrne'),
#   ('Sullivan Stapleton', 'Eva Green'),
#   ('Chow Yun-Fat', 'Michelle Yeoh'),
#   ('Kristen Stewart', 'Robert Pattinson'),
#   ('Joey Lauren Adams', 'Ben Affleck'),
#   ("Dylan O'Brien", 'Ki Hong Lee'),
#   ('Tom Hanks', 'Barkhad Abdi'),
#   ('Gerard Butler', 'Frederick Schmidt'),
#   ('Hayden Christensen', 'Samuel L. Jackson'),
#   ('Russell Crowe', 'Cate Blanchett'),
#   ('Christian Bale', 'Sean Bean'),
#   ('Michael Fassbender', 'Marion Cotillard'),
#   ('Clint Eastwood', 'Sondra Locke'),
#   ('Pierce Brosnan', 'Halle Berry'),
#   ('Troy Quane', 'Rachel Brosnahan'),
#   ('Melissa McCarthy', 'Tiffany Haddish'),
#   ('Arnold Schwarzenegger', 'Nick Stahl'),
#   ('Kevin Bacon', 'Elisabeth Shue'),
#   ('Ranbir Kapoor', 'Sanjay Dutt'),
#   ('Karen Gillan', 'Lena Headey'),
#   ('Jake Gyllenhaal', 'Rachel McAdams'),
#   ('Tovino Thomas', 'Kalyani Priyadarshan'),
#   ('Robert Downey Jr.', 'Jude Law'),
#   ('Leonardo DiCaprio', 'Jeremy Irons'),
#   ('Kyle Chandler', 'Vera Farmiga'),
#   ('Noomi Rapace', 'Orlando Bloom'),
#   ('Mark Wahlberg', 'Nicola Peltz Beckham'),
#   ('Frank Grillo', 'Mel Gibson'),
#   ('Fawad Khan', 'Hamza Ali Abbasi'),
#   ('Demi Moore', 'Viggo Mortensen'),
#   ('Boyd Holbrook', 'Cleopatra Coleman'),
#   ('Will Ferrell', 'Jonah Hill'),
#   ('Kate Mara', 'Anya Taylor-Joy'),
#   ('Kim Eui-sung', 'Lee Hanee'),
#   ('Dwayne Johnson', 'John Hurt'),
#   ('Dwayne Johnson', 'Billy Bob Thornton'),
#   ('Jorge Lendeborg Jr.', 'Debby Ryan'),
#   ('Angelina Jolie', 'Jon Voight'),
#   ('Burt Reynolds', 'Sally Field'),
#   ('Christopher Miller', 'Chris Pratt'),
#   ('Ryan Reynolds', 'Samuel L. Jackson'),
#   ('James Franco', 'Andy Serkis'),
#   ('Thomas Jane', 'John Travolta'),
#   ('Matthew McConaughey', 'Christian Bale'),
#   ('Michael York', 'Jenny Agutter'),
#   ('Steve Railsback', 'Mathilda May'),
#   ('Javier Gutiérrez', 'Karra Elejalde'),
#   ('Gerard Butler', 'Aaron Eckhart'),
#   ('Sylvester Stallone', 'Richard Crenna'),
#   ('Ben Affleck', 'Morgan Freeman'),
#   ('Seth Rogen', 'James Franco'),
#   ('Saoirse Ronan', 'Cate Blanchett'),
#   ('George Clooney', 'Britt Robertson'),
#   ('Harrison Ford', 'Gary Oldman'),
#   ('Tom Hanks', 'Felicity Jones'),
#   ('Jeremy Renner', 'Rachel Weisz'),
#   ('Sheri Moon Zombie', 'Bill Moseley'),
#   ('Madison Skye Validum', 'Hudson Hua'),
#   ('Robert Rodriguez', 'Mickey Rourke'),
#   ('Rhona Mitra', 'Bob Hoskins'),
#   ('Mel Gibson', 'Madeleine Stowe'),
#   ('Sylvester Stallone', 'John Lithgow'),
#   ('Jennifer Coolidge', 'Jennifer Lopez'),
#   ('Gerard Butler', 'Jim Sturgess'),
#   ('Adam Sandler', 'Jennifer Aniston'),
#   ('Shia LaBeouf', 'Rosie Huntington-Whiteley'),
#   ('Sean Connery', 'Stuart Townsend'),
#   ('Alexa PenaVega', 'Daryl Sabara'),
#   ('Ben Barnes', 'Julianne Moore'),
#   ('Gary Oldman', 'William Hurt'),
#   ('Robert Englund', 'Ken Kirzinger'),
#   ('Ana de la Reguera', 'Tenoch Huerta'),
#   ('Will Smith', 'Bridget Moynahan'),
#   ('Charlie Sheen', 'Kiefer Sutherland'),
#   ('Aaron Taylor-Johnson', 'Elizabeth Olsen'),
#   ('Vin Diesel', 'Karl Urban'),
#   ('Denzel Washington', 'Mark Wahlberg'),
#   ('Santosh Sen', 'Pradeep Khadka'),
#   ('Jennifer Lawrence', 'Josh Hutcherson'),
#   ('Scott Eastwood', 'Kevin Durand'),
#   ('Emilio Estevez', 'Pat Hingle'),
#   ('Robert Downey Jr.', 'Jared Harris'),
#   ('Charlie Sheen', 'Cary Elwes'),
#   ('Keanu Reeves', 'Hiroyuki Sanada'),
#   ('Katheryn Winnick', 'Liam Neeson'),
#   ('Michael Douglas', 'Kathleen Turner'),
#   ('Iko Uwais', 'Ananda George'),
#   ('Jean-Claude Van Damme', 'Donald Gibb'),
#   ('Matt Damon', 'Heath Ledger'),
#   ('Tilda Swinton', 'Paul Dano'),
#   ('Thora Birch', 'Anne Heche'),
#   ('Matt Damon', 'Edgar Ramírez'),
#   ('Ray Winstone', 'Crispin Glover'),
#   ('Colin Farrell', 'Jamie Foxx'),
#   ('Kristy Swanson', 'Donald Sutherland'),
#   ('Mads Mikkelsen', 'Nikolaj Lie Kaas'),
#   ('Craig Sheffer', 'David Cronenberg'),
#   ('Mark Wahlberg', 'Lauren Cohan'),
#   ('Eli Roth', 'Quentin Tarantino'),
#   ('Liam Neeson', 'Bradley Cooper'),
#   ('Tilda Swinton', 'Michael Fassbender'),
#   ('Bruce Willis', 'Theo Rossi'),
#   ('Christian Bale', 'Casey Affleck'),
#   ('Matthew Broderick', 'Ally Sheedy'),
#   ('Aaron Paul', 'Dominic Cooper'),
#   ('Dwayne Johnson', 'Ashley Scott'),
#   ('Albert Magnoli', 'Sylvester Stallone'),
#   ('Antonio Banderas', 'Anthony Hopkins'),
#   ('Channing Tatum', 'Jamie Foxx'),
#   ('Dwayne Johnson', 'Kevin Hart'),
#   ('Chris Brown', 'Hayden Christensen'),
#   ('Ryan Reynolds', 'Justice Smith'),
#   ('Sean Connery', 'Ursula Andress'),
#   ('Allen Hughes', 'Denzel Washington'),
#   ('Jason Statham', 'Amber Valletta'),
#   ('Sylvester Stallone', 'Arnold Schwarzenegger'),
#   ('Bilall Fallah', 'Will Smith'),
#   ('Michael B. Jordan', 'Jodie Turner-Smith'),
#   ('Pierce Brosnan', 'Sophie Marceau'),
#   ('Ben Barnes', 'Skandar Keynes'),
#   ('Natsuki Hanae', 'Akari Kitô'),
#   ('Steve Zahn', 'Paul Walker'),
#   ('Matt Damon', 'Franka Potente'),
#   ('Emilio Estevez', 'Kiefer Sutherland'),
#   ('Bruce Willis', 'Cole Hauser'),
#   ('Scarlett Johansson', 'Ewan McGregor'),
#   ("Dylan O'Brien", 'Kaya Scodelario'),
#   ('Lee Marvin', 'Ernest Borgnine'),
#   ('Mel Gibson', 'Danny Glover'),
#   ('Ana de Armas', 'Chris Evans'),
#   ('Hyun Bin', 'Im Yoon-ah'),
#   ('Jeremy Renner', 'Ed Helms'),
#   ('Denzel Washington', 'Paula Patton'),
#   ('Benjamin Walker', 'Rufus Sewell'),
#   ('Johnny Depp', 'Armie Hammer'),
#   ('Idris Elba', 'Richard Madden'),
#   ('Dane DeHaan', 'Alex Russell'),
#   ('Sean Pertwee', 'Kevin McKidd'),
#   ('Steve Carell', 'Anne Hathaway'),
#   ('Sean Connery', 'Gert Fröbe'),
#   ('Oscar Isaac', 'Jessica Chastain'),
#   ('Sylvester Stallone', 'Julie Benz'),
#   ('Gary Oldman', 'Keri Russell'),
#   ('Daniel Radcliffe', 'Samara Weaving'),
#   ('Thomas Jane', 'Saffron Burrows'),
#   ('Kevin Costner', 'Robert Duvall'),
#   ('Burt Reynolds', 'Roger Moore'),
#   ('Edgar Ramírez', 'Luke Bracey'),
#   ('Milla Jovovich', 'Sienna Guillory'),
#   ('Guy Pearce', 'Yancey Arias'),
#   ('Vin Diesel', 'Brittany Snow'),
#   ('Elijah Wood', 'Jennifer Connelly'),
#   ('Atsuko Tanaka', 'Iemasa Kayumi'),
#   ('Drake Bell', 'Leslie Nielsen'),
#   ('Gugu Mbatha-Raw', 'David Oyelowo'),
#   ('Laurence Olivier', 'Harry Hamlin'),
#   ('Dennis Quaid', 'Channing Tatum'),
#   ('Mel Gibson', 'Danny Glover'),
#   ('Angelina Jolie', 'Liev Schreiber'),
#   ('Billy Campbell', 'Jennifer Connelly'),
#   ('Tyler Perry', 'Matthew Fox'),
#   ('Vinnie Jones', 'Lina Lecompte'),
#   ('Gene Hackman', 'Roy Scheider'),
#   ('Tatsuya Fujiwara', 'Aki Maeda'),
#   ('Bill Murray', 'Owen Wilson'),
#   ('Ma Dong-seok', 'Jeon Bae-soo'),
#   ('John Boyega', 'Scott Eastwood'),
#   ('Shia LaBeouf', 'Megan Fox'),
#   ('Ryôsuke Yamada', 'Tsubasa Honda'),
#   ('Vin Diesel', 'Asia Argento'),
#   ('Christopher Miller', 'Channing Tatum'),
#   ('Jason Statham', 'James Franco'),
#   ('Rachel Ward', 'Jeff Bridges'),
#   ('Ryan Reynolds', 'Jeff Bridges'),
#   ('Greg Cohan', 'George Schewnzer'),
#   ('Greg Strause', 'Reiko Aylesworth'),
#   ('Sam J. Jones', 'Melody Anderson'),
#   ('Jason Clarke', 'Michelle Monaghan'),
#   ('Bruce Willis', 'Jeremy Irons'),
#   ('Steven Strait', 'Sebastian Stan'),
#   ('Jeff Bridges', 'Bruce Boxleitner'),
#   ('Gene Hackman', 'Ernest Borgnine'),
#   ('Dolph Lundgren', 'Frank Langella'),
#   ('Jake Gyllenhaal', 'Darren Barnet'),
#   ('Ed Westwick', 'Rupert Graves'),
#   ('Jason Momoa', 'Garret Dillahunt'),
#   ('Henry Golding', 'Andrew Koji'),
#   ('Harrison Ford', 'Sean Bean'),
#   ('Natasha Henstridge', 'Michael Madsen'),
#   ('Hugh Jackman', 'Evangeline Lilly'),
#   ('Will Smith', 'Charlize Theron'),
#   ('Peri Baumeister', 'Carl Anton Koch'),
#   ('George Clooney', 'Paolo Bonacelli'),
#   ('Sharon Stone', 'Gene Hackman'),
#   ('Pushkar', 'Radhika Apte'),
#   ('Liam Neeson', 'Marcus Thomas'),
#   ('Johnny Depp', 'Angelina Jolie'),
#   ('Orlando Bloom', 'David Harbour'),
#   ('Mark Hamill', 'Martyn Ford'),
#   ('Clive Owen', 'Naomi Watts'),
#   ('Justin Theroux', 'Blanka Györfi-Tóth'),
#   ('Stephen Chow', 'Wah Yuen'),
#   ('Eddie Murphy', 'Ben Stiller'),
#   ('Luke Evans', 'Dominic Cooper'),
#   ('Billy Bob Thornton', 'Jay Hernandez'),
#   ('Paul Walker', 'Jessica Alba'),
#   ('Rupert Friend', 'Hannah Ware'),
#   ('Eddie Murphy', 'Judge Reinhold'),
#   ('Jean-Claude Van Damme', 'Raul Julia'),
#   ('Warren Beatty', 'Faye Dunaway'),
#   ('Bruce Willis', 'William Atherton'),
#   ('Dwayne Johnson', 'Steven Brand'),
#   ('Brian Taylor', 'Jason Statham'),
#   ('Antonio Banderas', 'Ben Kingsley'),
#   ('Zoe Saldana', 'Michelle Yeoh'),
#   ('Nicholas Hoult', 'Stanley Tucci'),
#   ('Karan Ashley', 'Johnny Yong Bosch'),
#   ('Reese Witherspoon', 'Chris Pine'),
#   ('Idris Elba', 'Ben Schwartz'),
#   ('Timothy Dalton', 'Robert Davi'),
#   ('Michael Caine', 'Ian Hendry'),
#   ('Michael Peña', 'Dax Shepard'),
#   ('Megan Fox', 'Will Arnett'),
#   ('Tom Hanks', 'Helena Zengel'),
#   ('John Belushi', 'Dan Aykroyd'),
#   ('Sandra Bullock', 'Michael McDonald'),
#   ('Henry Silva', 'Elizabeth Montgomery'),
#   ('Lee Jung-jae', 'Heo Sung-tae'),
#   ('Pierce Brosnan', 'Linda Hamilton'),
#   ('Adam Sandler', 'John Turturro'),
#   ('James Caan', 'Tuesday Weld'),
#   ('Joe Keery', 'Sasheer Zamata'),
#   ('Pierce Brosnan', 'Jonathan Pryce'),
#   ('Russell Crowe', 'Jennifer Connelly'),
#   ('Chris Hemsworth', 'Golshifteh Farahani'),
#   ('Chris Pine', 'Kevin Costner'),
#   ('Sam Worthington', 'Liam Neeson'),
#   ('Liam Hemsworth', 'Jeff Goldblum'),
#   ('Roger Moore', 'Lois Chiles'),
#   ('Robert Rodriguez', 'Danny Trejo'),
#   ('Lilly Wachowski', 'Keanu Reeves'),
#   ('Antonio Banderas', 'Salma Hayek'),
#   ('Roger Moore', 'Carole Bouquet'),
#   ('Sylvester Stallone', 'Antonio Tarver'),
#   ('Adam Sandler', 'Kevin James'),
#   ('Spencer Tracy', 'Milton Berle'),
#   ('Kurt Russell', 'Steve Buscemi'),
#   ('John Travolta', 'Forest Whitaker'),
#   ('Rainn Wilson', 'Elliot Page'),
#   ('Bruce Lee', 'John Saxon'),
#   ('Jay Baruchel', 'America Ferrera'),
#   ('Jon Voight', 'Jennifer Lopez'),
#   ('Tom Cruise', 'Nicole Kidman'),
#   ('Tatsuya Nakadai', 'Akira Ishihama'),
#   ('Wesley Snipes', 'Kris Kristofferson'),
#   ('James Marsden', 'Kate Bosworth'),
#   ('Liam Neeson', 'Vera Farmiga'),
#   ('Arnold Schwarzenegger', 'Michael Fassbender'),
#   ('Vikram', 'Karthi'),
#   ('Freddie Highmore', 'Sarah Bolger'),
#   ('Wesley Snipes', 'Kris Kristofferson'),
#   ('Dennis Quaid', 'Martin Short'),
#   ('Nick Nolte', 'Eddie Murphy'),
#   ('Pierce Brosnan', 'Kaya Scodelario'),
#   ('Donnie Yen', 'Simon Yam'),
#   ('Josh Hutcherson', 'Dwayne Johnson'),
#   ('William Shatner', 'Leonard Nimoy'),
#   ('Paul Hogan', 'Linda Kozlowski'),
#   ('Bruce Willis', 'Justin Long'),
#   ('Frank Grillo', 'Carmen Ejogo'),
#   ('Jim Belushi', 'Louis Gossett Jr.'),
#   ('Tatsuya Nakadai', 'Akira Terao'),
#   ('Lance Guest', 'Robert Preston'),
#   ('Will Arnett', 'Michael Cera'),
#   ('Arnold Schwarzenegger', 'Grace Jones'),
#   ('Upendra', 'Sudeep'),
#   ('Ethan Hawke', 'John Travolta'),
#   ('Josh Hartnett', 'Melissa George'),
#   ('Kate Beckinsale', 'Jai Courtney'),
#   ('Camilla Belle', 'Steven Strait'),
#   ('George Lazenby', 'Diana Rigg'),
#   ('Kris Kristofferson', 'Ali MacGraw'),
#   ('Nicky Whelan', 'Trace Adkins'),
#   ('Johnny Weissmuller', 'Brenda Joyce'),
#   ('Kane Hodder', 'Lexa Doig'),
#   ('Geena Davis', 'Samuel L. Jackson'),
#   ('Pamela Anderson', 'Amir AboulEla'),
#   ('Sacha Baron Cohen', 'Mark Strong'),
#   ('Lea Thompson', 'Jeffrey Jones'),
#   ('Clint Eastwood', 'Gian Maria Volontè'),
#   ('Jennifer Yuh Nelson', 'Jack Black'),
#   ('Rutger Hauer', 'C. Thomas Howell'),
#   ('Kim Da-Mi', 'Min-soo Jo'),
#   ('James McAvoy', 'Jamie Bell'),
#   ('Liam Neeson', 'Julianne Moore'),
#   ('Jackie Chan', 'John Cusack'),
#   ('Prabhas', 'Rana Daggubati'),
#   ('William Holden', 'Ernest Borgnine'),
#   ('Charlize Theron', 'Uma Thurman'),
#   ('Sharlto Copley', 'Dev Patel'),
#   ('Noomi Rapace', 'Aksel Hennie'),
#   ('Sylvester Stallone', 'Armand Assante'),
#   ('YaYa Gosselin', 'Pedro Pascal'),
#   ('Denzel Washington', 'John Goodman'),
#   ('Ariel Schulman', 'Jamie Foxx'),
#   ...]}

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df.head()
# Out:
#                  Movie Name Year of Release Watch Time Movie Rating  \
# 0    Thor: Love and Thunder            2022    118 min          6.4
# 1            The Woman King            2022    135 min          6.1
# 2         Top Gun: Maverick            2022    130 min          8.4
# 3  Avatar: The Way of Water            2022       None         None
# 4              Bullet Train            2022    127 min          7.5
#
#                                    Genres  \
# 0   Action, Adventure, Comedy
# 1      Action, Drama, History
# 2               Action, Drama
# 3  Action, Adventure, Fantasy
# 4    Action, Comedy, Thriller
#
#                                          Description               Director  \
# 0  Thor enlists the help of Valkyrie, Korg and ex...          Taika Waititi
# 1  A historical epic inspired by true events that...  Gina Prince-Bythewood
# 2  After thirty years, Maverick is still pushing ...        Joseph Kosinski
# 3  Jake Sully lives with his newfound family form...          James Cameron
# 4  Five assassins aboard a fast moving bullet tra...           David Leitch
#
#                                  Cast
# 0  (Chris Hemsworth, Natalie Portman)
# 1          (Viola Davis, Thuso Mbedu)
# 2     (Tom Cruise, Jennifer Connelly)
# 3         (Zoe Saldana, Kate Winslet)
# 4              (Brad Pitt, Joey King)

# %%
df.shape
# Out:
# (10045, 8)

# %%
df['Movie Name'].value_counts()
# Out:
# Hero                         5
# Run                          4
# Vendetta                     4
# Animal                       4
# Guru                         4
#                             ..
# Operation Dumbo Drop         1
# Fist of the North Star       1
# Suchîmubôi                   1
# Keeper of the Lost Cities    1
# Di yi lei xing wei xian      1
# Name: Movie Name, Length: 9665, dtype: int64

# %%
df = df.dropna()
df
# Out:
#                               Movie Name Year of Release Watch Time  \
# 0                 Thor: Love and Thunder            2022    118 min
# 1                         The Woman King            2022    135 min
# 2                      Top Gun: Maverick            2022    130 min
# 4                           Bullet Train            2022    127 min
# 5      Everything Everywhere All at Once            2022    139 min
# ...                                  ...             ...        ...
# 10040                          Inception            2010    148 min
# 10041                              Tenet            2020    150 min
# 10042                  Blade Runner 2049            2017    164 min
# 10043                          Lightyear            2022    100 min
# 10044                  VR (Vikrant Rona)            2022    148 min
#
#       Movie Rating                                    Genres  \
# 0              6.4     Action, Adventure, Comedy
# 1              6.1        Action, Drama, History
# 2              8.4                 Action, Drama
# 4              7.5      Action, Comedy, Thriller
# 5              8.1     Action, Adventure, Comedy
# ...            ...                                       ...
# 10040          8.8     Action, Adventure, Sci-Fi
# 10041          7.3      Action, Sci-Fi, Thriller
# 10042          8.0        Action, Drama, Mystery
# 10043          5.9  Animation, Action, Adventure
# 10044          7.4      Action, Adventure, Drama
#
#                                              Description  \
# 0      Thor enlists the help of Valkyrie, Korg and ex...
# 1      A historical epic inspired by true events that...
# 2      After thirty years, Maverick is still pushing ...
# 4      Five assassins aboard a fast moving bullet tra...
# 5      An aging Chinese immigrant is swept up in an i...
# ...                                                  ...
# 10040  A thief who steals corporate secrets through t...
# 10041  Armed with only one word, Tenet, and fighting ...
# 10042  Young Blade Runner K's discovery of a long-bur...
# 10043  While spending years attempting to return home...
# 10044  Almost half a century ago, a remote village in...
#
#                     Director                                       Cast
# 0              Taika Waititi         (Chris Hemsworth, Natalie Portman)
# 1      Gina Prince-Bythewood                 (Viola Davis, Thuso Mbedu)
# 2            Joseph Kosinski            (Tom Cruise, Jennifer Connelly)
# 4               David Leitch                     (Brad Pitt, Joey King)
# 5                   Dan Kwan          (Daniel Scheinert, Michelle Yeoh)
# ...                      ...                                        ...
# 10040      Christopher Nolan  (Leonardo DiCaprio, Joseph Gordon-Levitt)
# 10041      Christopher Nolan  (John David Washington, Robert Pattinson)
# 10042       Denis Villeneuve              (Harrison Ford, Ryan Gosling)
# 10043          Angus MacLane                 (Chris Evans, Keke Palmer)
# 10044          Anup Bhandari                   (Sudeep, Nirup Bhandari)
#
# [9018 rows x 8 columns]

# %%
df.sort_values("Movie Name", inplace=True)
df
# Out:
#                       Movie Name Year of Release Watch Time Movie Rating  \
# 1135                   #Saraitda            2020     98 min          6.3
# 1437                         '71            2014     99 min          7.2
# 3657               'A' gai wak 2            1987    106 min          7.0
# 6808  'Di puwedeng hindi puwede!            1999    108 min          7.5
# 6591                'G' fung bou            2021     83 min          4.9
# ...                          ...             ...        ...          ...
# 9740    Águila Roja, la película            2011    119 min          4.9
# 1218                    Æon Flux            2005     93 min          5.4
# 7904        Çanakkale Yolun Sonu            2013    101 min          7.1
# 5684                      Çiçero            2019    126 min          6.5
# 4003                Ölümlü Dünya            2018    107 min          7.6
#
#                                       Genres  \
# 1135       Action, Drama, Horror
# 1437        Action, Crime, Drama
# 3657       Action, Comedy, Crime
# 6808              Action, Comedy
# 6591               Action, Crime
# ...                                      ...
# 9740  Action, Adventure, History
# 1218   Action, Adventure, Sci-Fi
# 7904      Action, Drama, History
# 5684        Action, Crime, Drama
# 4003       Action, Comedy, Crime
#
#                                             Description           Director  \
# 1135  The rapid spread of an unknown infection has l...             Il Cho
# 1437  In 1971, a young and disoriented British soldi...       Yann Demange
# 3657  Dragon is now transferred to be the police hea...        Jackie Chan
# 6808                        my pets name is rudy castro    Francis Posadas
# 6591  Follows an investigator as he prevents a terro...          David Lam
# ...                                                 ...                ...
# 9740  Red Eagle takes place in 1660, where Portugal,...  José Ramón Ayerra
# 1218  Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 7904  April, 1915. First World War in Canakkale, Ott...         Kemal Uzun
# 5684  Ilyas Bazna works as a butler in the British E...        Serdar Akar
# 4003  Mermer Family lives a double life working at t...           Ali Atay
#
#                                       Cast
# 1135            (Yoo Ah-in, Park Shin-Hye)
# 1437            (Jack O'Connell, Sam Reid)
# 3657          (Jackie Chan, Maggie Cheung)
# 6808         (Robin Padilla, Vina Morales)
# 6591            (Louis Koo, Julian Cheung)
# ...                                    ...
# 9740       (David Janer, Javier Gutiérrez)
# 1218  (Charlize Theron, Frances McDormand)
# 7904          (Serdar Akar, Ahmet Karaman)
# 5684    (Erdal Besikçioglu, Burcu Biricik)
# 4003      (Ahmet Mümtaz Taylan, Alper Kul)
#
# [9018 rows x 8 columns]

# %%
df = df.drop_duplicates()
df
# Out:
#                       Movie Name Year of Release Watch Time Movie Rating  \
# 1135                   #Saraitda            2020     98 min          6.3
# 1437                         '71            2014     99 min          7.2
# 3657               'A' gai wak 2            1987    106 min          7.0
# 6808  'Di puwedeng hindi puwede!            1999    108 min          7.5
# 6591                'G' fung bou            2021     83 min          4.9
# ...                          ...             ...        ...          ...
# 9740    Águila Roja, la película            2011    119 min          4.9
# 1218                    Æon Flux            2005     93 min          5.4
# 7904        Çanakkale Yolun Sonu            2013    101 min          7.1
# 5684                      Çiçero            2019    126 min          6.5
# 4003                Ölümlü Dünya            2018    107 min          7.6
#
#                                       Genres  \
# 1135       Action, Drama, Horror
# 1437        Action, Crime, Drama
# 3657       Action, Comedy, Crime
# 6808              Action, Comedy
# 6591               Action, Crime
# ...                                      ...
# 9740  Action, Adventure, History
# 1218   Action, Adventure, Sci-Fi
# 7904      Action, Drama, History
# 5684        Action, Crime, Drama
# 4003       Action, Comedy, Crime
#
#                                             Description           Director  \
# 1135  The rapid spread of an unknown infection has l...             Il Cho
# 1437  In 1971, a young and disoriented British soldi...       Yann Demange
# 3657  Dragon is now transferred to be the police hea...        Jackie Chan
# 6808                        my pets name is rudy castro    Francis Posadas
# 6591  Follows an investigator as he prevents a terro...          David Lam
# ...                                                 ...                ...
# 9740  Red Eagle takes place in 1660, where Portugal,...  José Ramón Ayerra
# 1218  Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 7904  April, 1915. First World War in Canakkale, Ott...         Kemal Uzun
# 5684  Ilyas Bazna works as a butler in the British E...        Serdar Akar
# 4003  Mermer Family lives a double life working at t...           Ali Atay
#
#                                       Cast
# 1135            (Yoo Ah-in, Park Shin-Hye)
# 1437            (Jack O'Connell, Sam Reid)
# 3657          (Jackie Chan, Maggie Cheung)
# 6808         (Robin Padilla, Vina Morales)
# 6591            (Louis Koo, Julian Cheung)
# ...                                    ...
# 9740       (David Janer, Javier Gutiérrez)
# 1218  (Charlize Theron, Frances McDormand)
# 7904          (Serdar Akar, Ahmet Karaman)
# 5684    (Erdal Besikçioglu, Burcu Biricik)
# 4003      (Ahmet Mümtaz Taylan, Alper Kul)
#
# [8972 rows x 8 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#                       Movie Name Year of Release Watch Time Movie Rating  \
# 0                      #Saraitda            2020     98 min          6.3
# 1                            '71            2014     99 min          7.2
# 2                  'A' gai wak 2            1987    106 min          7.0
# 3     'Di puwedeng hindi puwede!            1999    108 min          7.5
# 4                   'G' fung bou            2021     83 min          4.9
# ...                          ...             ...        ...          ...
# 8967    Águila Roja, la película            2011    119 min          4.9
# 8968                    Æon Flux            2005     93 min          5.4
# 8969        Çanakkale Yolun Sonu            2013    101 min          7.1
# 8970                      Çiçero            2019    126 min          6.5
# 8971                Ölümlü Dünya            2018    107 min          7.6
#
#                                       Genres  \
# 0          Action, Drama, Horror
# 1           Action, Crime, Drama
# 2          Action, Comedy, Crime
# 3                 Action, Comedy
# 4                  Action, Crime
# ...                                      ...
# 8967  Action, Adventure, History
# 8968   Action, Adventure, Sci-Fi
# 8969      Action, Drama, History
# 8970        Action, Crime, Drama
# 8971       Action, Comedy, Crime
#
#                                             Description           Director  \
# 0     The rapid spread of an unknown infection has l...             Il Cho
# 1     In 1971, a young and disoriented British soldi...       Yann Demange
# 2     Dragon is now transferred to be the police hea...        Jackie Chan
# 3                           my pets name is rudy castro    Francis Posadas
# 4     Follows an investigator as he prevents a terro...          David Lam
# ...                                                 ...                ...
# 8967  Red Eagle takes place in 1660, where Portugal,...  José Ramón Ayerra
# 8968  Æon Flux is a mysterious assassin working for ...       Karyn Kusama
# 8969  April, 1915. First World War in Canakkale, Ott...         Kemal Uzun
# 8970  Ilyas Bazna works as a butler in the British E...        Serdar Akar
# 8971  Mermer Family lives a double life working at t...           Ali Atay
#
#                                       Cast
# 0               (Yoo Ah-in, Park Shin-Hye)
# 1               (Jack O'Connell, Sam Reid)
# 2             (Jackie Chan, Maggie Cheung)
# 3            (Robin Padilla, Vina Morales)
# 4               (Louis Koo, Julian Cheung)
# ...                                    ...
# 8967       (David Janer, Javier Gutiérrez)
# 8968  (Charlize Theron, Frances McDormand)
# 8969          (Serdar Akar, Ahmet Karaman)
# 8970    (Erdal Besikçioglu, Burcu Biricik)
# 8971      (Ahmet Mümtaz Taylan, Alper Kul)
#
# [8972 rows x 8 columns]

# %%
df[df['Movie Name'] == "Zack Snyder's Justice League"]
# Out:
#                         Movie Name Year of Release Watch Time Movie Rating  \
# 8878  Zack Snyder's Justice League            2021    242 min          8.0
#
#                                       Genres  \
# 8878  Action, Adventure, Fantasy
#
#                                             Description     Director  \
# 8878  Determined to ensure that Superman's ultimate ...  Zack Snyder
#
#                              Cast
# 8878  (Henry Cavill, Ben Affleck)

# %%
#creating an array of values and passing it in the url for dynamic webpages
pages = list(np.arange(10052,20002,50))
print(pages)

#the whole core of the script
for page in pages:
    pag = requests.get("https://www.imdb.com/search/title/?title_type=feature&genres=action&start={}&explore=genres&ref_=adv_nxt".format(page))
    soup = BeautifulSoup(pag.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
            name = store.find('h3', class_= 'lister-item-header').find('a').text
            movie_name.append(name)

            release = store.find('h3', class_= 'lister-item-header')
            try:
              year_of_release = store.find('span', class_ = "lister-item-year text-muted unbold").text[1:5]
              year.append(year_of_release)
            except:
              year.append(None)


            try: 
              runtime = store.p.find('span', class_ = 'runtime').text[0:7]
              time.append(runtime)
            except:
              time.append(None)

            rate = store.find('div', class_ = "inline-block ratings-imdb-rating")
            try:
              ratings = (rate.find('strong').text)
              rating.append(ratings)
            except:
              rating.append(None)

            genre = store.p.find('span', class_ = 'genre').text.replace('\n', '')
            genres.append(genre)

            describe = store.find_all('p', class_ = 'text-muted')
            description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
            description.append(description_)
            
            try:
              direct = store.select_one("p:nth-of-type(3)").find('a').text[:]
              director.append(direct)
            except:
              director.append(None)

            try:
              cast = store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(2)").text[:],store.select_one("p:nth-of-type(3)").select_one("a:nth-of-type(3)").text[:]
              casts.append(cast)
            except:
              casts.append(None)
